# %% [markdown]
# # Guided LDA on NSF Data
#
# Code references:
# 1. https://github.com/ShahrzadH/Insight_Project_SHV/blob/master/notebook/Guided%20LDA_6topics-4-grams.ipynb
# 2. https://github.com/vi3k6i5/GuidedLDA

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import gensim
import time

import guidedlda

from sklearn.decomposition import NMF, TruncatedSVD, LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from gensim.models.coherencemodel import CoherenceModel

import pyLDAvis
import pyLDAvis.sklearn

# %%
# import NSF data
f = open('/project/biocomplexity/sdad/projects_data/ncses/prd/RND Topic Modelling/agency_data.sav', 'rb')

# import entire dataset
#f = open('/project/biocomplexity/sdad/projects_data/ncses/prd/RND Topic Modelling/lda_data.sav', 'rb')

[corpus, id2word, docs] = pickle.load(f)
f.close()

# corpus - word frequency in docs
# id2word - dictionary
# docs - lemmatized abstracts

# %%
# create document-term matrix using Scikit-Learn 

# input needed is one string per document (not a list of strings)

text = []
i=0
for doc in docs:
    text.append(" ".join(doc))


vectorizer = CountVectorizer(max_df=0.4, min_df=3, lowercase=False, max_features=int(len(docs)/2))
doc_term_matrix = vectorizer.fit_transform(text)

# %%
print(doc_term_matrix.shape)
print(doc_term_matrix.sum())  # number of tokens in corpus
# Out:
# (116475, 58237)
# 19922704

# %%
# Normal LDA without seeding

lda_model = guidedlda.GuidedLDA(n_topics=5, n_iter=100, random_state=1, refresh=20)
lda_model.fit(doc_term_matrix)
# Out:
# INFO:guidedlda:n_documents: 116475
# INFO:guidedlda:vocab_size: 58237
# INFO:guidedlda:n_words: 19922704
# INFO:guidedlda:n_topics: 5
# INFO:guidedlda:n_iter: 100
# /sfs/qumulo/qhome/kjl5t/GuidedLDA/guidedlda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:guidedlda:<0> log likelihood: -198476508
# INFO:guidedlda:<20> log likelihood: -169768732
# INFO:guidedlda:<40> log likelihood: -165474868
# INFO:guidedlda:<60> log likelihood: -164004994
# INFO:guidedlda:<80> log likelihood: -163424244
# INFO:guidedlda:<99> log likelihood: -163131701

# %%
# Function to print out topics with terms - Guided LDA follow Scikit-Learn conventions

# function slightly modified from https://nlpforhackers.io/topic-modeling/

def print_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):  # loop through each row of term-topic matrix.  idx = row index.  topic = actual row
        print("\nTopic %d:" % (idx))
        #print([(vectorizer.get_feature_names()[i], topic[i])  # printing out words corresponding to indices found in next line
                        #for i in topic.argsort()[:-top_n - 1:-1]])  # finding indices of top words in topic
            
        print_list = [(vectorizer.get_feature_names()[i], topic[i])  
                        for i in topic.argsort()[:-top_n - 1:-1]]
        for item in print_list:
            print(item)

# %%
print_topics(lda_model, vectorizer, 10)
# Out:
# Topic 0:
# ('data', 0.008129984385145448)
# ('model', 0.006880674480795533)
# ('change', 0.00548626495942648)
# ('community', 0.00466498791620738)
# ('process', 0.004465943828521035)
# ('social', 0.00421823962647774)
# ('understand', 0.004215597448322611)
# ('water', 0.0039971773874986575)
# ('impact', 0.0037087396055637987)
# ('work', 0.0036653638475171064)
#
# Topic 1:
# ('cell', 0.009015437916728356)
# ('plant', 0.007089304998311383)
# ('specie', 0.006946759578522088)
# ('protein', 0.005474326528960433)
# ('gene', 0.005427669450248361)
# ('human', 0.004859740181787627)
# ('understand', 0.004676651369462325)
# ('model', 0.004440791792248887)
# ('biology', 0.004262207801316474)
# ('change', 0.004140255850751818)
#
# Topic 2:
# ('data', 0.011176347167708163)
# ('model', 0.010922299507924794)
# ('problem', 0.007652968934436753)
# ('theory', 0.006612906575547772)
# ('application', 0.006513477577667039)
# ('network', 0.006396747058128646)
# ('method', 0.006071303245682021)
# ('design', 0.005549848523316331)
# ('analysis', 0.004604397017036329)
# ('large', 0.004200329834018815)
#
# Topic 3:
# ('program', 0.014456738867578296)
# ('support', 0.009348846463824572)
# ('engineering', 0.008619868092773056)
# ('stem', 0.008067126250986743)
# ('education', 0.0074375405353289)
# ('community', 0.0073675206348127594)
# ('conference', 0.007139065874654165)
# ('development', 0.006332056851756272)
# ('learn', 0.006065031807415058)
# ('graduate', 0.006008363159115977)
#
# Topic 4:
# ('material', 0.014379259551070786)
# ('energy', 0.0062570531380174545)
# ('technology', 0.0059634766358972755)
# ('property', 0.005854480022472751)
# ('process', 0.0055832558913931195)
# ('application', 0.005275392306752178)
# ('structure', 0.005117543088579241)
# ('device', 0.005103947316503031)
# ('chemical', 0.005049103354568493)
# ('design', 0.0050382728242704955)

# %%
# Create anchors for topics 

seed_topic_list = [['pandemic', 'disease', 'virus', 'infection', 'viral', 'immune', 'pathogen']
                   ]

# %%
num_topics = 50

Glda_model = guidedlda.GuidedLDA(n_topics=num_topics, n_iter=100, alpha=1/num_topics, eta=0.1, 
                                 random_state=1, refresh=20)

# %%
tf_feature_names = vectorizer.get_feature_names()
word2id = dict((v, idx) for idx, v in enumerate(tf_feature_names))

# %%
word2id
# Out:
# {'aa': 0,
#  'aaa': 1,
#  'aaai': 2,
#  'aaai_conference': 3,
#  'aaai_doctoral_consortium': 4,
#  'aaas': 5,
#  'aabw': 6,
#  'aac': 7,
#  'aacc': 8,
#  'aachen_germany': 9,
#  'aacr': 10,
#  'aadl': 11,
#  'aae': 12,
#  'aag': 13,
#  'aaiw': 14,
#  'aalto': 15,
#  'aam': 16,
#  'aamas': 17,
#  'aamu': 18,
#  'aanderaa': 19,
#  'aao': 20,
#  'aap': 21,
#  'aapf': 22,
#  'aapf_fellows': 23,
#  'aapt': 24,
#  'aar': 25,
#  'aarhus_denmark': 26,
#  'aarhus_university': 27,
#  'aaron': 28,
#  'aaronson': 29,
#  'aas': 30,
#  'aat': 31,
#  'aau': 32,
#  'aauw': 33,
#  'aaws': 34,
#  'ab': 35,
#  'aba': 36,
#  'abac': 37,
#  'abaco': 38,
#  'abacus': 39,
#  'abalone': 40,
#  'abandon': 41,
#  'abandoned': 42,
#  'abandoned_mine': 43,
#  'abandonment': 44,
#  'abate': 45,
#  'abatement': 46,
#  'abb': 47,
#  'abbott': 48,
#  'abbreviate': 49,
#  'abc': 50,
#  'abc_transporter': 51,
#  'abc_transporters': 52,
#  'abc_triblock': 53,
#  'abcd': 54,
#  'abd': 55,
#  'abdel': 56,
#  'abdomen': 57,
#  'abdominal': 58,
#  'abduction': 59,
#  'abductive': 60,
#  'abductive_reasoning': 61,
#  'abe': 62,
#  'abel': 63,
#  'abel_jacobi': 64,
#  'abelian': 65,
#  'abelian_hodge': 66,
#  'abelian_sandpile': 67,
#  'abelian_statistics': 68,
#  'abelian_varieties': 69,
#  'abelianization': 70,
#  'aberdeen': 71,
#  'aberrant': 72,
#  'aberration': 73,
#  'aberration_corrected': 74,
#  'aberration_corrected_electron_microscopy': 75,
#  'aberration_corrected_scanning': 76,
#  'aberration_correction': 77,
#  'abet': 78,
#  'abet_accreditation': 79,
#  'abet_accredited': 80,
#  'abeta': 81,
#  'abf': 82,
#  'abfs': 83,
#  'abi': 84,
#  'abide': 85,
#  'abigail': 86,
#  'abilities': 87,
#  'ability': 88,
#  'abiogenic': 89,
#  'abiological': 90,
#  'abiotic': 91,
#  'abiotic_biotic': 92,
#  'abiotic_biotic_stresses': 93,
#  'abiotic_stress': 94,
#  'abiotic_stresses': 95,
#  'abiotically': 96,
#  'abl': 97,
#  'ablate': 98,
#  'ablation': 99,
#  'ablative': 100,
#  'able': 101,
#  'able_bodied': 102,
#  'ablowitz': 103,
#  'abm': 104,
#  'abms': 105,
#  'abnormal': 106,
#  'abnormality': 107,
#  'abnormally': 108,
#  'abo': 109,
#  'aboard': 110,
#  'aboard_nsf_ncar': 111,
#  'abolish': 112,
#  'aboriginal': 113,
#  'abort': 114,
#  'abortion': 115,
#  'abound': 116,
#  'aboutthe': 117,
#  'abouzaid': 118,
#  'aboveground': 119,
#  'aboveground_belowground': 120,
#  'abovementioned': 121,
#  'abp': 122,
#  'abr': 123,
#  'abraham': 124,
#  'abramovich': 125,
#  'abrams': 126,
#  'abramson': 127,
#  'abrasion': 128,
#  'abrasive': 129,
#  'abrc': 130,
#  'abrc_osu_edu': 131,
#  'abrcms': 132,
#  'abroad': 133,
#  'abrupt': 134,
#  'abrupt_climate_change': 135,
#  'abrupt_climatic': 136,
#  'abrupt_climatic_transitions': 137,
#  'abruptly': 138,
#  'abruptness': 139,
#  'abs': 140,
#  'abscisic_acid': 141,
#  'abscisic_acid_aba': 142,
#  'abscission': 143,
#  'abscission_zone': 144,
#  'absence': 145,
#  'absent': 146,
#  'absenteeism': 147,
#  'absolute': 148,
#  'absolute_configuration': 149,
#  'absolute_galois_group': 150,
#  'absolute_zero': 151,
#  'absolute_zero_temperature': 152,
#  'absolutely': 153,
#  'absolutely_dated': 154,
#  'absolutely_essential': 155,
#  'absorb': 156,
#  'absorb_emit': 157,
#  'absorb_sunlight': 158,
#  'absorb_visible': 159,
#  'absorbance': 160,
#  'absorbance_fluorescence': 161,
#  'absorbed': 162,
#  'absorbent': 163,
#  'absorber': 164,
#  'absorbing_aerosols': 165,
#  'absorbs': 166,
#  'absorbs_light': 167,
#  'absorbs_sunlight': 168,
#  'absorption': 169,
#  'absorption_coefficient': 170,
#  'absorption_spectroscopy': 171,
#  'absorptive': 172,
#  'absorptivity': 173,
#  'abstain': 174,
#  'abstention': 175,
#  'abstract': 176,
#  'abstract_nontechnical': 177,
#  'abstract_submissions': 178,
#  'abstracta': 179,
#  'abstractan': 180,
#  'abstracted': 181,
#  'abstracthigh': 182,
#  'abstractin': 183,
#  'abstractintellectual_merit': 184,
#  'abstraction': 185,
#  'abstractive': 186,
#  'abstractly': 187,
#  'abstractproposal': 188,
#  'abstractproposal_name': 189,
#  'abstractquantum': 190,
#  'abstracts_compiled': 191,
#  'abstracts_heavily_refereed': 192,
#  'abstracts_posters': 193,
#  'abstracts_submitted': 194,
#  'abstractthe': 195,
#  'abstractthis': 196,
#  'abstractwe': 197,
#  'abu': 198,
#  'abu_dhabi': 199,
#  'abundance': 200,
#  'abundance_supercooled_liquid': 201,
#  'abundances': 202,
#  'abundant': 203,
#  'abundant_cheap': 204,
#  'abundantly': 205,
#  'abuse': 206,
#  'abused': 207,
#  'abusive': 208,
#  'abyss': 209,
#  'abyssal': 210,
#  'abyssal_circulation': 211,
#  'abyssal_hills': 212,
#  'abyssal_mixing': 213,
#  'abyssal_ocean': 214,
#  'abyssal_peridotites': 215,
#  'abyssal_plain': 216,
#  'ac': 217,
#  'aca': 218,
#  'acac': 219,
#  'acacia': 220,
#  'academe': 221,
#  'academe_industry': 222,
#  'academe_industry_government': 223,
#  'academia': 224,
#  'academia_government': 225,
#  'academia_government_agencies': 226,
#  'academia_government_industry': 227,
#  'academia_government_private_sector': 228,
#  'academia_industry': 229,
#  'academia_industry_government': 230,
#  'academia_industry_government_agencies': 231,
#  'academia_private_sector': 232,
#  'academia_sinica': 233,
#  'academia_sinica_taiwan': 234,
#  'academic': 235,
#  'academic_nonacademic': 236,
#  'academically': 237,
#  'academically_prepared': 238,
#  'academically_qualified': 239,
#  'academically_socially': 240,
#  'academically_talented': 241,
#  'academically_talented_economically_disadvantaged': 242,
#  'academically_talented_financially_challenged': 243,
#  'academically_talented_financially_disadvantaged': 244,
#  'academically_talented_financially_needy': 245,
#  'academically_talented_low_income': 246,
#  'academician': 247,
#  'academicians': 248,
#  'academics': 249,
#  'academics_policy_makers': 250,
#  'academics_practitioners': 251,
#  'academy': 252,
#  'academy_sciences': 253,
#  'acadia': 254,
#  'acadis': 255,
#  'acaricide': 256,
#  'acartia': 257,
#  'acc': 258,
#  'accelerate': 259,
#  'accelerate_pace': 260,
#  'accelerated': 261,
#  'accelerated_pace': 262,
#  'accelerates': 263,
#  'accelerating': 264,
#  'accelerating_pace': 265,
#  'acceleration': 266,
#  'acceleration_deceleration': 267,
#  'accelerator': 268,
#  'accelerator_facility_jlab': 269,
#  'accelerator_facility_tjnaf': 270,
#  'accelerator_mass_spectrometer': 271,
#  'accelerator_mass_spectrometry': 272,
#  'accelerators_gpus': 273,
#  'accelerometer': 274,
#  'accelerometers_gyroscopes': 275,
#  'accelerometry': 276,
#  'accent': 277,
#  'accented_speech': 278,
#  'accentuate': 279,
#  'accept': 280,
#  'accept_reject': 281,
#  'acceptability': 282,
#  'acceptable': 283,
#  'acceptably': 284,
#  'acceptance': 285,
#  'accepted': 286,
#  'accepted_invitations': 287,
#  'accepted_papers_posters': 288,
#  'accepted_publication': 289,
#  'accepted_rejected': 290,
#  'acceptor': 291,
#  'accepts': 292,
#  'access': 293,
#  'accesscomputing': 294,
#  'accessed': 295,
#  'accessed_http_www': 296,
#  'accessibility': 297,
#  'accessibility_affordability': 298,
#  'accessible': 299,
#  'accessible_wider_audience': 300,
#  'accession': 301,
#  'accessory': 302,
#  'accessory_minerals': 303,
#  'accident': 304,
#  'accidental': 305,
#  'accidentally': 306,
#  'acclaim': 307,
#  'acclaimed': 308,
#  'acclimate': 309,
#  'acclimation': 310,
#  'acclimatization': 311,
#  'acclimatize': 312,
#  'acclimatory': 313,
#  'accommodate': 314,
#  'accommodated': 315,
#  'accommodates': 316,
#  'accommodation': 317,
#  'accommodative': 318,
#  'accompanied': 319,
#  'accompanies': 320,
#  'accompaniment': 321,
#  'accompany': 322,
#  'accomplish': 323,
#  'accomplish_feat': 324,
#  'accomplished': 325,
#  'accomplishes': 326,
#  'accomplishment': 327,
#  'accomplishments': 328,
#  'accord': 329,
#  'accordance': 330,
#  'accordance_cise': 331,
#  'according_census_bureau': 332,
#  'accordingly': 333,
#  'account': 334,
#  'accountability': 335,
#  'accountability_transparency': 336,
#  'accountable': 337,
#  'accounted_total_sailing': 338,
#  'accounting': 339,
#  'accounting_total_sailing': 340,
#  'accra': 341,
#  'accra_ghana': 342,
#  'accredit': 343,
#  'accreditation': 344,
#  'accreditation_board': 345,
#  'accreditation_commission': 346,
#  'accredited': 347,
#  'accrete': 348,
#  'accreted_terranes': 349,
#  'accreting_neutron_stars': 350,
#  'accretion': 351,
#  'accretion_disk': 352,
#  'accretion_disks': 353,
#  'accretion_disks_around': 354,
#  'accretionary': 355,
#  'accretionary_prism': 356,
#  'accretionary_prisms': 357,
#  'accretionary_wedge': 358,
#  'accretionary_wedges': 359,
#  'accrual': 360,
#  'accrue': 361,
#  'acculturate': 362,
#  'acculturation': 363,
#  'accumulate': 364,
#  'accumulated': 365,
#  'accumulates': 366,
#  'accumulating_evidence': 367,
#  'accumulating_evidence_suggests': 368,
#  'accumulation': 369,
#  'accumulative': 370,
#  'accumulator': 371,
#  'accumulibacter': 372,
#  'accuracy': 373,
#  'accuracy_completeness': 374,
#  'accuracy_repeatability': 375,
#  'accurate': 376,
#  'accurately': 377,
#  'accusation': 378,
#  'accusative': 379,
#  'accuse': 380,
#  'accustom': 381,
#  'accustomed': 382,
#  'acd': 383,
#  'ace': 384,
#  'acellular': 385,
#  'acene': 386,
#  'acentric': 387,
#  'acer': 388,
#  'acetal': 389,
#  'acetaldehyde': 390,
#  'acetate': 391,
#  'acetic_acid': 392,
#  'acetivorans': 393,
#  'acetoclastic': 394,
#  'acetone': 395,
#  'acetyl': 396,
#  'acetyl_coa': 397,
#  'acetyl_coa_carboxylase': 398,
#  'acetylate': 399,
#  'acetylation': 400,
#  'acetylcholine': 401,
#  'acetylene': 402,
#  'ach': 403,
#  'ache': 404,
#  'acheulean': 405,
#  'achievability': 406,
#  'achievable': 407,
#  'achieve': 408,
#  'achieved': 409,
#  'achievement': 410,
#  'achievements': 411,
#  'achievements_century': 412,
#  'achiever': 413,
#  'achieves': 414,
#  'achieving': 415,
#  'achilles_heel': 416,
#  'achim': 417,
#  'achiral': 418,
#  'achromatic': 419,
#  'aci': 420,
#  'acid': 421,
#  'acid_mine_drainage': 422,
#  'acid_rain': 423,
#  'acidic': 424,
#  'acidic_ionic_liquid': 425,
#  'acidification': 426,
#  'acidified': 427,
#  'acidify': 428,
#  'acidity': 429,
#  'acidocaldarius': 430,
#  'ack': 431,
#  'acknowledge': 432,
#  'acknowledgement': 433,
#  'acknowledges': 434,
#  'acknowledgment': 435,
#  'acl': 436,
#  'acm': 437,
#  'acm_bcb': 438,
#  'acm_ccs': 439,
#  'acm_digital': 440,
#  'acm_ieee': 441,
#  'acm_ieee_symposium': 442,
#  'acm_mobicom': 443,
#  'acm_mobicom_conference': 444,
#  'acm_mobisys': 445,
#  'acm_multimedia': 446,
#  'acm_org': 447,
#  'acm_siam_symposium': 448,
#  'acm_sigchi': 449,
#  'acm_sigcomm': 450,
#  'acm_sigcomm_internet': 451,
#  'acm_siggraph': 452,
#  'acm_sigkdd_conference': 453,
#  'acm_sigmetrics': 454,
#  'acm_sigmod': 455,
#  'acm_sigmod_pods': 456,
#  'acm_sigplan': 457,
#  'acm_sigplan_sigact_symposium': 458,
#  'acm_sigplan_symposium': 459,
#  'acm_sigspatial': 460,
#  'acm_sigspatial_conference': 461,
#  'acm_sigspatial_gis': 462,
#  'acme': 463,
#  'aco': 464,
#  'acomprehensive': 465,
#  'acorn': 466,
#  'acorn_woodpeckers': 467,
#  'acorns': 468,
#  'acoustic': 469,
#  'acoustic_articulatory': 470,
#  'acoustic_cavitation': 471,
#  'acoustic_doppler': 472,
#  'acoustic_doppler_current': 473,
#  'acoustic_metamaterials': 474,
#  'acoustic_modem': 475,
#  'acoustic_phonetic': 476,
#  'acoustic_phonons': 477,
#  'acoustic_wave': 478,
#  'acoustic_waves': 479,
#  'acoustical': 480,
#  'acoustically': 481,
#  'acoustics': 482,
#  'acousto': 483,
#  'acousto_optic': 484,
#  'acoustophoretic_separation': 485,
#  'acp': 486,
#  'acq': 487,
#  'acquaint': 488,
#  'acquaintance': 489,
#  'acquire': 490,
#  'acquire_gas_chromatograph': 491,
#  'acquire_liquid_chromatograph': 492,
#  'acquire_mhz_nmr_spectrometer': 493,
#  'acquire_mhz_nuclear': 494,
#  'acquired': 495,
#  'acquires': 496,
#  'acquisition': 497,
#  'acquisition_scada': 498,
#  'acr': 499,
#  'acre': 500,
#  'acreage': 501,
#  'acres': 502,
#  'acronym': 503,
#  'acropora': 504,
#  'acropora_palmata': 505,
#  'across': 506,
#  'across_globe': 507,
#  'acrylate': 508,
#  'acrylic': 509,
#  'acrylic_acid': 510,
#  'acs': 511,
#  'acs_seed': 512,
#  'acsac': 513,
#  'acsac_held': 514,
#  'act': 515,
#  'act_arra': 516,
#  'act_bill_deals': 517,
#  'act_concert': 518,
#  'act_gatekeepers': 519,
#  'act_passed_congress': 520,
#  'act_synergistically': 521,
#  'acted_upon': 522,
#  'actin': 523,
#  'actin_cytoskeleton': 524,
#  'actin_filament': 525,
#  'actin_filaments': 526,
#  'actin_myosin': 527,
#  'actin_polymerization': 528,
#  'acting': 529,
#  'actinide': 530,
#  'actinium': 531,
#  'action': 532,
#  'action_http_visionandchange': 533,
#  'action_potential': 534,
#  'actionability': 535,
#  'actionable': 536,
#  'actionable_intelligence': 537,
#  'actions_sofic_groups': 538,
#  'activatable': 539,
#  'activate': 540,
#  'activated': 541,
#  'activated_sludge': 542,
#  'activates': 543,
#  'activation': 544,
#  'activator': 545,
#  'active': 546,
#  'active_galactic_nuclei': 547,
#  'active_ingredient': 548,
#  'active_pharmaceutical_ingredient': 549,
#  'active_pharmaceutical_ingredients': 550,
#  'active_shooter': 551,
#  'actively': 552,
#  'actively_deforming': 553,
#  'actively_engaged': 554,
#  'activism': 555,
#  'activist': 556,
#  'activists': 557,
#  'activites': 558,
#  'activity': 559,
#  'activitythe': 560,
#  'acto_myosin': 561,
#  'actof': 562,
#  'actomyosin': 563,
#  'actor': 564,
#  'actual': 565,
#  'actuality': 566,
#  'actualize': 567,
#  'actually': 568,
#  'actually_happened': 569,
#  'actuarial': 570,
#  'actuate': 571,
#  'actuated': 572,
#  'actuation': 573,
#  'actuator': 574,
#  'actuators_sensors': 575,
#  'acuity': 576,
#  'acumen': 577,
#  'acute': 578,
#  'acutely': 579,
#  'acyclic': 580,
#  'acyl': 581,
#  'acyl_chain': 582,
#  'acylated': 583,
#  'acylation': 584,
#  'ad': 585,
#  'ada': 586,
#  'adam': 587,
#  'adam_veige': 588,
#  'adams': 589,
#  'adapt': 590,
#  'adaptability': 591,
#  'adaptable': 592,
#  'adaptation': 593,
#  'adaptation_personalization_umap': 594,
#  'adaptational': 595,
#  'adapted': 596,
#  'adapter': 597,
#  'adapting': 598,
#  'adaption': 599,
#  'adaptive': 600,
#  'adaptive_hypermedia': 601,
#  'adaptive_mesh_refinement': 602,
#  'adaptive_optics': 603,
#  'adaptive_radiation': 604,
#  'adaptively': 605,
#  'adaptively_adjust': 606,
#  'adaptiveness': 607,
#  'adaptivity': 608,
#  'adaptor': 609,
#  'adapts': 610,
#  'adare': 611,
#  'adatom': 612,
#  'adatoms': 613,
#  'adbc': 614,
#  'adc': 615,
#  'adcirc': 616,
#  'adcp': 617,
#  'adcps': 618,
#  'adcs': 619,
#  'add': 620,
#  'add_ons': 621,
#  'add_subtract': 622,
#  'added': 623,
#  'adder': 624,
#  'addict': 625,
#  'addiction': 626,
#  'addictive': 627,
#  'addis_ababa': 628,
#  'addis_ababa_ethiopia': 629,
#  'addis_ababa_university': 630,
#  'addition': 631,
#  'additionally': 632,
#  'additive': 633,
#  'additive_combinatorics': 634,
#  'additive_manufacturing': 635,
#  'additive_manufacturing_printing': 636,
#  'additive_multiplicative': 637,
#  'additive_subtractive': 638,
#  'additively': 639,
#  'additively_manufactured': 640,
#  'additively_manufactured_parts': 641,
#  'additives': 642,
#  'additivity': 643,
#  'addo': 644,
#  'address': 645,
#  'addressability': 646,
#  'addressable': 647,
#  'addressable_market': 648,
#  'addressed': 649,
#  'addresses': 650,
#  'addressing': 651,
#  'adduct': 652,
#  'adduction': 653,
#  'ade': 654,
#  'adelaide_australia': 655,
#  'adele': 656,
#  'adelic': 657,
#  'adelie': 658,
#  'adelie_penguin': 659,
#  'adenosine': 660,
#  'adenosine_triphosphate': 661,
#  'adenosine_triphosphate_atp': 662,
#  'adenovirus': 663,
#  'adenoviruses': 664,
#  'adept': 665,
#  'adeptly': 666,
#  'adequacy': 667,
#  'adequate': 668,
#  'adequately': 669,
#  'adhd': 670,
#  'adhere': 671,
#  'adherence': 672,
#  'adherent': 673,
#  'adheres': 674,
#  'adhesins': 675,
#  'adhesion': 676,
#  'adhesive': 677,
#  'adhesiveness': 678,
#  'adhesives': 679,
#  'adhesives_coatings': 680,
#  'adhoc': 681,
#  'adi': 682,
#  'adiabatic': 683,
#  'adiabatically': 684,
#  'adiabaticity': 685,
#  'adic': 686,
#  'adic_automorphic_forms': 687,
#  'adic_cohomology': 688,
#  'adic_galois_representations': 689,
#  'adic_hodge_theory': 690,
#  'adic_interpolation': 691,
#  'adic_langlands': 692,
#  'adically': 693,
#  'adipocytes': 694,
#  'adipose': 695,
#  'adipose_tissue': 696,
#  'adiposity': 697,
#  'adirondack': 698,
#  'adirondack_mountains': 699,
#  'adirondack_park': 700,
#  'adirondacks': 701,
#  'adjacency': 702,
#  'adjacency_matrix': 703,
#  'adjacent': 704,
#  'adjective': 705,
#  'adjoin': 706,
#  'adjoint': 707,
#  'adjoints': 708,
#  'adjudicate': 709,
#  'adjudicate_competing': 710,
#  'adjudication': 711,
#  'adjunct': 712,
#  'adjust': 713,
#  'adjustable': 714,
#  'adjusted': 715,
#  'adjusting': 716,
#  'adjustment': 717,
#  'adjusts': 718,
#  'adjuvant': 719,
#  'adl': 720,
#  'adler': 721,
#  'adler_planetarium': 722,
#  'adler_planetarium_astronomy': 723,
#  'adler_planetarium_chicago': 724,
#  'adls': 725,
#  'adm': 726,
#  'admi': 727,
#  'administer': 728,
#  'administered': 729,
#  'administers': 730,
#  'administrate': 731,
#  'administration': 732,
#  'administrative': 733,
#  'administratively': 734,
#  'administrator': 735,
#  'administrators': 736,
#  'admire': 737,
#  'admissibility': 738,
#  'admissible': 739,
#  'admission': 740,
#  'admissions_committee': 741,
#  'admissions_officers': 742,
#  'admit': 743,
#  'admits': 744,
#  'admittance': 745,
#  'admitted': 746,
#  'admixed': 747,
#  'admixture': 748,
#  'admixture_mapping': 749,
#  'admx': 750,
#  'adna': 751,
#  'adndp': 752,
#  'adobe': 753,
#  'adolescence': 754,
#  'adolescence_adulthood': 755,
#  'adolescent': 756,
#  'adolescent_girls': 757,
#  'adolescents': 758,
#  'adomet': 759,
#  'adopt': 760,
#  'adoptability': 761,
#  'adoptable': 762,
#  'adopted': 763,
#  'adopter': 764,
#  'adoption': 765,
#  'adoptive': 766,
#  'adopts': 767,
#  'adornment': 768,
#  'adp': 769,
#  'adp_glucose_pyrophosphorylase': 770,
#  'adp_ribosylation': 771,
#  'adr': 772,
#  'adrenal': 773,
#  'adrenal_gland': 774,
#  'adrenergic': 775,
#  'adrian': 776,
#  'adriatic': 777,
#  'adrienne': 778,
#  'adrs': 779,
#  'ads_cft': 780,
#  'ads_cft_correspondence': 781,
#  'adsorb': 782,
#  'adsorb_onto': 783,
#  'adsorbate': 784,
#  'adsorbates': 785,
#  'adsorbed': 786,
#  'adsorbed_onto': 787,
#  'adsorbent': 788,
#  'adsorbent_catalyst': 789,
#  'adsorbs': 790,
#  'adsorption': 791,
#  'adsorption_desorption': 792,
#  'adsorption_isotherms': 793,
#  'adsorptive': 794,
#  'adt': 795,
#  'adult': 796,
#  'adult_neurogenesis': 797,
#  'adulteration': 798,
#  'adulthood': 799,
#  'adults': 800,
#  'adv': 801,
#  'advance': 802,
#  'advanced': 803,
#  'advanced_cyberinfrastructure_aci': 804,
#  'advanced_cyberinfrastructure_behalf': 805,
#  'advanced_cyberinfrastructure_directorate': 806,
#  'advanced_institutes_pasi': 807,
#  'advanced_ligo': 808,
#  'advanced_ligo_detectors': 809,
#  'advanced_ligo_interferometers': 810,
#  'advanced_ligo_virgo': 811,
#  'advanced_modular_incoherent': 812,
#  'advancement': 813,
#  'advancements': 814,
#  'advancing': 815,
#  'advancing_informal': 816,
#  'advancing_innovative_neurotechnologies': 817,
#  'advantage': 818,
#  'advantaged_disadvantaged': 819,
#  'advantageous': 820,
#  'advantageously': 821,
#  'advantages': 822,
#  'advantages_disadvantages': 823,
#  'advect': 824,
#  'advection': 825,
#  'advection_diffusion': 826,
#  'advection_diffusion_equations': 827,
#  'advection_dispersion': 828,
#  'advection_dominated': 829,
#  'advective': 830,
#  'advective_diffusive': 831,
#  'advent': 832,
#  'adventitious': 833,
#  'adventure': 834,
#  'adversarial': 835,
#  'adversarial_attacks': 836,
#  'adversaries': 837,
#  'adversary': 838,
#  'adverse': 839,
#  'adversely': 840,
#  'adversely_affect': 841,
#  'adversely_affected': 842,
#  'adversely_affecting': 843,
#  'adversely_affects': 844,
#  'adversity': 845,
#  'advertise': 846,
#  'advertised': 847,
#  'advertised_nationally': 848,
#  'advertisement': 849,
#  'advertisement_calls': 850,
#  'advertiser': 851,
#  'advertising': 852,
#  'advice': 853,
#  'advise': 854,
#  'advised': 855,
#  'advisee': 856,
#  'advisement': 857,
#  'adviser': 858,
#  'advising': 859,
#  'advisor': 860,
#  'advisory': 861,
#  'advisory_board': 862,
#  'advisory_board_iab': 863,
#  'advisory_committee': 864,
#  'advisory_committee_composed': 865,
#  'advisory_committees': 866,
#  'advisory_council': 867,
#  'advisory_panel': 868,
#  'advisory_panels': 869,
#  'advligo': 870,
#  'advocacy': 871,
#  'advocacy_organizations': 872,
#  'advocate': 873,
#  'adw': 874,
#  'aea': 875,
#  'aeastp': 876,
#  'aec': 877,
#  'aect': 878,
#  'aedes_aegypti': 879,
#  'aeesp': 880,
#  'aegean': 881,
#  'aegis': 882,
#  'aegypti': 883,
#  'aej': 884,
#  'aem': 885,
#  'aemb': 886,
#  'aems': 887,
#  'aeolian': 888,
#  'aeolian_deposition': 889,
#  'aep': 890,
#  'aera': 891,
#  'aerate': 892,
#  'aeration': 893,
#  'aerial': 894,
#  'aerial_drones': 895,
#  'aerial_imagery': 896,
#  'aerial_photographs': 897,
#  'aerial_photography': 898,
#  'aerial_photos': 899,
#  'aerial_robots': 900,
#  'aerial_vehicle': 901,
#  'aerial_vehicles': 902,
#  'aero': 903,
#  'aeroacoustic': 904,
#  'aeroacoustics': 905,
#  'aerobic': 906,
#  'aerobic_anaerobic': 907,
#  'aerobic_respiration': 908,
#  'aerodynamic': 909,
#  'aerodynamic_drag': 910,
#  'aerodynamically': 911,
#  'aerodynamics': 912,
#  'aerodyne': 913,
#  'aeroecology': 914,
#  'aeroelastic': 915,
#  'aeroelasticity': 916,
#  'aerogel': 917,
#  'aerogels': 918,
#  'aeromagnetic': 919,
#  'aeronautical': 920,
#  'aeronautics': 921,
#  'aeronautics_astronautics': 922,
#  'aeronet': 923,
#  'aeronomic': 924,
#  'aeronomical': 925,
#  'aeronomy': 926,
#  'aerosol': 927,
#  'aerosol_cloud': 928,
#  'aerosol_cloud_precipitation': 929,
#  'aerosol_generator': 930,
#  'aerosol_jet_printing': 931,
#  'aerosol_radiative': 932,
#  'aerosol_radiative_forcing': 933,
#  'aerosolization': 934,
#  'aerosolize': 935,
#  'aerosols': 936,
#  'aerosols_clouds': 937,
#  'aerospace': 938,
#  'aerospace_automobile': 939,
#  'aerospace_automotive': 940,
#  'aerospace_automotive_industries': 941,
#  'aerospace_industries': 942,
#  'aerosphere': 943,
#  'aeruginosa': 944,
#  'aes': 945,
#  'aesthetic': 946,
#  'aesthetic_appeal': 947,
#  'aesthetically': 948,
#  'aesthetically_pleasing': 949,
#  'aet': 950,
#  'aew': 951,
#  'aews': 952,
#  'afar': 953,
#  'afarensis': 954,
#  'afc': 955,
#  'afem': 956,
#  'affair': 957,
#  'affect': 958,
#  'affected': 959,
#  'affecting': 960,
#  'affective': 961,
#  'affectively': 962,
#  'affects_million_americans': 963,
#  'afferent': 964,
#  'affiliate': 965,
#  'affiliated': 966,
#  'affiliation': 967,
#  'affiliative': 968,
#  'affine': 969,
#  'affine_algebras': 970,
#  'affine_flag_varieties': 971,
#  'affine_grassmannian': 972,
#  'affine_grassmannians': 973,
#  'affine_hecke_algebras': 974,
#  'affine_invariant': 975,
#  'affine_kac': 976,
#  'affine_kac_moody': 977,
#  'affine_lie': 978,
#  'affine_lie_algebras': 979,
#  'affine_sieve': 980,
#  'affine_transformation': 981,
#  'affinis': 982,
#  'affinity': 983,
#  'affinity_chromatography': 984,
#  'affinity_purification': 985,
#  'affinity_tags': 986,
#  'affirm': 987,
#  'affirm_cognizant': 988,
#  'affirmation': 989,
#  'affirmative': 990,
#  'affirmative_action': 991,
#  'affix': 992,
#  'affixed': 993,
#  'afflict': 994,
#  'affliction': 995,
#  'affluence': 996,
#  'affluent': 997,
#  'afford': 998,
#  'affordability': 999,
#  ...}

# %%
seed_topics = {}
for t_id, st in enumerate(seed_topic_list):
    for word in st:
        seed_topics[word2id[word]] = t_id

# %%
Glda_model.fit(doc_term_matrix, seed_topics=seed_topics, seed_confidence=0.8)
# Out:
# INFO:guidedlda:n_documents: 116475
# INFO:guidedlda:vocab_size: 58237
# INFO:guidedlda:n_words: 19922704
# INFO:guidedlda:n_topics: 50
# INFO:guidedlda:n_iter: 100
# /sfs/qumulo/qhome/kjl5t/GuidedLDA/guidedlda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO
doc_topic = model.transform(doc_term_matrix)
for i in range(9):
    print("top topic: {} Document: {}".format(doc_topic[i].argmax(),
                                                  ', '.join(np.array(vocab)[list(reversed(X[i,:].argsort()))[0:5]])))

# %%
# Function to format topics as a "list of list of strings".
# Needed for topic coherence function in Gensim

# function slightly modified from https://nlpforhackers.io/topic-modeling/

def list_topics(model, vectorizer, top_n=10):

    #input. top_n: how many words to list per topic.  If -1, then list all words.
       
    topic_words = []
    
    for idx, topic in enumerate(model.components_):  # loop through each row of H.  idx = row index.  topic = actual row
        #print("\nTopic %d:" % (idx))
        #print([(vectorizer.get_feature_names()[i], topic[i])  # printing out words corresponding to indices found in next line
                        #for i in topic.argsort()[:-top_n - 1:-1]])  # finding indices of top words in topic
            
        if top_n == -1:   
            topic_words.append([vectorizer.get_feature_names()[i] for i in topic.argsort()[::-1]])
        else:
            topic_words.append([vectorizer.get_feature_names()[i] for i in topic.argsort()[:-top_n - 1:-1]])
        
    return topic_words

# %%
topics = list_topics(Glda_model, vectorizer, top_n=10)

# %%
cm = CoherenceModel(topics=topics, corpus=corpus, dictionary=id2word, 
                    texts=docs, coherence='c_v', processes=10) #window_size=500 )

# %%
coherence = cm.get_coherence() 
print(coherence)
# Out:
# INFO:gensim.topic_coherence.probability_estimation:using ParallelWordOccurrenceAccumulator(processes=10, batch_size=64) to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:1 batches submitted to accumulate stats from 64 documents (3755 virtual)
# INFO:gensim.topic_coherence.text_analysis:2 batches submitted to accumulate stats from 128 documents (9645 virtual)
# INFO:gensim.topic_coherence.text_analysis:3 batches submitted to accumulate stats from 192 documents (13800 virtual)
# INFO:gensim.topic_coherence.text_analysis:4 batches submitted to accumulate stats from 256 documents (18870 virtual)
# INFO:gensim.topic_coherence.text_analysis:5 batches submitted to accumulate stats from 320 documents (23366 virtual)
# INFO:gensim.topic_coherence.text_analysis:6 batches submitted to accumulate stats from 384 documents (29174 virtual)
# INFO:gensim.topic_coherence.text_analysis:7 batches submitted to accumulate stats from 448 documents (34162 virtual)
# INFO:gensim.topic_coherence.text_analysis:8 batches submitted to accumulate stats from 512 documents (38527 virtual)
# INFO:gensim.topic_coherence.text_analysis:9 batches submitted to accumulate stats from 576 documents (42231 virtual)
# INFO:gensim.topic_coherence.text_analysis:10 batches submitted to accumulate stats from 640 documents (47070 virtual)
# INFO:gensim.topic_coherence.text_analysis:11 batches submitted to accumulate stats from 704 documents (50800 virtual)
# INFO:gensim.topic_coherence.text_analysis:12 batches submitted to accumulate stats from 768 documents (55910 virtual)
# INFO:gensim.topic_coherence.text_analysis:13 batches submitted to accumulate stats from 832 documents (58863 virtual)
# INFO:gensim.topic_coherence.text_analysis:14 batches submitted to accumulate stats from 896 documents (62737 virtual)
# INFO:gensim.topic_coherence.text_analysis:15 batches submitted to accumulate stats from 960 documents (67679 virtual)
# INFO:gensim.topic_coherence.text_analysis:16 batches submitted to accumulate stats from 1024 documents (71734 virtual)
# INFO:gensim.topic_coherence.text_analysis:17 batches submitted to accumulate stats from 1088 documents (75620 virtual)
# INFO:gensim.topic_coherence.text_analysis:18 batches submitted to accumulate stats from 1152 documents (79639 virtual)
# INFO:gensim.topic_coherence.text_analysis:19 batches submitted to accumulate stats from 1216 documents (83423 virtual)
# INFO:gensim.topic_coherence.text_analysis:20 batches submitted to accumulate stats from 1280 documents (86683 virtual)
# INFO:gensim.topic_coherence.text_analysis:21 batches submitted to accumulate stats from 1344 documents (91302 virtual)
# INFO:gensim.topic_coherence.text_analysis:22 batches submitted to accumulate stats from 1408 documents (95150 virtual)
# INFO:gensim.topic_coherence.text_analysis:23 batches submitted to accumulate stats from 1472 documents (98529 virtual)
# INFO:gensim.topic_coherence.text_analysis:24 batches submitted to accumulate stats from 1536 documents (102807 virtual)
# INFO:gensim.topic_coherence.text_analysis:25 batches submitted to accumulate stats from 1600 documents (107095 virtual)
# INFO:gensim.topic_coherence.text_analysis:26 batches submitted to accumulate stats from 1664 documents (111492 virtual)
# INFO:gensim.topic_coherence.text_analysis:27 batches submitted to accumulate stats from 1728 documents (114295 virtual)
# INFO:gensim.topic_coherence.text_analysis:28 batches submitted to accumulate stats from 1792 documents (117905 virtual)
# INFO:gensim.topic_coherence.text_analysis:29 batches submitted to accumulate stats from 1856 documents (122661 virtual)
# INFO:gensim.topic_coherence.text_analysis:30 batches submitted to accumulate stats from 1920 documents (126248 virtual)
# INFO:gensim.topic_coherence.text_analysis:31 batches submitted to accumulate stats from 1984 documents (131269 virtual)
# INFO:gensim.topic_coherence.text_analysis:32 batches submitted to accumulate stats from 2048 documents (136497 virtual)
# INFO:gensim.topic_coherence.text_analysis:33 batches submitted to accumulate stats from 2112 documents (141202 virtual)
# INFO:gensim.topic_coherence.text_analysis:34 batches submitted to accumulate stats from 2176 documents (143355 virtual)
# INFO:gensim.topic_coherence.text_analysis:35 batches submitted to accumulate stats from 2240 documents (146439 virtual)
# INFO:gensim.topic_coherence.text_analysis:36 batches submitted to accumulate stats from 2304 documents (150364 virtual)
# INFO:gensim.topic_coherence.text_analysis:37 batches submitted to accumulate stats from 2368 documents (153548 virtual)
# INFO:gensim.topic_coherence.text_analysis:38 batches submitted to accumulate stats from 2432 documents (156565 virtual)
# INFO:gensim.topic_coherence.text_analysis:39 batches submitted to accumulate stats from 2496 documents (160081 virtual)
# INFO:gensim.topic_coherence.text_analysis:40 batches submitted to accumulate stats from 2560 documents (163548 virtual)
# INFO:gensim.topic_coherence.text_analysis:41 batches submitted to accumulate stats from 2624 documents (166490 virtual)
# INFO:gensim.topic_coherence.text_analysis:42 batches submitted to accumulate stats from 2688 documents (169264 virtual)
# INFO:gensim.topic_coherence.text_analysis:43 batches submitted to accumulate stats from 2752 documents (172108 virtual)
# INFO:gensim.topic_coherence.text_analysis:44 batches submitted to accumulate stats from 2816 documents (175903 virtual)
# INFO:gensim.topic_coherence.text_analysis:45 batches submitted to accumulate stats from 2880 documents (181049 virtual)
# INFO:gensim.topic_coherence.text_analysis:46 batches submitted to accumulate stats from 2944 documents (185140 virtual)
# INFO:gensim.topic_coherence.text_analysis:47 batches submitted to accumulate stats from 3008 documents (189000 virtual)
# INFO:gensim.topic_coherence.text_analysis:48 batches submitted to accumulate stats from 3072 documents (194241 virtual)
# INFO:gensim.topic_coherence.text_analysis:49 batches submitted to accumulate stats from 3136 documents (199256 virtual)
# INFO:gensim.topic_coherence.text_analysis:50 batches submitted to accumulate stats from 3200 documents (203470 virtual)
# INFO:gensim.topic_coherence.text_analysis:51 batches submitted to accumulate stats from 3264 documents (207363 virtual)
# INFO:gensim.topic_coherence.text_analysis:52 batches submitted to accumulate stats from 3328 documents (211708 virtual)
# INFO:gensim.topic_coherence.text_analysis:53 batches submitted to accumulate stats from 3392 documents (214630 virtual)
# INFO:gensim.topic_coherence.text_analysis:54 batches submitted to accumulate stats from 3456 documents (218872 virtual)
# INFO:gensim.topic_coherence.text_analysis:55 batches submitted to accumulate stats from 3520 documents (222393 virtual)
# INFO:gensim.topic_coherence.text_analysis:56 batches submitted to accumulate stats from 3584 documents (226500 virtual)
# INFO:gensim.topic_coherence.text_analysis:57 batches submitted to accumulate stats from 3648 documents (231260 virtual)
# INFO:gensim.topic_coherence.text_analysis:58 batches submitted to accumulate stats from 3712 documents (236865 virtual)
# INFO:gensim.topic_coherence.text_analysis:59 batches submitted to accumulate stats from 3776 documents (241775 virtual)
# INFO:gensim.topic_coherence.text_analysis:60 batches submitted to accumulate stats from 3840 documents (246204 virtual)
# INFO:gensim.topic_coherence.text_analysis:61 batches submitted to accumulate stats from 3904 documents (249667 virtual)
# INFO:gensim.topic_coherence.text_analysis:62 batches submitted to accumulate stats from 3968 documents (253238 virtual)
# INFO:gensim.topic_coherence.text_analysis:63 batches submitted to accumulate stats from 4032 documents (257208 virtual)
# INFO:gensim.topic_coherence.text_analysis:64 batches submitted to accumulate stats from 4096 documents (259955 virtual)
# INFO:gensim.topic_coherence.text_analysis:65 batches submitted to accumulate stats from 4160 documents (262413 virtual)
# INFO:gensim.topic_coherence.text_analysis:66 batches submitted to accumulate stats from 4224 documents (266300 virtual)
# INFO:gensim.topic_coherence.text_analysis:67 batches submitted to accumulate stats from 4288 documents (269350 virtual)
# INFO:gensim.topic_coherence.text_analysis:68 batches submitted to accumulate stats from 4352 documents (272543 virtual)
# INFO:gensim.topic_coherence.text_analysis:69 batches submitted to accumulate stats from 4416 documents (275757 virtual)
# INFO:gensim.topic_coherence.text_analysis:70 batches submitted to accumulate stats from 4480 documents (280261 virtual)
# INFO:gensim.topic_coherence.text_analysis:71 batches submitted to accumulate stats from 4544 documents (284096 virtual)
# INFO:gensim.topic_coherence.text_analysis:72 batches submitted to accumulate stats from 4608 documents (287115 virtual)
# INFO:gensim.topic_coherence.text_analysis:73 batches submitted to accumulate stats from 4672 documents (291008 virtual)
# INFO:gensim.topic_coherence.text_analysis:74 batches submitted to accumulate stats from 4736 documents (295732 virtual)
# INFO:gensim.topic_coherence.text_analysis:75 batches submitted to accumulate stats from 4800 documents (299343 virtual)
# INFO:gensim.topic_coherence.text_analysis:76 batches submitted to accumulate stats from 4864 documents (302871 virtual)
# INFO:gensim.topic_coherence.text_analysis:77 batches submitted to accumulate stats from 4928 documents (306841 virtual)
# INFO:gensim.topic_coherence.text_analysis:78 batches submitted to accumulate stats from 4992 documents (311023 virtual)
# INFO:gensim.topic_coherence.text_analysis:79 batches submitted to accumulate stats from 5056 documents (314027 virtual)
# INFO:gensim.topic_coherence.text_analysis:80 batches submitted to accumulate stats from 5120 documents (316079 virtual)
# INFO:gensim.topic_coherence.text_analysis:81 batches submitted to accumulate stats from 5184 documents (319471 virtual)
# INFO:gensim.topic_coherence.text_analysis:82 batches submitted to accumulate stats from 5248 documents (323528 virtual)
# INFO:gensim.topic_coherence.text_analysis:83 batches submitted to accumulate stats from 5312 documents (326878 virtual)
# INFO:gensim.topic_coherence.text_analysis:84 batches submitted to accumulate stats from 5376 documents (329301 virtual)
# INFO:gensim.topic_coherence.text_analysis:85 batches submitted to accumulate stats from 5440 documents (332784 virtual)
# INFO:gensim.topic_coherence.text_analysis:86 batches submitted to accumulate stats from 5504 documents (336602 virtual)
# INFO:gensim.topic_coherence.text_analysis:87 batches submitted to accumulate stats from 5568 documents (340502 virtual)
# INFO:gensim.topic_coherence.text_analysis:88 batches submitted to accumulate stats from 5632 documents (343997 virtual)
# INFO:gensim.topic_coherence.text_analysis:89 batches submitted to accumulate stats from 5696 documents (347597 virtual)
# INFO:gensim.topic_coherence.text_analysis:90 batches submitted to accumulate stats from 5760 documents (350082 virtual)
# INFO:gensim.topic_coherence.text_analysis:91 batches submitted to accumulate stats from 5824 documents (352069 virtual)
# INFO:gensim.topic_coherence.text_analysis:92 batches submitted to accumulate stats from 5888 documents (355419 virtual)
# INFO:gensim.topic_coherence.text_analysis:93 batches submitted to accumulate stats from 5952 documents (357839 virtual)
# INFO:gensim.topic_coherence.text_analysis:94 batches submitted to accumulate stats from 6016 documents (362486 virtual)
# INFO:gensim.topic_coherence.text_analysis:95 batches submitted to accumulate stats from 6080 documents (366807 virtual)
# INFO:gensim.topic_coherence.text_analysis:96 batches submitted to accumulate stats from 6144 documents (370213 virtual)
# INFO:gensim.topic_coherence.text_analysis:97 batches submitted to accumulate stats from 6208 documents (374524 virtual)
# INFO:gensim.topic_coherence.text_analysis:98 batches submitted to accumulate stats from 6272 documents (377751 virtual)
# INFO:gensim.topic_coherence.text_analysis:99 batches submitted to accumulate stats from 6336 documents (380820 virtual)
# INFO:gensim.topic_coherence.text_analysis:100 batches submitted to accumulate stats from 6400 documents (384024 virtual)
# INFO:gensim.topic_coherence.text_analysis:101 batches submitted to accumulate stats from 6464 documents (387357 virtual)
# INFO:gensim.topic_coherence.text_analysis:102 batches submitted to accumulate stats from 6528 documents (390678 virtual)
# INFO:gensim.topic_coherence.text_analysis:103 batches submitted to accumulate stats from 6592 documents (395143 virtual)
# INFO:gensim.topic_coherence.text_analysis:104 batches submitted to accumulate stats from 6656 documents (398355 virtual)
# INFO:gensim.topic_coherence.text_analysis:105 batches submitted to accumulate stats from 6720 documents (402213 virtual)
# INFO:gensim.topic_coherence.text_analysis:106 batches submitted to accumulate stats from 6784 documents (406239 virtual)
# INFO:gensim.topic_coherence.text_analysis:107 batches submitted to accumulate stats from 6848 documents (410102 virtual)
# INFO:gensim.topic_coherence.text_analysis:108 batches submitted to accumulate stats from 6912 documents (413132 virtual)
# INFO:gensim.topic_coherence.text_analysis:109 batches submitted to accumulate stats from 6976 documents (416502 virtual)
# INFO:gensim.topic_coherence.text_analysis:110 batches submitted to accumulate stats from 7040 documents (420582 virtual)
# INFO:gensim.topic_coherence.text_analysis:111 batches submitted to accumulate stats from 7104 documents (424701 virtual)
# INFO:gensim.topic_coherence.text_analysis:112 batches submitted to accumulate stats from 7168 documents (428196 virtual)
# INFO:gensim.topic_coherence.text_analysis:113 batches submitted to accumulate stats from 7232 documents (431065 virtual)
# INFO:gensim.topic_coherence.text_analysis:114 batches submitted to accumulate stats from 7296 documents (435332 virtual)
# INFO:gensim.topic_coherence.text_analysis:115 batches submitted to accumulate stats from 7360 documents (438576 virtual)
# INFO:gensim.topic_coherence.text_analysis:116 batches submitted to accumulate stats from 7424 documents (442257 virtual)
# INFO:gensim.topic_coherence.text_analysis:117 batches submitted to accumulate stats from 7488 documents (445804 virtual)
# INFO:gensim.topic_coherence.text_analysis:118 batches submitted to accumulate stats from 7552 documents (449724 virtual)
# INFO:gensim.topic_coherence.text_analysis:119 batches submitted to accumulate stats from 7616 documents (452406 virtual)
# INFO:gensim.topic_coherence.text_analysis:120 batches submitted to accumulate stats from 7680 documents (455751 virtual)
# INFO:gensim.topic_coherence.text_analysis:121 batches submitted to accumulate stats from 7744 documents (460316 virtual)
# INFO:gensim.topic_coherence.text_analysis:122 batches submitted to accumulate stats from 7808 documents (463635 virtual)
# INFO:gensim.topic_coherence.text_analysis:123 batches submitted to accumulate stats from 7872 documents (467247 virtual)
# INFO:gensim.topic_coherence.text_analysis:124 batches submitted to accumulate stats from 7936 documents (470386 virtual)
# INFO:gensim.topic_coherence.text_analysis:125 batches submitted to accumulate stats from 8000 documents (476118 virtual)
# INFO:gensim.topic_coherence.text_analysis:126 batches submitted to accumulate stats from 8064 documents (479956 virtual)
# INFO:gensim.topic_coherence.text_analysis:127 batches submitted to accumulate stats from 8128 documents (482882 virtual)
# INFO:gensim.topic_coherence.text_analysis:128 batches submitted to accumulate stats from 8192 documents (486806 virtual)
# INFO:gensim.topic_coherence.text_analysis:129 batches submitted to accumulate stats from 8256 documents (490133 virtual)
# INFO:gensim.topic_coherence.text_analysis:130 batches submitted to accumulate stats from 8320 documents (494768 virtual)
# INFO:gensim.topic_coherence.text_analysis:131 batches submitted to accumulate stats from 8384 documents (498954 virtual)
# INFO:gensim.topic_coherence.text_analysis:132 batches submitted to accumulate stats from 8448 documents (502825 virtual)
# INFO:gensim.topic_coherence.text_analysis:133 batches submitted to accumulate stats from 8512 documents (505066 virtual)
# INFO:gensim.topic_coherence.text_analysis:134 batches submitted to accumulate stats from 8576 documents (508142 virtual)
# INFO:gensim.topic_coherence.text_analysis:135 batches submitted to accumulate stats from 8640 documents (511848 virtual)
# INFO:gensim.topic_coherence.text_analysis:136 batches submitted to accumulate stats from 8704 documents (514836 virtual)
# INFO:gensim.topic_coherence.text_analysis:137 batches submitted to accumulate stats from 8768 documents (518182 virtual)
# INFO:gensim.topic_coherence.text_analysis:138 batches submitted to accumulate stats from 8832 documents (521848 virtual)
# INFO:gensim.topic_coherence.text_analysis:139 batches submitted to accumulate stats from 8896 documents (525253 virtual)
# INFO:gensim.topic_coherence.text_analysis:140 batches submitted to accumulate stats from 8960 documents (528579 virtual)
# INFO:gensim.topic_coherence.text_analysis:141 batches submitted to accumulate stats from 9024 documents (531863 virtual)
# INFO:gensim.topic_coherence.text_analysis:142 batches submitted to accumulate stats from 9088 documents (535891 virtual)
# INFO:gensim.topic_coherence.text_analysis:143 batches submitted to accumulate stats from 9152 documents (539084 virtual)
# INFO:gensim.topic_coherence.text_analysis:144 batches submitted to accumulate stats from 9216 documents (542119 virtual)
# INFO:gensim.topic_coherence.text_analysis:145 batches submitted to accumulate stats from 9280 documents (545579 virtual)
# INFO:gensim.topic_coherence.text_analysis:146 batches submitted to accumulate stats from 9344 documents (550542 virtual)
# INFO:gensim.topic_coherence.text_analysis:147 batches submitted to accumulate stats from 9408 documents (554101 virtual)
# INFO:gensim.topic_coherence.text_analysis:148 batches submitted to accumulate stats from 9472 documents (557397 virtual)
# INFO:gensim.topic_coherence.text_analysis:149 batches submitted to accumulate stats from 9536 documents (560589 virtual)
# INFO:gensim.topic_coherence.text_analysis:150 batches submitted to accumulate stats from 9600 documents (563848 virtual)
# INFO:gensim.topic_coherence.text_analysis:151 batches submitted to accumulate stats from 9664 documents (567591 virtual)
# INFO:gensim.topic_coherence.text_analysis:152 batches submitted to accumulate stats from 9728 documents (570820 virtual)
# INFO:gensim.topic_coherence.text_analysis:153 batches submitted to accumulate stats from 9792 documents (574684 virtual)
# INFO:gensim.topic_coherence.text_analysis:154 batches submitted to accumulate stats from 9856 documents (578806 virtual)
# INFO:gensim.topic_coherence.text_analysis:155 batches submitted to accumulate stats from 9920 documents (581448 virtual)
# INFO:gensim.topic_coherence.text_analysis:156 batches submitted to accumulate stats from 9984 documents (583547 virtual)
# INFO:gensim.topic_coherence.text_analysis:157 batches submitted to accumulate stats from 10048 documents (586107 virtual)
# INFO:gensim.topic_coherence.text_analysis:158 batches submitted to accumulate stats from 10112 documents (587627 virtual)
# INFO:gensim.topic_coherence.text_analysis:159 batches submitted to accumulate stats from 10176 documents (591054 virtual)
# INFO:gensim.topic_coherence.text_analysis:160 batches submitted to accumulate stats from 10240 documents (592688 virtual)
# INFO:gensim.topic_coherence.text_analysis:161 batches submitted to accumulate stats from 10304 documents (594176 virtual)
# INFO:gensim.topic_coherence.text_analysis:162 batches submitted to accumulate stats from 10368 documents (597773 virtual)
# INFO:gensim.topic_coherence.text_analysis:163 batches submitted to accumulate stats from 10432 documents (599859 virtual)
# INFO:gensim.topic_coherence.text_analysis:164 batches submitted to accumulate stats from 10496 documents (604188 virtual)
# INFO:gensim.topic_coherence.text_analysis:165 batches submitted to accumulate stats from 10560 documents (608252 virtual)
# INFO:gensim.topic_coherence.text_analysis:166 batches submitted to accumulate stats from 10624 documents (614027 virtual)
# INFO:gensim.topic_coherence.text_analysis:167 batches submitted to accumulate stats from 10688 documents (617914 virtual)
# INFO:gensim.topic_coherence.text_analysis:168 batches submitted to accumulate stats from 10752 documents (621849 virtual)
# INFO:gensim.topic_coherence.text_analysis:169 batches submitted to accumulate stats from 10816 documents (625636 virtual)
# INFO:gensim.topic_coherence.text_analysis:170 batches submitted to accumulate stats from 10880 documents (630204 virtual)
# INFO:gensim.topic_coherence.text_analysis:171 batches submitted to accumulate stats from 10944 documents (633131 virtual)
# INFO:gensim.topic_coherence.text_analysis:172 batches submitted to accumulate stats from 11008 documents (636972 virtual)
# INFO:gensim.topic_coherence.text_analysis:173 batches submitted to accumulate stats from 11072 documents (641975 virtual)
# INFO:gensim.topic_coherence.text_analysis:174 batches submitted to accumulate stats from 11136 documents (645231 virtual)
# INFO:gensim.topic_coherence.text_analysis:175 batches submitted to accumulate stats from 11200 documents (649950 virtual)
# INFO:gensim.topic_coherence.text_analysis:176 batches submitted to accumulate stats from 11264 documents (653828 virtual)
# INFO:gensim.topic_coherence.text_analysis:177 batches submitted to accumulate stats from 11328 documents (658180 virtual)
# INFO:gensim.topic_coherence.text_analysis:178 batches submitted to accumulate stats from 11392 documents (662790 virtual)
# INFO:gensim.topic_coherence.text_analysis:179 batches submitted to accumulate stats from 11456 documents (667446 virtual)
# INFO:gensim.topic_coherence.text_analysis:180 batches submitted to accumulate stats from 11520 documents (671307 virtual)
# INFO:gensim.topic_coherence.text_analysis:181 batches submitted to accumulate stats from 11584 documents (673622 virtual)
# INFO:gensim.topic_coherence.text_analysis:182 batches submitted to accumulate stats from 11648 documents (677139 virtual)
# INFO:gensim.topic_coherence.text_analysis:183 batches submitted to accumulate stats from 11712 documents (681507 virtual)
# INFO:gensim.topic_coherence.text_analysis:184 batches submitted to accumulate stats from 11776 documents (685755 virtual)
# INFO:gensim.topic_coherence.text_analysis:185 batches submitted to accumulate stats from 11840 documents (689219 virtual)
# INFO:gensim.topic_coherence.text_analysis:186 batches submitted to accumulate stats from 11904 documents (693704 virtual)
# INFO:gensim.topic_coherence.text_analysis:187 batches submitted to accumulate stats from 11968 documents (697211 virtual)
# INFO:gensim.topic_coherence.text_analysis:188 batches submitted to accumulate stats from 12032 documents (701939 virtual)
# INFO:gensim.topic_coherence.text_analysis:189 batches submitted to accumulate stats from 12096 documents (706782 virtual)
# INFO:gensim.topic_coherence.text_analysis:190 batches submitted to accumulate stats from 12160 documents (711439 virtual)
# INFO:gensim.topic_coherence.text_analysis:191 batches submitted to accumulate stats from 12224 documents (715791 virtual)
# INFO:gensim.topic_coherence.text_analysis:192 batches submitted to accumulate stats from 12288 documents (719026 virtual)
# INFO:gensim.topic_coherence.text_analysis:193 batches submitted to accumulate stats from 12352 documents (723430 virtual)
# INFO:gensim.topic_coherence.text_analysis:194 batches submitted to accumulate stats from 12416 documents (727287 virtual)
# INFO:gensim.topic_coherence.text_analysis:195 batches submitted to accumulate stats from 12480 documents (731117 virtual)
# INFO:gensim.topic_coherence.text_analysis:196 batches submitted to accumulate stats from 12544 documents (735061 virtual)
# INFO:gensim.topic_coherence.text_analysis:197 batches submitted to accumulate stats from 12608 documents (738145 virtual)
# INFO:gensim.topic_coherence.text_analysis:198 batches submitted to accumulate stats from 12672 documents (741143 virtual)
# INFO:gensim.topic_coherence.text_analysis:199 batches submitted to accumulate stats from 12736 documents (745055 virtual)
# INFO:gensim.topic_coherence.text_analysis:200 batches submitted to accumulate stats from 12800 documents (749610 virtual)
# INFO:gensim.topic_coherence.text_analysis:201 batches submitted to accumulate stats from 12864 documents (753817 virtual)
# INFO:gensim.topic_coherence.text_analysis:202 batches submitted to accumulate stats from 12928 documents (758324 virtual)
# INFO:gensim.topic_coherence.text_analysis:203 batches submitted to accumulate stats from 12992 documents (763064 virtual)
# INFO:gensim.topic_coherence.text_analysis:204 batches submitted to accumulate stats from 13056 documents (765936 virtual)
# INFO:gensim.topic_coherence.text_analysis:205 batches submitted to accumulate stats from 13120 documents (770800 virtual)
# INFO:gensim.topic_coherence.text_analysis:206 batches submitted to accumulate stats from 13184 documents (773943 virtual)
# INFO:gensim.topic_coherence.text_analysis:207 batches submitted to accumulate stats from 13248 documents (778424 virtual)
# INFO:gensim.topic_coherence.text_analysis:208 batches submitted to accumulate stats from 13312 documents (782795 virtual)
# INFO:gensim.topic_coherence.text_analysis:209 batches submitted to accumulate stats from 13376 documents (786290 virtual)
# INFO:gensim.topic_coherence.text_analysis:210 batches submitted to accumulate stats from 13440 documents (791632 virtual)
# INFO:gensim.topic_coherence.text_analysis:211 batches submitted to accumulate stats from 13504 documents (796791 virtual)
# INFO:gensim.topic_coherence.text_analysis:212 batches submitted to accumulate stats from 13568 documents (800924 virtual)
# INFO:gensim.topic_coherence.text_analysis:213 batches submitted to accumulate stats from 13632 documents (805310 virtual)
# INFO:gensim.topic_coherence.text_analysis:214 batches submitted to accumulate stats from 13696 documents (809094 virtual)
# INFO:gensim.topic_coherence.text_analysis:215 batches submitted to accumulate stats from 13760 documents (813705 virtual)
# INFO:gensim.topic_coherence.text_analysis:216 batches submitted to accumulate stats from 13824 documents (817800 virtual)
# INFO:gensim.topic_coherence.text_analysis:217 batches submitted to accumulate stats from 13888 documents (822794 virtual)
# INFO:gensim.topic_coherence.text_analysis:218 batches submitted to accumulate stats from 13952 documents (827144 virtual)
# INFO:gensim.topic_coherence.text_analysis:219 batches submitted to accumulate stats from 14016 documents (832294 virtual)
# INFO:gensim.topic_coherence.text_analysis:220 batches submitted to accumulate stats from 14080 documents (836614 virtual)
# INFO:gensim.topic_coherence.text_analysis:221 batches submitted to accumulate stats from 14144 documents (840663 virtual)
# INFO:gensim.topic_coherence.text_analysis:222 batches submitted to accumulate stats from 14208 documents (844191 virtual)
# INFO:gensim.topic_coherence.text_analysis:223 batches submitted to accumulate stats from 14272 documents (847529 virtual)
# INFO:gensim.topic_coherence.text_analysis:224 batches submitted to accumulate stats from 14336 documents (852051 virtual)
# INFO:gensim.topic_coherence.text_analysis:225 batches submitted to accumulate stats from 14400 documents (856377 virtual)
# INFO:gensim.topic_coherence.text_analysis:226 batches submitted to accumulate stats from 14464 documents (860136 virtual)
# INFO:gensim.topic_coherence.text_analysis:227 batches submitted to accumulate stats from 14528 documents (863971 virtual)
# INFO:gensim.topic_coherence.text_analysis:228 batches submitted to accumulate stats from 14592 documents (867327 virtual)
# INFO:gensim.topic_coherence.text_analysis:229 batches submitted to accumulate stats from 14656 documents (871418 virtual)
# INFO:gensim.topic_coherence.text_analysis:230 batches submitted to accumulate stats from 14720 documents (875248 virtual)
# INFO:gensim.topic_coherence.text_analysis:231 batches submitted to accumulate stats from 14784 documents (879625 virtual)
# INFO:gensim.topic_coherence.text_analysis:232 batches submitted to accumulate stats from 14848 documents (883542 virtual)
# INFO:gensim.topic_coherence.text_analysis:233 batches submitted to accumulate stats from 14912 documents (887232 virtual)
# INFO:gensim.topic_coherence.text_analysis:234 batches submitted to accumulate stats from 14976 documents (891022 virtual)
# INFO:gensim.topic_coherence.text_analysis:235 batches submitted to accumulate stats from 15040 documents (895058 virtual)
# INFO:gensim.topic_coherence.text_analysis:236 batches submitted to accumulate stats from 15104 documents (899144 virtual)
# INFO:gensim.topic_coherence.text_analysis:237 batches submitted to accumulate stats from 15168 documents (903113 virtual)
# INFO:gensim.topic_coherence.text_analysis:238 batches submitted to accumulate stats from 15232 documents (907206 virtual)
# INFO:gensim.topic_coherence.text_analysis:239 batches submitted to accumulate stats from 15296 documents (911699 virtual)
# INFO:gensim.topic_coherence.text_analysis:240 batches submitted to accumulate stats from 15360 documents (916496 virtual)
# INFO:gensim.topic_coherence.text_analysis:241 batches submitted to accumulate stats from 15424 documents (919780 virtual)
# INFO:gensim.topic_coherence.text_analysis:242 batches submitted to accumulate stats from 15488 documents (923044 virtual)
# INFO:gensim.topic_coherence.text_analysis:243 batches submitted to accumulate stats from 15552 documents (927260 virtual)
# INFO:gensim.topic_coherence.text_analysis:244 batches submitted to accumulate stats from 15616 documents (931329 virtual)
# INFO:gensim.topic_coherence.text_analysis:245 batches submitted to accumulate stats from 15680 documents (936034 virtual)
# INFO:gensim.topic_coherence.text_analysis:246 batches submitted to accumulate stats from 15744 documents (940092 virtual)
# INFO:gensim.topic_coherence.text_analysis:247 batches submitted to accumulate stats from 15808 documents (944190 virtual)
# INFO:gensim.topic_coherence.text_analysis:248 batches submitted to accumulate stats from 15872 documents (947926 virtual)
# INFO:gensim.topic_coherence.text_analysis:249 batches submitted to accumulate stats from 15936 documents (951536 virtual)
# INFO:gensim.topic_coherence.text_analysis:250 batches submitted to accumulate stats from 16000 documents (955949 virtual)
# INFO:gensim.topic_coherence.text_analysis:251 batches submitted to accumulate stats from 16064 documents (959990 virtual)
# INFO:gensim.topic_coherence.text_analysis:252 batches submitted to accumulate stats from 16128 documents (963781 virtual)
# INFO:gensim.topic_coherence.text_analysis:253 batches submitted to accumulate stats from 16192 documents (967588 virtual)
# INFO:gensim.topic_coherence.text_analysis:254 batches submitted to accumulate stats from 16256 documents (971355 virtual)
# INFO:gensim.topic_coherence.text_analysis:255 batches submitted to accumulate stats from 16320 documents (975452 virtual)
# INFO:gensim.topic_coherence.text_analysis:256 batches submitted to accumulate stats from 16384 documents (979944 virtual)
# INFO:gensim.topic_coherence.text_analysis:257 batches submitted to accumulate stats from 16448 documents (983803 virtual)
# INFO:gensim.topic_coherence.text_analysis:258 batches submitted to accumulate stats from 16512 documents (986930 virtual)
# INFO:gensim.topic_coherence.text_analysis:259 batches submitted to accumulate stats from 16576 documents (990338 virtual)
# INFO:gensim.topic_coherence.text_analysis:260 batches submitted to accumulate stats from 16640 documents (994546 virtual)
# INFO:gensim.topic_coherence.text_analysis:261 batches submitted to accumulate stats from 16704 documents (1000105 virtual)
# INFO:gensim.topic_coherence.text_analysis:262 batches submitted to accumulate stats from 16768 documents (1003784 virtual)
# INFO:gensim.topic_coherence.text_analysis:263 batches submitted to accumulate stats from 16832 documents (1009364 virtual)
# INFO:gensim.topic_coherence.text_analysis:264 batches submitted to accumulate stats from 16896 documents (1013453 virtual)
# INFO:gensim.topic_coherence.text_analysis:265 batches submitted to accumulate stats from 16960 documents (1016987 virtual)
# INFO:gensim.topic_coherence.text_analysis:266 batches submitted to accumulate stats from 17024 documents (1021249 virtual)
# INFO:gensim.topic_coherence.text_analysis:267 batches submitted to accumulate stats from 17088 documents (1024409 virtual)
# INFO:gensim.topic_coherence.text_analysis:268 batches submitted to accumulate stats from 17152 documents (1028921 virtual)
# INFO:gensim.topic_coherence.text_analysis:269 batches submitted to accumulate stats from 17216 documents (1032340 virtual)
# INFO:gensim.topic_coherence.text_analysis:270 batches submitted to accumulate stats from 17280 documents (1036454 virtual)
# INFO:gensim.topic_coherence.text_analysis:271 batches submitted to accumulate stats from 17344 documents (1039184 virtual)
# INFO:gensim.topic_coherence.text_analysis:272 batches submitted to accumulate stats from 17408 documents (1044055 virtual)
# INFO:gensim.topic_coherence.text_analysis:273 batches submitted to accumulate stats from 17472 documents (1048126 virtual)
# INFO:gensim.topic_coherence.text_analysis:274 batches submitted to accumulate stats from 17536 documents (1051447 virtual)
# INFO:gensim.topic_coherence.text_analysis:275 batches submitted to accumulate stats from 17600 documents (1055597 virtual)
# INFO:gensim.topic_coherence.text_analysis:276 batches submitted to accumulate stats from 17664 documents (1059750 virtual)
# INFO:gensim.topic_coherence.text_analysis:277 batches submitted to accumulate stats from 17728 documents (1063895 virtual)
# INFO:gensim.topic_coherence.text_analysis:278 batches submitted to accumulate stats from 17792 documents (1068832 virtual)
# INFO:gensim.topic_coherence.text_analysis:279 batches submitted to accumulate stats from 17856 documents (1073591 virtual)
# INFO:gensim.topic_coherence.text_analysis:280 batches submitted to accumulate stats from 17920 documents (1078814 virtual)
# INFO:gensim.topic_coherence.text_analysis:281 batches submitted to accumulate stats from 17984 documents (1082762 virtual)
# INFO:gensim.topic_coherence.text_analysis:282 batches submitted to accumulate stats from 18048 documents (1087312 virtual)
# INFO:gensim.topic_coherence.text_analysis:283 batches submitted to accumulate stats from 18112 documents (1091322 virtual)
# INFO:gensim.topic_coherence.text_analysis:284 batches submitted to accumulate stats from 18176 documents (1095144 virtual)
# INFO:gensim.topic_coherence.text_analysis:285 batches submitted to accumulate stats from 18240 documents (1098308 virtual)
# INFO:gensim.topic_coherence.text_analysis:286 batches submitted to accumulate stats from 18304 documents (1102747 virtual)
# INFO:gensim.topic_coherence.text_analysis:287 batches submitted to accumulate stats from 18368 documents (1107846 virtual)
# INFO:gensim.topic_coherence.text_analysis:288 batches submitted to accumulate stats from 18432 documents (1111734 virtual)
# INFO:gensim.topic_coherence.text_analysis:289 batches submitted to accumulate stats from 18496 documents (1115255 virtual)
# INFO:gensim.topic_coherence.text_analysis:290 batches submitted to accumulate stats from 18560 documents (1119964 virtual)
# INFO:gensim.topic_coherence.text_analysis:291 batches submitted to accumulate stats from 18624 documents (1123271 virtual)
# INFO:gensim.topic_coherence.text_analysis:292 batches submitted to accumulate stats from 18688 documents (1127433 virtual)
# INFO:gensim.topic_coherence.text_analysis:293 batches submitted to accumulate stats from 18752 documents (1131818 virtual)
# INFO:gensim.topic_coherence.text_analysis:294 batches submitted to accumulate stats from 18816 documents (1136370 virtual)
# INFO:gensim.topic_coherence.text_analysis:295 batches submitted to accumulate stats from 18880 documents (1139282 virtual)
# INFO:gensim.topic_coherence.text_analysis:296 batches submitted to accumulate stats from 18944 documents (1143735 virtual)
# INFO:gensim.topic_coherence.text_analysis:297 batches submitted to accumulate stats from 19008 documents (1147543 virtual)
# INFO:gensim.topic_coherence.text_analysis:298 batches submitted to accumulate stats from 19072 documents (1150099 virtual)
# INFO:gensim.topic_coherence.text_analysis:299 batches submitted to accumulate stats from 19136 documents (1153615 virtual)
# INFO:gensim.topic_coherence.text_analysis:300 batches submitted to accumulate stats from 19200 documents (1157746 virtual)
# INFO:gensim.topic_coherence.text_analysis:301 batches submitted to accumulate stats from 19264 documents (1161642 virtual)
# INFO:gensim.topic_coherence.text_analysis:302 batches submitted to accumulate stats from 19328 documents (1165632 virtual)
# INFO:gensim.topic_coherence.text_analysis:303 batches submitted to accumulate stats from 19392 documents (1169623 virtual)
# INFO:gensim.topic_coherence.text_analysis:304 batches submitted to accumulate stats from 19456 documents (1173543 virtual)
# INFO:gensim.topic_coherence.text_analysis:305 batches submitted to accumulate stats from 19520 documents (1177305 virtual)
# INFO:gensim.topic_coherence.text_analysis:306 batches submitted to accumulate stats from 19584 documents (1181904 virtual)
# INFO:gensim.topic_coherence.text_analysis:307 batches submitted to accumulate stats from 19648 documents (1185363 virtual)
# INFO:gensim.topic_coherence.text_analysis:308 batches submitted to accumulate stats from 19712 documents (1189431 virtual)
# INFO:gensim.topic_coherence.text_analysis:309 batches submitted to accumulate stats from 19776 documents (1193250 virtual)
# INFO:gensim.topic_coherence.text_analysis:310 batches submitted to accumulate stats from 19840 documents (1197396 virtual)
# INFO:gensim.topic_coherence.text_analysis:311 batches submitted to accumulate stats from 19904 documents (1199960 virtual)
# INFO:gensim.topic_coherence.text_analysis:312 batches submitted to accumulate stats from 19968 documents (1204624 virtual)
# INFO:gensim.topic_coherence.text_analysis:313 batches submitted to accumulate stats from 20032 documents (1208943 virtual)
# INFO:gensim.topic_coherence.text_analysis:314 batches submitted to accumulate stats from 20096 documents (1214650 virtual)
# INFO:gensim.topic_coherence.text_analysis:315 batches submitted to accumulate stats from 20160 documents (1218565 virtual)
# INFO:gensim.topic_coherence.text_analysis:316 batches submitted to accumulate stats from 20224 documents (1222951 virtual)
# INFO:gensim.topic_coherence.text_analysis:317 batches submitted to accumulate stats from 20288 documents (1226133 virtual)
# INFO:gensim.topic_coherence.text_analysis:318 batches submitted to accumulate stats from 20352 documents (1228692 virtual)
# INFO:gensim.topic_coherence.text_analysis:319 batches submitted to accumulate stats from 20416 documents (1233125 virtual)
# INFO:gensim.topic_coherence.text_analysis:320 batches submitted to accumulate stats from 20480 documents (1236825 virtual)
# INFO:gensim.topic_coherence.text_analysis:321 batches submitted to accumulate stats from 20544 documents (1239534 virtual)
# INFO:gensim.topic_coherence.text_analysis:322 batches submitted to accumulate stats from 20608 documents (1244806 virtual)
# INFO:gensim.topic_coherence.text_analysis:323 batches submitted to accumulate stats from 20672 documents (1248480 virtual)
# INFO:gensim.topic_coherence.text_analysis:324 batches submitted to accumulate stats from 20736 documents (1252703 virtual)
# INFO:gensim.topic_coherence.text_analysis:325 batches submitted to accumulate stats from 20800 documents (1257846 virtual)
# INFO:gensim.topic_coherence.text_analysis:326 batches submitted to accumulate stats from 20864 documents (1260077 virtual)
# INFO:gensim.topic_coherence.text_analysis:327 batches submitted to accumulate stats from 20928 documents (1263097 virtual)
# INFO:gensim.topic_coherence.text_analysis:328 batches submitted to accumulate stats from 20992 documents (1265816 virtual)
# INFO:gensim.topic_coherence.text_analysis:329 batches submitted to accumulate stats from 21056 documents (1268233 virtual)
# INFO:gensim.topic_coherence.text_analysis:330 batches submitted to accumulate stats from 21120 documents (1271521 virtual)
# INFO:gensim.topic_coherence.text_analysis:331 batches submitted to accumulate stats from 21184 documents (1275810 virtual)
# INFO:gensim.topic_coherence.text_analysis:332 batches submitted to accumulate stats from 21248 documents (1279175 virtual)
# INFO:gensim.topic_coherence.text_analysis:333 batches submitted to accumulate stats from 21312 documents (1282134 virtual)
# INFO:gensim.topic_coherence.text_analysis:334 batches submitted to accumulate stats from 21376 documents (1286165 virtual)
# INFO:gensim.topic_coherence.text_analysis:335 batches submitted to accumulate stats from 21440 documents (1290004 virtual)
# INFO:gensim.topic_coherence.text_analysis:336 batches submitted to accumulate stats from 21504 documents (1292857 virtual)
# INFO:gensim.topic_coherence.text_analysis:337 batches submitted to accumulate stats from 21568 documents (1297083 virtual)
# INFO:gensim.topic_coherence.text_analysis:338 batches submitted to accumulate stats from 21632 documents (1301068 virtual)
# INFO:gensim.topic_coherence.text_analysis:339 batches submitted to accumulate stats from 21696 documents (1304507 virtual)
# INFO:gensim.topic_coherence.text_analysis:340 batches submitted to accumulate stats from 21760 documents (1308828 virtual)
# INFO:gensim.topic_coherence.text_analysis:341 batches submitted to accumulate stats from 21824 documents (1312397 virtual)
# INFO:gensim.topic_coherence.text_analysis:342 batches submitted to accumulate stats from 21888 documents (1315793 virtual)
# INFO:gensim.topic_coherence.text_analysis:343 batches submitted to accumulate stats from 21952 documents (1319842 virtual)
# INFO:gensim.topic_coherence.text_analysis:344 batches submitted to accumulate stats from 22016 documents (1323774 virtual)
# INFO:gensim.topic_coherence.text_analysis:345 batches submitted to accumulate stats from 22080 documents (1326723 virtual)
# INFO:gensim.topic_coherence.text_analysis:346 batches submitted to accumulate stats from 22144 documents (1331397 virtual)
# INFO:gensim.topic_coherence.text_analysis:347 batches submitted to accumulate stats from 22208 documents (1334772 virtual)
# INFO:gensim.topic_coherence.text_analysis:348 batches submitted to accumulate stats from 22272 documents (1337337 virtual)
# INFO:gensim.topic_coherence.text_analysis:349 batches submitted to accumulate stats from 22336 documents (1340458 virtual)
# INFO:gensim.topic_coherence.text_analysis:350 batches submitted to accumulate stats from 22400 documents (1343139 virtual)
# INFO:gensim.topic_coherence.text_analysis:351 batches submitted to accumulate stats from 22464 documents (1346296 virtual)
# INFO:gensim.topic_coherence.text_analysis:352 batches submitted to accumulate stats from 22528 documents (1351296 virtual)
# INFO:gensim.topic_coherence.text_analysis:353 batches submitted to accumulate stats from 22592 documents (1353854 virtual)
# INFO:gensim.topic_coherence.text_analysis:354 batches submitted to accumulate stats from 22656 documents (1357903 virtual)
# INFO:gensim.topic_coherence.text_analysis:355 batches submitted to accumulate stats from 22720 documents (1360784 virtual)
# INFO:gensim.topic_coherence.text_analysis:356 batches submitted to accumulate stats from 22784 documents (1364912 virtual)
# INFO:gensim.topic_coherence.text_analysis:357 batches submitted to accumulate stats from 22848 documents (1368500 virtual)
# INFO:gensim.topic_coherence.text_analysis:358 batches submitted to accumulate stats from 22912 documents (1371305 virtual)
# INFO:gensim.topic_coherence.text_analysis:359 batches submitted to accumulate stats from 22976 documents (1376469 virtual)
# INFO:gensim.topic_coherence.text_analysis:360 batches submitted to accumulate stats from 23040 documents (1380741 virtual)
# INFO:gensim.topic_coherence.text_analysis:361 batches submitted to accumulate stats from 23104 documents (1385144 virtual)
# INFO:gensim.topic_coherence.text_analysis:362 batches submitted to accumulate stats from 23168 documents (1388917 virtual)
# INFO:gensim.topic_coherence.text_analysis:363 batches submitted to accumulate stats from 23232 documents (1391827 virtual)
# INFO:gensim.topic_coherence.text_analysis:364 batches submitted to accumulate stats from 23296 documents (1394666 virtual)
# INFO:gensim.topic_coherence.text_analysis:365 batches submitted to accumulate stats from 23360 documents (1399310 virtual)
# INFO:gensim.topic_coherence.text_analysis:366 batches submitted to accumulate stats from 23424 documents (1403296 virtual)
# INFO:gensim.topic_coherence.text_analysis:367 batches submitted to accumulate stats from 23488 documents (1405851 virtual)
# INFO:gensim.topic_coherence.text_analysis:368 batches submitted to accumulate stats from 23552 documents (1409190 virtual)
# INFO:gensim.topic_coherence.text_analysis:369 batches submitted to accumulate stats from 23616 documents (1412244 virtual)
# INFO:gensim.topic_coherence.text_analysis:370 batches submitted to accumulate stats from 23680 documents (1414900 virtual)
# INFO:gensim.topic_coherence.text_analysis:371 batches submitted to accumulate stats from 23744 documents (1419699 virtual)
# INFO:gensim.topic_coherence.text_analysis:372 batches submitted to accumulate stats from 23808 documents (1423179 virtual)
# INFO:gensim.topic_coherence.text_analysis:373 batches submitted to accumulate stats from 23872 documents (1425577 virtual)
# INFO:gensim.topic_coherence.text_analysis:374 batches submitted to accumulate stats from 23936 documents (1428533 virtual)
# INFO:gensim.topic_coherence.text_analysis:375 batches submitted to accumulate stats from 24000 documents (1431100 virtual)
# INFO:gensim.topic_coherence.text_analysis:376 batches submitted to accumulate stats from 24064 documents (1434470 virtual)
# INFO:gensim.topic_coherence.text_analysis:377 batches submitted to accumulate stats from 24128 documents (1439028 virtual)
# INFO:gensim.topic_coherence.text_analysis:378 batches submitted to accumulate stats from 24192 documents (1444080 virtual)
# INFO:gensim.topic_coherence.text_analysis:379 batches submitted to accumulate stats from 24256 documents (1448105 virtual)
# INFO:gensim.topic_coherence.text_analysis:380 batches submitted to accumulate stats from 24320 documents (1453451 virtual)
# INFO:gensim.topic_coherence.text_analysis:381 batches submitted to accumulate stats from 24384 documents (1457921 virtual)
# INFO:gensim.topic_coherence.text_analysis:382 batches submitted to accumulate stats from 24448 documents (1461849 virtual)
# INFO:gensim.topic_coherence.text_analysis:383 batches submitted to accumulate stats from 24512 documents (1465799 virtual)
# INFO:gensim.topic_coherence.text_analysis:384 batches submitted to accumulate stats from 24576 documents (1470488 virtual)
# INFO:gensim.topic_coherence.text_analysis:385 batches submitted to accumulate stats from 24640 documents (1475989 virtual)
# INFO:gensim.topic_coherence.text_analysis:386 batches submitted to accumulate stats from 24704 documents (1480621 virtual)
# INFO:gensim.topic_coherence.text_analysis:387 batches submitted to accumulate stats from 24768 documents (1485432 virtual)
# INFO:gensim.topic_coherence.text_analysis:388 batches submitted to accumulate stats from 24832 documents (1489541 virtual)
# INFO:gensim.topic_coherence.text_analysis:389 batches submitted to accumulate stats from 24896 documents (1494877 virtual)
# INFO:gensim.topic_coherence.text_analysis:390 batches submitted to accumulate stats from 24960 documents (1498355 virtual)
# INFO:gensim.topic_coherence.text_analysis:391 batches submitted to accumulate stats from 25024 documents (1503023 virtual)
# INFO:gensim.topic_coherence.text_analysis:392 batches submitted to accumulate stats from 25088 documents (1506782 virtual)
# INFO:gensim.topic_coherence.text_analysis:393 batches submitted to accumulate stats from 25152 documents (1510939 virtual)
# ...
# INFO:gensim.topic_coherence.text_analysis:1708 batches submitted to accumulate stats from 109312 documents (8348737 virtual)
# INFO:gensim.topic_coherence.text_analysis:1709 batches submitted to accumulate stats from 109376 documents (8355166 virtual)
# INFO:gensim.topic_coherence.text_analysis:1710 batches submitted to accumulate stats from 109440 documents (8362107 virtual)
# INFO:gensim.topic_coherence.text_analysis:1711 batches submitted to accumulate stats from 109504 documents (8368401 virtual)
# INFO:gensim.topic_coherence.text_analysis:1712 batches submitted to accumulate stats from 109568 documents (8374529 virtual)
# INFO:gensim.topic_coherence.text_analysis:1713 batches submitted to accumulate stats from 109632 documents (8380603 virtual)
# INFO:gensim.topic_coherence.text_analysis:1714 batches submitted to accumulate stats from 109696 documents (8386556 virtual)
# INFO:gensim.topic_coherence.text_analysis:1715 batches submitted to accumulate stats from 109760 documents (8392528 virtual)
# INFO:gensim.topic_coherence.text_analysis:1716 batches submitted to accumulate stats from 109824 documents (8399088 virtual)
# INFO:gensim.topic_coherence.text_analysis:1717 batches submitted to accumulate stats from 109888 documents (8405888 virtual)
# INFO:gensim.topic_coherence.text_analysis:1718 batches submitted to accumulate stats from 109952 documents (8411720 virtual)
# INFO:gensim.topic_coherence.text_analysis:1719 batches submitted to accumulate stats from 110016 documents (8419125 virtual)
# INFO:gensim.topic_coherence.text_analysis:1720 batches submitted to accumulate stats from 110080 documents (8425394 virtual)
# INFO:gensim.topic_coherence.text_analysis:1721 batches submitted to accumulate stats from 110144 documents (8432777 virtual)
# INFO:gensim.topic_coherence.text_analysis:1722 batches submitted to accumulate stats from 110208 documents (8440195 virtual)
# INFO:gensim.topic_coherence.text_analysis:1723 batches submitted to accumulate stats from 110272 documents (8446478 virtual)
# INFO:gensim.topic_coherence.text_analysis:1724 batches submitted to accumulate stats from 110336 documents (8453276 virtual)
# INFO:gensim.topic_coherence.text_analysis:1725 batches submitted to accumulate stats from 110400 documents (8459458 virtual)
# INFO:gensim.topic_coherence.text_analysis:1726 batches submitted to accumulate stats from 110464 documents (8466685 virtual)
# INFO:gensim.topic_coherence.text_analysis:1727 batches submitted to accumulate stats from 110528 documents (8474383 virtual)
# INFO:gensim.topic_coherence.text_analysis:1728 batches submitted to accumulate stats from 110592 documents (8481381 virtual)
# INFO:gensim.topic_coherence.text_analysis:1729 batches submitted to accumulate stats from 110656 documents (8488495 virtual)
# INFO:gensim.topic_coherence.text_analysis:1730 batches submitted to accumulate stats from 110720 documents (8494955 virtual)
# INFO:gensim.topic_coherence.text_analysis:1731 batches submitted to accumulate stats from 110784 documents (8501110 virtual)
# INFO:gensim.topic_coherence.text_analysis:1732 batches submitted to accumulate stats from 110848 documents (8508007 virtual)
# INFO:gensim.topic_coherence.text_analysis:1733 batches submitted to accumulate stats from 110912 documents (8516306 virtual)
# INFO:gensim.topic_coherence.text_analysis:1734 batches submitted to accumulate stats from 110976 documents (8523644 virtual)
# INFO:gensim.topic_coherence.text_analysis:1735 batches submitted to accumulate stats from 111040 documents (8529792 virtual)
# INFO:gensim.topic_coherence.text_analysis:1736 batches submitted to accumulate stats from 111104 documents (8536283 virtual)
# INFO:gensim.topic_coherence.text_analysis:1737 batches submitted to accumulate stats from 111168 documents (8543836 virtual)
# INFO:gensim.topic_coherence.text_analysis:1738 batches submitted to accumulate stats from 111232 documents (8550831 virtual)
# INFO:gensim.topic_coherence.text_analysis:1739 batches submitted to accumulate stats from 111296 documents (8557860 virtual)
# INFO:gensim.topic_coherence.text_analysis:1740 batches submitted to accumulate stats from 111360 documents (8564034 virtual)
# INFO:gensim.topic_coherence.text_analysis:1741 batches submitted to accumulate stats from 111424 documents (8571200 virtual)
# INFO:gensim.topic_coherence.text_analysis:1742 batches submitted to accumulate stats from 111488 documents (8577177 virtual)
# INFO:gensim.topic_coherence.text_analysis:1743 batches submitted to accumulate stats from 111552 documents (8583815 virtual)
# INFO:gensim.topic_coherence.text_analysis:1744 batches submitted to accumulate stats from 111616 documents (8589684 virtual)
# INFO:gensim.topic_coherence.text_analysis:1745 batches submitted to accumulate stats from 111680 documents (8595411 virtual)
# INFO:gensim.topic_coherence.text_analysis:1746 batches submitted to accumulate stats from 111744 documents (8602239 virtual)
# INFO:gensim.topic_coherence.text_analysis:1747 batches submitted to accumulate stats from 111808 documents (8609532 virtual)
# INFO:gensim.topic_coherence.text_analysis:1748 batches submitted to accumulate stats from 111872 documents (8615596 virtual)
# INFO:gensim.topic_coherence.text_analysis:1749 batches submitted to accumulate stats from 111936 documents (8620792 virtual)
# INFO:gensim.topic_coherence.text_analysis:1750 batches submitted to accumulate stats from 112000 documents (8626712 virtual)
# INFO:gensim.topic_coherence.text_analysis:1751 batches submitted to accumulate stats from 112064 documents (8632640 virtual)
# INFO:gensim.topic_coherence.text_analysis:1752 batches submitted to accumulate stats from 112128 documents (8639015 virtual)
# INFO:gensim.topic_coherence.text_analysis:1753 batches submitted to accumulate stats from 112192 documents (8644616 virtual)
# INFO:gensim.topic_coherence.text_analysis:1754 batches submitted to accumulate stats from 112256 documents (8651066 virtual)
# INFO:gensim.topic_coherence.text_analysis:1755 batches submitted to accumulate stats from 112320 documents (8656846 virtual)
# INFO:gensim.topic_coherence.text_analysis:1756 batches submitted to accumulate stats from 112384 documents (8662754 virtual)
# INFO:gensim.topic_coherence.text_analysis:1757 batches submitted to accumulate stats from 112448 documents (8667767 virtual)
# INFO:gensim.topic_coherence.text_analysis:1758 batches submitted to accumulate stats from 112512 documents (8674667 virtual)
# INFO:gensim.topic_coherence.text_analysis:1759 batches submitted to accumulate stats from 112576 documents (8680414 virtual)
# INFO:gensim.topic_coherence.text_analysis:1760 batches submitted to accumulate stats from 112640 documents (8686727 virtual)
# INFO:gensim.topic_coherence.text_analysis:1761 batches submitted to accumulate stats from 112704 documents (8692783 virtual)
# INFO:gensim.topic_coherence.text_analysis:1762 batches submitted to accumulate stats from 112768 documents (8698661 virtual)
# INFO:gensim.topic_coherence.text_analysis:1763 batches submitted to accumulate stats from 112832 documents (8703972 virtual)
# INFO:gensim.topic_coherence.text_analysis:1764 batches submitted to accumulate stats from 112896 documents (8709795 virtual)
# INFO:gensim.topic_coherence.text_analysis:1765 batches submitted to accumulate stats from 112960 documents (8717331 virtual)
# INFO:gensim.topic_coherence.text_analysis:1766 batches submitted to accumulate stats from 113024 documents (8722911 virtual)
# INFO:gensim.topic_coherence.text_analysis:1767 batches submitted to accumulate stats from 113088 documents (8729981 virtual)
# INFO:gensim.topic_coherence.text_analysis:1768 batches submitted to accumulate stats from 113152 documents (8735803 virtual)
# INFO:gensim.topic_coherence.text_analysis:1769 batches submitted to accumulate stats from 113216 documents (8741940 virtual)
# INFO:gensim.topic_coherence.text_analysis:1770 batches submitted to accumulate stats from 113280 documents (8748268 virtual)
# INFO:gensim.topic_coherence.text_analysis:1771 batches submitted to accumulate stats from 113344 documents (8753326 virtual)
# INFO:gensim.topic_coherence.text_analysis:1772 batches submitted to accumulate stats from 113408 documents (8759839 virtual)
# INFO:gensim.topic_coherence.text_analysis:1773 batches submitted to accumulate stats from 113472 documents (8765754 virtual)
# INFO:gensim.topic_coherence.text_analysis:1774 batches submitted to accumulate stats from 113536 documents (8770398 virtual)
# INFO:gensim.topic_coherence.text_analysis:1775 batches submitted to accumulate stats from 113600 documents (8775408 virtual)
# INFO:gensim.topic_coherence.text_analysis:1776 batches submitted to accumulate stats from 113664 documents (8780787 virtual)
# INFO:gensim.topic_coherence.text_analysis:1777 batches submitted to accumulate stats from 113728 documents (8788818 virtual)
# INFO:gensim.topic_coherence.text_analysis:1778 batches submitted to accumulate stats from 113792 documents (8795356 virtual)
# INFO:gensim.topic_coherence.text_analysis:1779 batches submitted to accumulate stats from 113856 documents (8800911 virtual)
# INFO:gensim.topic_coherence.text_analysis:1780 batches submitted to accumulate stats from 113920 documents (8807928 virtual)
# INFO:gensim.topic_coherence.text_analysis:1781 batches submitted to accumulate stats from 113984 documents (8814214 virtual)
# INFO:gensim.topic_coherence.text_analysis:1782 batches submitted to accumulate stats from 114048 documents (8816791 virtual)
# INFO:gensim.topic_coherence.text_analysis:1783 batches submitted to accumulate stats from 114112 documents (8821279 virtual)
# INFO:gensim.topic_coherence.text_analysis:1784 batches submitted to accumulate stats from 114176 documents (8826838 virtual)
# INFO:gensim.topic_coherence.text_analysis:1785 batches submitted to accumulate stats from 114240 documents (8832540 virtual)
# INFO:gensim.topic_coherence.text_analysis:1786 batches submitted to accumulate stats from 114304 documents (8838274 virtual)
# INFO:gensim.topic_coherence.text_analysis:1787 batches submitted to accumulate stats from 114368 documents (8844781 virtual)
# INFO:gensim.topic_coherence.text_analysis:1788 batches submitted to accumulate stats from 114432 documents (8851693 virtual)
# INFO:gensim.topic_coherence.text_analysis:1789 batches submitted to accumulate stats from 114496 documents (8858484 virtual)
# INFO:gensim.topic_coherence.text_analysis:1790 batches submitted to accumulate stats from 114560 documents (8864654 virtual)
# INFO:gensim.topic_coherence.text_analysis:1791 batches submitted to accumulate stats from 114624 documents (8868930 virtual)
# INFO:gensim.topic_coherence.text_analysis:1792 batches submitted to accumulate stats from 114688 documents (8874798 virtual)
# INFO:gensim.topic_coherence.text_analysis:1793 batches submitted to accumulate stats from 114752 documents (8881265 virtual)
# INFO:gensim.topic_coherence.text_analysis:1794 batches submitted to accumulate stats from 114816 documents (8886755 virtual)
# INFO:gensim.topic_coherence.text_analysis:1795 batches submitted to accumulate stats from 114880 documents (8892742 virtual)
# INFO:gensim.topic_coherence.text_analysis:1796 batches submitted to accumulate stats from 114944 documents (8898374 virtual)
# INFO:gensim.topic_coherence.text_analysis:1797 batches submitted to accumulate stats from 115008 documents (8905050 virtual)
# INFO:gensim.topic_coherence.text_analysis:1798 batches submitted to accumulate stats from 115072 documents (8911081 virtual)
# INFO:gensim.topic_coherence.text_analysis:1799 batches submitted to accumulate stats from 115136 documents (8916162 virtual)
# INFO:gensim.topic_coherence.text_analysis:1800 batches submitted to accumulate stats from 115200 documents (8921870 virtual)
# INFO:gensim.topic_coherence.text_analysis:1801 batches submitted to accumulate stats from 115264 documents (8927453 virtual)
# INFO:gensim.topic_coherence.text_analysis:1802 batches submitted to accumulate stats from 115328 documents (8933599 virtual)
# INFO:gensim.topic_coherence.text_analysis:1803 batches submitted to accumulate stats from 115392 documents (8939498 virtual)
# INFO:gensim.topic_coherence.text_analysis:1804 batches submitted to accumulate stats from 115456 documents (8945366 virtual)
# INFO:gensim.topic_coherence.text_analysis:1805 batches submitted to accumulate stats from 115520 documents (8951824 virtual)
# INFO:gensim.topic_coherence.text_analysis:1806 batches submitted to accumulate stats from 115584 documents (8958346 virtual)
# INFO:gensim.topic_coherence.text_analysis:1807 batches submitted to accumulate stats from 115648 documents (8963843 virtual)
# INFO:gensim.topic_coherence.text_analysis:1808 batches submitted to accumulate stats from 115712 documents (8968745 virtual)
# INFO:gensim.topic_coherence.text_analysis:1809 batches submitted to accumulate stats from 115776 documents (8974460 virtual)
# INFO:gensim.topic_coherence.text_analysis:1810 batches submitted to accumulate stats from 115840 documents (8979433 virtual)
# INFO:gensim.topic_coherence.text_analysis:1811 batches submitted to accumulate stats from 115904 documents (8985472 virtual)
# INFO:gensim.topic_coherence.text_analysis:1812 batches submitted to accumulate stats from 115968 documents (8990587 virtual)
# INFO:gensim.topic_coherence.text_analysis:1813 batches submitted to accumulate stats from 116032 documents (8996302 virtual)
# INFO:gensim.topic_coherence.text_analysis:1814 batches submitted to accumulate stats from 116096 documents (9002456 virtual)
# INFO:gensim.topic_coherence.text_analysis:1815 batches submitted to accumulate stats from 116160 documents (9008620 virtual)
# INFO:gensim.topic_coherence.text_analysis:1816 batches submitted to accumulate stats from 116224 documents (9013934 virtual)
# INFO:gensim.topic_coherence.text_analysis:1817 batches submitted to accumulate stats from 116288 documents (9018741 virtual)
# INFO:gensim.topic_coherence.text_analysis:1818 batches submitted to accumulate stats from 116352 documents (9024525 virtual)
# INFO:gensim.topic_coherence.text_analysis:1819 batches submitted to accumulate stats from 116416 documents (9030220 virtual)
# INFO:gensim.topic_coherence.text_analysis:1820 batches submitted to accumulate stats from 116480 documents (9034886 virtual)
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:10 accumulators retrieved from output queue
# INFO:gensim.topic_coherence.text_analysis:accumulated word occurrence stats for 9387958 virtual documents
# 0.5645480538470938

# %%
Glda_tc = cm.get_coherence_per_topic(with_std=True)

# %%
Glda_tc
# Out:
# [(0.7549215045123805, 0.10398905206062324),
#  (0.45665844527149596, 0.09649487657780381),
#  (0.5219731112740217, 0.1290153169186546),
#  (0.5269226726706037, 0.21633106146605002),
#  (0.7118582123410425, 0.09143509252805795),
#  (0.5291958258278945, 0.2327568838267143),
#  (0.4398362663597736, 0.08188502245901781),
#  (0.5935920241302689, 0.18129853997045398),
#  (0.5206423834177739, 0.1289478139481448),
#  (0.5460067123668926, 0.14731895347687196),
#  (0.6186104039562084, 0.18650536824445887),
#  (0.5279692364385312, 0.17606494823983257),
#  (0.45684240845793056, 0.05821801654327013),
#  (0.5050122782742061, 0.14832062777042856),
#  (0.49239667287986116, 0.1502489272583559),
#  (0.6543605392527478, 0.1629278384212371),
#  (0.6519106248441643, 0.13074402548556677),
#  (0.6236047917783848, 0.24400563439338963),
#  (0.5472984510553086, 0.09885931722675327),
#  (0.6195292204918832, 0.23657976439381984),
#  (0.6014147271570413, 0.14876048626620836),
#  (0.6353195740488109, 0.1728444496144985),
#  (0.6282759852068465, 0.14115456826938197),
#  (0.5291778352359593, 0.1453425248439096),
#  (0.4790800157965722, 0.10520063997258976),
#  (0.5226419555532897, 0.22446622497504568),
#  (0.5988381871961553, 0.21160462533335198),
#  (0.5447817859553364, 0.06160995976263101),
#  (0.4996300359022075, 0.16326486101495552),
#  (0.47875635098235253, 0.13692087284419205),
#  (0.5563248658045497, 0.14894688256230687),
#  (0.4488935334829539, 0.10188004490242047),
#  (0.5085003188496466, 0.1532528228637914),
#  (0.5700129840266565, 0.1932577763843059),
#  (0.5376275644206974, 0.13532200503519848),
#  (0.6397226847842785, 0.1363854147715631),
#  (0.6402337739921442, 0.23729537872881293),
#  (0.6736574922682208, 0.09908222902385257),
#  (0.690243589032169, 0.1596326530668753),
#  (0.49750909067712296, 0.21961952769787874),
#  (0.6319322167974528, 0.29572083474417815),
#  (0.5663928472890348, 0.12835006456371903),
#  (0.633037283781545, 0.17328825752351468),
#  (0.5638306167814701, 0.10663351592182017),
#  (0.6471316076189197, 0.20533288141575695),
#  (0.48000643026974926, 0.140446964311701),
#  (0.48154707605582026, 0.1087968845727104),
#  (0.5432881415046473, 0.13038271455252354),
#  (0.5605659386702687, 0.10747932987100468),
#  (0.5398863976113966, 0.18410749590854467)]

# %%
pyLDAvis.enable_notebook()

vis = pyLDAvis.sklearn.prepare(Glda_model, doc_term_matrix, vectorizer, n_jobs=10)
# Out:
# /sfs/qumulo/qhome/kjl5t/GuidedLDA/guidedlda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-46c2696b23cc> in <module>
#       1 pyLDAvis.enable_notebook()
#       2
# ----> 3 vis = pyLDAvis.sklearn.prepare(Glda_model, doc_term_matrix, vectorizer, n_jobs=10)
#
# ~/.local/lib/python3.7/site-packages/pyLDAvis/sklearn.py in prepare(lda_model, dtm, vectorizer, **kwargs)
#      92     See `pyLDAvis.prepare` for **kwargs.
#      93     """
# ---> 94     opts = fp.merge(_extract_data(lda_model, dtm, vectorizer), kwargs)
#      95     return pyLDAvis.prepare(**opts)
#
# ~/.local/lib/python3.7/site-packages/pyLDAvis/sklearn.py in _extract_data(lda_model, dtm, vectorizer)
#      51     # column dimensions of document-term matrix and topic-term distributions
#      52     # must match first before transforming to document-topic distributions
# ---> 53     doc_topic_dists = _get_doc_topic_dists(lda_model, dtm)
#      54
#      55     return {'vocab': vocab,
#
# ~/.local/lib/python3.7/site-packages/pyLDAvis/sklearn.py in _get_doc_topic_dists(lda_model, dtm)
#      28
#      29 def _get_doc_topic_dists(lda_model, dtm):
# ---> 30     return _row_norm(lda_model.transform(dtm))
#      31
#      32
#
# /sfs/qumulo/qhome/kjl5t/GuidedLDA/guidedlda/guidedlda.py in transform(self, X, max_iter, tol)
#     186         # TODO: this loop is parallelizable
#     187         for d in np.unique(DS):
# --> 188             doc_topic[d] = self._transform_single(WS[DS == d], max_iter, tol)
#     189         return doc_topic
#     190
#
# KeyboardInterrupt:

# %%
pyLDAvis.display(vis)
