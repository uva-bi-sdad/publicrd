# %% [markdown]
# # Text Preprocessing for use with Topic Models
#
# The text has already been cleaned.  This script will preprocess it - tokenize, remove stop words, add bigrams and trigrams, lemmatize.

# %%
import pandas as pd
import pickle
import nltk
import numpy as np
import time

import stanza
import gensim
import re
import spacy

import TextCleaning
import LDAvariables

# %% [markdown]
# ### Read in Cleaned Dataset

# %%
# load saved df.  df['working_abstract'] contains clean text.
df = pd.read_pickle("../../data/working/clean_dataset.pkl")
df.reset_index(inplace = True)
df.rename(columns={'index':'original index'}, inplace=True)

wa='working_abstract'

# %%
df.head()
# Out:
#    original index  PROJECT_ID  \
# 0               0       89996
# 1               1       89997
# 2               2       89998
# 3               3       89999
# 4               4       90000
#
#                                             ABSTRACT    FY  \
# 0  This is a project to explore Game-based, Metap...  2008
# 1  Institution: Franklin Institute Science Museum...  2008
# 2  Through programs (including small group conver...  2008
# 3  In partnership with the American Chemical Soci...  2008
# 4  Amphibian populations around the world are exp...  2008
#
#                                           FIRST_CHAR LAST_CHAR DEPARTMENT  \
# 0  This is a project to explore Game-based, Metap...         .        NSF
# 1  Institution: Franklin Institute Science Museum...         .        NSF
# 2  Through programs (including small group conver...         .        NSF
# 3  In partnership with the American Chemical Soci...         .        NSF
# 4  Amphibian populations around the world are exp...         .        NSF
#
#   AGENCY IC_CENTER PROJECT_NUMBER  ...  \
# 0    NSF       NaN        0814512  ...
# 1    NSF       NaN        0741659  ...
# 2    NSF       NaN        0813522  ...
# 3    NSF       NaN        0838627  ...
# 4    NSF       NaN        0815315  ...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Amphibia; Central America; Communicable Diseas...
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ZAMUDIO, KELLY R                                        NaN
#
#                                    ORGANIZATION_NAME CFDA_CODE FY_TOTAL_COST  \
# 0                         WHEELING JESUIT UNIVERSITY    47.076     1999467.0
# 1                                 FRANKLIN INSTITUTE    47.076     1799699.0
# 2                        SCIENCE MUSEUM OF MINNESOTA    47.076     1505858.0
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY    47.049       51000.0
# 4                          CORNELL UNIVERSITY ITHACA    47.074      370996.0
#
#                                     working_abstract nchar  Start Char  \
# 0  This is a project to explore Game-based, Metap...  2057           T
# 1  Institution:  Science Museum PI: Snyder, Steve...  1913           I
# 2  Through programs (including small group conver...  1154           T
# 3  In partnership with the American Chemical Soci...   826           I
# 4  Amphibian populations around the world are exp...  1322           A
#
#   Field Count
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Tokenize

# %%
spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-e302eb2ab33d> in <module>
# ----> 1 spacy.load("en_core_web_sm")
#
# ~/.local/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# ~/.local/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     167     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     168         return load_model_from_path(name, **overrides)
# --> 169     raise IOError(Errors.E050.format(name=name))
#     170
#     171
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
nlp = stanza.Pipeline(lang = 'en', processors = {'tokenize': 'spacy'})
# Out:
# 2020-07-15 22:19:30 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | spacy     |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | ner       | ontonotes |
# =========================
#
# 2020-07-15 22:19:30 INFO: Use device: cpu
# 2020-07-15 22:19:30 INFO: Loading: tokenize
# 2020-07-15 22:19:30 INFO: Using spaCy as tokenizer
# 2020-07-15 22:19:30 INFO: Loading: pos
# 2020-07-15 22:19:30 INFO: Loading: lemma
# 2020-07-15 22:19:30 INFO: Loading: depparse
# 2020-07-15 22:19:31 INFO: Loading: ner
# 2020-07-15 22:19:32 INFO: Done loading processors!

# %%
t1 = time.time()
nlp(df[wa][5])
t2 = time.time()

print(f"time: {t2-t1}")
# Out:
# time: 0.70782470703125

# %%
nlp(df[wa][0])
# Out:
# [
#   [
#     {
#       "id": "1",
#       "text": "This",
#       "lemma": "this",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 4,
#       "deprel": "nsubj",
#       "misc": "start_char=0|end_char=4"
#     },
#     {
#       "id": "2",
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "cop",
#       "misc": "start_char=5|end_char=7"
#     },
#     {
#       "id": "3",
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 4,
#       "deprel": "det",
#       "misc": "start_char=8|end_char=9"
#     },
#     {
#       "id": "4",
#       "text": "project",
#       "lemma": "project",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=10|end_char=17"
#     },
#     {
#       "id": "5",
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "head": 6,
#       "deprel": "mark",
#       "misc": "start_char=18|end_char=20"
#     },
#     {
#       "id": "6",
#       "text": "explore",
#       "lemma": "explore",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 4,
#       "deprel": "acl",
#       "misc": "start_char=21|end_char=28"
#     },
#     {
#       "id": "7",
#       "text": "Game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 9,
#       "deprel": "obl:npmod",
#       "misc": "start_char=29|end_char=33"
#     },
#     {
#       "id": "8",
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 9,
#       "deprel": "punct",
#       "misc": "start_char=33|end_char=34"
#     },
#     {
#       "id": "9",
#       "text": "based",
#       "lemma": "base",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 16,
#       "deprel": "amod",
#       "misc": "start_char=34|end_char=39"
#     },
#     {
#       "id": "10",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 12,
#       "deprel": "punct",
#       "misc": "start_char=39|end_char=40"
#     },
#     {
#       "id": "11",
#       "text": "Metaphor",
#       "lemma": "metaphor",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 12,
#       "deprel": "compound",
#       "misc": "start_char=41|end_char=49"
#     },
#     {
#       "id": "12",
#       "text": "Enhanced",
#       "lemma": "enhance",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 16,
#       "deprel": "amod",
#       "misc": "start_char=50|end_char=58"
#     },
#     {
#       "id": "13",
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=59|end_char=60"
#     },
#     {
#       "id": "14",
#       "text": "GaME",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 16,
#       "deprel": "compound",
#       "misc": "start_char=60|end_char=64"
#     },
#     {
#       "id": "15",
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=64|end_char=65"
#     },
#     {
#       "id": "16",
#       "text": "design",
#       "lemma": "design",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "obj",
#       "misc": "start_char=66|end_char=72"
#     },
#     {
#       "id": "17",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 4,
#       "deprel": "punct",
#       "misc": "start_char=72|end_char=73"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "GaME",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "nsubj",
#       "misc": "start_char=74|end_char=78"
#     },
#     {
#       "id": "2",
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "cop",
#       "misc": "start_char=79|end_char=81"
#     },
#     {
#       "id": "3",
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 4,
#       "deprel": "det",
#       "misc": "start_char=82|end_char=83"
#     },
#     {
#       "id": "4",
#       "text": "method",
#       "lemma": "method",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=84|end_char=90"
#     },
#     {
#       "id": "5",
#       "text": "for",
#       "lemma": "for",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "head": 6,
#       "deprel": "mark",
#       "misc": "start_char=91|end_char=94"
#     },
#     {
#       "id": "6",
#       "text": "applying",
#       "lemma": "apply",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 4,
#       "deprel": "acl",
#       "misc": "start_char=95|end_char=103"
#     },
#     {
#       "id": "7",
#       "text": "cognitive",
#       "lemma": "cognitive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 10,
#       "deprel": "amod",
#       "misc": "start_char=104|end_char=113"
#     },
#     {
#       "id": "8",
#       "text": "science",
#       "lemma": "science",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 9,
#       "deprel": "compound",
#       "misc": "start_char=114|end_char=121"
#     },
#     {
#       "id": "9",
#       "text": "metaphor",
#       "lemma": "metaphor",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "compound",
#       "misc": "start_char=122|end_char=130"
#     },
#     {
#       "id": "10",
#       "text": "theory",
#       "lemma": "theory",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "obj",
#       "misc": "start_char=131|end_char=137"
#     },
#     {
#       "id": "11",
#       "text": "toward",
#       "lemma": "toward",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 13,
#       "deprel": "case",
#       "misc": "start_char=138|end_char=144"
#     },
#     {
#       "id": "12",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 13,
#       "deprel": "det",
#       "misc": "start_char=145|end_char=148"
#     },
#     {
#       "id": "13",
#       "text": "design",
#       "lemma": "design",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "obl",
#       "misc": "start_char=149|end_char=155"
#     },
#     {
#       "id": "14",
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 19,
#       "deprel": "case",
#       "misc": "start_char=156|end_char=158"
#     },
#     {
#       "id": "15",
#       "text": "computer",
#       "lemma": "computer",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 17,
#       "deprel": "compound",
#       "misc": "start_char=159|end_char=167"
#     },
#     {
#       "id": "16",
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 17,
#       "deprel": "punct",
#       "misc": "start_char=167|end_char=168"
#     },
#     {
#       "id": "17",
#       "text": "mediated",
#       "lemma": "mediate",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 19,
#       "deprel": "amod",
#       "misc": "start_char=168|end_char=176"
#     },
#     {
#       "id": "18",
#       "text": "learning",
#       "lemma": "learning",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 19,
#       "deprel": "compound",
#       "misc": "start_char=177|end_char=185"
#     },
#     {
#       "id": "19",
#       "text": "environments",
#       "lemma": "environment",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 13,
#       "deprel": "nmod",
#       "misc": "start_char=186|end_char=198"
#     },
#     {
#       "id": "20",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 4,
#       "deprel": "punct",
#       "misc": "start_char=198|end_char=199"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "The",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=200|end_char=203"
#     },
#     {
#       "id": "2",
#       "text": "process",
#       "lemma": "process",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "nsubj",
#       "misc": "start_char=204|end_char=211"
#     },
#     {
#       "id": "3",
#       "text": "uses",
#       "lemma": "use",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=212|end_char=216"
#     },
#     {
#       "id": "4",
#       "text": "structure",
#       "lemma": "structure",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "compound",
#       "misc": "start_char=217|end_char=226"
#     },
#     {
#       "id": "5",
#       "text": "mapping",
#       "lemma": "mapping",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "compound",
#       "misc": "start_char=227|end_char=234"
#     },
#     {
#       "id": "6",
#       "text": "theory",
#       "lemma": "theory",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "obj",
#       "misc": "start_char=235|end_char=241"
#     },
#     {
#       "id": "7",
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "head": 8,
#       "deprel": "mark",
#       "misc": "start_char=242|end_char=244"
#     },
#     {
#       "id": "8",
#       "text": "design",
#       "lemma": "design",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 3,
#       "deprel": "advcl",
#       "misc": "start_char=245|end_char=251"
#     },
#     {
#       "id": "9",
#       "text": "videogame",
#       "lemma": "videogame",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "compound",
#       "misc": "start_char=252|end_char=261"
#     },
#     {
#       "id": "10",
#       "text": "worlds",
#       "lemma": "world",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 8,
#       "deprel": "obj",
#       "misc": "start_char=262|end_char=268"
#     },
#     {
#       "id": "11",
#       "text": "aligned",
#       "lemma": "align",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 10,
#       "deprel": "acl",
#       "misc": "start_char=269|end_char=276"
#     },
#     {
#       "id": "12",
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 14,
#       "deprel": "case",
#       "misc": "start_char=277|end_char=281"
#     },
#     {
#       "id": "13",
#       "text": "science",
#       "lemma": "science",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 14,
#       "deprel": "compound",
#       "misc": "start_char=282|end_char=289"
#     },
#     {
#       "id": "14",
#       "text": "concepts",
#       "lemma": "concept",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 11,
#       "deprel": "obl",
#       "misc": "start_char=290|end_char=298"
#     },
#     {
#       "id": "15",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 3,
#       "deprel": "punct",
#       "misc": "start_char=298|end_char=299"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "This",
#       "lemma": "this",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 6,
#       "deprel": "nsubj",
#       "misc": "start_char=300|end_char=304"
#     },
#     {
#       "id": "2",
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 6,
#       "deprel": "cop",
#       "misc": "start_char=305|end_char=307"
#     },
#     {
#       "id": "3",
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=308|end_char=309"
#     },
#     {
#       "id": "4",
#       "text": "rigorous",
#       "lemma": "rigorous",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 6,
#       "deprel": "amod",
#       "misc": "start_char=310|end_char=318"
#     },
#     {
#       "id": "5",
#       "text": "specification",
#       "lemma": "specification",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "compound",
#       "misc": "start_char=319|end_char=332"
#     },
#     {
#       "id": "6",
#       "text": "procedure",
#       "lemma": "procedure",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=333|end_char=342"
#     },
#     {
#       "id": "7",
#       "text": "for",
#       "lemma": "for",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "head": 8,
#       "deprel": "mark",
#       "misc": "start_char=343|end_char=346"
#     },
#     {
#       "id": "8",
#       "text": "mapping",
#       "lemma": "map",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 6,
#       "deprel": "acl",
#       "misc": "start_char=347|end_char=354"
#     },
#     {
#       "id": "9",
#       "text": "relational",
#       "lemma": "relational",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 10,
#       "deprel": "amod",
#       "misc": "start_char=355|end_char=365"
#     },
#     {
#       "id": "10",
#       "text": "structure",
#       "lemma": "structure",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "obj",
#       "misc": "start_char=366|end_char=375"
#     },
#     {
#       "id": "11",
#       "text": "from",
#       "lemma": "from",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 13,
#       "deprel": "case",
#       "misc": "start_char=376|end_char=380"
#     },
#     {
#       "id": "12",
#       "text": "targeted",
#       "lemma": "target",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 13,
#       "deprel": "amod",
#       "misc": "start_char=381|end_char=389"
#     },
#     {
#       "id": "13",
#       "text": "concept",
#       "lemma": "concept",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "obl",
#       "misc": "start_char=390|end_char=397"
#     },
#     {
#       "id": "14",
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 16,
#       "deprel": "case",
#       "misc": "start_char=398|end_char=400"
#     },
#     {
#       "id": "15",
#       "text": "game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 16,
#       "deprel": "compound",
#       "misc": "start_char=401|end_char=405"
#     },
#     {
#       "id": "16",
#       "text": "world",
#       "lemma": "world",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "nmod",
#       "misc": "start_char=406|end_char=411"
#     },
#     {
#       "id": "17",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 6,
#       "deprel": "punct",
#       "misc": "start_char=411|end_char=412"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "GaME",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 2,
#       "deprel": "compound",
#       "misc": "start_char=413|end_char=417"
#     },
#     {
#       "id": "2",
#       "text": "design",
#       "lemma": "design",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "nsubj",
#       "misc": "start_char=418|end_char=424"
#     },
#     {
#       "id": "3",
#       "text": "translates",
#       "lemma": "translate",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=425|end_char=435"
#     },
#     {
#       "id": "4",
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=436|end_char=437"
#     },
#     {
#       "id": "5",
#       "text": "targeted",
#       "lemma": "target",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 6,
#       "deprel": "amod",
#       "misc": "start_char=438|end_char=446"
#     },
#     {
#       "id": "6",
#       "text": "concept",
#       "lemma": "concept",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "obj",
#       "misc": "start_char=447|end_char=454"
#     },
#     {
#       "id": "7",
#       "text": "into",
#       "lemma": "into",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 10,
#       "deprel": "case",
#       "misc": "start_char=455|end_char=459"
#     },
#     {
#       "id": "8",
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 10,
#       "deprel": "det",
#       "misc": "start_char=460|end_char=461"
#     },
#     {
#       "id": "9",
#       "text": "game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "compound",
#       "misc": "start_char=462|end_char=466"
#     },
#     {
#       "id": "10",
#       "text": "system",
#       "lemma": "system",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "obl",
#       "misc": "start_char=467|end_char=473"
#     },
#     {
#       "id": "11",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 13,
#       "deprel": "punct",
#       "misc": "start_char=473|end_char=474"
#     },
#     {
#       "id": "12",
#       "text": "game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "compound",
#       "misc": "start_char=475|end_char=479"
#     },
#     {
#       "id": "13",
#       "text": "play",
#       "lemma": "play",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "conj",
#       "misc": "start_char=480|end_char=484"
#     },
#     {
#       "id": "14",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 17,
#       "deprel": "punct",
#       "misc": "start_char=484|end_char=485"
#     },
#     {
#       "id": "15",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 17,
#       "deprel": "cc",
#       "misc": "start_char=486|end_char=489"
#     },
#     {
#       "id": "16",
#       "text": "game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 17,
#       "deprel": "compound",
#       "misc": "start_char=490|end_char=494"
#     },
#     {
#       "id": "17",
#       "text": "goal",
#       "lemma": "goal",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "conj",
#       "misc": "start_char=495|end_char=499"
#     },
#     {
#       "id": "18",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 3,
#       "deprel": "punct",
#       "misc": "start_char=499|end_char=500"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "Because",
#       "lemma": "because",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "head": 10,
#       "deprel": "mark",
#       "misc": "start_char=501|end_char=508"
#     },
#     {
#       "id": "2",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 4,
#       "deprel": "det",
#       "misc": "start_char=509|end_char=512"
#     },
#     {
#       "id": "3",
#       "text": "relational",
#       "lemma": "relational",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 4,
#       "deprel": "amod",
#       "misc": "start_char=513|end_char=523"
#     },
#     {
#       "id": "4",
#       "text": "structure",
#       "lemma": "structure",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=524|end_char=533"
#     },
#     {
#       "id": "5",
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 8,
#       "deprel": "case",
#       "misc": "start_char=534|end_char=536"
#     },
#     {
#       "id": "6",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 8,
#       "deprel": "det",
#       "misc": "start_char=537|end_char=540"
#     },
#     {
#       "id": "7",
#       "text": "game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "compound",
#       "misc": "start_char=541|end_char=545"
#     },
#     {
#       "id": "8",
#       "text": "world",
#       "lemma": "world",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "nmod",
#       "misc": "start_char=546|end_char=551"
#     },
#     {
#       "id": "9",
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 10,
#       "deprel": "aux:pass",
#       "misc": "start_char=552|end_char=554"
#     },
#     {
#       "id": "10",
#       "text": "designed",
#       "lemma": "design",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 21,
#       "deprel": "advcl",
#       "misc": "start_char=555|end_char=563"
#     },
#     {
#       "id": "11",
#       "text": "as",
#       "lemma": "as",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 13,
#       "deprel": "case",
#       "misc": "start_char=564|end_char=566"
#     },
#     {
#       "id": "12",
#       "text": "an",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 13,
#       "deprel": "det",
#       "misc": "start_char=567|end_char=569"
#     },
#     {
#       "id": "13",
#       "text": "analog",
#       "lemma": "analog",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "obl",
#       "misc": "start_char=570|end_char=576"
#     },
#     {
#       "id": "14",
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 18,
#       "deprel": "case",
#       "misc": "start_char=577|end_char=579"
#     },
#     {
#       "id": "15",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 18,
#       "deprel": "det",
#       "misc": "start_char=580|end_char=583"
#     },
#     {
#       "id": "16",
#       "text": "targeted",
#       "lemma": "target",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 18,
#       "deprel": "amod",
#       "misc": "start_char=584|end_char=592"
#     },
#     {
#       "id": "17",
#       "text": "conceptual",
#       "lemma": "conceptual",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 18,
#       "deprel": "amod",
#       "misc": "start_char=593|end_char=603"
#     },
#     {
#       "id": "18",
#       "text": "domain",
#       "lemma": "domain",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "nmod",
#       "misc": "start_char=604|end_char=610"
#     },
#     {
#       "id": "19",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 21,
#       "deprel": "punct",
#       "misc": "start_char=610|end_char=611"
#     },
#     {
#       "id": "20",
#       "text": "players",
#       "lemma": "player",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 21,
#       "deprel": "nsubj",
#       "misc": "start_char=612|end_char=619"
#     },
#     {
#       "id": "21",
#       "text": "begin",
#       "lemma": "begin",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=620|end_char=625"
#     },
#     {
#       "id": "22",
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "head": 23,
#       "deprel": "mark",
#       "misc": "start_char=626|end_char=628"
#     },
#     {
#       "id": "23",
#       "text": "construct",
#       "lemma": "construct",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 21,
#       "deprel": "xcomp",
#       "misc": "start_char=629|end_char=638"
#     },
#     {
#       "id": "24",
#       "text": "mental",
#       "lemma": "mental",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 25,
#       "deprel": "amod",
#       "misc": "start_char=639|end_char=645"
#     },
#     {
#       "id": "25",
#       "text": "models",
#       "lemma": "model",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 23,
#       "deprel": "obj",
#       "misc": "start_char=646|end_char=652"
#     },
#     {
#       "id": "26",
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 29,
#       "deprel": "case",
#       "misc": "start_char=653|end_char=655"
#     },
#     {
#       "id": "27",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 29,
#       "deprel": "det",
#       "misc": "start_char=656|end_char=659"
#     },
#     {
#       "id": "28",
#       "text": "targeted",
#       "lemma": "target",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 29,
#       "deprel": "amod",
#       "misc": "start_char=660|end_char=668"
#     },
#     {
#       "id": "29",
#       "text": "concept",
#       "lemma": "concept",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 25,
#       "deprel": "nmod",
#       "misc": "start_char=669|end_char=676"
#     },
#     {
#       "id": "30",
#       "text": "during",
#       "lemma": "during",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 32,
#       "deprel": "case",
#       "misc": "start_char=677|end_char=683"
#     },
#     {
#       "id": "31",
#       "text": "interactive",
#       "lemma": "interactive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 32,
#       "deprel": "amod",
#       "misc": "start_char=684|end_char=695"
#     },
#     {
#       "id": "32",
#       "text": "gameplay",
#       "lemma": "gameplay",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 29,
#       "deprel": "nmod",
#       "misc": "start_char=696|end_char=704"
#     },
#     {
#       "id": "33",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 21,
#       "deprel": "punct",
#       "misc": "start_char=704|end_char=705"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "This",
#       "lemma": "this",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 2,
#       "deprel": "nsubj",
#       "misc": "start_char=706|end_char=710"
#     },
#     {
#       "id": "2",
#       "text": "makes",
#       "lemma": "make",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=711|end_char=716"
#     },
#     {
#       "id": "3",
#       "text": "learning",
#       "lemma": "learn",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 2,
#       "deprel": "xcomp",
#       "misc": "start_char=717|end_char=725"
#     },
#     {
#       "id": "4",
#       "text": "concrete",
#       "lemma": "concrete",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "obj",
#       "misc": "start_char=726|end_char=734"
#     },
#     {
#       "id": "5",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 6,
#       "deprel": "cc",
#       "misc": "start_char=735|end_char=738"
#     },
#     {
#       "id": "6",
#       "text": "embodied",
#       "lemma": "embody",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 3,
#       "deprel": "conj",
#       "misc": "start_char=739|end_char=747"
#     },
#     {
#       "id": "7",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 2,
#       "deprel": "punct",
#       "misc": "start_char=747|end_char=748"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "Gameplay",
#       "lemma": "gameplay",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 2,
#       "deprel": "compound",
#       "misc": "start_char=749|end_char=757"
#     },
#     {
#       "id": "2",
#       "text": "experiences",
#       "lemma": "experience",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 4,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=758|end_char=769"
#     },
#     {
#       "id": "3",
#       "text": "are",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "aux:pass",
#       "misc": "start_char=770|end_char=773"
#     },
#     {
#       "id": "4",
#       "text": "designed",
#       "lemma": "design",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=774|end_char=782"
#     },
#     {
#       "id": "5",
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "head": 6,
#       "deprel": "mark",
#       "misc": "start_char=783|end_char=785"
#     },
#     {
#       "id": "6",
#       "text": "guide",
#       "lemma": "guide",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 4,
#       "deprel": "advcl",
#       "misc": "start_char=786|end_char=791"
#     },
#     {
#       "id": "7",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 8,
#       "deprel": "det",
#       "misc": "start_char=792|end_char=795"
#     },
#     {
#       "id": "8",
#       "text": "learner",
#       "lemma": "learner",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "obj",
#       "misc": "start_char=796|end_char=803"
#     },
#     {
#       "id": "9",
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "head": 10,
#       "deprel": "mark",
#       "misc": "start_char=804|end_char=806"
#     },
#     {
#       "id": "10",
#       "text": "discover",
#       "lemma": "discover",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 6,
#       "deprel": "advcl",
#       "misc": "start_char=807|end_char=815"
#     },
#     {
#       "id": "11",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 13,
#       "deprel": "det",
#       "misc": "start_char=816|end_char=819"
#     },
#     {
#       "id": "12",
#       "text": "relational",
#       "lemma": "relational",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 13,
#       "deprel": "amod",
#       "misc": "start_char=820|end_char=830"
#     },
#     {
#       "id": "13",
#       "text": "structure",
#       "lemma": "structure",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "obj",
#       "misc": "start_char=831|end_char=840"
#     },
#     {
#       "id": "14",
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 17,
#       "deprel": "case",
#       "misc": "start_char=841|end_char=843"
#     },
#     {
#       "id": "15",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 17,
#       "deprel": "det",
#       "misc": "start_char=844|end_char=847"
#     },
#     {
#       "id": "16",
#       "text": "targeted",
#       "lemma": "target",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 17,
#       "deprel": "amod",
#       "misc": "start_char=848|end_char=856"
#     },
#     {
#       "id": "17",
#       "text": "concept",
#       "lemma": "concept",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "nmod",
#       "misc": "start_char=857|end_char=864"
#     },
#     {
#       "id": "18",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 4,
#       "deprel": "punct",
#       "misc": "start_char=864|end_char=865"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "This",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=866|end_char=870"
#     },
#     {
#       "id": "2",
#       "text": "gameplay",
#       "lemma": "gameplay",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "nsubj",
#       "misc": "start_char=871|end_char=879"
#     },
#     {
#       "id": "3",
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 6,
#       "deprel": "cop",
#       "misc": "start_char=880|end_char=882"
#     },
#     {
#       "id": "4",
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=883|end_char=884"
#     },
#     {
#       "id": "5",
#       "text": "readiness",
#       "lemma": "readiness",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "compound",
#       "misc": "start_char=885|end_char=894"
#     },
#     {
#       "id": "6",
#       "text": "activity",
#       "lemma": "activity",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=895|end_char=903"
#     },
#     {
#       "id": "7",
#       "text": "for",
#       "lemma": "for",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "head": 8,
#       "deprel": "mark",
#       "misc": "start_char=904|end_char=907"
#     },
#     {
#       "id": "8",
#       "text": "preparing",
#       "lemma": "prepare",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 6,
#       "deprel": "acl",
#       "misc": "start_char=908|end_char=917"
#     },
#     {
#       "id": "9",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 10,
#       "deprel": "det",
#       "misc": "start_char=918|end_char=921"
#     },
#     {
#       "id": "10",
#       "text": "learner",
#       "lemma": "learner",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "obj",
#       "misc": "start_char=922|end_char=929"
#     },
#     {
#       "id": "11",
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 13,
#       "deprel": "case",
#       "misc": "start_char=930|end_char=933"
#     },
#     {
#       "id": "12",
#       "text": "subsequent",
#       "lemma": "subsequent",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 13,
#       "deprel": "amod",
#       "misc": "start_char=934|end_char=944"
#     },
#     {
#       "id": "13",
#       "text": "instruction",
#       "lemma": "instruction",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "obl",
#       "misc": "start_char=945|end_char=956"
#     },
#     {
#       "id": "14",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 6,
#       "deprel": "punct",
#       "misc": "start_char=956|end_char=957"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "The",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 3,
#       "deprel": "det",
#       "misc": "start_char=958|end_char=961"
#     },
#     {
#       "id": "2",
#       "text": "primary",
#       "lemma": "primary",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 3,
#       "deprel": "amod",
#       "misc": "start_char=962|end_char=969"
#     },
#     {
#       "id": "3",
#       "text": "objective",
#       "lemma": "objective",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 25,
#       "deprel": "nsubj",
#       "misc": "start_char=970|end_char=979"
#     },
#     {
#       "id": "4",
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 9,
#       "deprel": "case",
#       "misc": "start_char=980|end_char=982"
#     },
#     {
#       "id": "5",
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 9,
#       "deprel": "det",
#       "misc": "start_char=983|end_char=986"
#     },
#     {
#       "id": "6",
#       "text": "Cyber",
#       "lemma": "Cyber",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "obl:npmod",
#       "misc": "start_char=987|end_char=992"
#     },
#     {
#       "id": "7",
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 8,
#       "deprel": "punct",
#       "misc": "start_char=992|end_char=993"
#     },
#     {
#       "id": "8",
#       "text": "Enabled",
#       "lemma": "enable",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 9,
#       "deprel": "amod",
#       "misc": "start_char=993|end_char=1000"
#     },
#     {
#       "id": "9",
#       "text": "Teaching",
#       "lemma": "teaching",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "nmod",
#       "misc": "start_char=1001|end_char=1009"
#     },
#     {
#       "id": "10",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 11,
#       "deprel": "cc",
#       "misc": "start_char=1010|end_char=1013"
#     },
#     {
#       "id": "11",
#       "text": "Learning",
#       "lemma": "learning",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 9,
#       "deprel": "conj",
#       "misc": "start_char=1014|end_char=1022"
#     },
#     {
#       "id": "12",
#       "text": "through",
#       "lemma": "through",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 20,
#       "deprel": "case",
#       "misc": "start_char=1023|end_char=1030"
#     },
#     {
#       "id": "13",
#       "text": "Game",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "obl:npmod",
#       "misc": "start_char=1031|end_char=1035"
#     },
#     {
#       "id": "14",
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=1035|end_char=1036"
#     },
#     {
#       "id": "15",
#       "text": "based",
#       "lemma": "base",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 20,
#       "deprel": "amod",
#       "misc": "start_char=1036|end_char=1041"
#     },
#     {
#       "id": "16",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 20,
#       "deprel": "punct",
#       "misc": "start_char=1041|end_char=1042"
#     },
#     {
#       "id": "17",
#       "text": "Metaphor",
#       "lemma": "metaphor",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 18,
#       "deprel": "compound",
#       "misc": "start_char=1043|end_char=1051"
#     },
#     {
#       "id": "18",
#       "text": "Enhanced",
#       "lemma": "enhance",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 20,
#       "deprel": "amod",
#       "misc": "start_char=1052|end_char=1060"
#     },
#     {
#       "id": "19",
#       "text": "Learning",
#       "lemma": "learning",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 20,
#       "deprel": "compound",
#       "misc": "start_char=1061|end_char=1069"
#     },
#     {
#       "id": "20",
#       "text": "Objects",
#       "lemma": "object",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 9,
#       "deprel": "nmod",
#       "misc": "start_char=1070|end_char=1077"
#     },
#     {
#       "id": "21",
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 22,
#       "deprel": "punct",
#       "misc": "start_char=1078|end_char=1079"
#     },
#     {
#       "id": "22",
#       "text": "CyGaMEs",
#       "lemma": "cygame",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 20,
#       "deprel": "appos",
#       "misc": "start_char=1079|end_char=1086"
#     },
#     {
#       "id": "23",
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 22,
#       "deprel": "punct",
#       "misc": "start_char=1086|end_char=1087"
#     },
#     {
#       "id": "24",
#       "text": "project",
#       "lemma": "project",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "nmod",
#       "misc": "start_char=1088|end_char=1095"
#     },
#     {
#       "id": "25",
#       "text": "is",
#       "lemma": "be",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1096|end_char=1098"
#     },
#     {
#       "id": "26",
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "head": 28,
#       "deprel": "mark",
#       "misc": "start_char=1099|end_char=1101"
#     },
#     {
#       "id": "27",
#       "text": "empirically",
#       "lemma": "empirically",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 28,
#       "deprel": "advmod",
#       "misc": "start_char=1102|end_char=1113"
#     },
#     {
#       "id": "28",
#       "text": "test",
#       "lemma": "test",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 25,
#       "deprel": "ccomp",
#       "misc": "start_char=1114|end_char=1118"
#     },
#     {
#       "id": "29",
#       "text": "this",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 30,
#       "deprel": "det",
#       "misc": "start_char=1119|end_char=1123"
#     },
#     {
#       "id": "30",
#       "text": "application",
#       "lemma": "application",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 28,
#       "deprel": "obj",
#       "misc": "start_char=1124|end_char=1135"
#     },
#     {
#       "id": "31",
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 34,
#       "deprel": "case",
#       "misc": "start_char=1136|end_char=1138"
#     },
#     {
#       "id": "32",
#       "text": "cognitive",
#       "lemma": "cognitive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 34,
#       "deprel": "amod",
#       "misc": "start_char=1139|end_char=1148"
#     },
#     {
#       "id": "33",
#       "text": "science",
#       "lemma": "science",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 34,
#       "deprel": "compound",
#       "misc": "start_char=1149|end_char=1156"
#     },
#     {
#       "id": "34",
#       "text": "theory",
#       "lemma": "theory",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 30,
#       "deprel": "nmod",
#       "misc": "start_char=1157|end_char=1163"
#     },
#     {
#       "id": "35",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 25,
#       "deprel": "punct",
#       "misc": "start_char=1163|end_char=1164"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "Aptly",
#       "lemma": "aptly",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 4,
#       "deprel": "amod",
#       "misc": "start_char=1165|end_char=1170"
#     },
#     {
#       "id": "2",
#       "text": "designed",
#       "lemma": "design",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 4,
#       "deprel": "amod",
#       "misc": "start_char=1171|end_char=1179"
#     },
#     {
#       "id": "3",
#       "text": "videogame",
#       "lemma": "videogame",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "compound",
#       "misc": "start_char=1180|end_char=1189"
#     },
#     {
#       "id": "4",
#       "text": "worlds",
#       "lemma": "world",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 6,
#       "deprel": "nsubj",
#       "misc": "start_char=1190|end_char=1196"
#     },
#     {
#       "id": "5",
#       "text": "will",
#       "lemma": "will",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "head": 6,
#       "deprel": "aux",
#       "misc": "start_char=1197|end_char=1201"
#     },
#     {
#       "id": "6",
#       "text": "provide",
#       "lemma": "provide",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1202|end_char=1209"
#     },
#     {
#       "id": "7",
#       "text": "common",
#       "lemma": "common",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 8,
#       "deprel": "amod",
#       "misc": "start_char=1210|end_char=1216"
#     },
#     {
#       "id": "8",
#       "text": "experience",
#       "lemma": "experience",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "obj",
#       "misc": "start_char=1217|end_char=1227"
#     },
#     {
#       "id": "9",
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "head": 10,
#       "deprel": "nsubj",
#       "misc": "start_char=1228|end_char=1232"
#     },
#     {
#       "id": "10",
#       "text": "prepares",
#       "lemma": "prepare",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 8,
#       "deprel": "acl:relcl",
#       "misc": "start_char=1233|end_char=1241"
#     },
#     {
#       "id": "11",
#       "text": "educators",
#       "lemma": "educator",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 10,
#       "deprel": "obj",
#       "misc": "start_char=1242|end_char=1251"
#     },
#     {
#       "id": "12",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
# ...
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 13,
#       "deprel": "case",
#       "misc": "start_char=1661|end_char=1663"
#     },
#     {
#       "id": "12",
#       "text": "CyGaMEs",
#       "lemma": "CyGaMEs",
#       "upos": "PROPN",
#       "xpos": "NNPS",
#       "feats": "Number=Plur",
#       "head": 13,
#       "deprel": "compound",
#       "misc": "start_char=1664|end_char=1671"
#     },
#     {
#       "id": "13",
#       "text": "research",
#       "lemma": "research",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "nmod",
#       "misc": "start_char=1672|end_char=1680"
#     },
#     {
#       "id": "14",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=1680|end_char=1681"
#     }
#   ],
#   [
#     {
#       "id": "1",
#       "text": "This",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=1682|end_char=1686"
#     },
#     {
#       "id": "2",
#       "text": "project",
#       "lemma": "project",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "nsubj",
#       "misc": "start_char=1687|end_char=1694"
#     },
#     {
#       "id": "3",
#       "text": "will",
#       "lemma": "will",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "head": 8,
#       "deprel": "aux",
#       "misc": "start_char=1695|end_char=1699"
#     },
#     {
#       "id": "4",
#       "text": ":",
#       "lemma": ":",
#       "upos": "PUNCT",
#       "xpos": ":",
#       "head": 8,
#       "deprel": "punct",
#       "misc": "start_char=1699|end_char=1700"
#     },
#     {
#       "id": "5",
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 6,
#       "deprel": "punct",
#       "misc": "start_char=1701|end_char=1702"
#     },
#     {
#       "id": "6",
#       "text": "a",
#       "lemma": "a",
#       "upos": "X",
#       "xpos": "LS",
#       "head": 8,
#       "deprel": "nummod",
#       "misc": "start_char=1702|end_char=1703"
#     },
#     {
#       "id": "7",
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 6,
#       "deprel": "punct",
#       "misc": "start_char=1703|end_char=1704"
#     },
#     {
#       "id": "8",
#       "text": "complete",
#       "lemma": "complete",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=1705|end_char=1713"
#     },
#     {
#       "id": "9",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 10,
#       "deprel": "punct",
#       "misc": "start_char=1713|end_char=1714"
#     },
#     {
#       "id": "10",
#       "text": "refine",
#       "lemma": "refine",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 8,
#       "deprel": "conj",
#       "misc": "start_char=1715|end_char=1721"
#     },
#     {
#       "id": "11",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 12,
#       "deprel": "cc",
#       "misc": "start_char=1722|end_char=1725"
#     },
#     {
#       "id": "12",
#       "text": "test",
#       "lemma": "test",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 10,
#       "deprel": "conj",
#       "misc": "start_char=1726|end_char=1730"
#     },
#     {
#       "id": "13",
#       "text": "existing",
#       "lemma": "exist",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 15,
#       "deprel": "amod",
#       "misc": "start_char=1731|end_char=1739"
#     },
#     {
#       "id": "14",
#       "text": "Selene",
#       "lemma": "Selene",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "compound",
#       "misc": "start_char=1740|end_char=1746"
#     },
#     {
#       "id": "15",
#       "text": "prototype",
#       "lemma": "prototype",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "obj",
#       "misc": "start_char=1747|end_char=1756"
#     },
#     {
#       "id": "16",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 15,
#       "deprel": "punct",
#       "misc": "start_char=1756|end_char=1757"
#     },
#     {
#       "id": "17",
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 18,
#       "deprel": "punct",
#       "misc": "start_char=1758|end_char=1759"
#     },
#     {
#       "id": "18",
#       "text": "b",
#       "lemma": "b",
#       "upos": "X",
#       "xpos": "LS",
#       "head": 19,
#       "deprel": "nummod",
#       "misc": "start_char=1759|end_char=1760"
#     },
#     {
#       "id": "19",
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 20,
#       "deprel": "punct",
#       "misc": "start_char=1760|end_char=1761"
#     },
#     {
#       "id": "20",
#       "text": "collect",
#       "lemma": "collect",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 22,
#       "deprel": "compound",
#       "misc": "start_char=1762|end_char=1769"
#     },
#     {
#       "id": "21",
#       "text": "GaME",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 22,
#       "deprel": "compound",
#       "misc": "start_char=1770|end_char=1774"
#     },
#     {
#       "id": "22",
#       "text": "data",
#       "lemma": "data",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "conj",
#       "misc": "start_char=1775|end_char=1779"
#     },
#     {
#       "id": "23",
#       "text": "representing",
#       "lemma": "represent",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 22,
#       "deprel": "acl",
#       "misc": "start_char=1780|end_char=1792"
#     },
#     {
#       "id": "24",
#       "text": "perceptions",
#       "lemma": "perception",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 23,
#       "deprel": "obj",
#       "misc": "start_char=1793|end_char=1804"
#     },
#     {
#       "id": "25",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 26,
#       "deprel": "cc",
#       "misc": "start_char=1805|end_char=1808"
#     },
#     {
#       "id": "26",
#       "text": "learning",
#       "lemma": "learning",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=1809|end_char=1817"
#     },
#     {
#       "id": "27",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 29,
#       "deprel": "punct",
#       "misc": "start_char=1817|end_char=1818"
#     },
#     {
#       "id": "28",
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 29,
#       "deprel": "punct",
#       "misc": "start_char=1819|end_char=1820"
#     },
#     {
#       "id": "29",
#       "text": "c",
#       "lemma": "c",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 24,
#       "deprel": "appos",
#       "misc": "start_char=1820|end_char=1821"
#     },
#     {
#       "id": "30",
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 29,
#       "deprel": "punct",
#       "misc": "start_char=1821|end_char=1822"
#     },
#     {
#       "id": "31",
#       "text": "develop",
#       "lemma": "develop",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 15,
#       "deprel": "acl",
#       "misc": "start_char=1823|end_char=1830"
#     },
#     {
#       "id": "32",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 33,
#       "deprel": "cc",
#       "misc": "start_char=1831|end_char=1834"
#     },
#     {
#       "id": "33",
#       "text": "refine",
#       "lemma": "refine",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 31,
#       "deprel": "conj",
#       "misc": "start_char=1835|end_char=1841"
#     },
#     {
#       "id": "34",
#       "text": "new",
#       "lemma": "new",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 35,
#       "deprel": "amod",
#       "misc": "start_char=1842|end_char=1845"
#     },
#     {
#       "id": "35",
#       "text": "methods",
#       "lemma": "method",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 31,
#       "deprel": "obj",
#       "misc": "start_char=1846|end_char=1853"
#     },
#     {
#       "id": "36",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 37,
#       "deprel": "cc",
#       "misc": "start_char=1854|end_char=1857"
#     },
#     {
#       "id": "37",
#       "text": "metrics",
#       "lemma": "metric",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 35,
#       "deprel": "conj",
#       "misc": "start_char=1858|end_char=1865"
#     },
#     {
#       "id": "38",
#       "text": "for",
#       "lemma": "for",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "head": 39,
#       "deprel": "mark",
#       "misc": "start_char=1866|end_char=1869"
#     },
#     {
#       "id": "39",
#       "text": "assessing",
#       "lemma": "assess",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 35,
#       "deprel": "acl",
#       "misc": "start_char=1870|end_char=1879"
#     },
#     {
#       "id": "40",
#       "text": "motivation",
#       "lemma": "motivation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 39,
#       "deprel": "obj",
#       "misc": "start_char=1880|end_char=1890"
#     },
#     {
#       "id": "41",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 42,
#       "deprel": "punct",
#       "misc": "start_char=1890|end_char=1891"
#     },
#     {
#       "id": "42",
#       "text": "engagement",
#       "lemma": "engagement",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 40,
#       "deprel": "conj",
#       "misc": "start_char=1892|end_char=1902"
#     },
#     {
#       "id": "43",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 45,
#       "deprel": "punct",
#       "misc": "start_char=1902|end_char=1903"
#     },
#     {
#       "id": "44",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 45,
#       "deprel": "cc",
#       "misc": "start_char=1904|end_char=1907"
#     },
#     {
#       "id": "45",
#       "text": "achievement",
#       "lemma": "achievement",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 40,
#       "deprel": "conj",
#       "misc": "start_char=1908|end_char=1919"
#     },
#     {
#       "id": "46",
#       "text": "within",
#       "lemma": "within",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 48,
#       "deprel": "case",
#       "misc": "start_char=1920|end_char=1926"
#     },
#     {
#       "id": "47",
#       "text": "instructional",
#       "lemma": "instructional",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 48,
#       "deprel": "amod",
#       "misc": "start_char=1927|end_char=1940"
#     },
#     {
#       "id": "48",
#       "text": "videogames",
#       "lemma": "videogame",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 39,
#       "deprel": "obl",
#       "misc": "start_char=1941|end_char=1951"
#     },
#     {
#       "id": "49",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 57,
#       "deprel": "punct",
#       "misc": "start_char=1951|end_char=1952"
#     },
#     {
#       "id": "50",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 57,
#       "deprel": "cc",
#       "misc": "start_char=1953|end_char=1956"
#     },
#     {
#       "id": "51",
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 52,
#       "deprel": "punct",
#       "misc": "start_char=1957|end_char=1958"
#     },
#     {
#       "id": "52",
#       "text": "d",
#       "lemma": "d",
#       "upos": "X",
#       "xpos": "LS",
#       "head": 53,
#       "deprel": "nummod",
#       "misc": "start_char=1958|end_char=1959"
#     },
#     {
#       "id": "53",
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 57,
#       "deprel": "punct",
#       "misc": "start_char=1959|end_char=1960"
#     },
#     {
#       "id": "54",
#       "text": "integrate",
#       "lemma": "integrate",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 57,
#       "deprel": "compound",
#       "misc": "start_char=1961|end_char=1970"
#     },
#     {
#       "id": "55",
#       "text": "GaME",
#       "lemma": "game",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 57,
#       "deprel": "compound",
#       "misc": "start_char=1971|end_char=1975"
#     },
#     {
#       "id": "56",
#       "text": "data",
#       "lemma": "data",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 57,
#       "deprel": "compound",
#       "misc": "start_char=1976|end_char=1980"
#     },
#     {
#       "id": "57",
#       "text": "collection",
#       "lemma": "collection",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 40,
#       "deprel": "conj",
#       "misc": "start_char=1981|end_char=1991"
#     },
#     {
#       "id": "58",
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 59,
#       "deprel": "cc",
#       "misc": "start_char=1992|end_char=1995"
#     },
#     {
#       "id": "59",
#       "text": "assessment",
#       "lemma": "assessment",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 57,
#       "deprel": "conj",
#       "misc": "start_char=1996|end_char=2006"
#     },
#     {
#       "id": "60",
#       "text": "within",
#       "lemma": "within",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 66,
#       "deprel": "case",
#       "misc": "start_char=2007|end_char=2013"
#     },
#     {
#       "id": "61",
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 66,
#       "deprel": "det",
#       "misc": "start_char=2014|end_char=2015"
#     },
#     {
#       "id": "62",
#       "text": "cyber",
#       "lemma": "cyber",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 64,
#       "deprel": "compound",
#       "misc": "start_char=2016|end_char=2021"
#     },
#     {
#       "id": "63",
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 64,
#       "deprel": "punct",
#       "misc": "start_char=2021|end_char=2022"
#     },
#     {
#       "id": "64",
#       "text": "enabled",
#       "lemma": "enable",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 66,
#       "deprel": "amod",
#       "misc": "start_char=2022|end_char=2029"
#     },
#     {
#       "id": "65",
#       "text": "informatics",
#       "lemma": "informatic",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 66,
#       "deprel": "compound",
#       "misc": "start_char=2030|end_char=2041"
#     },
#     {
#       "id": "66",
#       "text": "infrastructure",
#       "lemma": "infrastructure",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 57,
#       "deprel": "nmod",
#       "misc": "start_char=2042|end_char=2056"
#     },
#     {
#       "id": "67",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 8,
#       "deprel": "punct",
#       "misc": "start_char=2056|end_char=2057"
#     }
#   ]
# ]

# %%
# spacy tokenizer recognizes " " as a proper noun when there is a double space in a sentence (not at the end of one.)

# %%
#Create a pipeline for lemmatizing working abstract. This pipeline will tokenize, determine pos, and then lemmatize the token appropriately.
nlp = stanza.Pipeline(lang='en',processors='tokenize,pos,lemma',tokenize_batch_size=500,lemma_batch_size=500)
# Out:
# 2020-06-23 15:06:05 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# | pos       | ewt     |
# | lemma     | ewt     |
# =======================
#
# 2020-06-23 15:06:05 INFO: Use device: cpu
# 2020-06-23 15:06:05 INFO: Loading: tokenize
# 2020-06-23 15:06:05 INFO: Loading: pos
# 2020-06-23 15:06:06 INFO: Loading: lemma
# 2020-06-23 15:06:06 INFO: Done loading processors!

# %%
# Use this function after tokenizing

def remove_first_x_tokens(tokened_abstract,bad_start_phrases,max_tokens_to_skip=3):
    """removes each bad_start_phrase occuring within max_tokens_to_skip of the front--phrases must be lowered.
    be careful calling this, as order matters! It always starts looking at the first token, which will change between runs.
    both tokened_abstract and each phrase in bad_start_phrases must be a list, not just a string
    eg the phrase 'overall project summary' and 'technical abstract' should be input as a list of lists: 
    [ ['overall','project','summary'],['technical','abstract']] """
    
    assert [type(phrase)==list for phrase in bad_start_phrases] #Make sure not just a string
    assert [type(tokened_abstract)==list]
    if type(tokened_abstract)!=list:
        return np.nan
    else:
        for token_sequence in bad_start_phrases:
            #Look for a match within up to 3 tokens from the start. The reasoning here is some abstract start with numbers indicating sections
            #EG 8., 8.a, 8.1.1.--from EDA of first tokens
            for idx in range(0,max_tokens_to_skip):
                if tokened_abstract[idx:len(token_sequence)+idx]==token_sequence:
                    tokened_abstract=tokened_abstract[len(token_sequence)+idx:]
                    break
        return tokened_abstract

# %%
#Original list used to remove--must be updated now that lemmatization occurs before
#start_phrases_to_remove=[['section'],['abstract'],['contact','pd','pi'],['technical'],['nontechnical'],['non','technical'],
#                         ['project','summary','abstract'], ['overall','project','summary'],['project','abstract'],
#                        ['project','narrative'],['abstract'],['summary'],['description','provided','by','the','applicant'],
#                         ['description','provided','by','applicant'],['description','provided','by','candidate'],
#                         ['provided','by','investigator'], ['provided','by','the','investigator'],['description']]

start_phrases_to_remove=[['section'],['abstract'],['contact','pd','pi'],['nontechnical'],['non','technical'], ['non-technical'],['technical'],
                         ['project','summary','abstract'], ['overall','project','summary'],['project','abstract'],
                        ['project','narrative'],['abstract'],['summary'],['description','provide','applicant'],
                         ['description','provide','applicant'],['description','provide','candidate'],
                         ['provide','investigator'],['description']]

# institution, pi? other form words?

# %% [markdown]
# ### Remove Stop Words

# %%
def create_stopwords():
    """ creates list of stopwords. stop words include the general English list and any additional we see sneaking through
    #We no longer remove words specific to the corpus that do not aid in meaning like science/research"""
    
    stopWords = set(nltk.corpus.stopwords.words('english'))
    
    # format stop words the same way we formatted our corpus, ie. without apostrophes.  
    stop_wds = stopWords.copy()
    for word in stopWords:
        if "\'" in word:
            stop_wds.discard(word)
            stop_wds.add(word.replace("\'",""))
    
    # more stop words that do not add meaning to topics
    additional_stopwords=['another','well','addition', 'thus',
                      'specifically', 'similar','including',
                       'via','within', 'thus', 'particular', 'furthermore','include','also',
                      'includes','however','whether','due', 'may','overall', 'whether','could',
                      'many','finally', 'several', 'specific', 'additional', 'therefore', 'either', 'various',
                       'within', 'among', 'would'] 
        
    sw = stop_wds.union(additional_stopwords)
    
    return sw

# %%
def remove_stopwords(doc, stop_words):
    """remove stopwords"""
    #If no acceptable tokens, this is np.nan
    if type(doc)!=list:
        return np.nan
    
    return [word for word in doc if word not in stop_words]

# %% [markdown]
# ### Create Bigrams and Trigrams

# %%
def apply_n_grams(abstract,function):
    """apply an n-gram--could be bi or tri gram--to abstract"""
    #Non lists--aka no acceptable tokens
    if type(abstract)==list:
        return function[abstract]
    else:
        return abstract

# %%
def clean_up_tokens(doc):
    """determines for each doc which tokens to clean up formatting further in keep_token, and decides which of these cleaned up tokens will be kept"""
    kept_tokens=[]
    #Ignores documents that are abstracts with no valid tokens
    if type(doc)!=list:
        return np.nan
    else:
        for token in doc:
            keep,altered_token=keep_token(token)
            if keep:
                kept_tokens.append(altered_token)
        return kept_tokens

# %%
      
def keep_token(token):
    """strips hyphens, replaces internal hyphens with _, turns non-alphanumeric tokens into alphanumerics', strips leading _ if produced by alphamumeric,
    then removes those updated tokens that: are numeric but not length 4, are tokens related to college names (see below) or are less than length 2."""
    token=token.strip('- ') #Removes leading and trailing hyphens
    token=token.replace('-','_')
    if not str.isalnum(token):
        token=re.sub(r'\W+', '', token)
    token=token.strip('_')
    #Names of universities
    if 'university' in token or 'college' in token or 'universities' in token:
        return (not token in college_tokens, token)
    if str.isnumeric(token):
        #keep years
        return (len(token)==4,token)
    else:
        #Keep anything that is alphanumeric or alpha if its over length 2--allows mixed types e.g. h1n1
        return (len(token)>=2,token)

# %%
#Any specific university word is removed--schools within college/university, college names, etc. that cannot apply to multiple schools
#This list was generated from all tokens that contained the string 'college','university',or 'universities'. The commented out parts of the list are terms
#That could be considered "generic" ie apply to more than one school
college_tokens=[#'college',
'aga_khan_university',
'ahmadu_bello_university',
'alabama_aamp_university',
'albert_einstein_college',
'alcorn_state_university',
'american_college_obstetricians',
'american_college_surgeons',
'americancollege',
#'amongcollege',
#'anduniversity',
'anne_molloy_trinity_college',
#'atuniversity',
'auburn_university',
'auburn_university_alabama',
'auburn_university_au',
'auburn_university_auburn',
'auburn_university_montgomery',
'auburn_university_tuskegee_university',
'augustana_college',
#'auniversity',
'babes_bolyai_university',
'barnard_college',
'baruch_college',
'bates_college',
'baylor_college',
'baylor_college_dentistry',
'baylor_college_medicine',
'baylor_college_ofmedicine',
'baylor_collegeof',
'baylorcollege_medicine',
'baylorcollege_medicine_bcm',
'ben_gurion_university',
'benedict_college',
'benedict_college_historically_black',
'berea_college',
'binghamton_university',
#'black_colleges',
'board_trinity_college',
'bostonuniversity',
'bowdoin_college',
'brownuniversity',
'bryn_mawr_college',
'bucknell_university',
#'cape_universities',
'cardiff_university',
'carleton_college',
'carnegie_mellon_university',
'carver_college',
'carver_college_medicine',
'case_western_reserveuniversity',
'case_westernreserve_university',
'catholic_university',
'cerritos_college',
'charles_drew_university',
'chulalongkorn_university',
'chulalongkorn_university_bangkok_thailand',
'claflin_university',
'claremont_colleges',
'clark_atlanta_university',
'colby_college',
'colby_sawyer_college',
#'college',
#'college',
#'college_american_pathologists',
#'college_arts',
#'college_arts_sciences',
'college_brockport',
'college_dentistry_nyucd',
'college_dentistry_ufcd',
#'college_goer',
#'college_graduates',
#'college_letters',
#'college_letters_arts_sciences',
#'college_letters_sciences',
'college_lewiston',
#'college_liberal_arts',
'college_london',
'college_medicine_aecom',
'college_medicine_uccom',
'college_menominee_nation',
#'college_optometry',
#'college_osteopathic_medicine',
'college_park_umcp',
'college_park_umd',
#'college_physicians_surgeons',
#'college_rheumatology_acr',
'college_south_hadley',
#'college_sports_medicine',
'college_st_scholastica',
'college_staten_island',
#'college_students_basics',
#'college_veterinary_medicine',
#'college_veterinary_pathologists',
#'college_veterinarymedicine',
'college_wcmc',
'college_wcmc_rockefeller_university',
'college_william_mary',
'college_wisconsin_mcw',
'college_wooster',
#'collegeand',
#'collegeof',
#'collegeof_medicine',
#'colleges',
#'colleges_arts_sciences',
#'colleges_chicago',
#'colleges_dentistry',
#'colleges_dentistry_medicine',
#'colleges_optometry',
'colleges_rcc_umb', #Iffy--not sure what this is
#'colleges_schools',
#'colleges_universities',
#'colleges_universities_hacu',
#'collegesand',
#'collegestudent',
'columbia_university',
'columbiauniversity',
'comanche_nation_college',
#'communitycollege',
'creighton_university',
'cross_university',
'cross__university',
'cuny_hunter_college',
'del_mar_college',
'depaul_university',
'dine_college',
'din_college',
'diné_college',
'diplomate_american_college',
'doane_college',
'doron_levy_university_maryland',
'dukeuniversity',
'eckerd_college',
'emoryuniversity',
'famu_fsu_college',
'fort_lewis_college',
'franklin_marshall_college',
'fudan_university',
'fudan_university_shanghai',
'fudan_university_shanghai_china',
'gallaudet_university',
'george_mason_university',
'george_washington_university',
'georgetown_howard_universities',
'georgetown_university',
'georgia_regents_university',
'gettysburg_college',
#'grant_universities_aplu',
'gu_howard_university',
'hackensack_university',
'hampton_university',
'hanyang_university',
'hartnell_college',
'harvarduniversity',
'harvey_mudd_college',
#'historically_black_college',
#'historically_black_colleges',
#'historically_black_colleges_universities',
'hokkaido_university',
'hold_bates_college',
'hold_colby_sawyer_college',
'hold_stonehill_college_easton',
'honors_college',
'houston_baylor_college',
'hunter_college',
'imperial_college',
'imperial_college_london',
'imperial_college_london_uk',
#'incollege',
'indiana_university',
'indianauniversity',
#'inspect_certified_college',
#'inter_college',
#'inter_university',
#'inter_university_consortium_political',
#'interuniversity',
#'interuniversity_consortium_political',
#'intra_university',
'james_cook_university',
'james_madison_university',
'jeffersonuniversity',
'john_jay_college',
'johns_hopkinsuniversity',
'kennesaw_state_university',
'king_college_london',
'kwame_nkrumah_university',
'kyoto_university',
'kyushu_university',
'langston_university',
'lehman_college',
'lehman_college_city',
'lehman_college_cuny',
'lemoyne_owen_college',
'lewis_clark_college',
#'liberal_art_college',
'louisiana_universities_marine',
'loyola_marymount_university',
'loyola_university',
'loyola_university_chicago',
'macalester_college',
'makerere_university',
'makerere_university_kampala_uganda',
'makerere_university_uganda',
'makerereuniversity',
'marquette_university',
'marquette_university_milwaukee',
'mbarara_university',
'mcgill_university',
'mcmaster_university',
'medgar_evers_college',
'medical_colleges_aamc',
'medicalcollege',
'medicaluniversity_south_carolina',
'medicine_yeshiva_university',
'meharrymedical_college',
'mellon_university',
'mellonuniversity',
'mexico_highlands_university',
'miami_dade_college',
'middlebury_college',
'millsaps_college',
'monash_university',
'monash_university_australia',
#'montana_tribal_college',
#'montana_tribal_colleges',
'montclair_state_university',
'morehouse_college',
'morehouse_college_spelman_college',
'mount_holyoke_college',
'msm_tuskegee_university',
'mt_marty_college',
'muhimbili_university',
#'multi_university',
#'muniversity',
'nakoda_college',
'nanyang_technological_university',
'nazarene_university',
'nazareth_college',
#'non_college',
#'non_university',
'northern_arizona_university',
'northern_kentucky_university',
'northshore_university',
'northshore_university_healthsystem',
'northwest_nazarene_university',
'northwestern_university',
'norwich_university',
#'ofuniversity',
'oglala_lakota_college',
'ohio_stateuniversity',
'old_dominion_university',
'olin_college',
#'otheruniversity',
#'participatinguniversity',
'pasadena_city_college',
'peking_university',
'peking_university_beijing_china',
'pennsylvania_college_optometry',
#'phduniversity',
#'polytechnic_university',
#'post__college',
'prairie_view_university',
#'pre_college',
#'pre_university',
#'pre__college',
#'precollege',
'queens_college',
'regents_university',
'researchuniversity',
'rockefeller_university',
'rockefeller_university_memorial_sloan',
'rockefeller_university_ru',
'rockefeller_university_weill_cornell',
'rockefelleruniversity',
'royal_college_surgeons',
'rutgers_university',
'rutgersuniversity',
'saddleback_college',
'saginaw_chippewa_tribal_college',
'saint_michael_college',
'salish_kootenai_college',
'salve_regina_university',
'sawyer_college',
#'scienceuniversity', #This is likely ohsu, as bellow, but for parsimony, this is kept
'scienceuniversity_ohsu',
'serc_carleton_college',
'shams_university',
'shams_university_cairo_egypt',
'shanghai_jiaotong_university',
'simon_fraser_university',
'sinte_gleska_university',
'sisseton_wahpeton_college',
'sitting_bull_college',
'skc_tribal_college',
'sokoine_university',
'south_africa_university_witwatersrand',
'southern_illinois_university_carbondale',
'southern_illinois_university_edwardsville',
'southern_methodist_university',
'spelman_college',
'st_edward_university',
'st_mary_college',
'st_olaf_college',
'st_philip_college',
'stanforduniversity',
'state_university_dominguez', #Specific university
#'stateuniversity', #This could be any state
'stellenbosch_university',
'stellenbosch_university_south_africa',
'stonehill_college',
'stonehill_college_easton_massachusetts',
'stony_brook_university',
'swarthmore_college',
'tarrant_county_college',
'tel_aviv_university',
'templeuniversity',
'texas_a_university',
'texas_southmost_college',
'texas_university_kingsville',
#'thecollege',
#'theuniversity',
'theuniversity_california_san',
'theuniversity_colorado',
'theuniversity_maryland',
'theuniversity_michigan',
'theuniversity_minnesota',
'theuniversity_north_carolina',
'theuniversity_pennsylvania',
'theuniversity_pittsburgh',
'tougaloo_college',
#'touniversity',
#'triangle_universities_nuclear', #this is a government research center
#'tribal_college',
'tribal_college_haskell_indian', #specific university
#'tribal_colleges',
#'tribal_colleges_universities',
#'tribal_colleges_universities_tcus',
'trinity_college',
'trinity_college_arts_sciences',
'trinity_college_dublin',
'tsinghua_university',
'tsinghua_university_beijing',
'tsinghua_university_beijing_china',
'tsinghua_university_china',
#'tsinghua_university_prof_roberto',
'tulaneuniversity',
'tuskegee_universities',
'tuskegee_university',
'tuskegee_university_hbcu',
'uams_colleges',
'ucsf_makerere_university',
'umbc_university_maryland',
'uniformed_services_university',
'united_negro_college',
#'universities',
#'universities_aau', #this is an association of universities, not a university
#'universities_hbcu',
'universities_kansas_ku',
#'universitiesand',
#'universitiesin',
#'university',
#'university',
'university_alabama_birmingham',
'university_alabama_huntsville',
'university_alabama_tuscaloosa',
'university_alabama_ua',
'university_alaska_anchorage',
'university_alaska_fairbanks',
'university_albany_suny',
'university_arizona_ua',
'university_arkansas_fayetteville',
'university_arkansas_pine',
'university_arkansas_ua',
'university_buffalo_suny',
'university_buffalo_ub',
'university_california_berkeley',
'university_california_davis',
'university_california_irvine',
'university_california_los',
'university_california_merced',
'university_california_riverside',
'university_california_san',
'university_california_sanfrancisco',
'university_california_santa',
'university_cincinnati_cincinnati',
'university_college_dublin',
'university_college_london',
'university_colorado_anschutz',
'university_colorado_boulder',
'university_colorado_denver',
'university_connecticut_uconn',
'university_feinberg_school',
'university_florida_gainesville',
'university_florida_uf',
'university_fullerton_csuf',
'university_georgia_athens',
'university_georgia_uga',
'university_hawaii_hilo',
'university_hawaii_manoa',
'university_hawaii_uh',
'university_hospitals_cleveland',
'university_houston_downtown',
'university_houston_uh',
'university_illinois_chicago',
'university_illinois_urbana',
'university_indianapolis_iupui',
'university_kansas_ku',
'university_kansas_lawrence',
'university_kingsville',
'university_langone_medical',
'university_louisiana_lafayette',
'university_louisiana_monroe',
'university_maryland',
'university_maryland_baltimore',
'university_maryland_baltimore_county',
'university_maryland_baltimore_umb',
'university_maryland_eastern_shore',
'university_maryland_greenebaum',
'university_maryland_marlene_stewart', 
'university_maryland_umd',
'university_massachusetts_amherst',
'university_massachusetts_dartmouth',
'university_massachusetts_lowell',
'university_massachusetts_umass',
'university_miami_miller',
'university_miami_um',
'university_michigan_ann',
'university_michigan_dearborn',
'university_michigan_um',
'university_minnesota',
'university_minnesota_duluth',
'university_minnesota_masonic',
'university_minnesota_minneapolis',
'university_minnesota_twin',
'university_minnesota_umn',
'university_missouri__columbia',
'university_missouri_columbia',
'university_missouri_kansas',
'university_missouri_mu',
'university_missouri_rolla',
'university_missouri_st',
'university_nebraska_lincoln',
'university_nebraska_omaha',
'university_nevada_las',
'university_nevada_reno',
'university_northcarolina_chapel',
'university_northridge_csun',
'university_ofalabama',
'university_ofcalifornia',
'university_ofcolorado',
'university_ofmichigan',
'university_ofminnesota',
'university_ofpennsylvania',
'university_ofrochester',
'university_oftexas',
'university_ofwashington',
'university_ofwashington_uw',
'university_ofwisconsin',
'university_ofwisconsin_madison',
'university_oklahoma_norman',
'university_oklahoma_ou',
'university_pennsylvania_upenn',
'university_pittsburgh_pitt',
'university_singapore_nus',
'university_singapore_singapore',
'university_tennessee_chattanooga',
'university_tennessee_knoxville',
'university_tennessee_memphis',
'university_texas_arlington',
'university_texas_austin',
'university_texas_brownsville',
'university_texas_dallas',
'university_texas_el',
'university_texas_pan',
'university_texas_rio',
'university_texas_southwestern',
'university_texas_tyler',
'university_toronto_toronto',
'university_venda',
'university_vermont_burlington',
'university_vermont_uvm',
'university_virginia_charlottesville',
'university_virginia_uva',
'university_washington_seattle',
'university_washington_uw',
'university_waterloo',
'university_west_indies',
'university_wisconsin_carbone',
'university_wisconsin_eau',
'university_wisconsin_madison',
'university_wisconsin_milwaukee',
'university_wisconsin_oshkosh',
'university_wisconsin_platteville',
'university_wisconsin_stout',
'university_witwatersrand',
'university_witwatersrand_south_africa',
'university_witwatersrand_wits',
#'universityabstract',
#'universityand',
#'universitycareer',
#'universityco',
#'universityhospitals',
#'universityin',
#'universityintellectual',
#'universitymedical',
#'universityof',
'universityof_california_san',
'universityof_chicago',
'universityof_colorado',
'universityof_kentucky',
'universityof_michigan',
'universityof_minnesota',
'universityof_pennsylvania',
'universityof_pittsburgh',
'universityof_washington',
#'universityproposal',
#'universityresources',
#'universitys',
#'universityschool_medicine',
#'universitytitle',
'urmc_college_arts',
'vanderbiltuniversity',
'virginia_commonwealth_university',
'wake_forest_university',
'washingtonuniversity',
'wayne_stateuniversity',
'weinberg_college_arts',
'wellesley_college',
'wesley_college',
'western_ontario_mcmaster_universities',
'western_ontario_mcmasters_universities',
'westminster_college',
#'withuniversity',
'xiamen_university',
'xiamen_university_china',
'yaleuniversity',
'yeshiva_university',
'yonsei_university',
'yonsei_university_seoul_south',
'yorkuniversity']

# %% [markdown]
# ### Lemmatization

# %%
"""
#Prior function which used the spacy module--but spacy is not 'research-grade'
def lemmatize_spacy(doc,punctuation_or_token='token'):
"""
"""use spacy to lemmatize a document. token takes a list of strings and is then turned into a string once again. Punctuation takes one string with punctuation and parses by sentence"""
"""
    assert punctuation_or_token in ['token','punctuation']
    if punctuation_or_token=='token':
        sentence=sp(' '.join(doc))
    elif punctuation_or_token=='punctuation':
        sentence=sp(doc)
    new_tokens=[]
    for word in sentence:
        if word.pos_ in ['NOUN','VERB','ADJ','ADV']:
            new_tokens.append(word.lemma_)
        elif word.pos_ in ['PROPN','NUM','X','INTJ']:
            new_tokens.append(word.text)
    return new_tokens
"""

# %%
def lemmatize_stanford(doc,pretokened=False,keep_numbers=True):
    """if pretokened, dont use this function, as it hasnt been adapted for it"""
    ##to compare lemmatization functions, try test cases 463, 40, and 2247 (iloc)
    assert not pretokened #If these are already tokened per another pipeline, this function won't work correctly
    new_tokens=[]
    if doc==' ': #Quirk that somehow two empty abstracts were not caught
        return np.nan #Produces null abstracts that can mess up your code if you're not careful
    else: 
        processed=nlp(doc)
        for sent in processed.sentences:
            for word in sent.words:
                #If its a regular noun, verb, adj, or adverb, keep lemmatized form
                if word.pos in ['NOUN','VERB','ADJ','ADV']:
                    new_tokens.append(word.lemma)
                #If you decided to retain numbers, their lemma is kept here. Note that number catching isnt perfect by this lemmatizing.
                elif word.pos=='NUM' and keep_numbers:
                    new_tokens.append(word.lemma)
                #Exact phrases are kept here with no attempt at lemmatization: e.g. mars does not become mars, and hopefully scientific words e.g. chemicals will be tagged as propn, x, or intj if needed
                elif word.pos in ['PROPN','X','INTJ']: 
                    new_tokens.append(word.text)
                #Note that no other tokens are kept
        return new_tokens

# %%
####################
#Lemmatize
####################
#In an ideal world, this would be run once. However, it takes ages, so instead, we ran it in parallel, and batches them together
#tokened_lemma_docs=df[wa].apply(lambda x: lemmatize_stanford(x,keep_numbers=False))

#Bring all the batches together
#tokened_lemma_docs=pd.concat([pd.read_pickle("./lemma_docs/lemma_docs_"+str(idx)+".pkl") for idx in range(20)],ignore_index=True)
#df['lemma_docs_with_stop']=tokened_lemma_docs

# working with a data subset
df['lemma_docs_with_stop'] = data_subset_name["working_abstract"].apply(lambda x: lemmatize_stanford(x,keep_numbers=False))

# %%
###############
#Additional cleaning post lemmatizing:
#abstracts with no tokens become np.nan
#remove_custom_words: Abstracts have the names of the pis removed (remove_custom_words) and lowercased
#remove_first_x_tokens: Remove starting phrases (and any tokens proceeding them up to "x") like 'description', 'provided', 'by', 'applicant'
#remove_stopwords: Removes standard and user-entered custom stopwords. Note that this is not the text cleaning version to account for emptylists
###############

#Fill nulls to account for 2 blanks
df['lemma_docs_with_stop'].fillna(value=np.nan,inplace=True)



#Remove starting phrases (and any tokens proceeding them up to "x") like 'description', 'provided', 'by', 'applicant'
no_pis=no_pis.apply(remove_first_x_tokens,args=[start_phrases_to_remove])

#Remove stopwords--nltk and those added on in 'additional_stopwords' function
stopWords = create_stopwords()
#tokened_docs_nostop = TextCleaning.remove_stopwords(no_pis, stopWords) #Old code--does not account for non list documents
tokened_docs_nostop = no_pis.apply(remove_stopwords,args=[stopWords])
df['tokened_docs_nostop'] = tokened_docs_nostop

# %%
##################
#Create bigrams and trigrams
###################
#Note that this is not trained on null abstracts
bigram = gensim.models.Phrases(df['tokened_docs_nostop'].dropna(), min_count=5, threshold=100) # higher threshold fewer phrases.
#This function will return a bigram if
bigram_docs=df['tokened_docs_nostop'].apply(lambda x: apply_n_grams(x,bigram))
trigram = gensim.models.Phrases(bigram_docs.dropna(), threshold=100)  
tri_docs =bigram_docs.apply(lambda x: apply_n_grams(x,trigram))
df['tns_bi_tri_docs'] = tri_docs

# %%
df['final_tokens']=df['tns_bi_tri_docs'].apply(clean_up_tokens)

# %%
# save processed text
df.to_pickle("./processed_dataset_stanford_lemma.pkl")

# %%
############
#Create datasets for analysis
############

#All data
docs = df['final_tokens'].dropna() #<--If you're having issues merging with a prior dataset, note that this will NOT be the same length as the df overall, because of nulls, so be careful appending
id2word, corpus = LDAvariables.createLDAvars(docs)
pickle.dump([corpus, id2word, docs], open('lda_data_stanford_lemma.sav','wb'))

#The two IDs for abstracts that were a space
print('Abstract IDs with no lemmas in them')
print(set(range(len(docs)))-set(docs.index))

#Just nsf
nsf_docs=df.groupby('AGENCY').get_group('NSF')['final_tokens'].dropna()
id2word, corpus = LDAvariables.createLDAvars(nsf_docs)
pickle.dump([corpus, id2word, nsf_docs], open('nsf_stanford_lemma.sav','wb'))
# Out:
# Abstract IDs with no lemmas in them
# {74268, 79910}

# %%
#Old code method:

#Data Cleaning
#df[wa]=df[wa].apply(str.lower)
#df[wa]=df.apply(remove_institution,axis=1) #case sensitive

#Tokenizing
#tokened_abstracts = TextCleaning.tokenize(df['working_abstract'])
#df['tokened_abstracts'] = tokened_abstracts

#Removal of stopwords, starting phrases, and PIs
#no_pis=df.apply(remove_custom_words,axis=1).apply(remove_first_x_tokens,args=[start_phrases_to_remove])
#stopWords = create_stopwords()
#tokened_docs_nostop = TextCleaning.remove_stopwords(no_pis, stopWords)
#df['tokened_docs_nostop'] = tokened_docs_nostop

#n-grams
#bigram = gensim.models.Phrases(df['tokened_docs_nostop'], min_count=5, threshold=100) # higher threshold fewer phrases.
#bigram_docs=df['tokened_docs_nostop'].apply(lambda x: bigram[x])
#trigram = gensim.models.Phrases(bigram_docs, threshold=100)  
#tri_docs =bigram_docs.apply(lambda x: trigram[x])
#df['tns_bi_tri_docs'] = tri_docs

#Lemmatizing
#lemma_docs = TextCleaning.lemmatize(df['tns_bi_tri_docs'])
#df['lemma_abstracts'] = lemma_docs

# save processed text

#df.to_pickle("./processed_dataset.pkl")
#df.to_csv('FRAbstractsProcessed.csv')

# Save only what is needed for LDA - docs, corpus, and dictionary. When loading the entire dataframe, I have run 
# out of memory to run the model

# from Sam's code:
#    corpus = corpus, dictionary = id2word, texts = docs

#docs = df['lemma_abstracts']
#id2word, corpus = LDAvariables.createLDAvars(docs)
#pickle.dump([corpus, id2word, docs], open('lda_data.sav','wb'))
