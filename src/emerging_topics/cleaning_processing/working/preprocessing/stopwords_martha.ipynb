# %%
import pandas as pd
import pickle
import nltk
import numpy as np

import LDAvariables
import stanza

import gensim
import spacy

# %%
#What version are we currently using? This might be something to consider for stopwords
#As new versions might have updated lists
print("NLTK", nltk.__version__) #3.4.5
print("Spacy",spacy.__version__)  #2.2.4
print("Gensim", gensim.__version__) #3.9.3
# Out:
# NLTK 3.4.5
# Spacy 2.2.4
# Gensim 3.8.1

# %%
#Run: #nltk - Current Method
from nltk.corpus import stopwords
nltkstopwords = stopwords.words('english')
nltkstopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
#Analysis
#How many words are in the list?
len(nltkstopwords)
# Out:
# 179

# %%
#Known for it's quickness, Con: Doesn't take off the punctuation marks or newline characters
from spacy.lang.en.stop_words import STOP_WORDS
spacySTOP_WORDS=STOP_WORDS
spacySTOP_WORDS
#Add additional stopwords
#STOP_WORDS.add("your_additional_stop_word_here")

#Potentially remove numbers, make custom
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
len(spacySTOP_WORDS)
# Out:
# 326

# %%
#Gensim - no need for tokenizaiton
from gensim.parsing.preprocessing import remove_stopwords
gensimstopwords = gensim.parsing.preprocessing.STOPWORDS
gensimstopwords 
#If you want to add custom stopwords
#from gensim.parsing.preprocessing import STOPWORDS
#my_stop_words = STOPWORDS.union(set(['mystopword1', 'mystopword2']))
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
# ...

# %%
len(gensimstopwords )
# Out:
# 337

# %%
# find the difference between spacy and gensim lists

in_spacy = set(spacySTOP_WORDS) - set(gensimstopwords)
in_gensim =  set(gensimstopwords) - set(spacySTOP_WORDS)

print(in_spacy)
print(in_gensim)
# Out:
# {'’m', '‘m', '’ve', "'d", '‘ve', "'re", '’ll', "'m", '’re', '’s', '‘s', '’d', '‘d', 'n‘t', '‘ll', "'ll", '‘re', 'n’t', 'ca', "'ve", "'s", "n't"}
# {'de', 'find', 'amoungst', 'describe', 'didn', 'fill', 'found', 'don', 'bill', 'thick', 'mill', 'system', 'fire', 'eg', 'doesn', 'ie', 'con', 'hasnt', 'interest', 'kg', 'thin', 'inc', 'un', 'km', 'couldnt', 'etc', 'co', 'detail', 'sincere', 'ltd', 'cant', 'cry', 'computer'}

# %%
# going to use spaCy list!

# %%
#On our clean dataset
df = pd.read_csv("FRAbstractsSqueakyClean.csv")
df.reset_index(inplace = True)
df.rename(columns={'index':'original index'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-1e14cd17c3d1> in <module>
#       1 #On our clean dataset
# ----> 2 df = pd.read_csv("FRAbstractsSqueakyClean.csv")
#       3 df.reset_index(inplace = True)
#       4 df.rename(columns={'index':'original index'}, inplace=True)
#
# ...

# %%
#Remove generic stopwords
# Out:
# Index(['original index', 'Unnamed: 0', 'PROJECT_ID', 'RAW_ABSTRACT', 'FY.x',
#        'PROJECT_TERMS', 'PROJECT_TITLE', 'DEPARTMENT', 'AGENCY', 'IC_CENTER',
#        'PROJECT_NUMBER', 'PROJECT_START_DATE', 'PROJECT_END_DATE',
#        'CONTACT_PI_PROJECT_LEADER', 'OTHER_PIS', 'CONGRESSIONAL_DISTRICT',
#        'DUNS_NUMBER', 'ORGANIZATION_NAME', 'ORGANIZATION_CITY',
#        'ORGANIZATION_STATE', 'ORGANIZATION_ZIP', 'ORGANIZATION_COUNTRY',
#        'BUDGET_START_DATE', 'BUDGET_END_DATE', 'CFDA_CODE', 'FY.y',
#        'FY_TOTAL_COST', 'FY_TOTAL_COST_SUB_PROJECTS', 'working_abstract',
#        'nchar', 'Start Char', 'LAST_CHAR', 'Field Count'],
#       dtype='object')

# %%
#Top 100 words - new dataset
top100 = pd.Series(' '.join(df['working_abstract']).lower().split()).value_counts()[:100]

# %%
top100
# Out:
# the          18656374
# of           15471264
# and          15352588
# to           10139646
# in            9804345
#                ...
# support        317463
# potential      308235
# core           305664
# most           304261
# genetic        298425
# Length: 100, dtype: int64
