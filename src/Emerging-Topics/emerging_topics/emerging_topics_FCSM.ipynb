# %% [markdown]
# # Emerging Topics final code
#
# This code was created from Martha and Sean's emerging topic code and was used to create the hottest/coldest topics static graphics for the full, pandemics, and coronavirus corpora.

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import gensim
import time

from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression as lm

import matplotlib.collections as mcol
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.lines import Line2D

import seaborn as sns

# %% [markdown]
# ### Data Ingestion

# %%
# full corpus
df = pd.read_pickle("../../data/final/final_dataset_7-20.pkl")

# pandemic corpus
#df = pd.read_pickle("../../data/final/dashboard_data/pandemic_corpus.pkl")
#df.reset_index(inplace=True)

# coronavirus corpus
#df = pd.read_pickle("../../data/final/dashboard_data/corona_corpus.pkl")
#df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0           17608     152242
# 1          111864     190316
# 2           22052     154213
# 3           35004     159362
# 4          371628     594482
#
#                                             ABSTRACT    FY  \
# 0  The multiprotein complex y-secretase proteolyt...  2008
# 1  DESCRIPTION (provided by applicant):   The Kis...  2008
# 2  DESCRIPTION (provided by applicant): The objec...  2008
# 3  Obesity is the cause of many adverse pregnancy...  2008
# 4  Local potato advisory groups have expressed in...  2010
#
#                                        PROJECT_TERMS  \
# 0  Active Sites; Affect; Alzheimer's Disease; Amy...
# 1  Affect; Animal Model; Axon; Behavior; Behavior...
# 2  Agreement; Antibodies; base; Binding; Biochemi...
# 3  African; Analysis of Variance; Asians; Birth; ...
# 4  cost; Health; interest; Manure; Parasitic nema...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0              STRUCTURE OF SIGNAL PEPTIDE PEPTIDASE        HHS    NIH
# 1  ROLE OF KISS1 NEURONS IN THE SEASONAL AND CIRC...        HHS    NIH
# 2  CARBONIC ANHYDRASE AS A MODEL TO UNDERSTAND DI...        HHS    NIH
# 3   OBESITY ON VAGAL TONE AND HBA1C DURING PREGNANCY        HHS    NIH
# 4  PLANT-PARASITIC NEMATODE MANAGEMENT AS A COMPO...       USDA   NIFA
#
#   IC_CENTER   PROJECT_NUMBER  ...  \
# 0       NaN  5F32AG027647-03  ...
# 1       NaN  5K99HD056157-02  ...
# 2       NaN  5F32GM076971-02  ...
# 3       NaN  5F31NR009611-03  ...
# 4       NaN          0219605  ...
#
#                                     working_abstract Start_Char nchar  \
# 0  The multiprotein complex y-secretase proteolyt...          T  1402
# 1  The Kissl gene encodes peptides called kisspep...          T  2553
# 2  The objective of this research is to understan...          T  1414
# 3  Obesity is the cause of many adverse pregnancy...          O  1545
# 4  Local potato advisory groups have expressed in...          L   271
#
#   LAST_CHAR                                     lemma_abstract  \
# 0         g  [multiprotein, complex, y-secretase, proteolyt...
# 1         y  [Kissl, gene, encode, peptide, call, kisspepti...
# 2         e  [objective, research, be, understand, biophysi...
# 3         d  [obesity, cause, many, adverse, pregnancyoutco...
# 4         s  [local, potato, advisory, group, express, inte...
#
#                                         clean_lemmas  \
# 0  [multiprotein, complex, y-secretase, proteolyt...
# 1  [kissl, gene, encode, peptide, call, kisspepti...
# 2  [objective, research, be, understand, biophysi...
# 3  [obesity, cause, many, adverse, pregnancyoutco...
# 4  [local, potato, advisory, group, express, inte...
#
#                                      stopwds_removed  \
# 0  [multiprotein, complex, y-secretase, proteolyt...
# 1  [kissl, gene, encode, peptide, kisspeptin, bin...
# 2  [objective, research, understand, biophysical,...
# 3  [obesity, cause, adverse, pregnancyoutcome, re...
# 4  [local, potato, advisory, group, express, inte...
#
#                                        n_grams_added  \
# 0  [multiprotein, complex, y-secretase, proteolyt...
# 1  [kissl, gene, encode, peptide, kisspeptin, bin...
# 2  [objective, research, understand, biophysical,...
# 3  [obesity, cause, adverse_pregnancyoutcome, res...
# 4  [local, potato, advisory, group, express, inte...
#
#                                         final_tokens  \
# 0  [multiprotein, complex, y_secretase, proteolyt...
# 1  [kissl, gene, encode, peptide, kisspeptin, bin...
# 2  [objective, research, understand, biophysical,...
# 3  [obesity, cause, adverse_pregnancyoutcome, res...
# 4  [local, potato, advisory, group, express, inte...
#
#                                 final_frqwds_removed
# 0  [multiprotein, y_secretase, proteolytically_cl...
# 1  [kissl, gene, encode, peptide, kisspeptin, bin...
# 2  [biophysical, basis, thermodynamics_kinetic, m...
# 3  [obesity, adverse_pregnancyoutcome, great, hea...
# 4  [local, potato, advisory, express, interest, m...
#
# [5 rows x 39 columns]

# %%
# input needed for LDA, NMF (all from Scikit-Learn) is one string per document (not a list of strings)

text = []
docs = df["final_frqwds_removed"]

for abstract in docs:
    text.append(" ".join(abstract))

# %% [markdown]
# ### Functions needed for all models

# %%
# function slightly modified from https://nlpforhackers.io/topic-modeling/

def print_topics(topic_term_mat, vectorizer, top_n=10):
    for idx, topic in enumerate(topic_term_mat):  # loop through each row of H.  idx = row index.  topic = actual row
        print("\nTopic %d:" % (idx))
        #print([(vectorizer.get_feature_names()[i], topic[i])  # printing out words corresponding to indices found in next line
                        #for i in topic.argsort()[:-top_n - 1:-1]])  # finding indices of top words in topic
            
        print_list = [(vectorizer.get_feature_names()[i], topic[i])  
                        for i in topic.argsort()[:-top_n - 1:-1]]
        for item in print_list:
            print(item)

# %%
# Function to format topics as a "list of list of strings".
# Needed for topic coherence function in Gensim

# function modified from https://nlpforhackers.io/topic-modeling/

def str_topics(topic_term_mat, vectorizer, top_n=10):

    #input. top_n: how many words to list per topic.  If -1, then list all words.
       
    topic_words = []
    
    for idx, topic in enumerate(topic_term_mat):  # loop through each row of H.  idx = row index.  topic = actual row
            
        if top_n == -1:   
            topic_words.append([vectorizer.get_feature_names()[i] for i in topic.argsort()[::-1]])
        else:
            topic_words.append([vectorizer.get_feature_names()[i] for i in topic.argsort()[:-top_n - 1:-1]])
    
    str_wds = []
    
    for wds in topic_words:
        str_wds.append(", ".join(wds))    
    
    return str_wds

# %% [markdown]
# ## NMF
# - Optimal Model: full dataset, 75 topics, random_state = 14
# - Pandemic Model: pandemic dataset, 30, random_state = 1
# - Coronavirus Model: coronavirus dataset, 30, random_state = 1

# %%
# use for full dataset
tfidf_vectorizer = TfidfVectorizer(max_df=0.6, min_df=20, lowercase=False, max_features=int(len(docs)/2))
tf_idf = tfidf_vectorizer.fit_transform(text)

# use for pandemic or coronavirus dataset
#tfidf_vectorizer = TfidfVectorizer(max_df=1.0, min_df=3, lowercase=False)
#tf_idf = tfidf_vectorizer.fit_transform(text)

# %%
# create model

num_topics = 30 

t1 = time.time()
nmf_model = NMF(n_components=num_topics, random_state = 1)
doc_topic = nmf_model.fit_transform(tf_idf)
t2 = time.time()
print(f"  Model time: {t2-t1}")

topic_term = nmf_model.components_
# Out:
#   Model time: 4.1740403175354

# %%
#print_topics(nmf_model, tfidf_vectorizer, 10)

# %%
# save nmf model on full dataset

#pickle.dump(nmf_model, open('full_nmf75.sav', 'wb'))

# %%
# read in model

#nmf_model = pickle.load(open('full_nmf75.sav', 'rb'))

# %%
# full dataset model ingestion so do not have to rerun

num_topics = 75

doc_topic, topic_term = pickle.load(open('final_model_DT_TT.sav','rb'))

# %% [markdown]
# ### Emerging Topics

# %%
# Extract Year from PROJECT_START_DATE

#On our graphs, we want to be able to show year. Therefore, this getYear function gets the year from different date formats from Project Start Year/End Year

#START

def getYear(a):   
    a = str(a)
    if a.find("/"):
        splitdate = a.split("/")
        if len(splitdate) == 3:
            a = splitdate[2]
        else:
            a = splitdate[0]
    year = str(a)
    return year

df['START_YEAR'] = df['PROJECT_START_DATE'].apply(getYear)

# %%
df["START_YEAR"].value_counts()
# Out:
# 2009    70341
# 2010    65365
# 2011    59286
# 2008    56170
# 2012    51579
# 2014    45773
# 2016    44917
# 2015    44798
# 2013    44227
# 2018    43224
# 2017    41733
# 2019    31166
# 2007    17863
# 2006    10504
# 2005     9521
# 2004     8038
# 2003     5093
# 1997     4507
# 2002     4486
# 2001     4406
# 2000     3635
# 1999     3475
# 1998     2677
# 1996     1851
# 1994     1598
# 1995     1436
# 1992     1269
# 1993     1179
# 1991     1136
# 1988      913
# 1990      845
# 1989      840
# 1987      704
# 1986      675
# 1985      665
# 1978      639
# 1983      637
# 1984      598
# 1977      506
# 1975      490
# 1979      463
# 1980      438
# 1982      393
# 1981      341
# 1976      336
# 2020       33
# 1974       32
# 1965        4
# 1972        4
# 1970        4
# 1973        1
# Name: START_YEAR, dtype: int64

# %%
df.dtypes
# Out:
# original index                  int64
# PROJECT_ID                     object
# ABSTRACT                       object
# FY                             object
# PROJECT_TERMS                  object
# PROJECT_TITLE                  object
# DEPARTMENT                     object
# AGENCY                         object
# IC_CENTER                      object
# PROJECT_NUMBER                 object
# PROJECT_START_DATE             object
# PROJECT_END_DATE               object
# CONTACT_PI_PROJECT_LEADER      object
# OTHER_PIS                      object
# CONGRESSIONAL_DISTRICT         object
# DUNS_NUMBER                    object
# ORGANIZATION_NAME              object
# ORGANIZATION_CITY              object
# ORGANIZATION_STATE             object
# ORGANIZATION_ZIP               object
# ORGANIZATION_COUNTRY           object
# BUDGET_START_DATE              object
# BUDGET_END_DATE                object
# CFDA_CODE                      object
# FY.y                           object
# FY_TOTAL_COST                 float64
# FY_TOTAL_COST_SUB_PROJECTS    float64
# ORG_COUNT                       int64
# PI_COUNT                        int64
# working_abstract               object
# Start_Char                     object
# nchar                           int64
# LAST_CHAR                      object
# lemma_abstract                 object
# clean_lemmas                   object
# stopwds_removed                object
# n_grams_added                  object
# final_tokens                   object
# final_frqwds_removed           object
# START_YEAR                     object
# dtype: object

# %%
#Pulls sample data subsetted by year then takes mean theta for each abstract

topic_frame = pd.DataFrame(doc_topic, columns=["Topic"+" "+str(i) for i in range(num_topics)])
topic_frame["START_YEAR"] = df["START_YEAR"]

# %%
topic_frame_se = topic_frame.groupby("START_YEAR").sem().reset_index()
topic_frame_se = topic_frame_se.sort_values(by = "START_YEAR")
topic_frame_se["START_YEAR"] = topic_frame_se["START_YEAR"].astype(int)

topic_wts_se_2010_2019 = topic_frame_se[topic_frame_se["START_YEAR"] > 2009] 
topic_wts_se_2010_2019 = topic_wts_se_2010_2019[topic_wts_se_2010_2019["START_YEAR"] < 2020]

# %%
topic_frame = topic_frame.groupby("START_YEAR").mean().reset_index()
topic_frame = topic_frame.sort_values(by = "START_YEAR")
topic_frame["START_YEAR"] = topic_frame["START_YEAR"].astype(int)

# %%
topic_frame.head()
# Out:
#    START_YEAR   Topic 0   Topic 1   Topic 2   Topic 3   Topic 4   Topic 5  \
# 0        1965  0.000363  0.000000  0.000100  0.000022  0.000000  0.000006
# 1        1970  0.000528  0.000242  0.000025  0.000000  0.000124  0.003027
# 2        1972  0.000166  0.002454  0.000226  0.000092  0.000146  0.000072
# 3        1973  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4        1974  0.000915  0.000542  0.001042  0.000538  0.001678  0.000957
#
#     Topic 6   Topic 7   Topic 8  ...  Topic 65  Topic 66  Topic 67  Topic 68  \
# 0  0.001205  0.000000  0.000387  ...  0.012315  0.001820  0.000145  0.000000
# 1  0.002041  0.001671  0.000000  ...  0.000044  0.000362  0.002179  0.002398
# 2  0.000000  0.000665  0.000612  ...  0.000726  0.000768  0.000033  0.009290
# 3  0.000000  0.000000  0.000416  ...  0.000000  0.000000  0.000000  0.000000
# 4  0.000466  0.001455  0.000905  ...  0.002261  0.000683  0.000866  0.000464
#
#    Topic 69  Topic 70  Topic 71  Topic 72  Topic 73  Topic 74
# 0  0.000055  0.000296  0.008933  0.001642  0.000010  0.000260
# 1  0.004706  0.000000  0.000075  0.000031  0.000066  0.004216
# 2  0.011979  0.000000  0.000015  0.000000  0.009114  0.000060
# 3  0.039855  0.000439  0.000000  0.000000  0.000000  0.000000
# 4  0.000765  0.000251  0.001519  0.000281  0.000961  0.003210
#
# [5 rows x 76 columns]

# %%
# filter topic_frame for years 2010 - 2019

topic_wts_2010_2019 = topic_frame[topic_frame["START_YEAR"] > 2009] 
topic_wts_2010_2019 = topic_wts_2010_2019[topic_wts_2010_2019["START_YEAR"] < 2020]

# %%
topic_wts_2010_2019
# Out:
#     START_YEAR   Topic 0   Topic 1   Topic 2   Topic 3   Topic 4   Topic 5  \
# 40        2010  0.000518  0.001195  0.001783  0.000584  0.001213  0.000830
# 41        2011  0.000509  0.001273  0.001839  0.000600  0.001205  0.000828
# 42        2012  0.000519  0.001173  0.001855  0.000590  0.001251  0.000881
# 43        2013  0.000483  0.001179  0.002049  0.000567  0.001129  0.000890
# 44        2014  0.000488  0.001167  0.001981  0.000581  0.001135  0.000873
# 45        2015  0.000476  0.001255  0.001868  0.000591  0.001194  0.000865
# 46        2016  0.000463  0.001376  0.001672  0.000549  0.001138  0.000859
# 47        2017  0.000496  0.001223  0.001857  0.000590  0.001131  0.000878
# 48        2018  0.000493  0.001328  0.001827  0.000616  0.001172  0.000906
# 49        2019  0.000539  0.000992  0.001990  0.000653  0.001268  0.000948
#
#      Topic 6   Topic 7   Topic 8  ...  Topic 65  Topic 66  Topic 67  Topic 68  \
# 40  0.001048  0.001069  0.000510  ...  0.000887  0.001528  0.000903  0.000774
# 41  0.001212  0.001167  0.000502  ...  0.000863  0.001621  0.000907  0.000805
# 42  0.001140  0.001100  0.000536  ...  0.000885  0.001539  0.000922  0.000806
# 43  0.001560  0.001159  0.000475  ...  0.000769  0.001899  0.000853  0.000742
# 44  0.001308  0.001143  0.000523  ...  0.000820  0.001699  0.000907  0.000785
# 45  0.001342  0.001195  0.000520  ...  0.000767  0.001791  0.000861  0.000776
# 46  0.001149  0.001353  0.000543  ...  0.000851  0.001631  0.000866  0.000840
# 47  0.001205  0.001221  0.000587  ...  0.000837  0.001651  0.000845  0.000852
# 48  0.001054  0.001230  0.000596  ...  0.000851  0.001581  0.000848  0.000868
# 49  0.001207  0.000985  0.000631  ...  0.000866  0.001644  0.000887  0.000893
#
#     Topic 69  Topic 70  Topic 71  Topic 72  Topic 73  Topic 74
# 40  0.000847  0.000893  0.001907  0.000661  0.001849  0.001551
# 41  0.000901  0.000842  0.001815  0.000742  0.001857  0.001514
# 42  0.000918  0.000901  0.001842  0.000691  0.001632  0.001642
# 43  0.000897  0.000798  0.001567  0.000613  0.002075  0.001537
# 44  0.000925  0.000854  0.001551  0.000680  0.001813  0.001547
# 45  0.000946  0.000808  0.001473  0.000651  0.001804  0.001503
# 46  0.001047  0.000806  0.001443  0.000723  0.001661  0.001517
# 47  0.000956  0.000842  0.001476  0.000726  0.001638  0.001584
# 48  0.000983  0.000850  0.001443  0.000780  0.001440  0.001594
# 49  0.000829  0.000933  0.001550  0.000898  0.001441  0.001774
#
# [10 rows x 76 columns]

# %%
topic_wts_se_2010_2019
# Out:
#     START_YEAR   Topic 0   Topic 1   Topic 2   Topic 3   Topic 4   Topic 5  \
# 40        2010  0.000004  0.000015  0.000022  0.000012  0.000019  0.000009
# 41        2011  0.000004  0.000016  0.000024  0.000013  0.000019  0.000010
# 42        2012  0.000005  0.000017  0.000026  0.000014  0.000021  0.000011
# 43        2013  0.000005  0.000018  0.000030  0.000015  0.000021  0.000012
# 44        2014  0.000005  0.000018  0.000029  0.000015  0.000021  0.000011
# 45        2015  0.000005  0.000019  0.000028  0.000015  0.000022  0.000011
# 46        2016  0.000005  0.000020  0.000026  0.000014  0.000021  0.000011
# 47        2017  0.000005  0.000019  0.000028  0.000015  0.000022  0.000012
# 48        2018  0.000005  0.000020  0.000027  0.000016  0.000022  0.000012
# 49        2019  0.000006  0.000021  0.000033  0.000019  0.000026  0.000014
#
#      Topic 6   Topic 7   Topic 8  ...  Topic 65  Topic 66  Topic 67  Topic 68  \
# 40  0.000015  0.000010  0.000007  ...  0.000018  0.000016  0.000014  0.000015
# 41  0.000017  0.000012  0.000008  ...  0.000019  0.000018  0.000015  0.000017
# 42  0.000018  0.000012  0.000008  ...  0.000020  0.000019  0.000017  0.000017
# 43  0.000024  0.000014  0.000009  ...  0.000020  0.000024  0.000016  0.000018
# 44  0.000021  0.000013  0.000009  ...  0.000020  0.000022  0.000017  0.000019
# 45  0.000021  0.000014  0.000009  ...  0.000019  0.000023  0.000017  0.000019
# 46  0.000019  0.000015  0.000009  ...  0.000021  0.000021  0.000016  0.000020
# 47  0.000021  0.000015  0.000010  ...  0.000021  0.000022  0.000017  0.000021
# 48  0.000018  0.000014  0.000010  ...  0.000020  0.000021  0.000016  0.000021
# 49  0.000024  0.000015  0.000012  ...  0.000024  0.000025  0.000019  0.000025
#
#     Topic 69  Topic 70  Topic 71  Topic 72  Topic 73  Topic 74
# 40  0.000019  0.000022  0.000022  0.000023  0.000021  0.000022
# 41  0.000021  0.000022  0.000022  0.000027  0.000022  0.000023
# 42  0.000022  0.000025  0.000025  0.000026  0.000021  0.000026
# 43  0.000023  0.000024  0.000023  0.000026  0.000027  0.000027
# 44  0.000024  0.000026  0.000023  0.000027  0.000024  0.000026
# 45  0.000025  0.000024  0.000022  0.000026  0.000024  0.000026
# 46  0.000028  0.000024  0.000022  0.000028  0.000022  0.000026
# 47  0.000027  0.000026  0.000022  0.000029  0.000023  0.000027
# 48  0.000026  0.000026  0.000022  0.000030  0.000020  0.000026
# 49  0.000027  0.000032  0.000026  0.000036  0.000024  0.000032
#
# [10 rows x 76 columns]

# %%
# perform regressions, track slopes

topic_slopes = []

for i in range(1,num_topics+1):
    linear_fit = lm().fit(topic_wts_2010_2019["START_YEAR"].values.reshape(-1,1), topic_wts_2010_2019.iloc[:,i].values.reshape(-1,1))
    
    topic_slopes.append(linear_fit.coef_[0][0])

# %%
topic_slopes[:5]
# Out:
# [-6.91390771380066e-07,
#  -3.08453870689152e-06,
#  3.2826113729421555e-06,
#  4.183827488750624e-06,
#  -1.5033842969605124e-06]

# %%
hot_cold = []

for slope in topic_slopes:
    if slope > 0:
        hot_cold.append("hot")
    else:
        hot_cold.append("cold")

# %%
hot_cold[:5]
# Out:
# ['cold', 'cold', 'hot', 'hot', 'cold']

# %%
topic_words = str_topics(topic_term, tfidf_vectorizer, top_n=10)

# %%
topic_words[:5]
# Out:
# ['cell, differentiation, cellular, antigen, culture, proliferation, human, line, cd4, epithelial',
#  'student, undergraduate, graduate, college, faculty, course, summer, reu, career, opportunity',
#  'cancer, nci, pancreatic, member, ovarian, prevention, colorectal, colon, oncology, incidence',
#  'hiv, aids, infect, prevention, cfar, antiretroviral, art, cd4, transmission, viral',
#  'infection, infect, immune, viral, hpv, hcv, parasite, immunity, chronic, tb']

# %%
# package up data for data table in RShiny dashboard

reg_topics = pd.DataFrame()
reg_topics["Slope"] = topic_slopes
reg_topics["Hot or Cold"] = hot_cold
reg_topics["Topic Words"] = topic_words

# %%
reg_topics
# Out:
#            Slope Hot or Cold  \
# 0  -6.913908e-07        cold
# 1  -3.084539e-06        cold
# 2   3.282611e-06         hot
# 3   4.183827e-06         hot
# 4  -1.503384e-06        cold
# ..           ...         ...
# 70  5.727105e-07         hot
# 71 -4.902685e-05        cold
# 72  1.744426e-05         hot
# 73 -4.736720e-05        cold
# 74  1.313904e-05         hot
#
#                                           Topic Words
# 0   cell, differentiation, cellular, antigen, cult...
# 1   student, undergraduate, graduate, college, fac...
# 2   cancer, nci, pancreatic, member, ovarian, prev...
# 3   hiv, aids, infect, prevention, cfar, antiretro...
# 4   infection, infect, immune, viral, hpv, hcv, pa...
# ..                                                ...
# 70  muscle, skeletal_muscle, exercise, motor, fibe...
# 71  receptor, ligand, bind, activation, gpcr, agon...
# 72  pd, parkinson, motor, lrrk2, da, dopamine, dop...
# 73  facility, user, equipment, instrument, laborat...
# 74  immune, il, inflammation, cytokine, inflammato...
#
# [75 rows x 3 columns]

# %%
#reg_topics.to_csv("./full_topics.csv", index=False)
#reg_topics.to_csv("./pan_topics.csv", index=False)
#reg_topics.to_csv("./cor_topics.csv", index=False)

# %% [markdown]
# ## Create plots - top 5 hot and cold topics, static plots

# %%
topic_wts_2010_2019
# Out:
#     START_YEAR   Topic 0   Topic 1   Topic 2   Topic 3   Topic 4   Topic 5  \
# 40        2010  0.000518  0.001195  0.001783  0.000584  0.001213  0.000830
# 41        2011  0.000509  0.001273  0.001839  0.000600  0.001205  0.000828
# 42        2012  0.000519  0.001173  0.001855  0.000590  0.001251  0.000881
# 43        2013  0.000483  0.001179  0.002049  0.000567  0.001129  0.000890
# 44        2014  0.000488  0.001167  0.001981  0.000581  0.001135  0.000873
# 45        2015  0.000476  0.001255  0.001868  0.000591  0.001194  0.000865
# 46        2016  0.000463  0.001376  0.001672  0.000549  0.001138  0.000859
# 47        2017  0.000496  0.001223  0.001857  0.000590  0.001131  0.000878
# 48        2018  0.000493  0.001328  0.001827  0.000616  0.001172  0.000906
# 49        2019  0.000539  0.000992  0.001990  0.000653  0.001268  0.000948
#
#      Topic 6   Topic 7   Topic 8  ...  Topic 65  Topic 66  Topic 67  Topic 68  \
# 40  0.001048  0.001069  0.000510  ...  0.000887  0.001528  0.000903  0.000774
# 41  0.001212  0.001167  0.000502  ...  0.000863  0.001621  0.000907  0.000805
# 42  0.001140  0.001100  0.000536  ...  0.000885  0.001539  0.000922  0.000806
# 43  0.001560  0.001159  0.000475  ...  0.000769  0.001899  0.000853  0.000742
# 44  0.001308  0.001143  0.000523  ...  0.000820  0.001699  0.000907  0.000785
# 45  0.001342  0.001195  0.000520  ...  0.000767  0.001791  0.000861  0.000776
# 46  0.001149  0.001353  0.000543  ...  0.000851  0.001631  0.000866  0.000840
# 47  0.001205  0.001221  0.000587  ...  0.000837  0.001651  0.000845  0.000852
# 48  0.001054  0.001230  0.000596  ...  0.000851  0.001581  0.000848  0.000868
# 49  0.001207  0.000985  0.000631  ...  0.000866  0.001644  0.000887  0.000893
#
#     Topic 69  Topic 70  Topic 71  Topic 72  Topic 73  Topic 74
# 40  0.000847  0.000893  0.001907  0.000661  0.001849  0.001551
# 41  0.000901  0.000842  0.001815  0.000742  0.001857  0.001514
# 42  0.000918  0.000901  0.001842  0.000691  0.001632  0.001642
# 43  0.000897  0.000798  0.001567  0.000613  0.002075  0.001537
# 44  0.000925  0.000854  0.001551  0.000680  0.001813  0.001547
# 45  0.000946  0.000808  0.001473  0.000651  0.001804  0.001503
# 46  0.001047  0.000806  0.001443  0.000723  0.001661  0.001517
# 47  0.000956  0.000842  0.001476  0.000726  0.001638  0.001584
# 48  0.000983  0.000850  0.001443  0.000780  0.001440  0.001594
# 49  0.000829  0.000933  0.001550  0.000898  0.001441  0.001774
#
# [10 rows x 76 columns]

# %%
# Sean's plots - legend

leg = str_topics(topic_term, tfidf_vectorizer, top_n=5)

# %%
#Make Graphs
#leg = []
topic_results = {}
fig = plt.figure()
fig.suptitle('Hot and Cold Topics', fontsize=16)
ax = fig.add_subplot(111)

for i in range(1,num_topics+1):
    linear_fit = lm().fit(topic_wts_2010_2019["START_YEAR"].values.reshape(-1,1), topic_wts_2010_2019.iloc[:,i].values.reshape(-1,1))
    topic_results[i] = linear_fit.coef_[0][0]
    ax.plot(topic_wts_2010_2019["START_YEAR"], topic_wts_2010_2019.iloc[:,i])
    #leg.append("Topic %d"%(n+1))

plt.xticks(np.arange(topic_wts_2010_2019["START_YEAR"].min(), topic_wts_2010_2019["START_YEAR"].max()+1, 1.0))
plt.xlabel('Year', fontsize=12)
plt.ylabel('Mean Weight', fontsize=12)
#ax.yaxis.set_label_coords(-0.14,0.5)
plt.legend(leg,bbox_to_anchor=(1.05, 1.0, 0.3, 0.2), loc='upper left')
plt.show()

# %%
class HandlerDashedLines(HandlerLineCollection):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize, trans):
        # figure out how many lines there are
        numlines = len(orig_handle.get_segments())
        xdata, xdata_marker = self.get_xdata(legend, xdescent, ydescent,
                                             width, height, fontsize)
        leglines = []
        # divide the vertical space where the lines will go
        # into equal parts based on the number of lines
        ydata = np.full_like(xdata, height / (numlines + 1))
        # for each line, create the line at the proper location
        # and set the dash pattern
        for i in range(numlines):
            legline = Line2D(xdata, ydata * (numlines - i) - ydescent)
            self.update_prop(legline, orig_handle, legend)
            # set color, dash pattern, and linewidth to that
            # of the lines in linecollection
            try:
                color = orig_handle.get_colors()[i]
            except IndexError:
                color = orig_handle.get_colors()[0]
            try:
                dashes = orig_handle.get_dashes()[i]
            except IndexError:
                dashes = orig_handle.get_dashes()[0]
            try:
                lw = orig_handle.get_linewidths()[i]
            except IndexError:
                lw = orig_handle.get_linewidths()[0]
            if dashes[0] is not None:
                legline.set_dashes(dashes[1])
            legline.set_color(color)
            legline.set_transform(trans)
            legline.set_linewidth(lw)
            leglines.append(legline)
        return leglines

# %%
# {column index, slope} - ex) 1: Topic 0 because Topic 0 is column 1 in the dataframe

#topic_results

# %%
def sort_dict(x):
    return sorted(x.items(), key=lambda l: l[1], reverse=True)

# %%
sort_slopes = sort_dict(topic_results)
top_slopes = [x[0] for x in sort_slopes[:5]]
bottom_slopes = [x[0] for x in sort_slopes[-5:]]

# %%
sort_slopes[:5]
# Out:
# [(62, 3.3683334899886546e-05),
#  (17, 3.153637714435134e-05),
#  (46, 2.9411393706615253e-05),
#  (42, 2.6993445093131538e-05),
#  (11, 2.6382139186212044e-05)]

# %%
top_slopes
# Out:
# [62, 17, 46, 42, 11]

# %%
bottom_slopes
# Out:
# [61, 58, 10, 74, 72]

# %% [markdown]
# ## plot hottest and coldest on same plot

# %%
# for plotting hot and cold on same graph

topnbot_slopes = top_slopes + bottom_slopes

# %%
topnbot_slopes
# Out:
# [62, 17, 46, 42, 11, 61, 58, 10, 74, 72]

# %%
# Make Graphs
#leg = []
color_list = plt.rcParams['axes.prop_cycle'].by_key()['color']

#color_list = ["#232d4b","#2c4f6b","#0e879c","#60999a","#d1e0bf","#d9e12b","#e6ce3a","#e6a01d","#e57200", "#ff0000"] #"#fdfdfd"]


line_return = []
fig = plt.figure(figsize=(8,7))
ax = fig.add_subplot(111)
line = [[(0, 0)]]
i = 0
for n in topnbot_slopes:
    linear_fit = lm().fit(topic_wts_2010_2019["START_YEAR"].values.reshape(-1,1), topic_wts_2010_2019.iloc[:,n].values.reshape(-1,1))
    #ax.plot(topic_wts_2010_2019["START_YEAR"], (topic_wts_2010_2019["START_YEAR"]*linear_fit.coef_[0][0])+linear_fit.intercept_,linestyle = 'dashed', color = color_list[i])
    ax.plot(topic_wts_2010_2019["START_YEAR"], topic_wts_2010_2019.iloc[:,n], '-o', color = color_list[i])
    ax.errorbar(topic_wts_2010_2019["START_YEAR"], topic_wts_2010_2019.iloc[:,n], 
            yerr = np.array(topic_wts_se_2010_2019.iloc[:,n]), fmt = "o", color = color_list[i])
    #line_return.append(mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=[color_list[i],color_list[i]]))
    line_return.append(mcol.LineCollection(line, linestyles=['solid'], colors=[color_list[i]]))
    i+=1
    #leg.append("Topic %d"%(n+1))

plt.xticks(np.arange(topic_wts_2010_2019["START_YEAR"].min(), topic_wts_2010_2019["START_YEAR"].max()+1, 1.0))
plt.xlabel('Year', fontsize=12)
plt.ylabel('Mean Topic Weight', fontsize=12)
#plt.ylim(bottom = -0.001, top = 0.05)
plt.title('Top Five Hottest and Coldest Topics', fontsize=16)
#ax.yaxis.set_label_coords(-0.14,0.5)

# set up the proxy artist
lc = mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=['blue','blue'])
lc2 = mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=['orange','orange'])
# create the legend
plt.legend(line_return, [leg[x-1] for x in topnbot_slopes], handler_map={type(line_return[0]): HandlerDashedLines()},
          handlelength=2, handleheight=2,bbox_to_anchor=(1.05, 0.7, 0.3, 0.2), loc='upper left')

#plt.legend([leg[x] for x in top_slopes],bbox_to_anchor=(1.05, 1.0, 0.3, 0.2), loc='upper left')
plt.show()

# %% [markdown]
# ## Plot hottest and coldest topics on separate plots

# %%
# Make Graphs
#leg = []
color_list = plt.rcParams['axes.prop_cycle'].by_key()['color']

#color_list = ["#232d4b","#2c4f6b","#0e879c","#60999a","#d1e0bf","#d9e12b","#e6ce3a","#e6a01d","#e57200", "#ff0000"] #"#fdfdfd"]
#color_list = ["#D3D3D3","#2c4f6b","#C0C0C0","#A9A9A9","#808080","#D3D3D3","#2c4f6b","#D3D3D3","#D3D3D3", "#D3D3D3"] #"#fdfdfd"]


line_return = []
fig = plt.figure()
fig.suptitle('Top Five Hottest Coronavirus Topics', fontsize=16)
ax = fig.add_subplot(111)
line = [[(0, 0)]]
i = 0
for n in top_slopes:
    zorder = 1
    color = color_list[i] #"#D3D3D3"
    if i == 0:
        zorder = 10
        color = color_list[i];
    linear_fit = lm().fit(topic_wts_2010_2019["START_YEAR"].values.reshape(-1,1), topic_wts_2010_2019.iloc[:,n].values.reshape(-1,1))
    #ax.plot(topic_wts_2010_2019["START_YEAR"], (topic_wts_2010_2019["START_YEAR"]*linear_fit.coef_[0][0])+linear_fit.intercept_,linestyle = 'dashed', color = color_list[i])
    ax.plot(topic_wts_2010_2019["START_YEAR"], topic_wts_2010_2019.iloc[:,n], '-o', color = color, zorder = zorder)
    ax.errorbar(topic_wts_2010_2019["START_YEAR"], topic_wts_2010_2019.iloc[:,n], 
            yerr = np.array(topic_wts_se_2010_2019.iloc[:,n]), fmt = "o", color = color, zorder = zorder)
    #line_return.append(mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=[color_list[i],color_list[i]]))
    line_return.append(mcol.LineCollection(line, linestyles=['solid'], colors=[color]))
    i+=1
    #leg.append("Topic %d"%(n+1))

plt.xticks(np.arange(topic_wts_2010_2019["START_YEAR"].min(), topic_wts_2010_2019["START_YEAR"].max()+1, 1.0))
plt.xlabel('Year', fontsize=12)
plt.ylabel('Mean Weight', fontsize=12)
plt.ylim(bottom = -0.002, top = 0.065)
#ax.yaxis.set_label_coords(-0.14,0.5)

# set up the proxy artist
lc = mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=['blue','blue'])
lc2 = mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=['orange','orange'])
# create the legend
plt.legend(line_return, [leg[x-1] for x in top_slopes], handler_map={type(line_return[0]): HandlerDashedLines()},
          handlelength=2, handleheight=2,bbox_to_anchor=(1.05, 0.7, 0.3, 0.2), loc='upper left')

#plt.legend([leg[x] for x in top_slopes],bbox_to_anchor=(1.05, 1.0, 0.3, 0.2), loc='upper left')
plt.show()


#Make Graphs
#leg = []

#bottom_slopes.reverse()  # so the plot legend has the coldest listed first

line_return = []
fig = plt.figure()
fig.suptitle('Top Five Coldest Coronavirus Topics', fontsize=16)
ax = fig.add_subplot(111)
i = 0
for n in bottom_slopes:
    zorder = 1
    color = color_list[i+5] #"#D3D3D3"
    if i == 4:
        zorder = 10
        color = color_list[i+5]
    linear_fit = lm().fit(topic_wts_2010_2019["START_YEAR"].values.reshape(-1,1), topic_wts_2010_2019.iloc[:,n].values.reshape(-1,1))
    #ax.plot(topic_wts_2010_2019["START_YEAR"], (topic_wts_2010_2019["START_YEAR"]*linear_fit.coef_[0][0])+linear_fit.intercept_,linestyle = 'dashed', color = color_list[i+5])
    ax.plot(topic_wts_2010_2019["START_YEAR"], topic_wts_2010_2019.iloc[:,n], '-o', color=color, zorder = zorder)
    ax.errorbar(topic_wts_2010_2019["START_YEAR"], topic_wts_2010_2019.iloc[:,n], 
            yerr = np.array(topic_wts_se_2010_2019.iloc[:,n]), fmt = "o", color=color, zorder = zorder)
    #line_return.append(mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=[color_list[i+5],color_list[i+5]]))
    line_return.append(mcol.LineCollection(line, linestyles=['solid'], colors=[color]))
    i+=1
    #leg.append("Topic %d"%(n+1))

plt.xticks(np.arange(topic_wts_2010_2019["START_YEAR"].min(), topic_wts_2010_2019["START_YEAR"].max()+1, 1.0))
plt.xlabel('Year', fontsize=12)
plt.ylabel('Mean Weight', fontsize=12)
plt.ylim(bottom = -0.002, top = 0.065)
#ax.yaxis.set_label_coords(-0.14,0.5)

# set up the proxy artist
lc = mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=['blue','blue'])
lc2 = mcol.LineCollection(2 * line, linestyles=['solid','dashed'], colors=['orange','orange'])

# create the legend
plt.legend(line_return, [leg[x-1] for x in bottom_slopes], handler_map={type(line_return[0]): HandlerDashedLines()},
          handlelength=2, handleheight=2,bbox_to_anchor=(1.05, 0.7, 0.3, 0.2), loc='upper left')

#plt.legend([leg[x] for x in top_slopes],bbox_to_anchor=(1.05, 1.0, 0.3, 0.2), loc='upper left')
plt.show()

# %%
bottom_slopes
# Out:
# [72, 74, 10, 58, 61]

# %%
[leg[x-1] for x in bottom_slopes]
# Out:
# ['receptor, ligand, bind, activation, gpcr',
#  'facility, user, equipment, instrument, laboratory',
#  'protein, membrane, bind, interaction, structural',
#  'animal, human, testing, contract, product',
#  'water, surface, irrigation, membrane, watershed']

# %%
# save model matrices if needed later

# save to file
topic_term = nmf_model.components_

pickle.dump([doc_topic, topic_term], open('final_model_DT_TT.sav','wb'))

# %%
#Melt to get the data for graphing purposes 
#topic_df = topic_frame.melt(id_vars =['START_YEAR'], var_name = "Topic", value_name = "Weight")
