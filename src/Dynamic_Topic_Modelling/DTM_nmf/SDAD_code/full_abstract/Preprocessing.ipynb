# %%
import pandas as pd
import numpy
import pickle
import time
import joblib
import gensim
import matplotlib.pyplot as plt

from itertools import islice
from scipy.linalg import block_diag
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.corpora import Dictionary, bleicorpus
from gensim.matutils import hellinger

# Remove warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# function to create a new dictionary and corpus
def createLDAvars(docs):

    # Create the variables needed for LDA from df[final_frqwds_removed]: dictionary (id2word), corpus
    
    # Create Dictionary
    id2word = gensim.corpora.Dictionary(docs)

    #Filter words to only those found in at least a set number of documents (min_appearances)
    id2word.filter_extremes(no_below=20, no_above=0.6)
    
    # filter out stop words - "use" already filtered out by previous line
    id2word.filter_tokens(bad_ids=[id2word.token2id['research'], id2word.token2id['aim'], id2word.token2id['project']])

    # Create Corpus (Term Document Frequency)

    #Creates a count for each unique word appearing in the document, where the word_id is substituted for the word
    # corpus not need for c_v coherence
    #corpus = [id2word.doc2bow(doc) for doc in docs]

    return id2word #, corpus


# function to pre-process the data: compute tfidf
def preprocess(df, stopwords):
    # Append all the final tokens
    text = []
    docs = df['list_final_tokens']
    
    for abstract in docs:
        text.append(' '.join(abstract))
        
    # Create the term-document matrix
    tfidf_vectorizer = TfidfVectorizer(max_df=1.0, min_df=0, lowercase=False, stop_words=stop_wds)
    tf_idf = tfidf_vectorizer.fit_transform(text)
            
    return (tf_idf, tfidf_vectorizer)

# %%
# Load the dataset.
df = pd.read_pickle("/project/biocomplexity/sdad/projects_data/ncses/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  ...  \
# 0       NaN        0814512          9/15/2008        8/31/2012  ...
# 1       NaN        0741659          9/15/2008        8/31/2012  ...
# 2       NaN        0813522          9/15/2008        8/31/2011  ...
# 3       NaN        0838627           8/1/2008       12/31/2010  ...
# 4       NaN        0847926          10/1/2008        9/30/2011  ...
#
#   BUDGET_END_DATE CFDA_CODE    FY FY_TOTAL_COST FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008     1999467.0                        NaN
# 1             NaN    47.076  2008     1799699.0                        NaN
# 2             NaN    47.076  2008     1505858.0                        NaN
# 3             NaN    47.049  2008       51000.0                        NaN
# 4             NaN    47.049  2008     1519821.0                        NaN
#
#   ORG_COUNT PI_COUNT FY_TOTAL_COST_SUM NUM_RECORDS  \
# 0         1        1         1999467.0           1
# 1         1        1         1799699.0           1
# 2         1        1         1505858.0           1
# 3         1        1           51000.0           1
# 4         1        1         1519821.0           1
#
#                                         final_tokens
# 0  project explore game base metaphor enhanced ga...
# 1  institution franklin institute science museum ...
# 2  program include small group conversation citiz...
# 3  partnership american chemical society acs nati...
# 4  center molecular interfacing cmi enable integr...
#
# [5 rows x 30 columns]

# %%
# Create a list of tokens 
df["list_final_tokens"] = df["final_tokens"].str.split(' ').tolist()
year = df['FY'].unique()
year
# Out:
# array(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020'], dtype=object)

# %%
# Split the dataset by fiscal year
for fy in year:
    df_subset = df[df['FY']==fy]
    
    # save the pickle file
    pickle.dump(df_subset, open('/project/biocomplexity/sdad/projects_data/ncses/prd/Dynamic_Topics_Modelling/nmf_fullabstract/Data/FR_'+str(fy)+'.pkl','wb'))

# %%
# print a subset of the data (at a given fiscal year): checking
fy = 2009
fw = open('/project/biocomplexity/sdad/projects_data/ncses/prd/Dynamic_Topics_Modelling/nmf_fullabstract/Data/FR_'+str(fy)+'.pkl', 'rb')
dfw = pickle.load(fw)
fw.close()
dfw
# Out:
#        PROJECT_ID                                           ABSTRACT  \
# 95725      103915  EDUCATION IN ACTION NASA Exchange City Learnin...
# 95726      103916  Educational Advancement Alliance Inc Math Scie...
# 95727      103917  CUBRC, Inc FY09 Earmark Entitled,  to continue...
# 95728      103918  University Corporation for Atmospheric Researc...
# 95729      103919  Proposal Number: 0850898PI:  John Doyle       ...
# ...           ...                                                ...
# 199249    1181809  A fully Cancer Center-managed facility, the Fl...
# 199250    1181734  The Cancer Center has an extensive approach to...
# 199251    1181593  DESCRIPTION OF SHARED RESOURCEThe purpose of t...
# 199252    1181484  DESCRIPTION OF SHARED RESOURCESince the incept...
# 199253    1181475  Humans vary in their genetic susceptibility to...
#
#                                             PROJECT_TERMS  \
# 95725   base; Cities; Learning; Mission; next generati...
# 95726   Development; Future; programs; Science; Techno...
# 95727   Development; Educational process of instructin...
# 95728   Joints; Life; programs; Request for Proposals;...
# 95729   Area; base; Computer Architectures; design; De...
# ...                                                   ...
# 199249  7-aminoactinomycin D; Accounting; annexin A5; ...
# 199250           Leadership; oncology; programs; Research
# 199251  Algorithms; base; Biology; Cancer Center; Comp...
# 199252  Animals; anticancer research; Area; Argon; Art...
# 199253  Adverse effects; Aromatic Polycyclic Hydrocarb...
#
#                                             PROJECT_TITLE DEPARTMENT AGENCY  \
# 95725   EDUCATION IN ACTION NASA EXCHANGE CITY LEARNIN...       NASA   NASA
# 95726   EDUCATIONAL ADVANCEMENT ALLIANCE INC MATH SCIE...       NASA   NASA
# 95727   CUBRC, INC FY09 EARMARK ENTITLED, ''TO CONTINU...       NASA   NASA
# 95728   UNIVERSITY CORPORATION FOR ATMOSPHERIC RESEARC...       NASA   NASA
# 95729   PLANNING FUTURE RESEARCH IN NETWORK SCIENCE AN...        NSF    NSF
# ...                                                   ...        ...    ...
# 199249                            FLOW CYTOMETRY RESOURCE        HHS    NIH
# 199250                                 PROGRAM LEADERSHIP        HHS    NIH
# 199251                          CANCER FUNCTIONAL IMAGING        HHS    NIH
# 199252                                       CELL IMAGING        HHS    NIH
# 199253  PROJECT 2: FUNCTIONAL PROFILING OF SUSCEPTIBIL...        HHS    NIH
#
#        IC_CENTER            PROJECT_NUMBER PROJECT_START_DATE  \
# 95725        NaN                NNX09AR64G          10/1/2009
# 95726        NaN                NNX09AQ21G           8/1/2009
# 95727        NaN                NNX09AT31G          10/1/2010
# 95728        NaN                NNX09AW48A          10/1/2009
# 95729        NaN                   0962520           6/1/2009
# ...          ...                       ...                ...
# 199249       NCI  3P30CA013696-36S3 (9014)                NaN
# 199250       NCI  3P30CA006973-47S5 (0002)                NaN
# 199251       NCI  3P30CA006973-47S5 (9036)                NaN
# 199252       NCI  3P30CA006973-47S5 (9006)                NaN
# 199253     NIEHS  3P42ES004705-22S3 (0028)          9/17/2009
#
#        PROJECT_END_DATE  ... CFDA_CODE    FY FY_TOTAL_COST  \
# 95725         9/30/2010  ...    43.001  2009      180776.0
# 95726         7/31/2010  ...    43.001  2009     2750000.0
# 95727         9/30/2011  ...    43.AAA  2009      250000.0
# 95728         9/30/2011  ...    43.001  2009     1605942.0
# 95729         2/28/2011  ...    47.070  2009       50400.0
# ...                 ...  ...       ...   ...           ...
# 199249              NaN  ...       NaN  2009           NaN
# 199250        9/29/2012  ...       NaN  2009           NaN
# 199251        9/29/2012  ...       NaN  2009           NaN
# 199252        9/29/2012  ...       NaN  2009           NaN
# 199253        9/16/2011  ...       NaN  2009           NaN
#
#        FY_TOTAL_COST_SUB_PROJECTS ORG_COUNT PI_COUNT FY_TOTAL_COST_SUM  \
# 95725                         NaN         1        1          180776.0
# 95726                         NaN         1        1         2750000.0
# 95727                         NaN         1        1          250000.0
# 95728                         NaN         1        1         1605942.0
# 95729                         NaN         1        1           50400.0
# ...                           ...       ...      ...               ...
# 199249                     2049.0         1        1               0.0
# 199250                   233821.0         1        1               0.0
# 199251                    93766.0         1        1               0.0
# 199252                    60852.0         1        1               0.0
# 199253                    11019.0         1        1               0.0
#
#        NUM_RECORDS                                       final_tokens  \
# 95725            1  education action nasa exchange city learning l...
# 95726            1  educational advancement alliance inc math scie...
# 95727            1  cubrc inc fy09_earmark_entitle continue develo...
# 95728            1  university corporation atmospheric research co...
# 95729            1  number 0850898pi john doyle institution univer...
# ...            ...                                                ...
# 199249           2  fully cancer center manage facility flow_cytom...
# 199250           2  cancer center extensive approach program plann...
# 199251           2  shared_resourcethe purpose cancer functional i...
# 199252           2  shared_resourcesince inception cell imaging co...
# 199253           2  human vary genetic susceptibility toxic effect...
#
#                                         list_final_tokens
# 95725   [education, action, nasa, exchange, city, lear...
# 95726   [educational, advancement, alliance, inc, math...
# 95727   [cubrc, inc, fy09_earmark_entitle, continue, d...
# 95728   [university, corporation, atmospheric, researc...
# 95729   [number, 0850898pi, john, doyle, institution, ...
# ...                                                   ...
# 199249  [fully, cancer, center, manage, facility, flow...
# 199250  [cancer, center, extensive, approach, program,...
# 199251  [shared_resourcethe, purpose, cancer, function...
# 199252  [shared_resourcesince, inception, cell, imagin...
# 199253  [human, vary, genetic, susceptibility, toxic, ...
#
# [103529 rows x 31 columns]

# %%
# Create the term-document matrix tfidf for each pkl file
stop_wds = ['research', 'aim', 'project']  # use will be eliminated by max_df

for fy in year:
    # Load the sample for a given year
    fw = open('/project/biocomplexity/sdad/projects_data/ncses/prd/Dynamic_Topics_Modelling/nmf_fullabstract/Data/FR_'+str(fy)+'.pkl', 'rb')
    dfw = pickle.load(fw)
    fw.close()
            
    # Pre-processing the pkl file
    (tf_idf, tfidf_vectorizer) = preprocess(dfw, stop_wds)
    docs = dfw['list_final_tokens']
    
    # Create the dictionary
    dictionary = createLDAvars(docs)
    
    # Save the term-document matrix
    joblib.dump((tf_idf,tfidf_vectorizer,docs,dictionary), '/project/biocomplexity/sdad/projects_data/ncses/prd/Dynamic_Topics_Modelling/nmf_fullabstract/Term_docs_'+str(fy)+'.pkl' )

# %%
# Build the full dictionary and docs (use during the 2nd stage)
docs = df['list_final_tokens']
dictionary = createLDAvars(docs)
path = '/project/biocomplexity/sdad/projects_data/ncses/prd/Dynamic_Topics_Modelling/nmf_fullabstract/'
joblib.dump((docs,dictionary), path+'dico_docs.pkl' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9920623d442b> in <module>
#       2 docs = df['list_final_tokens']
#       3 dictionary = createLDAvars(docs)
# ----> 4 joblib.dump((docs,dictionary), path+'dico_docs.pkl' )
#       5
#
# NameError: name 'path' is not defined

# %%
path = '/project/biocomplexity/sdad/projects_data/ncses/prd/Dynamic_Topics_Modelling/nmf_fullabstract/'
joblib.dump((docs,dictionary), path+'dico_docs.pkl' )
# Out:
# ['/project/biocomplexity/sdad/projects_data/ncses/prd/Dynamic_Topics_Modelling/nmf_fullabstract/dico_docs.pkl']
