# %% [markdown]
# # Emerging Topics final code - Full

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)

import numpy as np
import pickle
import matplotlib.pyplot as plt
import gensim
import time

from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# /home/kjl5t/.local/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# ### Data Ingestion

# %%
# full corpus
#df = pd.read_pickle("~/git/dspg21RnD/data/dspg21RnD/smaller-final-dataset.pkl")

df = pd.read_pickle("../../data/prd/Tech-Report/FR_meta_and_final_tokens_21SEPT14.pkl")

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT    FY  \
# 0  This is a project to explore Game-based, Metap...  2008
# 1  Institution: Franklin Institute Science Museum...  2008
# 2  Through programs (including small group conver...  2008
# 3  In partnership with the American Chemical Soci...  2008
# 4  The Center for Molecular Interfacing (CMI) wil...  2008
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE  FY.y  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT                                       final_tokens
# 0          1         1  [project, explore, game, base, metaphor, enhan...
# 1          1         1  [institution, franklin_institute, science, mus...
# 2          1         1  [program, small, group, conversation, citizen,...
# 3          1         1  [partnership, american, chemical, society, acs...
# 4          1         1  [center, molecular, interfacing, cmi, enable, ...

# %%
# input needed for LDA, NMF (all from Scikit-Learn) is one string per document (not a list of strings)

text = []
docs = df["final_tokens"]

for abstract in docs:
    text.append(" ".join(abstract))

# %% [markdown]
# ### Functions needed for all models

# %%
# function slightly modified from https://nlpforhackers.io/topic-modeling/

def print_topics(topic_term_mat, vectorizer, top_n=10):
    for idx, topic in enumerate(topic_term_mat):  # loop through each row of H.  idx = row index.  topic = actual row
        print("\nTopic %d:" % (idx))
        #print([(vectorizer.get_feature_names()[i], topic[i])  # printing out words corresponding to indices found in next line
                        #for i in topic.argsort()[:-top_n - 1:-1]])  # finding indices of top words in topic
            
        print_list = [(vectorizer.get_feature_names()[i], topic[i])  
                        for i in topic.argsort()[:-top_n - 1:-1]]
        for item in print_list:
            print(item)

# %% [markdown]
# ## NMF
# - Optimal Model: full dataset, 75 topics, random_state = 14

# %%
# use for full dataset

stop_wds = ['research', 'use', 'study', 'project']

tfidf_vectorizer = TfidfVectorizer(max_df=0.6, min_df=20, lowercase=False, stop_words=stop_wds)
tf_idf = tfidf_vectorizer.fit_transform(text)

# %%
tf_idf.shape
# Out:
# (696093, 95376)

# %%
# create model

num_topics = 20 

t1 = time.time()
nmf_model = NMF(n_components=num_topics, random_state = 1)
doc_topic = nmf_model.fit_transform(tf_idf)
t2 = time.time()
print(f"  Model time: {t2-t1}")

topic_term = nmf_model.components_
# Out:
#   Model time: 685.1318655014038

# %%
print_topics(topic_term, tfidf_vectorizer, 10)
# Out:
# Topic 0:
# ('cell', 15.050457169241678)
# ('stem', 2.3799323124857215)
# ('tumor', 2.1832560867456756)
# ('differentiation', 1.1652644945121313)
# ('tissue', 1.0258486214976599)
# ('antigen', 0.9626252910248001)
# ('immune', 0.9451342123334716)
# ('progenitor', 0.771568358522116)
# ('type', 0.7627707195323956)
# ('culture', 0.7475925919737014)
#
# Topic 1:
# ('program', 4.091925235220335)
# ('training', 3.941033417483468)
# ('trainee', 2.3714844064566796)
# ('faculty', 1.5852226851435753)
# ('career', 1.18303654808068)
# ('clinical', 1.041650990259731)
# ('mentor', 0.994660867651996)
# ('year', 0.9375399054530383)
# ('scientist', 0.9166743612273652)
# ('translational', 0.8847034603438638)
#
# Topic 2:
# ('core', 6.960161432837773)
# ('administrative', 2.212392924137825)
# ('center', 1.5351607016055062)
# ('investigator', 1.3313189491682835)
# ('provide', 1.1500166137015864)
# ('support', 1.0642729211884994)
# ('service', 0.9632952806334637)
# ('program', 0.8142258484757129)
# ('facility', 0.7506690474090505)
# ('scientific', 0.6870234440699827)
#
# Topic 3:
# ('health', 4.303760751313464)
# ('community', 3.555786254398973)
# ('care', 1.7298762247956607)
# ('disparity', 1.6022953594816987)
# ('center', 1.4733959304919626)
# ('public', 0.8726581129362766)
# ('intervention', 0.8490189672083712)
# ('policy', 0.7738116213446454)
# ('population', 0.7729779005757903)
# ('service', 0.7578478778961685)
#
# Topic 4:
# ('cancer', 7.404120779295831)
# ('breast', 2.2025441780385893)
# ('tumor', 2.186724398194548)
# ('prostate', 1.4436444027823427)
# ('lung', 0.5923459300433671)
# ('metastasis', 0.47112090849684163)
# ('ovarian', 0.4513874361864148)
# ('risk', 0.44660482491266246)
# ('imaging', 0.4163092009254775)
# ('nci', 0.39924362848466816)
#
# Topic 5:
# ('hiv', 8.763905093186112)
# ('aids', 1.1530744531694854)
# ('infect', 0.9995203714974589)
# ('infection', 0.803498634787006)
# ('viral', 0.5679843054115595)
# ('prevention', 0.5444581427522179)
# ('antiretroviral', 0.48530159547019275)
# ('art', 0.45296096067678204)
# ('cfar', 0.44921205409170073)
# ('transmission', 0.4285098000779276)
#
# Topic 6:
# ('system', 2.174841553920179)
# ('material', 1.939350999094575)
# ('imaging', 1.509324318111144)
# ('technology', 1.476915756634362)
# ('develop', 1.3350174594490933)
# ('device', 1.3330305140174765)
# ('new', 1.30603350483574)
# ('energy', 1.2159462360859778)
# ('method', 1.1984263368701455)
# ('high', 1.120465053844686)
#
# Topic 7:
# ('protein', 5.681893276383912)
# ('structure', 1.3116711510618781)
# ('membrane', 1.2883285752597406)
# ('bind', 1.255995918613652)
# ('rna', 1.1930361264621072)
# ('complex', 0.9987293696749517)
# ('interaction', 0.897922389234166)
# ('structural', 0.8103193373024118)
# ('function', 0.8038832268825787)
# ('domain', 0.70280427628771)
#
# Topic 8:
# ('patient', 4.565561941551952)
# ('clinical', 3.4976785819219725)
# ('trial', 2.3509032891593638)
# ('treatment', 1.7351457282519755)
# ('care', 1.3656990742942496)
# ('therapy', 1.0862907022950876)
# ('disease', 1.0341791214109626)
# ('outcome', 0.8595861521820244)
# ('phase', 0.805656475340938)
# ('protocol', 0.7428743613571079)
#
# Topic 9:
# ('gene', 5.137089973792561)
# ('genetic', 1.9249797290208643)
# ('expression', 1.6990711541554484)
# ('rna', 1.2811493411808579)
# ('genome', 1.16984542346455)
# ('identify', 1.122890604373236)
# ('disease', 1.0257798850451076)
# ('mutation', 0.9045793502341087)
# ('variant', 0.8844654060156586)
# ('human', 0.8377181338086276)
#
# Topic 10:
# ('signal', 2.5991231591026294)
# ('mouse', 2.5446299885876296)
# ('pathway', 1.6235813164497965)
# ('receptor', 1.622212641872543)
# ('mechanism', 1.6018576614647089)
# ('role', 1.4801397617761893)
# ('aim', 1.3826733744813207)
# ('induce', 1.3503788404895372)
# ('activation', 1.246084501497306)
# ('insulin', 1.1879734386585201)
#
# Topic 11:
# ('vaccine', 3.447079228320074)
# ('infection', 3.373373846801103)
# ('virus', 2.7831993161697137)
# ('immune', 2.4875067462490756)
# ('response', 1.9517070491494926)
# ('host', 1.5618795257743625)
# ('viral', 1.515198832943033)
# ('pathogen', 1.090164281703176)
# ('influenza', 0.990210596259835)
# ('antibody', 0.9646286676519696)
#
# Topic 12:
# ('student', 6.1493660520814775)
# ('science', 1.9370803193838277)
# ('stem', 1.5734206662450116)
# ('school', 1.494198735766095)
# ('undergraduate', 1.4644802138184139)
# ('engineering', 1.3065032742615088)
# ('graduate', 1.289741912407622)
# ('teacher', 1.247812218696738)
# ('program', 1.2444937639108322)
# ('education', 1.194954505196117)
#
# Topic 13:
# ('data', 5.540151852015838)
# ('analysis', 2.126959984319349)
# ('statistical', 1.479189726583391)
# ('method', 0.9235162771287483)
# ('database', 0.9099656828713872)
# ('software', 0.790235973322906)
# ('tool', 0.785432407777686)
# ('management', 0.7479202282794076)
# ('network', 0.7066367426632587)
# ('resource', 0.694443419869298)
#
# Topic 14:
# ('child', 3.286764220188371)
# ('risk', 2.4502340968111267)
# ('intervention', 1.9608057048640173)
# ('alcohol', 1.4416803686175645)
# ('exposure', 1.1942299413173023)
# ('behavior', 1.1741315655089672)
# ('age', 1.090643681194185)
# ('social', 0.9980772395857647)
# ('adolescent', 0.9819848179784016)
# ('factor', 0.9787269132877426)
#
# Topic 15:
# ('drug', 4.074021431484174)
# ('compound', 1.519939455568041)
# ('target', 1.101396979266886)
# ('screen', 1.0095150478534938)
# ('inhibitor', 0.9510363497766693)
# ('molecule', 0.7331738967743369)
# ('agent', 0.7105453102372542)
# ('assay', 0.699905290411569)
# ('treatment', 0.6674017932769074)
# ('resistance', 0.6555444549609815)
#
# Topic 16:
# ('brain', 3.362165132076127)
# ('ad', 2.0697420725073257)
# ('neuron', 1.5676974538666006)
# ('cognitive', 1.4337809582819787)
# ('neural', 1.1804949159071298)
# ('memory', 0.9750562677682035)
# ('imaging', 0.84758153793446)
# ('neuronal', 0.7559731632487284)
# ('circuit', 0.7145897021061152)
# ('disorder', 0.6766875838932684)
#
# Topic 17:
# ('dna', 4.907334050360435)
# ('repair', 1.1504826723443167)
# ('damage', 1.0636021066712522)
# ('replication', 0.7417382306828094)
# ('genome', 0.6925838178944189)
# ('methylation', 0.603001300714302)
# ('sequence', 0.47328102434405805)
# ('polymerase', 0.41173288023943333)
# ('chromatin', 0.41023029320347354)
# ('sequencing', 0.3871117081927725)
#
# Topic 18:
# ('plant', 2.306080275678665)
# ('water', 2.1535654541306686)
# ('climate', 1.482913585556176)
# ('crop', 1.3365129490464243)
# ('soil', 1.3328069026340226)
# ('food', 1.307889084882023)
# ('species', 1.2549217896411389)
# ('change', 1.237924013609123)
# ('production', 1.1122409242642775)
# ('environmental', 0.9481779774207902)
#
# Topic 19:
# ('conference', 2.770938389778559)
# ('meeting', 1.637350944028985)
# ('workshop', 1.1008676108981383)
# ('researcher', 0.8620279849053303)
# ('field', 0.7505313471745431)
# ('international', 0.7454222665971786)
# ('hold', 0.7015506866012275)
# ('scientist', 0.7012542996535887)
# ('scientific', 0.6116240375787344)
# ('participant', 0.6048034334214352)
