# %% [markdown]
# This code reduces the size of the full dataset by removing columns with intermediate NLP processing steps from Summer 2020.

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)

import pickle

# %%
# full corpus

df = pd.read_pickle("../../../data/prd/Tech-Report/FR_processed_21SEPT14.pkl")

# %%
df.shape
# Out:
# (696093, 35)

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT    FY  \
# 0  This is a project to explore Game-based, Metap...  2008
# 1  Institution: Franklin Institute Science Museum...  2008
# 2  Through programs (including small group conver...  2008
# 3  In partnership with the American Chemical Soci...  2008
# 4  The Center for Molecular Interfacing (CMI) wil...  2008
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# ...

# %%
df.columns
# Out:
# Index(['original index', 'PROJECT_ID', 'ABSTRACT', 'FY', 'PROJECT_TERMS',
#        'PROJECT_TITLE', 'DEPARTMENT', 'AGENCY', 'IC_CENTER', 'PROJECT_NUMBER',
#        'PROJECT_START_DATE', 'PROJECT_END_DATE', 'CONTACT_PI_PROJECT_LEADER',
#        'OTHER_PIS', 'CONGRESSIONAL_DISTRICT', 'DUNS_NUMBER',
#        'ORGANIZATION_NAME', 'ORGANIZATION_CITY', 'ORGANIZATION_STATE',
#        'ORGANIZATION_ZIP', 'ORGANIZATION_COUNTRY', 'BUDGET_START_DATE',
#        'BUDGET_END_DATE', 'CFDA_CODE', 'FY.y', 'FY_TOTAL_COST',
#        'FY_TOTAL_COST_SUB_PROJECTS', 'ORG_COUNT', 'PI_COUNT',
#        'working_abstract', 'lemma_abstract', 'clean_lemmas', 'stopwds_removed',
#        'n_grams_added', 'final_tokens'],
#       dtype='object')

# %%
smaller_df = df.drop(columns=['working_abstract', 'lemma_abstract', \
                              'clean_lemmas', 'stopwds_removed', 'n_grams_added'])

# %%
smaller_df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT    FY  \
# 0  This is a project to explore Game-based, Metap...  2008
# 1  Institution: Franklin Institute Science Museum...  2008
# 2  Through programs (including small group conver...  2008
# 3  In partnership with the American Chemical Soci...  2008
# 4  The Center for Molecular Interfacing (CMI) wil...  2008
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# ...

# %%
# save smaller corpus

smaller_df.to_pickle("../../../data/prd/Tech-Report/FR_meta_and_final_tokens_21SEPT14.pkl")
