# %%
import pandas as pd
import pickle
import numpy as np
import time
import matplotlib.pyplot as plt

import stanza

# %%
nlp = stanza.Pipeline(lang='en',processors='tokenize,pos,lemma',tokenize_batch_size=500,lemma_batch_size=500,
                      use_gpu = True)
# Out:
# 2021-10-15 15:34:49 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# | pos       | ewt     |
# | lemma     | ewt     |
# =======================
#
# 2021-10-15 15:34:49 INFO: Use device: cpu
# 2021-10-15 15:34:49 INFO: Loading: tokenize
# 2021-10-15 15:34:49 INFO: Loading: pos
# 2021-10-15 15:34:50 INFO: Loading: lemma
# 2021-10-15 15:34:50 INFO: Done loading processors!

# %%
nlp("anti-viral by-pass")
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "anti-",
#       "lemma": "anti-",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 0,
#       "end_char": 5
#     },
#     {
#       "id": 2,
#       "text": "viral",
#       "lemma": "viral",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 5,
#       "end_char": 10
#     },
#     {
#       "id": 3,
#       "text": "by",
#       "lemma": "by",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 11,
#       "end_char": 13
#     },
#     {
#       "id": 4,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 13,
#       "end_char": 14
#     },
#     {
#       "id": 5,
#       "text": "pass",
#       "lemma": "pass",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 14,
#       "end_char": 18
#     }
#   ]
# ]

# %%
nlp("Excessive anti-viral inflammation is the likely root cause of IAV-induced acute lung injury (ALI) and the more fatal form adult respiratory distress syndrome (ARDS). There is a great need for  Goldilocks  therapies that target unexploited aspects of IAV infection in the host. Pathogenic influenza strains are known to by-pass neutralizing and immunoregulatory functions of surfactant proteins A (SP-A) and D (SP-D). Importantly, SP-A gene polymorphisms have been associated with increased morbidity and mortality from pandemic influenza-induced ARDS. However, we have found a novel role for the surfactant protein A receptor SP-R210 in IAV infection in vivo, a finding that may overcome this critical knowledge barrier and lead to new therapeutics. Specifically, we found that IAV co-opts the SP-R210 isoform SP-R210L to infect macrophages initiating the disease process of viral replication and inflammation in the lung. ")
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Excessive",
#       "lemma": "excessive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 0,
#       "end_char": 9
#     },
#     {
#       "id": 2,
#       "text": "anti-viral",
#       "lemma": "anti-viral",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 10,
#       "end_char": 20
#     },
#     {
#       "id": 3,
#       "text": "inflammation",
#       "lemma": "inflammation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 21,
#       "end_char": 33
#     },
#     {
#       "id": 4,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 34,
#       "end_char": 36
#     },
#     {
#       "id": 5,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 37,
#       "end_char": 40
#     },
#     {
#       "id": 6,
#       "text": "likely",
#       "lemma": "likely",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 41,
#       "end_char": 47
#     },
#     {
#       "id": 7,
#       "text": "root",
#       "lemma": "root",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 48,
#       "end_char": 52
#     },
#     {
#       "id": 8,
#       "text": "cause",
#       "lemma": "cause",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 53,
#       "end_char": 58
#     },
#     {
#       "id": 9,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 59,
#       "end_char": 61
#     },
#     {
#       "id": 10,
#       "text": "IAV",
#       "lemma": "IAV",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 62,
#       "end_char": 65
#     },
#     {
#       "id": 11,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 65,
#       "end_char": 66
#     },
#     {
#       "id": 12,
#       "text": "induced",
#       "lemma": "induce",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 66,
#       "end_char": 73
#     },
#     {
#       "id": 13,
#       "text": "acute",
#       "lemma": "acute",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 74,
#       "end_char": 79
#     },
#     {
#       "id": 14,
#       "text": "lung",
#       "lemma": "lung",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 80,
#       "end_char": 84
#     },
#     {
#       "id": 15,
#       "text": "injury",
#       "lemma": "injury",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 85,
#       "end_char": 91
#     },
#     {
#       "id": 16,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "start_char": 92,
#       "end_char": 93
#     },
#     {
#       "id": 17,
#       "text": "ALI",
#       "lemma": "ALI",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 93,
#       "end_char": 96
#     },
#     {
#       "id": 18,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "start_char": 96,
#       "end_char": 97
#     },
#     {
#       "id": 19,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 98,
#       "end_char": 101
#     },
#     {
#       "id": 20,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 102,
#       "end_char": 105
#     },
#     {
#       "id": 21,
#       "text": "more",
#       "lemma": "more",
#       "upos": "ADV",
#       "xpos": "RBR",
#       "start_char": 106,
#       "end_char": 110
#     },
#     {
#       "id": 22,
#       "text": "fatal",
#       "lemma": "fatal",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 111,
#       "end_char": 116
#     },
#     {
#       "id": 23,
#       "text": "form",
#       "lemma": "form",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 117,
#       "end_char": 121
#     },
#     {
#       "id": 24,
#       "text": "adult",
#       "lemma": "adult",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 122,
#       "end_char": 127
#     },
#     {
#       "id": 25,
#       "text": "respiratory",
#       "lemma": "respiratory",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 128,
#       "end_char": 139
#     },
#     {
#       "id": 26,
#       "text": "distress",
#       "lemma": "distress",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 140,
#       "end_char": 148
#     },
#     {
#       "id": 27,
#       "text": "syndrome",
#       "lemma": "syndrome",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 149,
#       "end_char": 157
#     },
#     {
#       "id": 28,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "start_char": 158,
#       "end_char": 159
#     },
#     {
#       "id": 29,
#       "text": "ARDS",
#       "lemma": "ARDS",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 159,
#       "end_char": 163
#     },
#     {
#       "id": 30,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "start_char": 163,
#       "end_char": 164
#     },
#     {
#       "id": 31,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 164,
#       "end_char": 165
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "There",
#       "lemma": "there",
#       "upos": "PRON",
#       "xpos": "EX",
#       "start_char": 166,
#       "end_char": 171
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 172,
#       "end_char": 174
#     },
#     {
#       "id": 3,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 175,
#       "end_char": 176
#     },
#     {
#       "id": 4,
#       "text": "great",
#       "lemma": "great",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 177,
#       "end_char": 182
#     },
#     {
#       "id": 5,
#       "text": "need",
#       "lemma": "need",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 183,
#       "end_char": 187
#     },
#     {
#       "id": 6,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 188,
#       "end_char": 191
#     },
#     {
#       "id": 7,
#       "text": "Goldilocks",
#       "lemma": "Goldilocks",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Plur",
#       "start_char": 193,
#       "end_char": 203
#     },
#     {
#       "id": 8,
#       "text": "therapies",
#       "lemma": "therapy",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 205,
#       "end_char": 214
#     },
#     {
#       "id": 9,
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "start_char": 215,
#       "end_char": 219
#     },
#     {
#       "id": 10,
#       "text": "target",
#       "lemma": "target",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 220,
#       "end_char": 226
#     },
#     {
#       "id": 11,
#       "text": "unexploited",
#       "lemma": "unexploit",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 227,
#       "end_char": 238
#     },
#     {
#       "id": 12,
#       "text": "aspects",
#       "lemma": "aspect",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 239,
#       "end_char": 246
#     },
#     {
#       "id": 13,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 247,
#       "end_char": 249
#     },
#     {
#       "id": 14,
#       "text": "IAV",
#       "lemma": "iav",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 250,
#       "end_char": 253
#     },
#     {
#       "id": 15,
#       "text": "infection",
#       "lemma": "infection",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 254,
#       "end_char": 263
#     },
#     {
#       "id": 16,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 264,
#       "end_char": 266
#     },
#     {
#       "id": 17,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 267,
#       "end_char": 270
#     },
#     {
#       "id": 18,
#       "text": "host",
#       "lemma": "host",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 271,
#       "end_char": 275
#     },
#     {
#       "id": 19,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 275,
#       "end_char": 276
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Pathogenic",
#       "lemma": "pathogenic",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 277,
#       "end_char": 287
#     },
#     {
#       "id": 2,
#       "text": "influenza",
#       "lemma": "influenza",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 288,
#       "end_char": 297
#     },
#     {
#       "id": 3,
#       "text": "strains",
#       "lemma": "strain",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 298,
#       "end_char": 305
#     },
#     {
#       "id": 4,
#       "text": "are",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 306,
#       "end_char": 309
#     },
#     {
#       "id": 5,
#       "text": "known",
#       "lemma": "know",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 310,
#       "end_char": 315
#     },
#     {
#       "id": 6,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 316,
#       "end_char": 318
#     },
#     {
#       "id": 7,
#       "text": "by",
#       "lemma": "by",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 319,
#       "end_char": 321
#     },
#     {
#       "id": 8,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 321,
#       "end_char": 322
#     },
#     {
#       "id": 9,
#       "text": "pass",
#       "lemma": "pass",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 322,
#       "end_char": 326
#     },
#     {
#       "id": 10,
#       "text": "neutralizing",
#       "lemma": "neutralizing",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 327,
#       "end_char": 339
#     },
#     {
#       "id": 11,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 340,
#       "end_char": 343
#     },
#     {
#       "id": 12,
#       "text": "immunoregulatory",
#       "lemma": "immunoregulatory",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 344,
#       "end_char": 360
#     },
#     {
#       "id": 13,
#       "text": "functions",
#       "lemma": "function",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 361,
#       "end_char": 370
#     },
#     {
#       "id": 14,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 371,
#       "end_char": 373
#     },
#     {
#       "id": 15,
#       "text": "surfactant",
#       "lemma": "surfactant",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 374,
#       "end_char": 384
#     },
#     {
#       "id": 16,
#       "text": "proteins",
#       "lemma": "protein",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 385,
#       "end_char": 393
#     },
#     {
#       "id": 17,
#       "text": "A",
#       "lemma": "a",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 394,
#       "end_char": 395
#     },
#     {
#       "id": 18,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "start_char": 396,
#       "end_char": 397
#     },
#     {
#       "id": 19,
#       "text": "SP",
#       "lemma": "sp",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 397,
#       "end_char": 399
#     },
#     {
#       "id": 20,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 399,
#       "end_char": 400
#     },
#     {
#       "id": 21,
#       "text": "A",
#       "lemma": "a",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 400,
#       "end_char": 401
#     },
#     {
#       "id": 22,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "start_char": 401,
#       "end_char": 402
#     },
#     {
#       "id": 23,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 403,
#       "end_char": 406
#     },
#     {
#       "id": 24,
#       "text": "D",
#       "lemma": "d",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 407,
#       "end_char": 408
#     },
#     {
#       "id": 25,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "start_char": 409,
#       "end_char": 410
#     },
#     {
#       "id": 26,
#       "text": "SP",
#       "lemma": "sp",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 410,
#       "end_char": 412
#     },
#     {
#       "id": 27,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 412,
#       "end_char": 413
#     },
#     {
#       "id": 28,
#       "text": "D",
#       "lemma": "d",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 413,
#       "end_char": 414
#     },
#     {
#       "id": 29,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "start_char": 414,
#       "end_char": 415
#     },
#     {
#       "id": 30,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 415,
#       "end_char": 416
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Importantly",
#       "lemma": "importantly",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 417,
#       "end_char": 428
#     },
#     {
#       "id": 2,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 428,
#       "end_char": 429
#     },
#     {
#       "id": 3,
#       "text": "SP",
#       "lemma": "sp",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 430,
#       "end_char": 432
#     },
#     {
#       "id": 4,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 432,
#       "end_char": 433
#     },
#     {
#       "id": 5,
#       "text": "A",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 433,
#       "end_char": 434
#     },
#     {
#       "id": 6,
#       "text": "gene",
#       "lemma": "gene",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 435,
#       "end_char": 439
#     },
#     {
#       "id": 7,
#       "text": "polymorphisms",
#       "lemma": "polymorphism",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 440,
#       "end_char": 453
#     },
#     {
#       "id": 8,
#       "text": "have",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 454,
#       "end_char": 458
#     },
#     {
#       "id": 9,
#       "text": "been",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 459,
#       "end_char": 463
#     },
#     {
#       "id": 10,
#       "text": "associated",
#       "lemma": "associate",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "start_char": 464,
#       "end_char": 474
#     },
#     {
#       "id": 11,
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 475,
#       "end_char": 479
#     },
#     {
#       "id": 12,
#       "text": "increased",
#       "lemma": "increase",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 480,
#       "end_char": 489
#     },
#     {
#       "id": 13,
#       "text": "morbidity",
#       "lemma": "morbidity",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 490,
#       "end_char": 499
#     },
#     {
#       "id": 14,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 500,
#       "end_char": 503
#     },
#     {
#       "id": 15,
#       "text": "mortality",
#       "lemma": "mortality",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 504,
#       "end_char": 513
#     },
#     {
#       "id": 16,
#       "text": "from",
#       "lemma": "from",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 514,
#       "end_char": 518
#     },
#     {
#       "id": 17,
#       "text": "pandemic",
#       "lemma": "pandemic",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 519,
#       "end_char": 527
#     },
#     {
#       "id": 18,
#       "text": "influenza",
#       "lemma": "influenza",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 528,
#       "end_char": 537
#     },
#     {
#       "id": 19,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 537,
#       "end_char": 538
#     },
#     {
#       "id": 20,
#       "text": "induced",
#       "lemma": "induce",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 538,
#       "end_char": 545
#     },
#     {
#       "id": 21,
#       "text": "ARDS",
#       "lemma": "ard",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 546,
#       "end_char": 550
#     },
#     {
#       "id": 22,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 550,
#       "end_char": 551
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "However",
#       "lemma": "however",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 552,
#       "end_char": 559
#     },
#     {
#       "id": 2,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 559,
#       "end_char": 560
#     },
#     {
#       "id": 3,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 561,
#       "end_char": 563
#     },
#     {
#       "id": 4,
#       "text": "have",
#       "lemma": "have",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#       "start_char": 564,
#       "end_char": 568
#     },
#     {
#       "id": 5,
#       "text": "found",
#       "lemma": "find",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "start_char": 569,
#       "end_char": 574
#     },
#     {
#       "id": 6,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 575,
#       "end_char": 576
#     },
#     {
#       "id": 7,
#       "text": "novel",
#       "lemma": "novel",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 577,
#       "end_char": 582
#     },
#     {
#       "id": 8,
#       "text": "role",
#       "lemma": "role",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 583,
#       "end_char": 587
#     },
#     {
#       "id": 9,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 588,
#       "end_char": 591
#     },
#     {
#       "id": 10,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 592,
#       "end_char": 595
#     },
#     {
#       "id": 11,
#       "text": "surfactant",
#       "lemma": "surfactant",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 596,
#       "end_char": 606
#     },
#     {
#       "id": 12,
#       "text": "protein",
#       "lemma": "protein",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 607,
#       "end_char": 614
#     },
#     {
#       "id": 13,
#       "text": "A",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 615,
#       "end_char": 616
#     },
#     {
#       "id": 14,
#       "text": "receptor",
#       "lemma": "receptor",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 617,
#       "end_char": 625
#     },
#     {
#       "id": 15,
#       "text": "SP",
#       "lemma": "sp",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 626,
#       "end_char": 628
#     },
#     {
#       "id": 16,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 628,
#       "end_char": 629
#     },
#     {
#       "id": 17,
#       "text": "R210",
#       "lemma": "r210",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 629,
#       "end_char": 633
#     },
#     {
#       "id": 18,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 634,
#       "end_char": 636
#     },
#     {
#       "id": 19,
#       "text": "IAV",
#       "lemma": "iav",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 637,
#       "end_char": 640
#     },
#     {
#       "id": 20,
#       "text": "infection",
#       "lemma": "infection",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 641,
#       "end_char": 650
#     },
#     {
#       "id": 21,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 651,
#       "end_char": 653
#     },
#     {
#       "id": 22,
#       "text": "vivo",
#       "lemma": "vivo",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 654,
#       "end_char": 658
#     },
#     {
#       "id": 23,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 658,
#       "end_char": 659
#     },
#     {
#       "id": 24,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 660,
#       "end_char": 661
#     },
#     {
#       "id": 25,
#       "text": "finding",
#       "lemma": "finding",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 662,
#       "end_char": 669
#     },
#     {
#       "id": 26,
#       "text": "that",
#       "lemma": "that",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "start_char": 670,
#       "end_char": 674
#     },
#     {
#       "id": 27,
#       "text": "may",
#       "lemma": "may",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "start_char": 675,
#       "end_char": 678
#     },
#     {
#       "id": 28,
#       "text": "overcome",
#       "lemma": "overcome",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 679,
#       "end_char": 687
#     },
#     {
#       "id": 29,
#       "text": "this",
#       "lemma": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 688,
#       "end_char": 692
#     },
#     {
#       "id": 30,
#       "text": "critical",
#       "lemma": "critical",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 693,
#       "end_char": 701
#     },
#     {
#       "id": 31,
#       "text": "knowledge",
#       "lemma": "knowledge",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 702,
#       "end_char": 711
#     },
#     {
#       "id": 32,
#       "text": "barrier",
#       "lemma": "barrier",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 712,
#       "end_char": 719
#     },
#     {
#       "id": 33,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 720,
#       "end_char": 723
#     },
#     {
#       "id": 34,
#       "text": "lead",
#       "lemma": "lead",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 724,
#       "end_char": 728
#     },
#     {
#       "id": 35,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 729,
#       "end_char": 731
#     },
#     {
#       "id": 36,
#       "text": "new",
#       "lemma": "new",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 732,
#       "end_char": 735
#     },
#     {
#       "id": 37,
#       "text": "therapeutics",
#       "lemma": "therapeutics",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 736,
#       "end_char": 748
#     },
#     {
#       "id": 38,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 748,
#       "end_char": 749
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Specifically",
#       "lemma": "specifically",
#       "upos": "ADV",
#       "xpos": "RB",
#       "start_char": 750,
#       "end_char": 762
#     },
#     {
#       "id": 2,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 762,
#       "end_char": 763
#     },
#     {
#       "id": 3,
#       "text": "we",
#       "lemma": "we",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "start_char": 764,
#       "end_char": 766
#     },
#     {
#       "id": 4,
#       "text": "found",
#       "lemma": "find",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "start_char": 767,
#       "end_char": 772
#     },
#     {
#       "id": 5,
#       "text": "that",
#       "lemma": "that",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "start_char": 773,
#       "end_char": 777
#     },
#     {
#       "id": 6,
#       "text": "IAV",
#       "lemma": "IAV",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 778,
#       "end_char": 781
#     },
#     {
#       "id": 7,
#       "text": "co-opts",
#       "lemma": "co-opt",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 782,
#       "end_char": 789
#     },
#     {
#       "id": 8,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 790,
#       "end_char": 793
#     },
#     {
#       "id": 9,
#       "text": "SP",
#       "lemma": "sp",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 794,
#       "end_char": 796
#     },
#     {
#       "id": 10,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 796,
#       "end_char": 797
#     },
#     {
#       "id": 11,
#       "text": "R210",
#       "lemma": "r210",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 797,
#       "end_char": 801
#     },
#     {
#       "id": 12,
#       "text": "isoform",
#       "lemma": "isoform",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 802,
#       "end_char": 809
#     },
#     {
#       "id": 13,
#       "text": "SP",
#       "lemma": "sp",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 810,
#       "end_char": 812
#     },
#     {
#       "id": 14,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "start_char": 812,
#       "end_char": 813
#     },
#     {
#       "id": 15,
#       "text": "R210L",
#       "lemma": "r210l",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 813,
#       "end_char": 818
#     },
#     {
#       "id": 16,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "start_char": 819,
#       "end_char": 821
#     },
#     {
#       "id": 17,
#       "text": "infect",
#       "lemma": "infect",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "start_char": 822,
#       "end_char": 828
#     },
#     {
#       "id": 18,
#       "text": "macrophages",
#       "lemma": "macrophage",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 829,
#       "end_char": 840
#     },
#     {
#       "id": 19,
#       "text": "initiating",
#       "lemma": "initiate",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "start_char": 841,
#       "end_char": 851
#     },
#     {
#       "id": 20,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 852,
#       "end_char": 855
#     },
#     {
#       "id": 21,
#       "text": "disease",
#       "lemma": "disease",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 856,
#       "end_char": 863
#     },
#     {
#       "id": 22,
#       "text": "process",
#       "lemma": "process",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 864,
#       "end_char": 871
#     },
#     {
#       "id": 23,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 872,
#       "end_char": 874
#     },
#     {
#       "id": 24,
#       "text": "viral",
#       "lemma": "viral",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 875,
#       "end_char": 880
#     },
#     {
#       "id": 25,
#       "text": "replication",
#       "lemma": "replication",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 881,
#       "end_char": 892
#     },
#     {
#       "id": 26,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "start_char": 893,
#       "end_char": 896
#     },
#     {
#       "id": 27,
#       "text": "inflammation",
#       "lemma": "inflammation",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 897,
#       "end_char": 909
#     },
#     {
#       "id": 28,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 910,
#       "end_char": 912
#     },
#     {
#       "id": 29,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 913,
#       "end_char": 916
#     },
#     {
#       "id": 30,
#       "text": "lung",
#       "lemma": "lung",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 917,
#       "end_char": 921
#     },
#     {
#       "id": 31,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 921,
#       "end_char": 922
#     }
#   ]
# ]
