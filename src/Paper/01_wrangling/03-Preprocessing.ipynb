# %% [markdown]
# # NLP Preprocessing of our dataset
#
# The text has already been cleaned, tokenized, lemmatized, stop words removed.  This script will do a little bit more cleaning and add bigrams and trigrams.

# %%
import pandas as pd
import pickle
import numpy as np
import time

import spacy
#from spacy.lang.en.stop_words import STOP_WORDS
#import gensim
from gensim.models.phrases import Phrases, Phraser
import re

pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### Read in data

# %%
# load saved df.  df['working_abstract'] contains cleaned text.

df = pd.read_pickle("../../../data/prd/Paper/FR_clean_22DEC21.pkl")
df.reset_index(inplace = True)
df.rename(columns={'index':'original index'}, inplace=True)

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                     working_abstract  nchar Start_Char
# 0  This is a project to explore Game-based, Metap...   2057          T
# 1  Institution: Franklin Institute Science Museum...   2053          I
# 2  Through programs (including small group conver...   1154          T
# 3  In partnership with the American Chemical Soci...    875          I
# 4  The Center for Molecular Interfacing (CMI) wil...   2309          T

# %%
# drop start_char, nchar
df = df.drop(columns = ['Start_Char', 'nchar'])

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                     working_abstract
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...

# %%
df.shape
# Out:
# (1143904, 31)

# %%
# read in list of lemmatized tokens.  list is in same order as df rows

file = open("../../../data/prd/Paper/FR_lemmas_22DEC21.pkl",'rb')
lem = pickle.load(file)
file.close()

# %%
df['lemma_abstract'] = lem

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                     working_abstract  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                       lemma_abstract
# 0  [project, explore, game, base, Metaphor, Enhan...
# 1  [institution, Franklin, Institute, Science, Mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, American, Chemical, Society, ACS...
# 4  [Center, Molecular, Interfacing, CMI, enable, ...

# %% [markdown]
# #### lower-case lemmas

# %%
def lower_case(abstract):
    # abstract is a list of string tokens    
    return [x.lower() for x in abstract]
               
df = df.assign(lower_lemmas = df["lemma_abstract"].apply(lower_case))

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                     working_abstract  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                       lemma_abstract  \
# 0  [project, explore, game, base, Metaphor, Enhan...
# 1  [institution, Franklin, Institute, Science, Mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, American, Chemical, Society, ACS...
# 4  [Center, Molecular, Interfacing, CMI, enable, ...
#
#                                         lower_lemmas
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...

# %% [markdown]
# #### Clean-up lemmatized tokens at the start of abstracts

# %% [markdown]
# ##### Helper function for remaining code

# %%
def drop_empties(df, col):
    
    # This function drops empty abstracts from the dataframe
    
    l1 = len(df)
    ix = df[df[col].apply(len)==0].index
    print(ix)
    df.drop(ix,axis=0,inplace=True)
    l2 = len(df)
    
    print(f"dropped {l1-l2}")
    
    return df

# %%
def remove_first_x_tokens(tokened_abstract,bad_start_phrases,max_tokens_to_skip=3):
    
    """removes each bad_start_phrase occuring within max_tokens_to_skip of the front--phrases must be lowered.
    be careful calling this, as order matters! It always starts looking at the first token, which will change 
    between runs.
    both tokened_abstract and each phrase in bad_start_phrases must be a list, not just a string
    eg the phrase 'overall project summary' and 'technical abstract' should be input as a list of lists: 
    [ ['overall','project','summary'],['technical','abstract']] """
    
    assert [type(phrase)==list for phrase in bad_start_phrases] #Make sure not just a string
    
    assert [type(tokened_abstract)==list]

    for token_sequence in bad_start_phrases:
        
        #Look for a match within up to 3 tokens from the start. The reasoning here is some abstract start with
        # numbers indicating sections.  EG 8., 8.a, 8.1.1.--from EDA of first tokens
        
        for idx in range(0,max_tokens_to_skip):
            if tokened_abstract[idx:len(token_sequence)+idx]==token_sequence:
                tokened_abstract=tokened_abstract[len(token_sequence)+idx:]
                break
                
    return tokened_abstract

# %%
start_phrases_to_remove=[['section'],['abstract'],['contact','pd','pi'],['nontechnical'],['non','technical'], 
                         ['non-technical'],['technical'],
                         ['project','summary','abstract'], ['overall','project','summary'],['project','abstract'],
                        ['project','narrative'], ['summary'], ['description','provide','applicant'],
                         ['description','provide','candidate'], ['provide','investigator'],['description']]

# %%
#Remove starting phrases (and any tokens proceeding them up to "x") like 'description', 'provided', 'by', 
# 'applicant'

df = df.assign(clean_lemmas = df["lower_lemmas"].apply(remove_first_x_tokens,args=[start_phrases_to_remove]))
df = drop_empties(df, "clean_lemmas")
# Out:
# Int64Index([373293], dtype='int64')
# dropped 1

# %% [markdown]
# ### Find bigrams and trigrams

# %%
def add_n_grams(docs):

    #Calculate bi and tri grams on tokenized, lemmatized, and stop words removed abstracts -- gensim

    # Build the bigram and trigram models
    bi_phrases = Phrases(docs, min_count=5, threshold=100) # higher threshold --> fewer phrases.
    bigram = Phraser(bi_phrases)  # should provide a speed-up
    bi_docs = bigram[docs]
    
    print("bigrams complete")
    
    tri_phrases = Phrases(bi_docs, threshold=100)  
    trigram = Phraser(tri_phrases)
    tri_docs = trigram[bi_docs]

    return tri_docs

# %%
# add in bigrams and trigrams -- time ~25 minutes

df = df.assign(n_grams_added = add_n_grams(df["clean_lemmas"]))
# Out:
# bigrams complete
# /apps/software/standard/core/anaconda/2020.11-py3.8/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                     working_abstract  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                       lemma_abstract  \
# 0  [project, explore, game, base, Metaphor, Enhan...
# 1  [institution, Franklin, Institute, Science, Mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, American, Chemical, Society, ACS...
# 4  [Center, Molecular, Interfacing, CMI, enable, ...
#
#                                         lower_lemmas  \
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...
#
#                                         clean_lemmas  \
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...
#
#                                        n_grams_added
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...

# %%
len(df)
# Out:
# 1143903

# %%
# drop lower_lemma column
df = df.drop(columns = ['lower_lemmas'])

# %%
df.head()
# Out:
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                     working_abstract  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                       lemma_abstract  \
# 0  [project, explore, game, base, Metaphor, Enhan...
# 1  [institution, Franklin, Institute, Science, Mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, American, Chemical, Society, ACS...
# 4  [Center, Molecular, Interfacing, CMI, enable, ...
#
#                                         clean_lemmas  \
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...
#
#                                        n_grams_added
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...

# %% [markdown]
# ### Final Token Clean-Up
#
# 1. strips hyphens, replaces internal hyphens with _, removes non-alphanumeric tokens, strips leading _ if produced by alphanumeric; then removes those updated tokens that: are numeric but not length 4, or are less than length 2.

# %%
def clean_up_tokens(doc):
    
    """determines for each doc which tokens to clean up formatting further in keep_token, and decides which of 
    these cleaned up tokens will be kept"""
    
    kept_tokens=[]

    for token in doc:
        keep,altered_token=keep_token(token)
        if keep:
            kept_tokens.append(altered_token)
    
    return kept_tokens

# %%
def keep_token(token):
    
    """strips hyphens, replaces internal hyphens with _, removes non-alphanumeric characters in tokens, strips 
    leading and trailing _ if produced by alphanumeric, then removes those updated tokens that: are numeric but 
    not length 4, or are less than length 2."""
    
    token=token.strip('- ') #Removes leading and trailing hyphens
    
    token=token.replace('-','_')
    
    if not str.isalnum(token):
        token=re.sub(r'\W+', '', token)
    
    token=token.strip('_')

    if str.isnumeric(token):
        #keep years
        return (len(token)==4,token)
    else:
        #Keep anything that is alphanumeric if it has at least length 2--allows mixed types e.g. h1n1
        return (len(token)>=2,token)

# %%
df = df.assign(final_tokens = df['n_grams_added'].apply(clean_up_tokens))

# %%
df = drop_empties(df, "final_tokens")
# Out:
# Int64Index([ 83436,  83440,  85499, 280446, 280451, 284406, 284407, 284408,
#             284409, 284410, 284411, 285140, 286132, 286143, 375028, 375029,
#             375030, 375035, 375036, 375037, 375038, 375039, 375040, 375041,
#             375042, 375043, 375046, 375047, 375048, 375049, 375052, 375824,
#             376209, 376210],
#            dtype='int64')
# dropped 34

# %%
print(len(df))
df.head()
# Out:
# 1143869
#    original index PROJECT_ID  \
# 0               0      89996
# 1               1      89997
# 2               2      89998
# 3               3      89999
# 4               5      90001
#
#                                             ABSTRACT  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                     working_abstract  \
# 0  This is a project to explore Game-based, Metap...
# 1  Institution: Franklin Institute Science Museum...
# 2  Through programs (including small group conver...
# 3  In partnership with the American Chemical Soci...
# 4  The Center for Molecular Interfacing (CMI) wil...
#
#                                       lemma_abstract  \
# 0  [project, explore, game, base, Metaphor, Enhan...
# 1  [institution, Franklin, Institute, Science, Mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, American, Chemical, Society, ACS...
# 4  [Center, Molecular, Interfacing, CMI, enable, ...
#
#                                         clean_lemmas  \
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...
#
#                                        n_grams_added  \
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...
#
#                                         final_tokens
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...

# %%
# save nlp columns one at a time due to what appears to be a max limit on data size for pickle 
# (could have spun a session with more memory too I think)

temp_list = []

for entry in df['clean_lemmas']:
    temp_list.append(" ".join(entry))

# %%
file = open("../../../data/prd/Paper/FR_clean_lemmas_23DEC21.pkl", 'wb')
pickle.dump(temp_list, file)
file.close()

# %%
temp_list = []

for entry in df['n_grams_added']:
    temp_list.append(" ".join(entry))

# %%
file = open("../../../data/prd/Paper/FR_n_grams_23DEC21.pkl", 'wb')
pickle.dump(temp_list, file)
file.close()

# %%
# save smaller version of dataset

df = df.drop(columns = ['original index', 'working_abstract', 'lemma_abstract', 'clean_lemmas', 'n_grams_added'])

# %%
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens
# 0  [project, explore, game, base, metaphor, enhan...
# 1  [institution, franklin, institute, science, mu...
# 2  [program, include, small, group, conversation,...
# 3  [partnership, american, chemical, society, acs...
# 4  [center, molecular, interfacing, cmi, enable, ...

# %%
df.shape
# Out:
# (1143869, 30)

# %%
# convert columns with a list of strings per row to one string per row - using a loop for the entries of one token

temp_list = []

for entry in df['final_tokens']:
    temp_list.append(" ".join(entry))

# %%
df['final_tokens'] = temp_list

# %%
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens
# 0  project explore game base metaphor enhanced ga...
# 1  institution franklin institute science museum ...
# 2  program include small group conversation citiz...
# 3  partnership american chemical society acs nati...
# 4  center molecular interfacing cmi enable integr...

# %%
# save final df

df.to_pickle("../../../data/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")
