# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

import pandas as pd
pd.set_option('display.max_columns', 50)

import numpy as np
import pickle
import matplotlib.pyplot as plt
import time
import re
import csv

from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression as lm
from scipy import stats

import matplotlib.collections as mcol
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.lines import Line2D

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

import scipy.sparse
import math

# %%
#data frame with only labeled abstracts
df = pd.read_csv("/home/seh6fy/git/publicrd/data/prd/Digital_abstract_labelled/labelled_abstracts.csv")
#data frame with all of the abstracts
df_big = pd.read_pickle("/home/seh6fy/git/publicrd/data/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")

# %%
df = df[~df.label.isnull()]
df = df[~df.ABSTRACT.isnull()]

# %%
df_big = df_big[~df_big.ABSTRACT.isnull()]

# %%
#creates a dataframe with the training and testing data 
both = [df, df_big]
new_df= pd.concat(both)

# %%
new_df= new_df.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')

# %%
new_df['index']=new_df.index

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
v = TfidfVectorizer()
training = v.fit_transform(new_df['ABSTRACT'])

# %%
train_df = new_df[~new_df.label.isnull()]

# %%
train_df= train_df.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')

# %%
training_data = train_df.sample(frac=0.80, random_state=25)
testing_data = train_df.drop(training_data.index)

# %%
train_id = training_data.index
test_id = testing_data.index

# %%
x_train= training[train_id]
x_test= training[test_id]

# %%
train_df['index'] = train_df.index
y_test = train_df.loc[train_df["index"].isin(test_id)]
y_test = y_test['label']

# %%
train_df['index'] = train_df.index
y_train = train_df.loc[train_df["index"].isin(train_id)]
y_train = y_train['label']

# %%
neighbors = int(math.sqrt(len(train_df.index)))

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors= 30)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=30)

# %%
# from sklearn.svm import SVC
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import StandardScaler
# clf = make_pipeline(StandardScaler(), SVC(gamma='auto', ))
# clf.fit(x_train, y_train)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
confusion = (confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.61      0.49      0.54       104
# Non Big-data       0.66      0.76      0.71       136
#
#     accuracy                           0.64       240
#    macro avg       0.63      0.62      0.62       240
# weighted avg       0.64      0.64      0.63       240

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 50  54]
#  [ 34 102]]

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
import seaborn as sns
labels = ['True Neg','False Pos','False Neg','True Pos']

labels = np.asarray(labels).reshape(2,2)

ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')

ax.set_title('TF-IDF Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()
plt.savefig('tfidf.PNG')

# %%
corpus_test = training[new_df.index]

# %%
corpus_pred = classifier.predict(corpus_test)

# %%
predictions2 = new_df.loc[new_df.index,]
predictions2['PREDICTIONS'] = corpus_pred

# %%
predictions2 = predictions2[["label", "PREDICTIONS","ABSTRACT"]]

# %%
big_data = predictions2.loc[predictions2['PREDICTIONS'] == 'Big-data']

# %%
index = big_data.index

# %%
final_frame = new_df.loc[new_df["index"].isin(index)]

# %%
final_frame = final_frame[final_frame.label.isnull()]

# %%
final_frame
# Out:
#          Unnamed: 0  Duplicates    index PROJECT_ID  \
# 1204            NaN         NaN     1204      90001
# 1205            NaN         NaN     1205      90002
# 1211            NaN         NaN     1211      89992
# 1212            NaN         NaN     1212      90011
# 1214            NaN         NaN     1214      90013
# ...             ...         ...      ...        ...
# 1145052         NaN         NaN  1145052    1294171
# 1145053         NaN         NaN  1145053    1294174
# 1145060         NaN         NaN  1145060    1294181
# 1145063         NaN         NaN  1145063    1294185
# 1145066         NaN         NaN  1145066    1294188
#
#                                                   ABSTRACT  \
# 1204     The Center for Molecular Interfacing (CMI) wil...
# 1205     DRU: Integrated optimization of evacuation and...
# 1211     ABSTRACT: The United States over the past two ...
# 1212     The Ohio State University College of Education...
# 1214     This multidisciplinary project draws upon soci...
# ...                                                    ...
# 1145052  The recent geological record can offer useful ...
# 1145053  The recent geological record can offer useful ...
# 1145060  This Rapid Response Research (RAPID) project e...
# 1145063  This doctoral dissertation project focuses on ...
# 1145066  The COVID-19 pandemic has caused unprecedented...
#
#         Is it related to Big-Data Expert name label  \
# 1204                          NaN         NaN   NaN
# 1205                          NaN         NaN   NaN
# 1211                          NaN         NaN   NaN
# 1212                          NaN         NaN   NaN
# 1214                          NaN         NaN   NaN
# ...                           ...         ...   ...
# 1145052                       NaN         NaN   NaN
# 1145053                       NaN         NaN   NaN
# 1145060                       NaN         NaN   NaN
# 1145063                       NaN         NaN   NaN
# 1145066                       NaN         NaN   NaN
#
#                                              PROJECT_TERMS  \
# 1204     Address; Architecture; Carbon Nanotubes; Catal...
# 1205     Accounting; Address; Affect; American; Area; b...
# 1211     Address; Award; Biomedical Research; Biotechno...
# 1212     career; career development; Collaborations; Co...
# 1214     career; Collaborations; Communities; Complex; ...
# ...                                                    ...
# 1145052                                                NaN
# 1145053                                                NaN
# 1145060                                                NaN
# 1145063                                                NaN
# 1145066                                                NaN
#
#                                              PROJECT_TITLE DEPARTMENT AGENCY  \
# 1204         CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
# 1205     DRU: INTEGRATED OPTIMIZATION OF EVACUATION AND...        NSF    NSF
# 1211     MOD AND DAT: PATENT POOLS AND BIOMEDICAL INNOV...        NSF    NSF
# 1212     MATH AND SCIENCE MIDDLE SCHOOL PATHWAYS PORTAL...        NSF    NSF
# 1214     CDI-TYPE II: WHAT DRIVES THE DYNAMIC CREATION ...        NSF    NSF
# ...                                                    ...        ...    ...
# 1145052  Collaborative  Research: Neotoma  Paleoecology...        NSF    NSF
# 1145053  Collaborative Research: Neotoma Paleoecology D...        NSF    NSF
# 1145060  RAPID: Impacts, Disruption, and Displacement A...        NSF    NSF
# 1145063  Doctoral Dissertation Research: Analyzing the ...        NSF    NSF
# 1145066  Collaborative Research: RAPID: Maintain Mobili...        NSF    NSF
#
#         IC_CENTER PROJECT_NUMBER     PROJECT_START_DATE  \
# 1204          NaN        0847926              10/1/2008
# 1205          NaN        0826832               9/1/2008
# 1211          NaN        0830288              10/1/2008
# 1212          NaN        0840824               9/1/2008
# 1214          NaN        0835614              9/15/2008
# ...           ...            ...                    ...
# 1145052       NaN        1948297   6/1/2020 12:00:00 AM
# 1145053       NaN        1948229   6/1/2020 12:00:00 AM
# 1145060       NaN        2024139  10/1/2019 12:00:00 AM
# 1145063       NaN        1946079   7/1/2020 12:00:00 AM
# 1145066       NaN        2028098  4/15/2020 12:00:00 AM
#
#               PROJECT_END_DATE CONTACT_PI_PROJECT_LEADER  \
# 1204                 9/30/2011          ABRUNA, HECTOR D
# 1205                 8/31/2012        DAVIDSON, RACHEL A
# 1211                 9/30/2011              LERNER, JOSH
# 1212                 8/31/2011       LIGHTLE, KIMBERLY S
# 1214                 8/31/2012         MCFARLAND, DANIEL
# ...                        ...                       ...
# 1145052  5/31/2023 12:00:00 AM                       NaN
# 1145053  5/31/2023 12:00:00 AM                       NaN
# 1145060  1/31/2022 12:00:00 AM                       NaN
# 1145063  6/30/2022 12:00:00 AM                       NaN
# 1145066  3/31/2021 12:00:00 AM                       NaN
#
#                                                  OTHER_PIS  \
# 1204                                                   NaN
# 1205                    NOZICK, LINDA; WACHTENDORF, TRICIA
# 1211                                          TIROLE, JEAN
# 1212        KAHLE, JANE; HENTON, MARY; NAIR-PILLAI, SARITA
# 1214     JURAFSKY, DANIEL; MANNING, CHRISTOPHER; POWELL...
# ...                                                    ...
# 1145052                                                NaN
# 1145053                                                NaN
# 1145060                                                NaN
# 1145063                                                NaN
# 1145066                                                NaN
#
#         CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 1204                        22   872612445
# 1205                        00   059007500
# 1211                        08   054552435
# 1212                        15   071650709
# 1214                        14   009214214
# ...                        ...         ...
# 1145052                    NaN   041071101
# 1145053                    NaN   003403953
# 1145060                    NaN   804878247
# 1145063                    NaN   965088057
# 1145066                    NaN   003387891
#
#                                  ORGANIZATION_NAME ORGANIZATION_CITY  \
# 1204                     CORNELL UNIVERSITY ITHACA            ITHACA
# 1205                        UNIVERSITY OF DELAWARE            NEWARK
# 1211          NATIONAL BUREAU OF ECONOMIC RESEARCH         CAMBRIDGE
# 1212     OHIO STATE UNIVERSITY RESEARCH FOUNDATION          COLUMBUS
# 1214                           STANFORD UNIVERSITY          STANFORD
# ...                                            ...               ...
# 1145052              KENT STATE UNIVERSITY AT KENT               NaN
# 1145053    PENNSYLVANIA STATE UNIVERSITY-UNIV PARK               NaN
# 1145060      STATE UNIVERSITY NEW YORK STONY BROOK               NaN
# 1145063              UNIVERSITY OF HAWAII AT MANOA               NaN
# 1145066          UNIVERSITY OF TENNESSEE KNOXVILLE               NaN
#
#         ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY  \
# 1204                    NY       14850-2820        UNITED STATES
# 1205                    DE       19716-2553        UNITED STATES
# 1211                    MA       02138-5317        UNITED STATES
# 1212                    OH       43210-1016        UNITED STATES
# 1214                    CA       94305-6203        UNITED STATES
# ...                    ...              ...                  ...
# 1145052                NaN              NaN                  NaN
# 1145053                NaN              NaN                  NaN
# 1145060                NaN              NaN                  NaN
# 1145063                NaN              NaN                  NaN
# 1145066                NaN              NaN                  NaN
#
#         BUDGET_START_DATE BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  \
# 1204                  NaN             NaN    47.049  2008      1519821.0
# 1205                  NaN             NaN    47.075  2008       757499.0
# 1211                  NaN             NaN    47.075  2008       400000.0
# 1212                  NaN             NaN    47.076  2008      2369022.0
# 1214                  NaN             NaN    47.076  2008      1186174.0
# ...                   ...             ...       ...   ...            ...
# 1145052               NaN             NaN    47.050  2020        14559.0
# 1145053               NaN             NaN    47.050  2020        74849.0
# 1145060               NaN             NaN    47.041  2020         9689.0
# 1145063               NaN             NaN    47.075  2020        18001.0
# 1145066               NaN             NaN    47.041  2020       132226.0
#
#          FY_TOTAL_COST_SUB_PROJECTS  ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  \
# 1204                            NaN        1.0       1.0          1519821.0
# 1205                            NaN        1.0       1.0           757499.0
# 1211                            NaN        1.0       1.0           400000.0
# 1212                            NaN        1.0       1.0          2369022.0
# 1214                            NaN        1.0       1.0          1186174.0
# ...                             ...        ...       ...                ...
# 1145052                         NaN        1.0       0.0            14559.0
# 1145053                         NaN        9.0       0.0           604915.0
# 1145060                         NaN        1.0       0.0             9689.0
# 1145063                         NaN        1.0       0.0            18001.0
# 1145066                         NaN        2.0       0.0           182205.0
#
#          NUM_RECORDS                                       final_tokens
# 1204             1.0  center molecular interfacing cmi enable integr...
# 1205             1.0  dru integrated optimization evacuation_shelter...
# 1211             1.0  united_states past decade see explosion patent...
# 1212             1.0  ohio state university college education osu na...
# 1214             1.0  multidisciplinary project draw sociology compu...
# ...              ...                                                ...
# 1145052          1.0  recent geological record offer useful insight ...
# 1145053          9.0  recent geological record offer useful insight ...
# 1145060          1.0  rapid response research rapid project examine ...
# 1145063          1.0  doctoral_dissertation project focus create lan...
# 1145066          2.0  covid_19_pandemic cause unprecedented disrupti...
#
# [257123 rows x 36 columns]

# %%
final_frame.to_csv(r'tfidf_refined.csv')

# %%
# merged_inner = merged_inner[[ "PREDICTIONS","ABSTRACT", "PROJECT_ID","PROJECT_TERMS","PROJECT_TITLE","DEPARTMENT","AGENCY","PROJECT_NUMBER","PROJECT_START_DATE","PROJECT_END_DATE","FY_TOTAL_COST"]]

# %%
# merged_inner.to_csv(r'"C:/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/"tfidf_dataframe.csv')

# %%
# from sklearn.metrics import classification_report, confusion_matrix
# print(confusion_matrix(y_test, y_pred))
# print(classification_report(y_test, y_pred))

# %%
# error = []

# # Calculating error for K values between 1 and 40
# for i in range(1, 40):
#     knn = KNeighborsClassifier(n_neighbors=i)
#     knn.fit(x_train, y_train)
#     pred_i = knn.predict(x_test)
#     error.append(np.mean(pred_i != y_test))

# %%
#https://stackabuse.com/k-nearest-neighbors-algorithm-in-python-and-scikit-learn/
