# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

import scipy.sparse
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression as lm
from scipy import stats

import gensim
import nltk
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize, punkt
from gensim.models import KeyedVectors

import matplotlib.collections as plt1
import matplotlib.pyplot as plt2
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.lines import Line2D
import seaborn as sns

import pandas as pd
pd.set_option('display.max_columns', 50)

import pickle
import time
import re
import csv
import math
import pickle
import time
import spacy

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/yhu2bk/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#data frame with only labeled abstracts
df_lab = pd.read_csv("/home/seh6fy/git/publicrd/data/prd/Digital_abstract_labelled/labelled_abstracts.csv")

#data frame with all of the abstracts
df = pd.read_pickle("/home/seh6fy/git/publicrd/data/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")

# %%
# Remove Null Abstracts. Reset the index and create a variable index to link with PROJECT_ID
df = df[~df.ABSTRACT.isnull()]
df.reset_index(inplace = True, drop = True)
df['index'] = df.index
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4

# %%
df_lab = df_lab[['PROJECT_ID','ABSTRACT','Is it related to Big-Data','label']]
df_lab.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0      950056  ï»¿   DESCRIPTION (provided by applicant): Adv...
# 1     1178172  Project Summary/AbstractThe establishment of t...
# 2      163037  DESCRIPTION (provided by applicant): The long-...
# 3      880197  DESCRIPTION (provided by applicant): The most ...
# 4      887331  Transsphenoidal surgery (TSS) is the best trea...
#
#   Is it related to Big-Data         label
# 0                         1      Big-data
# 1                         1      Big-data
# 2                         0  Non Big-data
# 3                         0  Non Big-data
# 4                         0  Non Big-data

# %%
# merge with the labelled data using PROJECT_ID.
df['PROJECT_ID'] = pd.to_numeric(df['PROJECT_ID'])
df_merge = df.merge(df_lab[['PROJECT_ID','Is it related to Big-Data','label']], how='left', on='PROJECT_ID')
len(df_merge)
# Out:
# 1143869

# %%
df_merge
# Out:
#          PROJECT_ID                                           ABSTRACT  \
# 0             89996  This is a project to explore Game-based, Metap...
# 1             89997  Institution: Franklin Institute Science Museum...
# 2             89998  Through programs (including small group conver...
# 3             89999  In partnership with the American Chemical Soci...
# 4             90001  The Center for Molecular Interfacing (CMI) wil...
# ...             ...                                                ...
# 1143864     1294186  Circadian rhythms are fundamental endogenous p...
# 1143865     1294187  Recent research suggests that learning about g...
# 1143866     1294188  The COVID-19 pandemic has caused unprecedented...
# 1143867     1294189  Subduction zones – locations where one of the ...
# 1143868     1294190  Stretching for over 80 miles along the Illinoi...
#
#                                              PROJECT_TERMS  \
# 0        Achievement; analog; base; Cognitive Science; ...
# 1        Active Learning; Child; Computer software; des...
# 2        Address; Age; Birth; Brain; Caregivers; Child;...
# 3        Advanced Development; American; Chemicals; Che...
# 4        Address; Architecture; Carbon Nanotubes; Catal...
# ...                                                    ...
# 1143864                                                NaN
# 1143865                                                NaN
# 1143866                                                NaN
# 1143867                                                NaN
# 1143868                                                NaN
#
#                                              PROJECT_TITLE DEPARTMENT AGENCY  \
# 0        RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1        ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2        BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3        FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4            CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
# ...                                                    ...        ...    ...
# 1143864  Revealing the Palatable Meal-Inducible Circadi...        NSF    NSF
# 1143865  Collaborative Research : Improving the teachin...        NSF    NSF
# 1143866  Collaborative Research: RAPID: Maintain Mobili...        NSF    NSF
# 1143867  Collaborative Research: Synthesizing arc-scale...        NSF    NSF
# 1143868  EAGER: Collaborative Research: Invisible Flood...        NSF    NSF
#
#         IC_CENTER PROJECT_NUMBER     PROJECT_START_DATE  \
# 0             NaN        0814512              9/15/2008
# 1             NaN        0741659              9/15/2008
# 2             NaN        0813522              9/15/2008
# 3             NaN        0838627               8/1/2008
# 4             NaN        0847926              10/1/2008
# ...           ...            ...                    ...
# 1143864       NaN        1931115   5/1/2020 12:00:00 AM
# 1143865       NaN        1956119   7/1/2020 12:00:00 AM
# 1143866       NaN        2028098  4/15/2020 12:00:00 AM
# 1143867       NaN        1948834   7/1/2020 12:00:00 AM
# 1143868       NaN        2026780   8/1/2020 12:00:00 AM
#
#               PROJECT_END_DATE CONTACT_PI_PROJECT_LEADER  \
# 0                    8/31/2012           REESE, DEBBIE D
# 1                    8/31/2012            SNYDER, STEVEN
# 2                    8/31/2011    FINK, LAURIE KLEINBAUM
# 3                   12/31/2010              JOST, JOHN W
# 4                    9/30/2011          ABRUNA, HECTOR D
# ...                        ...                       ...
# 1143864  4/30/2025 12:00:00 AM                       NaN
# 1143865  6/30/2025 12:00:00 AM                       NaN
# 1143866  3/31/2021 12:00:00 AM                       NaN
# 1143867  6/30/2023 12:00:00 AM                       NaN
# 1143868  7/31/2022 12:00:00 AM                       NaN
#
#                                          OTHER_PIS CONGRESSIONAL_DISTRICT  \
# 0        CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN                     01
# 1                      ELINICH, KAREN; YOON, SUSAN                     02
# 2              CADIGAN, KAREN; ELLENBOGEN, KIRSTEN                     04
# 3               MILLER, BRADLEY; BOWMAN, KATHERINE                     04
# 4                                              NaN                     22
# ...                                            ...                    ...
# 1143864                                        NaN                    NaN
# 1143865                                        NaN                    NaN
# 1143866                                        NaN                    NaN
# 1143867                                        NaN                    NaN
# 1143868                                        NaN                    NaN
#
#         DUNS_NUMBER                                  ORGANIZATION_NAME  \
# 0         068719400                         WHEELING JESUIT UNIVERSITY
# 1         001741859                                 FRANKLIN INSTITUTE
# 2         061451670                        SCIENCE MUSEUM OF MINNESOTA
# 3         009059242  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY
# 4         872612445                          CORNELL UNIVERSITY ITHACA
# ...             ...                                                ...
# 1143864   800771545                     UNIVERSITY OF TEXAS SW MED CTR
# 1143865   170230239                         UNIVERSITY OF TEXAS AUSTIN
# 1143866   003387891                  UNIVERSITY OF TENNESSEE KNOXVILLE
# 1143867   872612445                          CORNELL UNIVERSITY ITHACA
# 1143868   068552207                              WASHINGTON UNIVERSITY
#
#         ORGANIZATION_CITY ORGANIZATION_STATE ORGANIZATION_ZIP  \
# 0                WHEELING                 WV       26003-6243
# 1            PHILADELPHIA                 PA       19103-1115
# 2              SAINT PAUL                 MN       55102-1202
# 3                  DURHAM                 NC       27709-3757
# 4                  ITHACA                 NY       14850-2820
# ...                   ...                ...              ...
# 1143864               NaN                NaN              NaN
# 1143865               NaN                NaN              NaN
# 1143866               NaN                NaN              NaN
# 1143867               NaN                NaN              NaN
# 1143868               NaN                NaN              NaN
#
#         ORGANIZATION_COUNTRY BUDGET_START_DATE BUDGET_END_DATE CFDA_CODE  \
# 0              UNITED STATES               NaN             NaN    47.076
# 1              UNITED STATES               NaN             NaN    47.076
# 2              UNITED STATES               NaN             NaN    47.076
# 3              UNITED STATES               NaN             NaN    47.049
# 4              UNITED STATES               NaN             NaN    47.049
# ...                      ...               ...             ...       ...
# 1143864                  NaN               NaN             NaN    47.074
# 1143865                  NaN               NaN             NaN    47.076
# 1143866                  NaN               NaN             NaN    47.041
# 1143867                  NaN               NaN             NaN    47.050
# 1143868                  NaN               NaN             NaN    47.050
#
#            FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  ORG_COUNT  PI_COUNT  \
# 0        2008      1999467.0                         NaN          1         1
# 1        2008      1799699.0                         NaN          1         1
# 2        2008      1505858.0                         NaN          1         1
# 3        2008        51000.0                         NaN          1         1
# 4        2008      1519821.0                         NaN          1         1
# ...       ...            ...                         ...        ...       ...
# 1143864  2020       700000.0                         NaN          1         0
# 1143865  2020       136238.0                         NaN          3         0
# 1143866  2020       132226.0                         NaN          2         0
# 1143867  2020        30484.0                         NaN          3         0
# 1143868  2020       164897.0                         NaN          2         0
#
#          FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0                1999467.0            1
# 1                1799699.0            1
# 2                1505858.0            1
# 3                  51000.0            1
# 4                1519821.0            1
# ...                    ...          ...
# 1143864           700000.0            1
# 1143865           672158.0            3
# 1143866           182205.0            2
# 1143867           191004.0            3
# 1143868           299968.0            2
#
#                                               final_tokens    index  \
# 0        project explore game base metaphor enhanced ga...        0
# 1        institution franklin institute science museum ...        1
# 2        program include small group conversation citiz...        2
# 3        partnership american chemical society acs nati...        3
# 4        center molecular interfacing cmi enable integr...        4
# ...                                                    ...      ...
# 1143864  circadian_rhythm fundamental endogenous proper...  1143864
# 1143865  recent research suggest learn genetic high sch...  1143865
# 1143866  covid_19_pandemic cause unprecedented disrupti...  1143866
# 1143867  subduction_zone location earth tectonic_plate ...  1143867
# 1143868  stretch mile illinois bank mississippi_river a...  1143868
#
#         Is it related to Big-Data label
# 0                             NaN   NaN
# 1                             NaN   NaN
# 2                             NaN   NaN
# 3                             NaN   NaN
# 4                             NaN   NaN
# ...                           ...   ...
# 1143864                       NaN   NaN
# 1143865                       NaN   NaN
# 1143866                       NaN   NaN
# 1143867                       NaN   NaN
# 1143868                       NaN   NaN
#
# [1143869 rows x 33 columns]

# %%
# Save project ID of labelled data
project_id_lab = list(df_lab['PROJECT_ID'])

# Get the index of labelled abstract
subset_df = df_merge.loc[df_merge['PROJECT_ID'].isin(project_id_lab),['index', 'PROJECT_ID']]
index_lab = list(subset_df['index'])

# %% [markdown]
# # 1. TFIDF approach

# %% [markdown]
# ## 1.1. Vectorize, build the training and test sample

# %%
# Compute the TFIDF matrix on the full data
v = TfidfVectorizer()
tfidf = v.fit_transform(df['ABSTRACT'])

# %%
# Subset the TFIDF matrix on labelled data: select rows corresponding to the index
tfidf_lab = tfidf[index_lab,:]
tfidf_lab.shape
# Out:
# (1200, 1307953)

# %%
# Build the training and test sample: randomly select 80% of index_lab as training and the rest as test
import random

# Build the index for the training and the test
index_training = random.sample(index_lab, int(0.8 * len(index_lab)))
index_test = list(set(index_lab) - set(index_training))

# sort those index (sort help to extract the Y value for each set)
index_training.sort()
index_test.sort()

# Extract those index in the TFIDF matrix and compute the X training and Test
X_train_tfidf = tfidf[index_training,:]
X_test_tfidf = tfidf[index_test,:]

# %%
# Create Y for training and test using the index order from the sampling
Y_train_tfidf = [df_merge.loc[df_merge['index']== i,'label'].values.tolist() for i in index_training]
Y_train_tfidf = sum(Y_train_tfidf, [])

Y_test_tfidf = [df_merge.loc[df_merge['index']== i,'label'].values.tolist() for i in index_test]
Y_test_tfidf = sum(Y_test_tfidf, [])

# %% [markdown]
# ## 1.2. KNN classifier

# %%
# number of neighbors
k = int(math.sqrt(len(Y_train_tfidf)))
print('Number of neighbors:', k)
# Out:
# Number of neighbors: 30

# %%
# Run KNN
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors= k)
classifier.fit(X_train_tfidf,Y_train_tfidf)
# Out:
# KNeighborsClassifier(n_neighbors=30)

# %%
# Predict the classification
Y_pred_tfidf = classifier.predict(X_test_tfidf)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_tfidf, Y_pred_tfidf)
#print(confusion)
print(classification_report(Y_test_tfidf, Y_pred_tfidf))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.64      0.97      0.77       108
# Non Big-data       0.96      0.55      0.70       132
#
#     accuracy                           0.74       240
#    macro avg       0.80      0.76      0.73       240
# weighted avg       0.81      0.74      0.73       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('KNN Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('tfidf_KNN.PNG')

# %%
# Predict the classification for the whole data: use the whole TFIDF
Y_tfidf = classifier.predict(tfidf)

# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_KNN'] = Y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index  \
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4
#
#   Is it related to Big-Data label Prediction_KNN
# 0                       NaN   NaN       Big-data
# 1                       NaN   NaN       Big-data
# 2                       NaN   NaN       Big-data
# 3                       NaN   NaN   Non Big-data
# 4                       NaN   NaN       Big-data

# %%
# Count the number of projects that is Big data related
df_bigdata = df_merge[df_merge['Prediction_KNN']=='Big-data']
print('Number of abstracts related to Big data:', len(df_bigdata))
# Out:
# Number of abstracts related to Big data: 370506

# %%
cb_pal = {"blue":'#377eb8', "orange":'#ff7f00', "green":'#4daf4a', "pink":'#f781bf', "brown":'#a65628', 
          "purple":'#984ea3', "gray":'#999999', "red":'#e41a1c', "yellow":'#dede00'}

# %%
# Distribution over time and agencies
df_bigdata["FY"] = df_bigdata["FY"].astype('int')
year_counts = df_bigdata['FY'].value_counts().sort_index(ascending=True)

# Distribution
year = year_counts.index.tolist()
count = year_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(year, count, color='navy')
#plt.xlim(-0.7, len(year)-0.3)
plt2.xlim(2007.3,2020.7)
plt2.xticks(year, rotation=45)
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
#x_ticks = ax.xaxis.get_major_ticks()
#x_ticks[-1].label1.set_visible(False)
plt2.xlabel("FY")
plt2.ylabel("Number of Projects")
plt2.title("Big data sample")

plt2.savefig("big_data_time.png", dpi = 800, bbox_inches = "tight")
# Out:
# <ipython-input-20-a496b776c9c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bigdata["FY"] = df_bigdata["FY"].astype('int')
# <ipython-input-20-a496b776c9c3>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

# %%
agency_counts = 100*df_bigdata["DEPARTMENT"].value_counts()/len(df_bigdata)
agency = agency_counts.index.tolist()
count = agency_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(agency, count, color=cb_pal['blue'])
plt2.ylim(0,100)
plt2.xlabel("Agency")
plt2.ylabel("Percent of Dataset")
plt2.title("Project Distribution by Funding Agency")

plt2.savefig("big_data_agency.png", dpi = 800, bbox_inches = "tight")

# %%
# save the data
#df_bigdata.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/tfidf_method.csv")

# %% [markdown]
# ## 1.3. SVM

# %%
# We run SVM with default parameters provides by Sklearn. We train the model
from sklearn import svm
classifier_svm = svm.SVC()
classifier_svm.fit(X_train_tfidf,Y_train_tfidf)
# Out:
# SVC()

# %%
# Predict the classification
Y_pred_tfidf = classifier_svm.predict(X_test_tfidf)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_tfidf, Y_pred_tfidf)
#print(confusion)
print(classification_report(Y_test_tfidf, Y_pred_tfidf))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.88      0.74      0.80       108
# Non Big-data       0.81      0.92      0.86       132
#
#     accuracy                           0.84       240
#    macro avg       0.85      0.83      0.83       240
# weighted avg       0.84      0.84      0.84       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('KNN Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('tfidf_SVM.PNG')

# %%
# Predict the classification for the whole data: use the whole TFIDF
Y_tfidf = classifier_svm.predict(tfidf)

# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_SVM'] = Y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index  \
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4
#
#   Is it related to Big-Data label Prediction_KNN Prediction_SVM
# 0                       NaN   NaN       Big-data   Non Big-data
# 1                       NaN   NaN       Big-data   Non Big-data
# 2                       NaN   NaN       Big-data   Non Big-data
# 3                       NaN   NaN   Non Big-data   Non Big-data
# 4                       NaN   NaN       Big-data   Non Big-data

# %%
# Cross comparision between SVM and KNN
pd.crosstab(df_merge['Prediction_KNN'], df_merge['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_KNN
# Big-data           21710        348796   370506
# Non Big-data          79        773284   773363
# Total              21789       1122080  1143869

# %% [markdown]
# ## 1.4. Decision Tree

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.tree import DecisionTreeClassifier
classifier_DT = DecisionTreeClassifier()
classifier_DT.fit(X_train_tfidf,Y_train_tfidf)
# Out:
# DecisionTreeClassifier()

# %%
# Predict the classification
Y_pred_tfidf = classifier_DT.predict(X_test_tfidf)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_tfidf, Y_pred_tfidf)
#print(confusion)
print(classification_report(Y_test_tfidf, Y_pred_tfidf))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.79      0.75      0.77       108
# Non Big-data       0.80      0.84      0.82       132
#
#     accuracy                           0.80       240
#    macro avg       0.80      0.80      0.80       240
# weighted avg       0.80      0.80      0.80       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('KNN Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('tfidf_DT.PNG')

# %%
# Predict the classification for the whole data: use the whole TFIDF
Y_tfidf = classifier_DT.predict(tfidf)

# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_DT'] = Y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index  \
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4
#
#   Is it related to Big-Data label Prediction_KNN Prediction_SVM Prediction_DT
# 0                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 1                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 2                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 3                       NaN   NaN   Non Big-data   Non Big-data  Non Big-data
# 4                       NaN   NaN       Big-data   Non Big-data  Non Big-data

# %%
# Cross comparision between NN and SVM
pd.crosstab(df_merge['Prediction_DT'], df_merge['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_DT
# Big-data            7972         58797    66769
# Non Big-data       13817       1063283  1077100
# Total              21789       1122080  1143869

# %%
# Cross comparision between NN and KNN
pd.crosstab(df_merge['Prediction_DT'], df_merge['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_DT
# Big-data           38098         28671    66769
# Non Big-data      332408        744692  1077100
# Total             370506        773363  1143869

# %% [markdown]
# ## 1.5. Random Forest

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.ensemble import RandomForestClassifier
classifier_RF = RandomForestClassifier()
classifier_RF.fit(X_train_tfidf,Y_train_tfidf)
# Out:
# RandomForestClassifier()

# %%
# Predict the classification
Y_pred_tfidf = classifier_RF.predict(X_test_tfidf)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_tfidf, Y_pred_tfidf)
#print(confusion)
print(classification_report(Y_test_tfidf, Y_pred_tfidf))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.85      0.65      0.74       108
# Non Big-data       0.76      0.91      0.83       132
#
#     accuracy                           0.79       240
#    macro avg       0.81      0.78      0.78       240
# weighted avg       0.80      0.79      0.79       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('KNN Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('tfidf_RF.PNG')

# %%
# Predict the classification for the whole data: use the whole TFIDF
Y_tfidf = classifier_RF.predict(tfidf)

# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_RF'] = Y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index  \
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4
#
#   Is it related to Big-Data label Prediction_KNN Prediction_SVM Prediction_DT  \
# 0                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 1                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 2                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 3                       NaN   NaN   Non Big-data   Non Big-data  Non Big-data
# 4                       NaN   NaN       Big-data   Non Big-data  Non Big-data
#
#   Prediction_RF
# 0  Non Big-data
# 1  Non Big-data
# 2  Non Big-data
# 3  Non Big-data
# 4      Big-data

# %%
# Cross comparision between RF and DT
pd.crosstab(df_merge['Prediction_RF'], df_merge['Prediction_DT'], margins=True, margins_name="Total")
# Out:
# Prediction_DT  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data           8533         27400    35933
# Non Big-data      58236       1049700  1107936
# Total             66769       1077100  1143869

# %%
# Cross comparision between RF and SVM
pd.crosstab(df_merge['Prediction_RF'], df_merge['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data           13327         22606    35933
# Non Big-data        8462       1099474  1107936
# Total              21789       1122080  1143869

# %%
# Cross comparision between RF and SVM
pd.crosstab(df_merge['Prediction_RF'], df_merge['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data           33750          2183    35933
# Non Big-data      336756        771180  1107936
# Total             370506        773363  1143869

# %% [markdown]
# ## 1.4. Neural network classifier

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.neural_network import MLPClassifier
classifier_nn = MLPClassifier()
classifier_nn.fit(X_train_tfidf,Y_train_tfidf)
# Out:
# MLPClassifier()

# %%
# Predict the classification
Y_pred_tfidf = classifier_nn.predict(X_test_tfidf)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_tfidf, Y_pred_tfidf)
#print(confusion)
print(classification_report(Y_test_tfidf, Y_pred_tfidf))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.84      0.81      0.82       108
# Non Big-data       0.85      0.87      0.86       132
#
#     accuracy                           0.84       240
#    macro avg       0.84      0.84      0.84       240
# weighted avg       0.84      0.84      0.84       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('KNN Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('tfidf_NN.PNG')

# %%
# Predict the classification for the whole data: use the whole TFIDF
Y_tfidf = classifier_nn.predict(tfidf)

# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_NN'] = Y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index  \
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4
#
#   Is it related to Big-Data label Prediction_KNN Prediction_SVM Prediction_DT  \
# 0                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 1                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 2                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 3                       NaN   NaN   Non Big-data   Non Big-data  Non Big-data
# 4                       NaN   NaN       Big-data   Non Big-data  Non Big-data
#
#   Prediction_RF Prediction_NN
# 0  Non Big-data  Non Big-data
# 1  Non Big-data      Big-data
# 2  Non Big-data  Non Big-data
# 3  Non Big-data  Non Big-data
# 4      Big-data  Non Big-data

# %%
# Cross comparision between NN and KNN
pd.crosstab(df_merge['Prediction_NN'], df_merge['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data           85229          4286    89515
# Non Big-data      285277        769077  1054354
# Total             370506        773363  1143869

# %%
# Cross comparision between NN and SVM
pd.crosstab(df_merge['Prediction_NN'], df_merge['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data           19658         69857    89515
# Non Big-data        2131       1052223  1054354
# Total              21789       1122080  1143869

# %%
# Cross comparision between NN and DT
pd.crosstab(df_merge['Prediction_NN'], df_merge['Prediction_DT'], margins=True, margins_name="Total")
# Out:
# Prediction_DT  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data          15210         74305    89515
# Non Big-data      51559       1002795  1054354
# Total             66769       1077100  1143869

# %%
# Cross comparision between NN and RF
pd.crosstab(df_merge['Prediction_NN'], df_merge['Prediction_RF'], margins=True, margins_name="Total")
# Out:
# Prediction_RF  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data          25467         64048    89515
# Non Big-data      10466       1043888  1054354
# Total             35933       1107936  1143869

# %%
# save the data
df_merge.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/FR_final_predicted.csv")

# %% [markdown]
# ## 1.5. Decision rule based on all classifiers

# %%
# Compute a score to be identify as big data
df_merge = pd.read_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/FR_final_predicted.csv")
df_merge['score'] = np.where(df_merge['Prediction_KNN'].str.contains("Non Big-data"), 0, 1) + np.where(df_merge['Prediction_SVM'].str.contains("Non Big-data"), 0, 1) + np.where(df_merge['Prediction_DT'].str.contains("Non Big-data"), 0, 1) + np.where(df_merge['Prediction_RF'].str.contains("Non Big-data"), 0, 1) + np.where(df_merge['Prediction_NN'].str.contains("Non Big-data"), 0, 1)
# Out:
# /apps/software/standard/core/anaconda/2020.11-py3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (3,7,8,11,12,13,14,16,17,18,19,20,21,22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_merge.head()
# Out:
#    Unnamed: 0  PROJECT_ID                                           ABSTRACT  \
# 0           0       89996  This is a project to explore Game-based, Metap...
# 1           1       89997  Institution: Franklin Institute Science Museum...
# 2           2       89998  Through programs (including small group conver...
# 3           3       89999  In partnership with the American Chemical Soci...
# 4           4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                    1.0   068719400
# 1                    2.0   001741859
# 2                    4.0   061451670
# 3                    4.0   009059242
# 4                   22.0   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index  \
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4
#
#   Is it related to Big-Data label Prediction_KNN Prediction_SVM Prediction_DT  \
# 0                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 1                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 2                       NaN   NaN       Big-data   Non Big-data  Non Big-data
# 3                       NaN   NaN   Non Big-data   Non Big-data  Non Big-data
# 4                       NaN   NaN       Big-data   Non Big-data  Non Big-data
#
#   Prediction_RF Prediction_NN  score
# 0  Non Big-data  Non Big-data      1
# 1  Non Big-data      Big-data      2
# 2  Non Big-data  Non Big-data      1
# 3  Non Big-data  Non Big-data      0
# 4      Big-data  Non Big-data      2

# %%
# Distribution of abstracts
df_merge['score'].value_counts()
# Out:
# 0    738966
# 1    287333
# 2     77573
# 3     23219
# 4     11514
# 5      5264
# Name: score, dtype: int64

# %%
# Used a rule (majority votes from classifiers) to identify Big-data abstracts. Useful because we have an impair number of classifier
df_merge['Big_data'] = 0
df_merge.loc[df_merge['score']>2,'Big_data'] = 1
df_merge['Big_data'].value_counts()
# Out:
# 0    1103872
# 1      39997
# Name: Big_data, dtype: int64

# %%
# subset the data to big-data and save
df_bigdata = df_merge[df_merge['Big_data']==1]
df_bigdata.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/abstracts_classification_big_data.csv")

# %% [markdown]
# ## Descriptive statistics of our Big data

# %%
# Distribution over time and agencies
df_bigdata["FY"] = df_bigdata["FY"].astype('int')
year_counts = df_bigdata['FY'].value_counts().sort_index(ascending=True)

# Distribution
year = year_counts.index.tolist()
count = year_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(year, count, color='navy')
#plt.xlim(-0.7, len(year)-0.3)
plt2.xlim(2007.3,2020.7)
plt2.xticks(year, rotation=45)
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
#x_ticks = ax.xaxis.get_major_ticks()
#x_ticks[-1].label1.set_visible(False)
plt2.xlabel("FY")
plt2.ylabel("Number of Projects")
plt2.title("Big data sample")

plt2.savefig("big_data_time.png", dpi = 800, bbox_inches = "tight")
# Out:
# <ipython-input-74-a496b776c9c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bigdata["FY"] = df_bigdata["FY"].astype('int')
# <ipython-input-74-a496b776c9c3>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

# %%
agency_counts = 100*df_bigdata["DEPARTMENT"].value_counts()/len(df_bigdata)
agency = agency_counts.index.tolist()
count = agency_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(agency, count, color=cb_pal['blue'])
plt2.ylim(0,100)
plt2.xlabel("Agency")
plt2.ylabel("Percent of Dataset")
plt2.title("Project Distribution by Funding Agency")

plt2.savefig("big_data_agency.png", dpi = 800, bbox_inches = "tight")
