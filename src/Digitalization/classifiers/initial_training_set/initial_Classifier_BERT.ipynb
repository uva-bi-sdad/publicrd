# %% [markdown]
# ### Classification of FR abstracts as big data or not.
#
# Uses BERT as vectorization and initial labeled dataset of 1200 abstracts.

# %%
import pandas as pd
import numpy as np
import pickle
import time
import math
import seaborn as sns
import matplotlib.pyplot as plt

from sentence_transformers import SentenceTransformer

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import classification_report, confusion_matrix

pd.set_option('display.max_columns', 50)

# %% [markdown]
# #### Ingest Data - labeled set and full corpus

# %%
# read in old training dataset - 1200 labeled abstracts
df_lab = pd.read_csv("../../../../data/prd/Digital_abstract_labelled/AUG-2022-labelled_abstracts.csv")
print(df_lab.shape)
df_lab.head()
# Out:
# (1200, 8)
#    Unnamed: 0  Duplicates  index  PROJECT_ID  \
# 0           0           0    979      950056
# 1           1           0    816     1178172
# 2           2           0   1096      163037
# 3           3           0    725      880197
# 4           4           0     92      887331
#
#                                             ABSTRACT  \
# 0  ï»¿   DESCRIPTION (provided by applicant): Adv...
# 1  Project Summary/AbstractThe establishment of t...
# 2  DESCRIPTION (provided by applicant): The long-...
# 3  DESCRIPTION (provided by applicant): The most ...
# 4  Transsphenoidal surgery (TSS) is the best trea...
#
#    Is it related to Big-Data Expert name         label
# 0                          1    Kristian      Big-data
# 1                          1    Kristian      Big-data
# 2                          0    Kristian  Non Big-data
# 3                          0    Kristian  Non Big-data
# 4                          0    Kristian  Non Big-data

# %%
df_lab = df_lab[['PROJECT_ID','ABSTRACT','Is it related to Big-Data','label']]
df_lab.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0      950056  ï»¿   DESCRIPTION (provided by applicant): Adv...
# 1     1178172  Project Summary/AbstractThe establishment of t...
# 2      163037  DESCRIPTION (provided by applicant): The long-...
# 3      880197  DESCRIPTION (provided by applicant): The most ...
# 4      887331  Transsphenoidal surgery (TSS) is the best trea...
#
#    Is it related to Big-Data         label
# 0                          1      Big-data
# 1                          1      Big-data
# 2                          0  Non Big-data
# 3                          0  Non Big-data
# 4                          0  Non Big-data

# %%
#data frame with all of the abstracts
df = pd.read_pickle("../../../../data/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")

# Reset the df index and create a variable index to link with PROJECT_ID
df.reset_index(inplace = True, drop = True)
print(df.shape)
df.head()
# Out:
# (1143869, 30)
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens
# 0  project explore game base metaphor enhanced ga...
# 1  institution franklin institute science museum ...
# 2  program include small group conversation citiz...
# 3  partnership american chemical society acs nati...
# 4  center molecular interfacing cmi enable integr...

# %%
df = df[['PROJECT_ID','ABSTRACT']]
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...

# %%
# merge with the labelled data using PROJECT_ID.
df['PROJECT_ID'] = pd.to_numeric(df['PROJECT_ID'])
df_merge = df.merge(df_lab[['PROJECT_ID','Is it related to Big-Data','label']], how='left', on='PROJECT_ID')
len(df_merge)
# Out:
# 1143869

# %%
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label
# 0                        NaN   NaN
# 1                        NaN   NaN
# 2                        NaN   NaN
# 3                        NaN   NaN
# 4                        NaN   NaN

# %%
# Save project ID of labelled data
project_id_lab = list(df_lab['PROJECT_ID'])

# Get the index of labelled abstract
subset_df = df_merge.loc[df_merge['PROJECT_ID'].isin(project_id_lab),['PROJECT_ID','label']]

# %%
subset_df.head()
# Out:
#       PROJECT_ID         label
# 1050       91187  Non Big-data
# 1413       91311  Non Big-data
# 3557       93680      Big-data
# 4845       95339  Non Big-data
# 6670       97249  Non Big-data

# %%
# build training and testing sets from the labeled data 
# sklearn to find list of indices for training and test set

X_train_idx, X_test_idx, y_train_bert, y_test_bert = train_test_split(subset_df.index, 
                                                                        subset_df['label'].values, 
                                                                        test_size=0.20, random_state=0, 
                                                                        stratify=subset_df['label'].values)

# %% [markdown]
# # 1. BERT approach

# %% [markdown]
# ## 1.1. Vectorize, build the training and test sample

# %%
# load model
#model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# embed abstracts
#vector = model.encode(df['ABSTRACT'])
#print(vector.shape)

# %%
# save document embeddings
#doc_reps = pd.DataFrame(vector)
#doc_reps.to_csv('BERT_vector_final.csv', index=False)

# %%
doc_reps = pd.read_csv('../../../../data/prd/Doc2Vec/bert_final.csv')
print(doc_reps.shape)
doc_reps.head()
# Out:
# (1143869, 384)
#           0         1         2         3         4         5         6  \
# 0  0.120384  0.008162  0.009289 -0.140070  0.010064  0.007225  0.061013
# 1 -0.005723 -0.023757  0.003688 -0.032687  0.033107  0.032948 -0.014487
# 2  0.036217  0.059167  0.031518 -0.000336  0.046316  0.082325 -0.027813
# 3 -0.030398 -0.084991 -0.039250  0.034691  0.002237  0.018312 -0.046295
# 4 -0.038410 -0.048780 -0.021245  0.033772 -0.002839 -0.030921  0.021801
#
#           7         8         9        10        11        12        13  \
# 0  0.042500  0.095583  0.107619 -0.023043 -0.038347  0.042783  0.032119
# 1 -0.056128 -0.006319  0.053143 -0.035040 -0.070863 -0.011705  0.057314
# 2 -0.004897 -0.024080  0.062721 -0.041332 -0.047162 -0.069163  0.007913
# 3  0.042458  0.025696 -0.037021 -0.088993 -0.029559 -0.023216  0.062934
# 4  0.049377 -0.061806  0.080630  0.049207  0.002447 -0.005403  0.020945
#
#          14        15        16        17        18        19        20  \
# 0  0.110502 -0.038045  0.089364  0.017840 -0.004085 -0.037523  0.129334
# 1 -0.053268 -0.036528  0.070674 -0.011142  0.005872  0.049121  0.080075
# 2 -0.014558  0.036254  0.047470 -0.031500  0.000672 -0.018463 -0.016055
# 3 -0.064281 -0.007081 -0.010292 -0.082310 -0.002397 -0.027546 -0.085231
# 4  0.013926  0.062776  0.002002  0.064310 -0.003859  0.037739  0.040226
#
#          21        22        23        24  ...       359       360       361  \
# 0 -0.043084  0.033499 -0.007758 -0.091202  ... -0.003242 -0.100648  0.000979
# 1 -0.016251  0.039404 -0.010731 -0.042231  ... -0.024683 -0.106609 -0.063258
# 2  0.023507  0.078935  0.047967 -0.032528  ...  0.051790 -0.010477  0.031305
# 3 -0.035928  0.110653  0.031994 -0.054664  ... -0.051298 -0.088649  0.069451
# 4 -0.058133  0.042782 -0.084857 -0.029862  ... -0.007837 -0.023693  0.025372
#
#         362       363       364       365       366       367       368  \
# 0  0.007670  0.033875  0.015629  0.033797 -0.112476 -0.047719 -0.027371
# 1 -0.023506 -0.003999 -0.008228 -0.012774 -0.053927 -0.138681  0.021173
# 2  0.044788 -0.024096 -0.030966  0.047872 -0.023352 -0.003438 -0.014512
# 3 -0.031952  0.027472 -0.030654  0.038263 -0.041856  0.048861  0.010228
# 4 -0.074445 -0.005446 -0.031198  0.027064  0.049099 -0.001438  0.059517
#
#         369       370       371       372       373       374       375  \
# 0  0.061570 -0.091944  0.132762 -0.045460  0.037191  0.084080  0.051874
# 1  0.048514 -0.066839  0.002106 -0.020242  0.052653  0.110053  0.047916
# 2  0.023850 -0.082180 -0.071767  0.073354 -0.009636  0.107215  0.112982
# 3  0.032982 -0.036680 -0.063126 -0.033184 -0.052148  0.051312  0.105293
# 4 -0.025691  0.016474  0.048081 -0.006332 -0.007037 -0.050787  0.048785
#
#         376       377       378       379       380       381       382  \
# 0  0.017190  0.053510 -0.014727  0.020528  0.008453  0.053260 -0.038878
# 1  0.111496 -0.052864 -0.004679  0.068760  0.000062 -0.033812 -0.081289
# 2  0.007532  0.051477  0.016350  0.069353  0.038180  0.169784 -0.068943
# 3 -0.016690 -0.051876  0.035793 -0.041464  0.088343 -0.034776 -0.027763
# 4 -0.153048  0.044875  0.029507 -0.029255  0.036017 -0.118791 -0.065013
#
#         383
# 0  0.035753
# 1  0.092443
# 2  0.057399
# 3 -0.017640
# 4  0.000929
#
# [5 rows x 384 columns]

# %%
# convert to numpy array
doc_reps_np = doc_reps.to_numpy()

# %%
# Create feature train and test sets from the BERT matrix

X_train_bert = doc_reps_np[X_train_idx] 
X_test_bert = doc_reps_np[X_test_idx]

# %% [markdown]
# ## 1.2. KNN classifier

# %%
# number of neighbors
k = int(math.sqrt(len(y_train_bert)))
print('Number of neighbors:', k)
# Out:
# Number of neighbors: 30

# %%
# Run KNN

classifierKNN = KNeighborsClassifier(n_neighbors= k)  # njobs? don't need

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifierKNN, X_train_bert, y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifierKNN.fit(X_train_bert, y_train_bert)

# find model accuracy
classifierKNN.score(X_test_bert,y_test_bert)
# Out:
# [0.86458333 0.75       0.78645833 0.79166667 0.83333333]
# Accuracy: 0.81.   Standard Deviation: 0.04
# 0.7666666666666667

# %%
# Predict the classification
y_pred_bert = classifierKNN.predict(X_test_bert)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_bert, y_pred_bert)
print(confusion)
print(classification_report(y_test_bert, y_pred_bert))
# Out:
# [[ 78  19]
#  [ 37 106]]
#               precision    recall  f1-score   support
#
#     Big-data       0.68      0.80      0.74        97
# Non Big-data       0.85      0.74      0.79       143
#
#     accuracy                           0.77       240
#    macro avg       0.76      0.77      0.76       240
# weighted avg       0.78      0.77      0.77       240

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('KNN Confusion Matrix\n BERT \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/bert_KNN.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data
t1 = time.time()
y_bert = classifierKNN.predict(doc_reps_np)
t2 = time.time()

print(t2-t1)
# Out:
# 22.238367557525635

# %%
# The vector keeps the order from index. Just add the prediction as new variable
df_merge['Prediction_KNN'] = y_bert
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN
# 0                        NaN   NaN       Big-data
# 1                        NaN   NaN   Non Big-data
# 2                        NaN   NaN   Non Big-data
# 3                        NaN   NaN   Non Big-data
# 4                        NaN   NaN   Non Big-data

# %% [markdown]
# ## 1.3. SVM

# %%
# We run SVM with default parameters provides by Sklearn. We train the model

classifier_svm = svm.SVC()

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_svm, X_train_bert, y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_svm.fit(X_train_bert, y_train_bert)

# find model accuracy
classifier_svm.score(X_test_bert,y_test_bert)
# Out:
# [0.86979167 0.79166667 0.84375    0.81770833 0.859375  ]
# Accuracy: 0.84.   Standard Deviation: 0.03
# 0.7958333333333333

# %%
# Predict the classification
y_pred_bert = classifier_svm.predict(X_test_bert)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_bert, y_pred_bert)
print(confusion)
print(classification_report(y_test_bert, y_pred_bert))
# Out:
# [[ 70  27]
#  [ 22 121]]
#               precision    recall  f1-score   support
#
#     Big-data       0.76      0.72      0.74        97
# Non Big-data       0.82      0.85      0.83       143
#
#     accuracy                           0.80       240
#    macro avg       0.79      0.78      0.79       240
# weighted avg       0.79      0.80      0.79       240

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('SVM Confusion Matrix\n BERT \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/bert_SVM.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data
t1 = time.time()
y_bert = classifier_svm.predict(doc_reps_np)
t2 = time.time()

print(t2-t1)
# Out:
# 173.56592440605164

# %%
# The vector keeps the order from index. Just add the prediction as new variable
df_merge['Prediction_SVM'] = y_bert
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM
# 0                        NaN   NaN       Big-data   Non Big-data
# 1                        NaN   NaN   Non Big-data   Non Big-data
# 2                        NaN   NaN   Non Big-data   Non Big-data
# 3                        NaN   NaN   Non Big-data   Non Big-data
# 4                        NaN   NaN   Non Big-data   Non Big-data

# %% [markdown]
# ## 1.4. Decision Tree

# %%
# Use default parameters provides by SKLearn and train the model
classifier_DT = DecisionTreeClassifier(random_state = 0)

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_DT, X_train_bert, y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_DT.fit(X_train_bert, y_train_bert)

# find model accuracy
classifier_DT.score(X_test_bert,y_test_bert)
# Out:
# [0.71354167 0.734375   0.67708333 0.75520833 0.703125  ]
# Accuracy: 0.72.   Standard Deviation: 0.03
# 0.75

# %%
# Predict the classification
y_pred_bert = classifier_DT.predict(X_test_bert)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_bert, y_pred_bert)
print(confusion)
print(classification_report(y_test_bert, y_pred_bert))
# Out:
# [[ 74  23]
#  [ 37 106]]
#               precision    recall  f1-score   support
#
#     Big-data       0.67      0.76      0.71        97
# Non Big-data       0.82      0.74      0.78       143
#
#     accuracy                           0.75       240
#    macro avg       0.74      0.75      0.75       240
# weighted avg       0.76      0.75      0.75       240

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('Decision Tree Confusion Matrix\n BERT \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/bert_DT.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data
t1 = time.time()
y_bert = classifier_DT.predict(doc_reps_np)
t2 = time.time()

print(t2-t1)
# Out:
# 2.6093738079071045

# %%
# The vector keeps the order from index. Just add the prediction as new variable
df_merge['Prediction_DT'] = y_bert
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM Prediction_DT
# 0                        NaN   NaN       Big-data   Non Big-data  Non Big-data
# 1                        NaN   NaN   Non Big-data   Non Big-data      Big-data
# 2                        NaN   NaN   Non Big-data   Non Big-data      Big-data
# 3                        NaN   NaN   Non Big-data   Non Big-data  Non Big-data
# 4                        NaN   NaN   Non Big-data   Non Big-data  Non Big-data

# %% [markdown]
# ## 1.5. Random Forest

# %%
# Use default parameters provides by SKLearn and train the model
classifier_RF = RandomForestClassifier(random_state=0)  # use njobs?

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_RF, X_train_bert, y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_RF.fit(X_train_bert, y_train_bert)

# find model accuracy
classifier_RF.score(X_test_bert,y_test_bert)
# Out:
# [0.83854167 0.796875   0.84375    0.80729167 0.8125    ]
# Accuracy: 0.82.   Standard Deviation: 0.02
# 0.8041666666666667

# %%
# Predict the classification
y_pred_bert = classifier_RF.predict(X_test_bert)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_bert, y_pred_bert)
print(confusion)
print(classification_report(y_test_bert, y_pred_bert))
# Out:
# [[ 66  31]
#  [ 16 127]]
#               precision    recall  f1-score   support
#
#     Big-data       0.80      0.68      0.74        97
# Non Big-data       0.80      0.89      0.84       143
#
#     accuracy                           0.80       240
#    macro avg       0.80      0.78      0.79       240
# weighted avg       0.80      0.80      0.80       240

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('Random Forest Confusion Matrix\n BERT \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/bert_RF.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data
t1 = time.time()
y_bert = classifier_RF.predict(doc_reps_np)
t2 = time.time()

print(t2-t1)
# Out:
# 13.12265920639038

# %%
# The vector keeps the order from index. Just add the prediction as new variable
df_merge['Prediction_RF'] = y_bert
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM  \
# 0                        NaN   NaN       Big-data   Non Big-data
# 1                        NaN   NaN   Non Big-data   Non Big-data
# 2                        NaN   NaN   Non Big-data   Non Big-data
# 3                        NaN   NaN   Non Big-data   Non Big-data
# 4                        NaN   NaN   Non Big-data   Non Big-data
#
#   Prediction_DT Prediction_RF
# 0  Non Big-data  Non Big-data
# 1      Big-data  Non Big-data
# 2      Big-data  Non Big-data
# 3  Non Big-data  Non Big-data
# 4  Non Big-data  Non Big-data

# %% [markdown]
# ## 1.6. Neural network classifier

# %%
# Use default parameters provides by SKLearn and train the model
classifier_nn = MLPClassifier(random_state=0, verbose=True)

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_nn, X_train_bert, y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
t1 = time.time()
classifier_nn.fit(X_train_bert, y_train_bert)
t2 = time.time()

print(t2-t1)

# find model accuracy
classifier_nn.score(X_test_bert,y_test_bert)
# Out:
# Iteration 1, loss = 0.69776449
# Iteration 2, loss = 0.66829112
# Iteration 3, loss = 0.64161356
# Iteration 4, loss = 0.61430528
# Iteration 5, loss = 0.58701359
# Iteration 6, loss = 0.56036510
# Iteration 7, loss = 0.53559321
# Iteration 8, loss = 0.51208256
# Iteration 9, loss = 0.48973699
# Iteration 10, loss = 0.47040559
# Iteration 11, loss = 0.45227986
# Iteration 12, loss = 0.43740570
# Iteration 13, loss = 0.42479104
# Iteration 14, loss = 0.41324606
# Iteration 15, loss = 0.40317041
# Iteration 16, loss = 0.39495511
# Iteration 17, loss = 0.38730340
# Iteration 18, loss = 0.38029087
# Iteration 19, loss = 0.37405481
# Iteration 20, loss = 0.36882735
# Iteration 21, loss = 0.36305281
# Iteration 22, loss = 0.35807965
# Iteration 23, loss = 0.35341624
# Iteration 24, loss = 0.34901443
# Iteration 25, loss = 0.34439188
# Iteration 26, loss = 0.34022952
# Iteration 27, loss = 0.33616652
# Iteration 28, loss = 0.33211089
# Iteration 29, loss = 0.32803565
# Iteration 30, loss = 0.32439080
# Iteration 31, loss = 0.32055315
# Iteration 32, loss = 0.31678611
# Iteration 33, loss = 0.31316434
# Iteration 34, loss = 0.30965715
# Iteration 35, loss = 0.30613699
# Iteration 36, loss = 0.30273077
# Iteration 37, loss = 0.29913727
# Iteration 38, loss = 0.29536090
# Iteration 39, loss = 0.29216389
# Iteration 40, loss = 0.28892445
# Iteration 41, loss = 0.28542632
# Iteration 42, loss = 0.28212513
# Iteration 43, loss = 0.27888533
# Iteration 44, loss = 0.27592975
# Iteration 45, loss = 0.27234134
# Iteration 46, loss = 0.26922447
# Iteration 47, loss = 0.26604197
# Iteration 48, loss = 0.26308532
# Iteration 49, loss = 0.25998865
# Iteration 50, loss = 0.25735224
# Iteration 51, loss = 0.25383330
# Iteration 52, loss = 0.25081729
# Iteration 53, loss = 0.24797730
# Iteration 54, loss = 0.24490756
# Iteration 55, loss = 0.24194573
# Iteration 56, loss = 0.23903004
# Iteration 57, loss = 0.23637746
# Iteration 58, loss = 0.23365480
# Iteration 59, loss = 0.23068860
# Iteration 60, loss = 0.22776246
# Iteration 61, loss = 0.22514313
# Iteration 62, loss = 0.22247608
# Iteration 63, loss = 0.21983982
# Iteration 64, loss = 0.21691353
# Iteration 65, loss = 0.21465432
# Iteration 66, loss = 0.21275538
# Iteration 67, loss = 0.20912988
# Iteration 68, loss = 0.20665924
# Iteration 69, loss = 0.20409414
# Iteration 70, loss = 0.20157529
# Iteration 71, loss = 0.19903564
# Iteration 72, loss = 0.19646159
# Iteration 73, loss = 0.19402435
# Iteration 74, loss = 0.19158462
# Iteration 75, loss = 0.18917189
# Iteration 76, loss = 0.18706637
# Iteration 77, loss = 0.18486121
# Iteration 78, loss = 0.18223672
# Iteration 79, loss = 0.17989509
# Iteration 80, loss = 0.17760375
# Iteration 81, loss = 0.17579277
# Iteration 82, loss = 0.17319728
# Iteration 83, loss = 0.17154136
# Iteration 84, loss = 0.16886281
# Iteration 85, loss = 0.16727426
# Iteration 86, loss = 0.16475389
# Iteration 87, loss = 0.16276115
# Iteration 88, loss = 0.16091723
# Iteration 89, loss = 0.15826247
# Iteration 90, loss = 0.15650769
# Iteration 91, loss = 0.15445716
# Iteration 92, loss = 0.15253084
# Iteration 93, loss = 0.15058285
# Iteration 94, loss = 0.14849375
# Iteration 95, loss = 0.14652530
# Iteration 96, loss = 0.14470819
# Iteration 97, loss = 0.14255446
# Iteration 98, loss = 0.14094815
# Iteration 99, loss = 0.13911893
# Iteration 100, loss = 0.13725074
# Iteration 101, loss = 0.13550483
# Iteration 102, loss = 0.13362295
# Iteration 103, loss = 0.13201923
# Iteration 104, loss = 0.13012826
# Iteration 105, loss = 0.12846006
# Iteration 106, loss = 0.12690381
# Iteration 107, loss = 0.12518337
# Iteration 108, loss = 0.12356583
# Iteration 109, loss = 0.12194349
# Iteration 110, loss = 0.12055224
# Iteration 111, loss = 0.11872520
# Iteration 112, loss = 0.11779210
# Iteration 113, loss = 0.11574503
# Iteration 114, loss = 0.11424830
# Iteration 115, loss = 0.11307668
# Iteration 116, loss = 0.11151778
# Iteration 117, loss = 0.11024221
# Iteration 118, loss = 0.10850091
# Iteration 119, loss = 0.10722638
# Iteration 120, loss = 0.10589670
# Iteration 121, loss = 0.10444934
# Iteration 122, loss = 0.10288614
# Iteration 123, loss = 0.10151341
# Iteration 124, loss = 0.10026577
# Iteration 125, loss = 0.09912414
# Iteration 126, loss = 0.09771549
# Iteration 127, loss = 0.09646836
# Iteration 128, loss = 0.09529080
# Iteration 129, loss = 0.09394646
# Iteration 130, loss = 0.09298176
# Iteration 131, loss = 0.09174476
# Iteration 132, loss = 0.09050422
# Iteration 133, loss = 0.08945271
# Iteration 134, loss = 0.08827170
# Iteration 135, loss = 0.08747714
# Iteration 136, loss = 0.08599330
# Iteration 137, loss = 0.08507317
# Iteration 138, loss = 0.08397610
# Iteration 139, loss = 0.08308924
# Iteration 140, loss = 0.08184312
# Iteration 141, loss = 0.08099907
# Iteration 142, loss = 0.07985131
# Iteration 143, loss = 0.07922795
# Iteration 144, loss = 0.07798559
# Iteration 145, loss = 0.07713757
# Iteration 146, loss = 0.07623034
# Iteration 147, loss = 0.07532633
# Iteration 148, loss = 0.07459891
# Iteration 149, loss = 0.07351475
# Iteration 150, loss = 0.07267892
# Iteration 151, loss = 0.07182987
# Iteration 152, loss = 0.07121671
# Iteration 153, loss = 0.06995778
# Iteration 154, loss = 0.06963765
# Iteration 155, loss = 0.06857162
# Iteration 156, loss = 0.06765092
# Iteration 157, loss = 0.06701730
# Iteration 158, loss = 0.06628631
# Iteration 159, loss = 0.06546674
# Iteration 160, loss = 0.06485851
# Iteration 161, loss = 0.06394207
# Iteration 162, loss = 0.06356723
# Iteration 163, loss = 0.06267592
# Iteration 164, loss = 0.06182284
# Iteration 165, loss = 0.06116467
# Iteration 166, loss = 0.06061900
# Iteration 167, loss = 0.05993885
# Iteration 168, loss = 0.05948126
# Iteration 169, loss = 0.05867961
# Iteration 170, loss = 0.05818633
# Iteration 171, loss = 0.05744631
# Iteration 172, loss = 0.05698785
# Iteration 173, loss = 0.05635970
# Iteration 174, loss = 0.05570387
# Iteration 175, loss = 0.05504810
# Iteration 176, loss = 0.05454819
# Iteration 177, loss = 0.05391455
# Iteration 178, loss = 0.05338550
# Iteration 179, loss = 0.05313680
# Iteration 180, loss = 0.05239241
# Iteration 181, loss = 0.05185260
# Iteration 182, loss = 0.05136854
# Iteration 183, loss = 0.05083984
# Iteration 184, loss = 0.05049370
# Iteration 185, loss = 0.05011552
# Iteration 186, loss = 0.04940386
# Iteration 187, loss = 0.04892217
# Iteration 188, loss = 0.04860449
# Iteration 189, loss = 0.04806346
# Iteration 190, loss = 0.04768309
# Iteration 191, loss = 0.04724915
# Iteration 192, loss = 0.04681254
# Iteration 193, loss = 0.04630423
# Iteration 194, loss = 0.04592816
# Iteration 195, loss = 0.04557109
# Iteration 196, loss = 0.04512207
# Iteration 197, loss = 0.04482546
# Iteration 198, loss = 0.04447320
# Iteration 199, loss = 0.04393073
# Iteration 200, loss = 0.04374623
# Iteration 1, loss = 0.69845764
# Iteration 2, loss = 0.66659364
# Iteration 3, loss = 0.63683194
# Iteration 4, loss = 0.60689282
# Iteration 5, loss = 0.57781424
# Iteration 6, loss = 0.54843627
# Iteration 7, loss = 0.52049403
# Iteration 8, loss = 0.49406753
# Iteration 9, loss = 0.47051292
# Iteration 10, loss = 0.44913338
# Iteration 11, loss = 0.43029331
# Iteration 12, loss = 0.41406958
# Iteration 13, loss = 0.40078621
# Iteration 14, loss = 0.38872469
# Iteration 15, loss = 0.37829535
# Iteration 16, loss = 0.37000472
# Iteration 17, loss = 0.36183735
# Iteration 18, loss = 0.35522653
# Iteration 19, loss = 0.34861021
# Iteration 20, loss = 0.34343182
# Iteration 21, loss = 0.33814119
# Iteration 22, loss = 0.33325121
# Iteration 23, loss = 0.32884434
# Iteration 24, loss = 0.32478249
# /home/kjl5t/.conda/envs/bert_new/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 25, loss = 0.32035398
# Iteration 26, loss = 0.31657473
# Iteration 27, loss = 0.31277229
# Iteration 28, loss = 0.30907139
# Iteration 29, loss = 0.30542126
# Iteration 30, loss = 0.30217935
# Iteration 31, loss = 0.29867247
# Iteration 32, loss = 0.29513065
# Iteration 33, loss = 0.29202422
# Iteration 34, loss = 0.28880237
# Iteration 35, loss = 0.28549042
# Iteration 36, loss = 0.28215192
# Iteration 37, loss = 0.27938067
# Iteration 38, loss = 0.27636307
# Iteration 39, loss = 0.27314591
# Iteration 40, loss = 0.27028584
# Iteration 41, loss = 0.26714757
# Iteration 42, loss = 0.26430161
# Iteration 43, loss = 0.26152847
# Iteration 44, loss = 0.25843321
# Iteration 45, loss = 0.25591376
# Iteration 46, loss = 0.25293776
# Iteration 47, loss = 0.25013898
# Iteration 48, loss = 0.24773979
# Iteration 49, loss = 0.24467949
# Iteration 50, loss = 0.24195156
# Iteration 51, loss = 0.23952210
# Iteration 52, loss = 0.23684906
# Iteration 53, loss = 0.23410463
# Iteration 54, loss = 0.23175500
# Iteration 55, loss = 0.22874870
# Iteration 56, loss = 0.22631228
# Iteration 57, loss = 0.22404236
# Iteration 58, loss = 0.22120121
# Iteration 59, loss = 0.21899714
# Iteration 60, loss = 0.21684306
# Iteration 61, loss = 0.21389804
# Iteration 62, loss = 0.21160011
# Iteration 63, loss = 0.20916982
# Iteration 64, loss = 0.20660532
# Iteration 65, loss = 0.20426667
# Iteration 66, loss = 0.20197776
# Iteration 67, loss = 0.19953329
# Iteration 68, loss = 0.19748084
# Iteration 69, loss = 0.19525610
# Iteration 70, loss = 0.19281330
# Iteration 71, loss = 0.19082799
# Iteration 72, loss = 0.18864813
# Iteration 73, loss = 0.18620997
# Iteration 74, loss = 0.18398618
# Iteration 75, loss = 0.18196449
# Iteration 76, loss = 0.18011898
# Iteration 77, loss = 0.17777874
# Iteration 78, loss = 0.17557623
# Iteration 79, loss = 0.17373766
# Iteration 80, loss = 0.17175728
# Iteration 81, loss = 0.16938801
# Iteration 82, loss = 0.16739364
# Iteration 83, loss = 0.16540069
# Iteration 84, loss = 0.16331379
# Iteration 85, loss = 0.16151325
# Iteration 86, loss = 0.15950659
# Iteration 87, loss = 0.15782593
# Iteration 88, loss = 0.15567345
# Iteration 89, loss = 0.15377646
# Iteration 90, loss = 0.15185881
# Iteration 91, loss = 0.14985486
# Iteration 92, loss = 0.14816933
# Iteration 93, loss = 0.14630918
# Iteration 94, loss = 0.14433789
# Iteration 95, loss = 0.14258442
# Iteration 96, loss = 0.14087557
# Iteration 97, loss = 0.13962713
# Iteration 98, loss = 0.13739797
# Iteration 99, loss = 0.13557549
# Iteration 100, loss = 0.13404577
# Iteration 101, loss = 0.13217038
# Iteration 102, loss = 0.13074843
# Iteration 103, loss = 0.12910789
# Iteration 104, loss = 0.12733443
# Iteration 105, loss = 0.12560995
# Iteration 106, loss = 0.12422952
# Iteration 107, loss = 0.12241829
# Iteration 108, loss = 0.12080878
# Iteration 109, loss = 0.11952389
# Iteration 110, loss = 0.11782952
# Iteration 111, loss = 0.11623144
# Iteration 112, loss = 0.11492632
# Iteration 113, loss = 0.11339931
# Iteration 114, loss = 0.11186231
# Iteration 115, loss = 0.11029229
# Iteration 116, loss = 0.10895815
# Iteration 117, loss = 0.10748515
# Iteration 118, loss = 0.10620302
# Iteration 119, loss = 0.10476592
# Iteration 120, loss = 0.10344578
# Iteration 121, loss = 0.10215948
# Iteration 122, loss = 0.10073553
# Iteration 123, loss = 0.09974926
# Iteration 124, loss = 0.09840827
# Iteration 125, loss = 0.09708495
# Iteration 126, loss = 0.09550733
# Iteration 127, loss = 0.09457701
# Iteration 128, loss = 0.09319646
# Iteration 129, loss = 0.09206545
# Iteration 130, loss = 0.09101402
# Iteration 131, loss = 0.08973127
# Iteration 132, loss = 0.08826628
# Iteration 133, loss = 0.08742178
# Iteration 134, loss = 0.08617519
# Iteration 135, loss = 0.08501488
# Iteration 136, loss = 0.08399326
# Iteration 137, loss = 0.08271096
# Iteration 138, loss = 0.08190694
# Iteration 139, loss = 0.08040060
# Iteration 140, loss = 0.07955974
# Iteration 141, loss = 0.07848459
# Iteration 142, loss = 0.07745209
# Iteration 143, loss = 0.07643527
# Iteration 144, loss = 0.07540825
# Iteration 145, loss = 0.07446962
# Iteration 146, loss = 0.07351434
# Iteration 147, loss = 0.07259429
# Iteration 148, loss = 0.07166258
# Iteration 149, loss = 0.07088673
# Iteration 150, loss = 0.07001056
# Iteration 151, loss = 0.06906154
# Iteration 152, loss = 0.06805353
# Iteration 153, loss = 0.06736617
# Iteration 154, loss = 0.06640323
# Iteration 155, loss = 0.06568293
# Iteration 156, loss = 0.06475244
# Iteration 157, loss = 0.06412224
# Iteration 158, loss = 0.06337459
# Iteration 159, loss = 0.06240815
# Iteration 160, loss = 0.06180081
# Iteration 161, loss = 0.06091740
# Iteration 162, loss = 0.06050546
# Iteration 163, loss = 0.05951856
# Iteration 164, loss = 0.05871293
# Iteration 165, loss = 0.05811093
# Iteration 166, loss = 0.05727804
# Iteration 167, loss = 0.05701749
# Iteration 168, loss = 0.05611151
# Iteration 169, loss = 0.05544400
# Iteration 170, loss = 0.05472128
# Iteration 171, loss = 0.05411000
# Iteration 172, loss = 0.05351035
# Iteration 173, loss = 0.05292376
# Iteration 174, loss = 0.05231480
# Iteration 175, loss = 0.05184931
# Iteration 176, loss = 0.05103857
# Iteration 177, loss = 0.05059529
# Iteration 178, loss = 0.04994218
# Iteration 179, loss = 0.04937940
# Iteration 180, loss = 0.04882138
# Iteration 181, loss = 0.04831895
# Iteration 182, loss = 0.04787991
# Iteration 183, loss = 0.04740715
# Iteration 184, loss = 0.04707356
# Iteration 185, loss = 0.04624891
# Iteration 186, loss = 0.04576777
# Iteration 187, loss = 0.04550934
# Iteration 188, loss = 0.04481856
# Iteration 189, loss = 0.04447335
# Iteration 190, loss = 0.04405331
# Iteration 191, loss = 0.04361803
# Iteration 192, loss = 0.04304003
# Iteration 193, loss = 0.04264903
# Iteration 194, loss = 0.04235303
# Iteration 195, loss = 0.04169154
# Iteration 196, loss = 0.04140793
# Iteration 197, loss = 0.04100465
# Iteration 198, loss = 0.04067466
# Iteration 199, loss = 0.04025273
# Iteration 200, loss = 0.03984236
# Iteration 1, loss = 0.69964531
# Iteration 2, loss = 0.66922593
# Iteration 3, loss = 0.64209791
# Iteration 4, loss = 0.61388103
# Iteration 5, loss = 0.58548277
# Iteration 6, loss = 0.55735233
# Iteration 7, loss = 0.53050734
# Iteration 8, loss = 0.50461691
# Iteration 9, loss = 0.48120304
# Iteration 10, loss = 0.45920964
# Iteration 11, loss = 0.44116106
# Iteration 12, loss = 0.42501678
# Iteration 13, loss = 0.41040260
# Iteration 14, loss = 0.39801400
# Iteration 15, loss = 0.38779813
# Iteration 16, loss = 0.37887726
# Iteration 17, loss = 0.37158565
# Iteration 18, loss = 0.36411013
# Iteration 19, loss = 0.35791755
# Iteration 20, loss = 0.35214514
# Iteration 21, loss = 0.34692059
# Iteration 22, loss = 0.34160012
# Iteration 23, loss = 0.33679276
# Iteration 24, loss = 0.33235000
# Iteration 25, loss = 0.32817670
# Iteration 26, loss = 0.32374273
# /home/kjl5t/.conda/envs/bert_new/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 27, loss = 0.31962533
# Iteration 28, loss = 0.31561612
# Iteration 29, loss = 0.31144275
# Iteration 30, loss = 0.30779130
# Iteration 31, loss = 0.30401678
# Iteration 32, loss = 0.30014358
# Iteration 33, loss = 0.29650585
# Iteration 34, loss = 0.29311979
# Iteration 35, loss = 0.28958822
# Iteration 36, loss = 0.28588740
# Iteration 37, loss = 0.28249155
# Iteration 38, loss = 0.27932303
# Iteration 39, loss = 0.27584209
# Iteration 40, loss = 0.27252025
# Iteration 41, loss = 0.26982074
# Iteration 42, loss = 0.26607343
# Iteration 43, loss = 0.26283086
# Iteration 44, loss = 0.25979013
# Iteration 45, loss = 0.25666698
# Iteration 46, loss = 0.25376669
# Iteration 47, loss = 0.25067390
# Iteration 48, loss = 0.24758926
# Iteration 49, loss = 0.24474458
# Iteration 50, loss = 0.24179605
# Iteration 51, loss = 0.23901496
# Iteration 52, loss = 0.23593876
# Iteration 53, loss = 0.23317018
# Iteration 54, loss = 0.23022630
# Iteration 55, loss = 0.22768212
# Iteration 56, loss = 0.22492116
# Iteration 57, loss = 0.22220501
# Iteration 58, loss = 0.21957111
# Iteration 59, loss = 0.21678423
# Iteration 60, loss = 0.21423471
# Iteration 61, loss = 0.21136089
# Iteration 62, loss = 0.20902745
# Iteration 63, loss = 0.20636529
# Iteration 64, loss = 0.20374310
# Iteration 65, loss = 0.20140650
# Iteration 66, loss = 0.19878618
# Iteration 67, loss = 0.19627482
# Iteration 68, loss = 0.19399434
# Iteration 69, loss = 0.19146239
# Iteration 70, loss = 0.18890861
# Iteration 71, loss = 0.18652130
# Iteration 72, loss = 0.18440817
# Iteration 73, loss = 0.18194731
# Iteration 74, loss = 0.17946520
# Iteration 75, loss = 0.17722859
# Iteration 76, loss = 0.17493931
# Iteration 77, loss = 0.17270192
# Iteration 78, loss = 0.17088335
# Iteration 79, loss = 0.16800545
# Iteration 80, loss = 0.16630235
# Iteration 81, loss = 0.16391584
# Iteration 82, loss = 0.16161609
# Iteration 83, loss = 0.15958733
# Iteration 84, loss = 0.15738853
# Iteration 85, loss = 0.15542319
# Iteration 86, loss = 0.15328645
# Iteration 87, loss = 0.15132714
# Iteration 88, loss = 0.14920856
# Iteration 89, loss = 0.14739018
# Iteration 90, loss = 0.14519574
# Iteration 91, loss = 0.14321930
# Iteration 92, loss = 0.14130016
# Iteration 93, loss = 0.13970884
# Iteration 94, loss = 0.13755757
# Iteration 95, loss = 0.13572035
# Iteration 96, loss = 0.13414931
# Iteration 97, loss = 0.13210803
# Iteration 98, loss = 0.13049587
# Iteration 99, loss = 0.12869953
# Iteration 100, loss = 0.12700666
# Iteration 101, loss = 0.12527459
# Iteration 102, loss = 0.12343851
# Iteration 103, loss = 0.12169489
# Iteration 104, loss = 0.12000402
# Iteration 105, loss = 0.11832968
# Iteration 106, loss = 0.11694366
# Iteration 107, loss = 0.11521615
# Iteration 108, loss = 0.11368151
# Iteration 109, loss = 0.11228336
# Iteration 110, loss = 0.11077597
# Iteration 111, loss = 0.10912209
# Iteration 112, loss = 0.10810198
# Iteration 113, loss = 0.10655068
# Iteration 114, loss = 0.10486539
# Iteration 115, loss = 0.10315218
# Iteration 116, loss = 0.10199558
# Iteration 117, loss = 0.10051425
# Iteration 118, loss = 0.09921835
# Iteration 119, loss = 0.09777575
# Iteration 120, loss = 0.09638346
# Iteration 121, loss = 0.09496067
# Iteration 122, loss = 0.09393040
# Iteration 123, loss = 0.09249418
# Iteration 124, loss = 0.09121613
# Iteration 125, loss = 0.09017110
# Iteration 126, loss = 0.08879214
# Iteration 127, loss = 0.08777896
# Iteration 128, loss = 0.08656010
# Iteration 129, loss = 0.08556616
# Iteration 130, loss = 0.08409776
# Iteration 131, loss = 0.08326519
# Iteration 132, loss = 0.08192992
# Iteration 133, loss = 0.08079794
# Iteration 134, loss = 0.07974939
# Iteration 135, loss = 0.07863379
# Iteration 136, loss = 0.07770237
# Iteration 137, loss = 0.07679383
# Iteration 138, loss = 0.07578744
# Iteration 139, loss = 0.07454775
# Iteration 140, loss = 0.07369796
# Iteration 141, loss = 0.07275038
# Iteration 142, loss = 0.07173178
# Iteration 143, loss = 0.07106577
# Iteration 144, loss = 0.06977111
# Iteration 145, loss = 0.06893290
# Iteration 146, loss = 0.06807393
# Iteration 147, loss = 0.06713918
# Iteration 148, loss = 0.06634102
# Iteration 149, loss = 0.06568607
# Iteration 150, loss = 0.06462622
# Iteration 151, loss = 0.06389987
# Iteration 152, loss = 0.06301594
# Iteration 153, loss = 0.06240152
# Iteration 154, loss = 0.06178026
# Iteration 155, loss = 0.06080608
# Iteration 156, loss = 0.05997619
# Iteration 157, loss = 0.05937072
# Iteration 158, loss = 0.05854185
# Iteration 159, loss = 0.05789620
# Iteration 160, loss = 0.05726836
# Iteration 161, loss = 0.05663568
# Iteration 162, loss = 0.05580395
# Iteration 163, loss = 0.05508144
# Iteration 164, loss = 0.05460537
# Iteration 165, loss = 0.05382029
# Iteration 166, loss = 0.05327624
# Iteration 167, loss = 0.05263652
# Iteration 168, loss = 0.05206644
# Iteration 169, loss = 0.05138007
# Iteration 170, loss = 0.05094556
# Iteration 171, loss = 0.05049631
# Iteration 172, loss = 0.04969448
# Iteration 173, loss = 0.04939141
# Iteration 174, loss = 0.04881002
# Iteration 175, loss = 0.04814444
# Iteration 176, loss = 0.04749931
# Iteration 177, loss = 0.04707340
# Iteration 178, loss = 0.04665692
# Iteration 179, loss = 0.04606536
# Iteration 180, loss = 0.04561805
# Iteration 181, loss = 0.04495226
# Iteration 182, loss = 0.04470451
# Iteration 183, loss = 0.04433851
# Iteration 184, loss = 0.04375682
# Iteration 185, loss = 0.04317514
# Iteration 186, loss = 0.04277496
# Iteration 187, loss = 0.04234067
# Iteration 188, loss = 0.04188576
# Iteration 189, loss = 0.04148311
# Iteration 190, loss = 0.04103967
# Iteration 191, loss = 0.04065057
# Iteration 192, loss = 0.04033016
# Iteration 193, loss = 0.03996177
# Iteration 194, loss = 0.03963252
# Iteration 195, loss = 0.03906836
# Iteration 196, loss = 0.03866450
# Iteration 197, loss = 0.03829305
# Iteration 198, loss = 0.03796809
# Iteration 199, loss = 0.03758116
# Iteration 200, loss = 0.03727169
# Iteration 1, loss = 0.69805633
# Iteration 2, loss = 0.66764452
# Iteration 3, loss = 0.63904324
# Iteration 4, loss = 0.61034321
# Iteration 5, loss = 0.58161951
# Iteration 6, loss = 0.55348118
# Iteration 7, loss = 0.52671311
# Iteration 8, loss = 0.50053478
# /home/kjl5t/.conda/envs/bert_new/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 9, loss = 0.47724945
# Iteration 10, loss = 0.45668543
# Iteration 11, loss = 0.43788734
# Iteration 12, loss = 0.42209521
# Iteration 13, loss = 0.40823809
# Iteration 14, loss = 0.39590088
# Iteration 15, loss = 0.38568235
# Iteration 16, loss = 0.37705991
# Iteration 17, loss = 0.36931907
# Iteration 18, loss = 0.36205648
# Iteration 19, loss = 0.35569335
# Iteration 20, loss = 0.35042186
# Iteration 21, loss = 0.34458980
# Iteration 22, loss = 0.33985651
# Iteration 23, loss = 0.33485937
# Iteration 24, loss = 0.33029699
# Iteration 25, loss = 0.32586517
# Iteration 26, loss = 0.32170567
# Iteration 27, loss = 0.31753802
# Iteration 28, loss = 0.31351563
# Iteration 29, loss = 0.31003932
# Iteration 30, loss = 0.30600397
# Iteration 31, loss = 0.30210224
# Iteration 32, loss = 0.29862444
# Iteration 33, loss = 0.29498084
# Iteration 34, loss = 0.29146739
# Iteration 35, loss = 0.28839832
# Iteration 36, loss = 0.28461195
# Iteration 37, loss = 0.28142658
# Iteration 38, loss = 0.27798067
# Iteration 39, loss = 0.27497621
# Iteration 40, loss = 0.27160547
# Iteration 41, loss = 0.26847497
# Iteration 42, loss = 0.26523385
# Iteration 43, loss = 0.26206211
# Iteration 44, loss = 0.25900760
# Iteration 45, loss = 0.25612208
# Iteration 46, loss = 0.25286350
# Iteration 47, loss = 0.25012648
# Iteration 48, loss = 0.24696243
# Iteration 49, loss = 0.24411194
# Iteration 50, loss = 0.24122181
# Iteration 51, loss = 0.23826643
# Iteration 52, loss = 0.23517360
# Iteration 53, loss = 0.23234549
# Iteration 54, loss = 0.22945616
# Iteration 55, loss = 0.22695330
# Iteration 56, loss = 0.22411236
# Iteration 57, loss = 0.22120506
# Iteration 58, loss = 0.21843057
# Iteration 59, loss = 0.21593664
# Iteration 60, loss = 0.21311602
# Iteration 61, loss = 0.21073173
# Iteration 62, loss = 0.20789541
# Iteration 63, loss = 0.20505342
# Iteration 64, loss = 0.20309524
# Iteration 65, loss = 0.20007851
# Iteration 66, loss = 0.19747137
# Iteration 67, loss = 0.19507460
# Iteration 68, loss = 0.19238407
# Iteration 69, loss = 0.18989212
# Iteration 70, loss = 0.18744924
# Iteration 71, loss = 0.18523510
# Iteration 72, loss = 0.18281029
# Iteration 73, loss = 0.18014914
# Iteration 74, loss = 0.17790978
# Iteration 75, loss = 0.17554210
# Iteration 76, loss = 0.17326915
# Iteration 77, loss = 0.17091992
# Iteration 78, loss = 0.16866318
# Iteration 79, loss = 0.16656772
# Iteration 80, loss = 0.16413222
# Iteration 81, loss = 0.16208846
# Iteration 82, loss = 0.15977857
# Iteration 83, loss = 0.15775378
# Iteration 84, loss = 0.15555335
# Iteration 85, loss = 0.15355841
# Iteration 86, loss = 0.15141025
# Iteration 87, loss = 0.14935829
# Iteration 88, loss = 0.14780892
# Iteration 89, loss = 0.14518134
# Iteration 90, loss = 0.14352459
# Iteration 91, loss = 0.14175045
# Iteration 92, loss = 0.13944973
# Iteration 93, loss = 0.13739816
# Iteration 94, loss = 0.13559482
# Iteration 95, loss = 0.13360624
# Iteration 96, loss = 0.13189426
# Iteration 97, loss = 0.12999388
# Iteration 98, loss = 0.12809120
# Iteration 99, loss = 0.12635695
# Iteration 100, loss = 0.12468314
# Iteration 101, loss = 0.12287632
# Iteration 102, loss = 0.12121911
# Iteration 103, loss = 0.11958975
# Iteration 104, loss = 0.11829276
# Iteration 105, loss = 0.11631227
# Iteration 106, loss = 0.11456832
# Iteration 107, loss = 0.11303945
# Iteration 108, loss = 0.11131199
# Iteration 109, loss = 0.10969941
# Iteration 110, loss = 0.10808230
# Iteration 111, loss = 0.10645845
# Iteration 112, loss = 0.10492213
# Iteration 113, loss = 0.10367189
# Iteration 114, loss = 0.10200466
# Iteration 115, loss = 0.10048606
# Iteration 116, loss = 0.09919728
# Iteration 117, loss = 0.09769396
# Iteration 118, loss = 0.09622119
# Iteration 119, loss = 0.09503439
# Iteration 120, loss = 0.09350956
# Iteration 121, loss = 0.09246957
# Iteration 122, loss = 0.09088789
# Iteration 123, loss = 0.08957631
# Iteration 124, loss = 0.08833722
# Iteration 125, loss = 0.08709350
# Iteration 126, loss = 0.08571558
# Iteration 127, loss = 0.08448630
# Iteration 128, loss = 0.08322669
# Iteration 129, loss = 0.08207122
# Iteration 130, loss = 0.08083228
# Iteration 131, loss = 0.07982168
# Iteration 132, loss = 0.07849134
# Iteration 133, loss = 0.07743047
# Iteration 134, loss = 0.07636730
# Iteration 135, loss = 0.07519399
# Iteration 136, loss = 0.07418547
# Iteration 137, loss = 0.07311258
# Iteration 138, loss = 0.07203287
# Iteration 139, loss = 0.07126686
# Iteration 140, loss = 0.06999938
# Iteration 141, loss = 0.06910410
# Iteration 142, loss = 0.06824859
# Iteration 143, loss = 0.06709808
# Iteration 144, loss = 0.06607781
# Iteration 145, loss = 0.06519018
# Iteration 146, loss = 0.06429931
# Iteration 147, loss = 0.06337521
# Iteration 148, loss = 0.06259867
# Iteration 149, loss = 0.06164356
# Iteration 150, loss = 0.06087502
# Iteration 151, loss = 0.06024806
# Iteration 152, loss = 0.05920897
# Iteration 153, loss = 0.05882743
# Iteration 154, loss = 0.05774261
# Iteration 155, loss = 0.05684609
# Iteration 156, loss = 0.05599409
# Iteration 157, loss = 0.05530949
# Iteration 158, loss = 0.05452336
# Iteration 159, loss = 0.05382435
# Iteration 160, loss = 0.05307124
# Iteration 161, loss = 0.05243793
# Iteration 162, loss = 0.05174133
# Iteration 163, loss = 0.05100074
# Iteration 164, loss = 0.05030863
# Iteration 165, loss = 0.04976919
# Iteration 166, loss = 0.04898587
# Iteration 167, loss = 0.04832576
# Iteration 168, loss = 0.04774169
# Iteration 169, loss = 0.04709098
# Iteration 170, loss = 0.04650941
# Iteration 171, loss = 0.04596438
# Iteration 172, loss = 0.04532186
# Iteration 173, loss = 0.04496000
# Iteration 174, loss = 0.04420524
# Iteration 175, loss = 0.04364449
# Iteration 176, loss = 0.04311763
# Iteration 177, loss = 0.04260443
# Iteration 178, loss = 0.04208534
# Iteration 179, loss = 0.04148915
# Iteration 180, loss = 0.04106540
# Iteration 181, loss = 0.04071102
# Iteration 182, loss = 0.04007216
# Iteration 183, loss = 0.03954694
# Iteration 184, loss = 0.03913800
# Iteration 185, loss = 0.03874336
# Iteration 186, loss = 0.03813379
# Iteration 187, loss = 0.03780582
# Iteration 188, loss = 0.03726885
# Iteration 189, loss = 0.03705331
# Iteration 190, loss = 0.03663559
# Iteration 191, loss = 0.03603275
# Iteration 192, loss = 0.03561005
# Iteration 193, loss = 0.03522956
# Iteration 194, loss = 0.03477634
# Iteration 195, loss = 0.03446483
# Iteration 196, loss = 0.03403513
# Iteration 197, loss = 0.03359163
# Iteration 198, loss = 0.03321749
# Iteration 199, loss = 0.03292799
# Iteration 200, loss = 0.03253827
# Iteration 1, loss = 0.69879606
# Iteration 2, loss = 0.66767305
# Iteration 3, loss = 0.63832076
# Iteration 4, loss = 0.61020751
# Iteration 5, loss = 0.58201617
# Iteration 6, loss = 0.55385929
# Iteration 7, loss = 0.52776942
# Iteration 8, loss = 0.50266561
# Iteration 9, loss = 0.48006920
# Iteration 10, loss = 0.46064244
# /home/kjl5t/.conda/envs/bert_new/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 11, loss = 0.44317406
# Iteration 12, loss = 0.42794942
# Iteration 13, loss = 0.41534918
# Iteration 14, loss = 0.40385665
# Iteration 15, loss = 0.39438589
# Iteration 16, loss = 0.38620623
# Iteration 17, loss = 0.37883391
# Iteration 18, loss = 0.37205823
# Iteration 19, loss = 0.36554840
# Iteration 20, loss = 0.35982141
# Iteration 21, loss = 0.35450304
# Iteration 22, loss = 0.34914250
# Iteration 23, loss = 0.34436717
# Iteration 24, loss = 0.33947983
# Iteration 25, loss = 0.33476959
# Iteration 26, loss = 0.33026298
# Iteration 27, loss = 0.32599453
# Iteration 28, loss = 0.32150680
# Iteration 29, loss = 0.31729939
# Iteration 30, loss = 0.31319586
# Iteration 31, loss = 0.30908266
# Iteration 32, loss = 0.30507816
# Iteration 33, loss = 0.30123797
# Iteration 34, loss = 0.29766912
# Iteration 35, loss = 0.29350933
# Iteration 36, loss = 0.28981814
# Iteration 37, loss = 0.28575764
# Iteration 38, loss = 0.28247268
# Iteration 39, loss = 0.27862340
# Iteration 40, loss = 0.27512090
# Iteration 41, loss = 0.27160651
# Iteration 42, loss = 0.26796299
# Iteration 43, loss = 0.26465177
# Iteration 44, loss = 0.26137773
# Iteration 45, loss = 0.25781804
# Iteration 46, loss = 0.25456675
# Iteration 47, loss = 0.25108282
# Iteration 48, loss = 0.24840530
# Iteration 49, loss = 0.24474322
# Iteration 50, loss = 0.24170586
# Iteration 51, loss = 0.23825892
# Iteration 52, loss = 0.23538677
# Iteration 53, loss = 0.23228926
# Iteration 54, loss = 0.22936222
# Iteration 55, loss = 0.22639091
# Iteration 56, loss = 0.22328800
# Iteration 57, loss = 0.22035833
# Iteration 58, loss = 0.21761106
# Iteration 59, loss = 0.21473260
# Iteration 60, loss = 0.21202672
# Iteration 61, loss = 0.20906864
# Iteration 62, loss = 0.20644910
# Iteration 63, loss = 0.20370488
# Iteration 64, loss = 0.20122926
# Iteration 65, loss = 0.19856700
# Iteration 66, loss = 0.19575128
# Iteration 67, loss = 0.19327239
# Iteration 68, loss = 0.19060982
# Iteration 69, loss = 0.18857976
# Iteration 70, loss = 0.18565069
# Iteration 71, loss = 0.18318455
# Iteration 72, loss = 0.18098353
# Iteration 73, loss = 0.17864180
# Iteration 74, loss = 0.17605593
# Iteration 75, loss = 0.17370254
# Iteration 76, loss = 0.17202552
# Iteration 77, loss = 0.16905944
# Iteration 78, loss = 0.16684320
# Iteration 79, loss = 0.16465865
# Iteration 80, loss = 0.16250657
# Iteration 81, loss = 0.16004113
# Iteration 82, loss = 0.15808161
# Iteration 83, loss = 0.15603758
# Iteration 84, loss = 0.15374420
# Iteration 85, loss = 0.15172881
# Iteration 86, loss = 0.14963326
# Iteration 87, loss = 0.14766170
# Iteration 88, loss = 0.14549949
# Iteration 89, loss = 0.14360640
# Iteration 90, loss = 0.14174809
# Iteration 91, loss = 0.14004727
# Iteration 92, loss = 0.13773490
# Iteration 93, loss = 0.13581950
# Iteration 94, loss = 0.13406496
# Iteration 95, loss = 0.13220302
# Iteration 96, loss = 0.13027584
# Iteration 97, loss = 0.12867376
# Iteration 98, loss = 0.12684245
# Iteration 99, loss = 0.12518213
# Iteration 100, loss = 0.12336651
# Iteration 101, loss = 0.12186798
# Iteration 102, loss = 0.12010646
# Iteration 103, loss = 0.11824325
# Iteration 104, loss = 0.11740085
# Iteration 105, loss = 0.11503736
# Iteration 106, loss = 0.11354653
# Iteration 107, loss = 0.11202040
# Iteration 108, loss = 0.11052673
# Iteration 109, loss = 0.10876219
# Iteration 110, loss = 0.10723588
# Iteration 111, loss = 0.10573529
# Iteration 112, loss = 0.10431582
# Iteration 113, loss = 0.10318100
# Iteration 114, loss = 0.10146999
# Iteration 115, loss = 0.10012889
# Iteration 116, loss = 0.09868942
# Iteration 117, loss = 0.09714614
# Iteration 118, loss = 0.09587465
# Iteration 119, loss = 0.09453256
# Iteration 120, loss = 0.09319420
# Iteration 121, loss = 0.09193964
# Iteration 122, loss = 0.09071856
# Iteration 123, loss = 0.08944152
# Iteration 124, loss = 0.08811086
# Iteration 125, loss = 0.08686635
# Iteration 126, loss = 0.08578975
# Iteration 127, loss = 0.08456791
# Iteration 128, loss = 0.08329664
# Iteration 129, loss = 0.08232220
# Iteration 130, loss = 0.08106422
# Iteration 131, loss = 0.08017915
# Iteration 132, loss = 0.07905275
# Iteration 133, loss = 0.07819309
# Iteration 134, loss = 0.07698680
# Iteration 135, loss = 0.07576876
# Iteration 136, loss = 0.07469149
# Iteration 137, loss = 0.07381507
# Iteration 138, loss = 0.07282798
# Iteration 139, loss = 0.07174623
# Iteration 140, loss = 0.07065267
# Iteration 141, loss = 0.06986435
# Iteration 142, loss = 0.06893501
# Iteration 143, loss = 0.06801856
# Iteration 144, loss = 0.06704235
# Iteration 145, loss = 0.06623313
# Iteration 146, loss = 0.06525160
# Iteration 147, loss = 0.06442975
# Iteration 148, loss = 0.06383416
# Iteration 149, loss = 0.06273345
# Iteration 150, loss = 0.06194772
# Iteration 151, loss = 0.06130263
# Iteration 152, loss = 0.06051198
# Iteration 153, loss = 0.05971314
# Iteration 154, loss = 0.05883921
# Iteration 155, loss = 0.05830757
# Iteration 156, loss = 0.05747613
# Iteration 157, loss = 0.05672403
# Iteration 158, loss = 0.05595383
# Iteration 159, loss = 0.05522163
# Iteration 160, loss = 0.05446961
# Iteration 161, loss = 0.05380165
# Iteration 162, loss = 0.05321156
# Iteration 163, loss = 0.05258132
# Iteration 164, loss = 0.05187925
# Iteration 165, loss = 0.05136776
# Iteration 166, loss = 0.05070388
# Iteration 167, loss = 0.04997047
# Iteration 168, loss = 0.04943647
# Iteration 169, loss = 0.04890405
# Iteration 170, loss = 0.04828917
# Iteration 171, loss = 0.04763892
# Iteration 172, loss = 0.04711461
# Iteration 173, loss = 0.04653422
# Iteration 174, loss = 0.04597978
# Iteration 175, loss = 0.04547459
# Iteration 176, loss = 0.04507417
# Iteration 177, loss = 0.04465023
# Iteration 178, loss = 0.04395747
# Iteration 179, loss = 0.04347356
# Iteration 180, loss = 0.04294758
# Iteration 181, loss = 0.04253884
# Iteration 182, loss = 0.04205885
# Iteration 183, loss = 0.04152524
# Iteration 184, loss = 0.04114887
# Iteration 185, loss = 0.04074065
# Iteration 186, loss = 0.04031596
# Iteration 187, loss = 0.03987227
# Iteration 188, loss = 0.03935779
# Iteration 189, loss = 0.03889558
# Iteration 190, loss = 0.03865841
# Iteration 191, loss = 0.03800848
# Iteration 192, loss = 0.03791656
# Iteration 193, loss = 0.03726391
# Iteration 194, loss = 0.03701980
# Iteration 195, loss = 0.03666026
# Iteration 196, loss = 0.03612852
# Iteration 197, loss = 0.03605731
# Iteration 198, loss = 0.03541681
# Iteration 199, loss = 0.03509008
# Iteration 200, loss = 0.03481204
# [0.875      0.79166667 0.8125     0.78645833 0.78645833]
# Accuracy: 0.81.   Standard Deviation: 0.03
# Iteration 1, loss = 0.69482664
# Iteration 2, loss = 0.65842258
# Iteration 3, loss = 0.62381707
# Iteration 4, loss = 0.58788637
# Iteration 5, loss = 0.55437377
# Iteration 6, loss = 0.52058352
# Iteration 7, loss = 0.49157784
# Iteration 8, loss = 0.46563952
# Iteration 9, loss = 0.44273548
# Iteration 10, loss = 0.42501893
# Iteration 11, loss = 0.41005424
# Iteration 12, loss = 0.39771089
# Iteration 13, loss = 0.38735983
# Iteration 14, loss = 0.37873704
# Iteration 15, loss = 0.37135866
# /home/kjl5t/.conda/envs/bert_new/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 16, loss = 0.36458173
# Iteration 17, loss = 0.35894029
# Iteration 18, loss = 0.35363668
# Iteration 19, loss = 0.34839409
# Iteration 20, loss = 0.34365589
# Iteration 21, loss = 0.33943223
# Iteration 22, loss = 0.33479145
# Iteration 23, loss = 0.33068669
# Iteration 24, loss = 0.32687528
# Iteration 25, loss = 0.32272127
# Iteration 26, loss = 0.31916237
# Iteration 27, loss = 0.31601025
# Iteration 28, loss = 0.31195267
# Iteration 29, loss = 0.30837963
# Iteration 30, loss = 0.30473848
# Iteration 31, loss = 0.30147253
# Iteration 32, loss = 0.29837051
# Iteration 33, loss = 0.29463738
# Iteration 34, loss = 0.29134660
# Iteration 35, loss = 0.28830191
# Iteration 36, loss = 0.28521395
# Iteration 37, loss = 0.28235359
# Iteration 38, loss = 0.27884849
# Iteration 39, loss = 0.27602036
# Iteration 40, loss = 0.27322488
# Iteration 41, loss = 0.26979867
# Iteration 42, loss = 0.26677394
# Iteration 43, loss = 0.26377054
# Iteration 44, loss = 0.26093880
# Iteration 45, loss = 0.25817473
# Iteration 46, loss = 0.25542967
# Iteration 47, loss = 0.25282623
# Iteration 48, loss = 0.24950745
# Iteration 49, loss = 0.24670120
# Iteration 50, loss = 0.24389425
# Iteration 51, loss = 0.24115739
# Iteration 52, loss = 0.23867739
# Iteration 53, loss = 0.23592952
# Iteration 54, loss = 0.23395692
# Iteration 55, loss = 0.23063675
# Iteration 56, loss = 0.22797109
# Iteration 57, loss = 0.22554452
# Iteration 58, loss = 0.22326383
# Iteration 59, loss = 0.22013809
# Iteration 60, loss = 0.21749131
# Iteration 61, loss = 0.21509906
# Iteration 62, loss = 0.21252554
# Iteration 63, loss = 0.21012967
# Iteration 64, loss = 0.20767842
# Iteration 65, loss = 0.20551621
# Iteration 66, loss = 0.20301937
# Iteration 67, loss = 0.20118466
# Iteration 68, loss = 0.19832557
# Iteration 69, loss = 0.19606346
# Iteration 70, loss = 0.19364643
# Iteration 71, loss = 0.19110908
# Iteration 72, loss = 0.18912940
# Iteration 73, loss = 0.18667267
# Iteration 74, loss = 0.18471169
# Iteration 75, loss = 0.18291172
# Iteration 76, loss = 0.17968434
# Iteration 77, loss = 0.17790536
# Iteration 78, loss = 0.17529046
# Iteration 79, loss = 0.17357597
# Iteration 80, loss = 0.17109469
# Iteration 81, loss = 0.16902462
# Iteration 82, loss = 0.16716995
# Iteration 83, loss = 0.16500779
# Iteration 84, loss = 0.16292367
# Iteration 85, loss = 0.16098262
# Iteration 86, loss = 0.15936992
# Iteration 87, loss = 0.15707111
# Iteration 88, loss = 0.15500638
# Iteration 89, loss = 0.15296120
# Iteration 90, loss = 0.15123709
# Iteration 91, loss = 0.14924798
# Iteration 92, loss = 0.14706866
# Iteration 93, loss = 0.14537466
# Iteration 94, loss = 0.14328425
# Iteration 95, loss = 0.14161966
# Iteration 96, loss = 0.13951245
# Iteration 97, loss = 0.13775726
# Iteration 98, loss = 0.13624808
# Iteration 99, loss = 0.13448887
# Iteration 100, loss = 0.13269771
# Iteration 101, loss = 0.13133011
# Iteration 102, loss = 0.12915623
# Iteration 103, loss = 0.12753138
# Iteration 104, loss = 0.12582454
# Iteration 105, loss = 0.12433311
# Iteration 106, loss = 0.12240289
# Iteration 107, loss = 0.12087819
# Iteration 108, loss = 0.11949409
# Iteration 109, loss = 0.11786395
# Iteration 110, loss = 0.11623547
# Iteration 111, loss = 0.11459525
# Iteration 112, loss = 0.11308623
# Iteration 113, loss = 0.11186024
# Iteration 114, loss = 0.11000253
# Iteration 115, loss = 0.10908199
# Iteration 116, loss = 0.10721160
# Iteration 117, loss = 0.10619184
# Iteration 118, loss = 0.10451923
# Iteration 119, loss = 0.10321107
# Iteration 120, loss = 0.10170994
# Iteration 121, loss = 0.10070126
# Iteration 122, loss = 0.09915304
# Iteration 123, loss = 0.09792769
# Iteration 124, loss = 0.09665976
# Iteration 125, loss = 0.09528522
# Iteration 126, loss = 0.09384680
# Iteration 127, loss = 0.09315627
# Iteration 128, loss = 0.09223086
# Iteration 129, loss = 0.09038189
# Iteration 130, loss = 0.08926057
# Iteration 131, loss = 0.08784061
# Iteration 132, loss = 0.08713557
# Iteration 133, loss = 0.08567742
# Iteration 134, loss = 0.08462901
# Iteration 135, loss = 0.08348159
# Iteration 136, loss = 0.08235035
# Iteration 137, loss = 0.08124099
# Iteration 138, loss = 0.08006513
# Iteration 139, loss = 0.07913191
# Iteration 140, loss = 0.07808229
# Iteration 141, loss = 0.07726284
# Iteration 142, loss = 0.07609508
# Iteration 143, loss = 0.07491575
# Iteration 144, loss = 0.07441738
# Iteration 145, loss = 0.07298536
# Iteration 146, loss = 0.07238447
# Iteration 147, loss = 0.07157582
# Iteration 148, loss = 0.07039782
# Iteration 149, loss = 0.06943897
# Iteration 150, loss = 0.06890983
# Iteration 151, loss = 0.06763849
# Iteration 152, loss = 0.06697111
# Iteration 153, loss = 0.06597071
# Iteration 154, loss = 0.06522930
# Iteration 155, loss = 0.06443006
# Iteration 156, loss = 0.06357137
# Iteration 157, loss = 0.06290001
# Iteration 158, loss = 0.06210745
# Iteration 159, loss = 0.06127428
# Iteration 160, loss = 0.06058039
# Iteration 161, loss = 0.06017849
# Iteration 162, loss = 0.05918326
# Iteration 163, loss = 0.05859344
# Iteration 164, loss = 0.05780842
# Iteration 165, loss = 0.05709521
# Iteration 166, loss = 0.05662471
# Iteration 167, loss = 0.05582125
# Iteration 168, loss = 0.05527217
# Iteration 169, loss = 0.05460844
# Iteration 170, loss = 0.05379930
# Iteration 171, loss = 0.05324766
# Iteration 172, loss = 0.05257921
# Iteration 173, loss = 0.05227479
# Iteration 174, loss = 0.05184232
# Iteration 175, loss = 0.05109344
# Iteration 176, loss = 0.05026817
# Iteration 177, loss = 0.04983776
# Iteration 178, loss = 0.04910974
# Iteration 179, loss = 0.04871114
# Iteration 180, loss = 0.04821086
# Iteration 181, loss = 0.04750996
# Iteration 182, loss = 0.04719067
# Iteration 183, loss = 0.04653596
# Iteration 184, loss = 0.04624309
# Iteration 185, loss = 0.04565353
# Iteration 186, loss = 0.04512637
# Iteration 187, loss = 0.04470230
# Iteration 188, loss = 0.04410905
# Iteration 189, loss = 0.04379047
# Iteration 190, loss = 0.04340564
# Iteration 191, loss = 0.04299623
# Iteration 192, loss = 0.04274995
# Iteration 193, loss = 0.04286600
# Iteration 194, loss = 0.04200026
# Iteration 195, loss = 0.04145072
# Iteration 196, loss = 0.04088562
# Iteration 197, loss = 0.04069523
# Iteration 198, loss = 0.04009847
# Iteration 199, loss = 0.03971436
# Iteration 200, loss = 0.03935648
# 1.8545851707458496
# /home/kjl5t/.conda/envs/bert_new/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.7625

# %%
# Predict the classification
y_pred_bert = classifier_nn.predict(X_test_bert)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_bert, y_pred_bert)
print(confusion)
print(classification_report(y_test_bert, y_pred_bert))
# Out:
# [[ 69  28]
#  [ 29 114]]
#               precision    recall  f1-score   support
#
#     Big-data       0.70      0.71      0.71        97
# Non Big-data       0.80      0.80      0.80       143
#
#     accuracy                           0.76       240
#    macro avg       0.75      0.75      0.75       240
# weighted avg       0.76      0.76      0.76       240

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('Neural Network Confusion Matrix\n BERT \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/bert_NN.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data
t1 = time.time()
y_bert = classifier_nn.predict(doc_reps_np)
t2 = time.time()

print(t2-t1)
# Out:
# 1.8176615238189697

# %%
# The vector keeps the order from index. Just add the prediction as new variable
df_merge['Prediction_NN'] = y_bert
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM  \
# 0                        NaN   NaN       Big-data   Non Big-data
# 1                        NaN   NaN   Non Big-data   Non Big-data
# 2                        NaN   NaN   Non Big-data   Non Big-data
# 3                        NaN   NaN   Non Big-data   Non Big-data
# 4                        NaN   NaN   Non Big-data   Non Big-data
#
#   Prediction_DT Prediction_RF Prediction_NN
# 0  Non Big-data  Non Big-data  Non Big-data
# 1      Big-data  Non Big-data  Non Big-data
# 2      Big-data  Non Big-data  Non Big-data
# 3  Non Big-data  Non Big-data  Non Big-data
# 4  Non Big-data  Non Big-data      Big-data

# %%
# save classification results
df_merge.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/big_data/bert_old_training_set.csv")
