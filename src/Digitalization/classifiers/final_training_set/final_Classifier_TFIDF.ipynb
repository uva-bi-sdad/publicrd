# %% [markdown]
# ### Classification of FR abstracts as big data or not.
#
# Uses TFIDF as vectorization and current labeled dataset of 1600 abstracts.

# %%
import pandas as pd
import numpy as np
import pickle
import time
import math
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import classification_report, confusion_matrix

pd.set_option('display.max_columns', 50)

# %% [markdown]
# #### Ingest Data - labeled set and full corpus

# %%
# read in new training dataset - 1600 labeled abstracts
df_lab = pd.read_csv("../../../../data/prd/Digital_abstract_labelled/DEC-2022-labelled_abstracts.csv")
print(df_lab.shape)
df_lab.head()
# Out:
# (1600, 8)
#    Unnamed: 0  Duplicates  index  PROJECT_ID  \
# 0           0           0    979      950056
# 1           1           0    816     1178172
# 2           2           0   1096      163037
# 3           3           0    725      880197
# 4           4           0     92      887331
#
#                                             ABSTRACT  \
# 0  ï»¿   DESCRIPTION (provided by applicant): Adv...
# 1  Project Summary/AbstractThe establishment of t...
# 2  DESCRIPTION (provided by applicant): The long-...
# 3  DESCRIPTION (provided by applicant): The most ...
# 4  Transsphenoidal surgery (TSS) is the best trea...
#
#    Is it related to Big-Data Expert name         label
# 0                          1    Kristian      Big-data
# 1                          1    Kristian      Big-data
# 2                          0    Kristian  Non Big-data
# 3                          0    Kristian  Non Big-data
# 4                          0    Kristian  Non Big-data

# %%
df_lab = df_lab[['PROJECT_ID','ABSTRACT','Is it related to Big-Data','label']]
df_lab.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0      950056  ï»¿   DESCRIPTION (provided by applicant): Adv...
# 1     1178172  Project Summary/AbstractThe establishment of t...
# 2      163037  DESCRIPTION (provided by applicant): The long-...
# 3      880197  DESCRIPTION (provided by applicant): The most ...
# 4      887331  Transsphenoidal surgery (TSS) is the best trea...
#
#    Is it related to Big-Data         label
# 0                          1      Big-data
# 1                          1      Big-data
# 2                          0  Non Big-data
# 3                          0  Non Big-data
# 4                          0  Non Big-data

# %%
#data frame with all of the abstracts
df = pd.read_pickle("../../../../data/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")

# Reset the df index and create a variable index to link with PROJECT_ID
df.reset_index(inplace = True, drop = True)
print(df.shape)
df.head()
# Out:
# (1143869, 30)
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens
# 0  project explore game base metaphor enhanced ga...
# 1  institution franklin institute science museum ...
# 2  program include small group conversation citiz...
# 3  partnership american chemical society acs nati...
# 4  center molecular interfacing cmi enable integr...

# %%
df = df[['PROJECT_ID','ABSTRACT']]
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...

# %%
# merge with the labelled data using PROJECT_ID.
df['PROJECT_ID'] = pd.to_numeric(df['PROJECT_ID'])
df_merge = df.merge(df_lab[['PROJECT_ID','Is it related to Big-Data','label']], how='left', on='PROJECT_ID')
len(df_merge)
# Out:
# 1143869

# %%
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label
# 0                        NaN   NaN
# 1                        NaN   NaN
# 2                        NaN   NaN
# 3                        NaN   NaN
# 4                        NaN   NaN

# %%
# Save project ID of labelled data
project_id_lab = list(df_lab['PROJECT_ID'])

# Get the index of labelled abstract
subset_df = df_merge.loc[df_merge['PROJECT_ID'].isin(project_id_lab),['PROJECT_ID','label']]

# %%
subset_df.head()
# Out:
#       PROJECT_ID         label
# 373        90145      Big-data
# 672        90761      Big-data
# 1050       91187  Non Big-data
# 1387       91282  Non Big-data
# 1413       91311  Non Big-data

# %%
# build training and testing sets from the labeled data 
# sklearn to find list of indices for training and test set

X_train_idx, X_test_idx, y_train_tfidf, y_test_tfidf = train_test_split(subset_df.index, 
                                                                        subset_df['label'].values, 
                                                                        test_size=0.20, random_state=0, 
                                                                        stratify=subset_df['label'].values)

# %% [markdown]
# ### 1.1 TFIDF Vectorization

# %%
# Compute the TFIDF matrix on the full data
t1 = time.time()
v = TfidfVectorizer()
tfidf = v.fit_transform(df['ABSTRACT'])
t2 = time.time()

print(t2-t1)
# Out:
# 213.80164790153503

# %%
tfidf
# Out:
# <1143869x1307953 sparse matrix of type '<class 'numpy.float64'>'
# 	with 213160046 stored elements in Compressed Sparse Row format>

# %%
# use training and testing set ids to create feature sets

X_train_tfidf = tfidf[X_train_idx,:]
X_test_tfidf = tfidf[X_test_idx,:]

# %% [markdown]
# ## 1.2. KNN classifier

# %%
# number of neighbors
k = int(math.sqrt(len(y_train_tfidf)))
print('Number of neighbors:', k)
# Out:
# Number of neighbors: 35

# %%
# Run KNN

classifierKNN = KNeighborsClassifier(n_neighbors= k)  # njobs? don't need

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifierKNN, X_train_tfidf, y_train_tfidf, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifierKNN.fit(X_train_tfidf, y_train_tfidf)

# find model accuracy
classifierKNN.score(X_test_tfidf,y_test_tfidf)
# Out:
# [0.72265625 0.7109375  0.73046875 0.72265625 0.7109375 ]
# Accuracy: 0.72.   Standard Deviation: 0.01
# 0.721875

# %%
# Predict the classification
y_pred_tfidf = classifierKNN.predict(X_test_tfidf)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_tfidf, y_pred_tfidf)
print(confusion)
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# [[130   7]
#  [ 82 101]]
#               precision    recall  f1-score   support
#
#     Big-data       0.61      0.95      0.74       137
# Non Big-data       0.94      0.55      0.69       183
#
#     accuracy                           0.72       320
#    macro avg       0.77      0.75      0.72       320
# weighted avg       0.80      0.72      0.72       320

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('KNN Confusion Matrix\n TFIDF \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/tfidf_KNN.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data: use the whole TFIDF
t1 = time.time()
y_tfidf = classifierKNN.predict(tfidf)
t2 = time.time()

print(t2-t1)
# Out:
# 156.20243668556213

# %%
# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_KNN'] = y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN
# 0                        NaN   NaN       Big-data
# 1                        NaN   NaN       Big-data
# 2                        NaN   NaN       Big-data
# 3                        NaN   NaN       Big-data
# 4                        NaN   NaN       Big-data

# %% [markdown]
# ## 1.3. SVM

# %%
# We run SVM with default parameters provides by Sklearn. We train the model

classifier_svm = svm.SVC()

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_svm, X_train_tfidf, y_train_tfidf, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_svm.fit(X_train_tfidf, y_train_tfidf)

# find model accuracy
classifier_svm.score(X_test_tfidf,y_test_tfidf)
# Out:
# [0.828125   0.83203125 0.8125     0.8203125  0.7890625 ]
# Accuracy: 0.82.   Standard Deviation: 0.02
# 0.825

# %%
# Predict the classification
y_pred_tfidf = classifier_svm.predict(X_test_tfidf)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_tfidf, y_pred_tfidf)
print(confusion)
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# [[102  35]
#  [ 21 162]]
#               precision    recall  f1-score   support
#
#     Big-data       0.83      0.74      0.78       137
# Non Big-data       0.82      0.89      0.85       183
#
#     accuracy                           0.82       320
#    macro avg       0.83      0.81      0.82       320
# weighted avg       0.83      0.82      0.82       320

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('SVM Confusion Matrix\n TFIDF \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/tfidf_SVM.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data: use the whole TFIDF
t1 = time.time()
y_tfidf = classifier_svm.predict(tfidf)
t2 = time.time()

print(t2-t1)
# Out:
# 1890.8089249134064

# %%
# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_SVM'] = y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM
# 0                        NaN   NaN       Big-data   Non Big-data
# 1                        NaN   NaN       Big-data   Non Big-data
# 2                        NaN   NaN       Big-data   Non Big-data
# 3                        NaN   NaN       Big-data   Non Big-data
# 4                        NaN   NaN       Big-data   Non Big-data

# %% [markdown]
# ## 1.4. Decision Tree

# %%
# Use default parameters provides by SKLearn and train the model
classifier_DT = DecisionTreeClassifier(random_state = 0)

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_DT, X_train_tfidf, y_train_tfidf, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_DT.fit(X_train_tfidf, y_train_tfidf)

# find model accuracy
classifier_DT.score(X_test_tfidf,y_test_tfidf)
# Out:
# [0.75390625 0.7734375  0.71875    0.79296875 0.75390625]
# Accuracy: 0.76.   Standard Deviation: 0.02
# 0.784375

# %%
# Predict the classification
y_pred_tfidf = classifier_DT.predict(X_test_tfidf)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_tfidf, y_pred_tfidf)
print(confusion)
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# [[106  31]
#  [ 38 145]]
#               precision    recall  f1-score   support
#
#     Big-data       0.74      0.77      0.75       137
# Non Big-data       0.82      0.79      0.81       183
#
#     accuracy                           0.78       320
#    macro avg       0.78      0.78      0.78       320
# weighted avg       0.79      0.78      0.78       320

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('Decision Tree Confusion Matrix\n TFIDF \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/tfidf_DT.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data: use the whole TFIDF
t1 = time.time()
y_tfidf = classifier_DT.predict(tfidf)
t2 = time.time()

print(t2-t1)
# Out:
# 2.077542543411255

# %%
# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_DT'] = y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM Prediction_DT
# 0                        NaN   NaN       Big-data   Non Big-data  Non Big-data
# 1                        NaN   NaN       Big-data   Non Big-data  Non Big-data
# 2                        NaN   NaN       Big-data   Non Big-data  Non Big-data
# 3                        NaN   NaN       Big-data   Non Big-data  Non Big-data
# 4                        NaN   NaN       Big-data   Non Big-data  Non Big-data

# %% [markdown]
# ## 1.5. Random Forest

# %%
# Use default parameters provides by SKLearn and train the model
classifier_RF = RandomForestClassifier(random_state=0)  # use njobs?

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_RF, X_train_tfidf, y_train_tfidf, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_RF.fit(X_train_tfidf, y_train_tfidf)

# find model accuracy
classifier_RF.score(X_test_tfidf,y_test_tfidf)
# Out:
# [0.80078125 0.80078125 0.7890625  0.79296875 0.80859375]
# Accuracy: 0.80.   Standard Deviation: 0.01
# 0.790625

# %%
# Predict the classification
y_pred_tfidf = classifier_RF.predict(X_test_tfidf)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_tfidf, y_pred_tfidf)
print(confusion)
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# [[ 99  38]
#  [ 29 154]]
#               precision    recall  f1-score   support
#
#     Big-data       0.77      0.72      0.75       137
# Non Big-data       0.80      0.84      0.82       183
#
#     accuracy                           0.79       320
#    macro avg       0.79      0.78      0.78       320
# weighted avg       0.79      0.79      0.79       320

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('Random Forest Confusion Matrix\n TFIDF \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/tfidf_RF.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data: use the whole TFIDF
t1 = time.time()
y_tfidf = classifier_RF.predict(tfidf)
t2 = time.time()

print(t2-t1)
# Out:
# 110.99350643157959

# %%
# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_RF'] = y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM  \
# 0                        NaN   NaN       Big-data   Non Big-data
# 1                        NaN   NaN       Big-data   Non Big-data
# 2                        NaN   NaN       Big-data   Non Big-data
# 3                        NaN   NaN       Big-data   Non Big-data
# 4                        NaN   NaN       Big-data   Non Big-data
#
#   Prediction_DT Prediction_RF
# 0  Non Big-data  Non Big-data
# 1  Non Big-data  Non Big-data
# 2  Non Big-data  Non Big-data
# 3  Non Big-data  Non Big-data
# 4  Non Big-data  Non Big-data

# %% [markdown]
# ## 1.6. Neural network classifier

# %%
# Use default parameters provides by SKLearn and train the model
classifier_nn = MLPClassifier(random_state=0, verbose=True)

# cross-validation with 5 folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_nn, X_train_tfidf, y_train_tfidf, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
t1 = time.time()
classifier_nn.fit(X_train_tfidf, y_train_tfidf)
t2 = time.time()

print(t2-t1)

# find model accuracy
classifier_nn.score(X_test_tfidf,y_test_tfidf)
# Out:
# Iteration 1, loss = 0.69459316
# Iteration 2, loss = 0.63176345
# Iteration 3, loss = 0.56801764
# Iteration 4, loss = 0.50436723
# Iteration 5, loss = 0.44469378
# Iteration 6, loss = 0.38853183
# Iteration 7, loss = 0.34011099
# Iteration 84, loss = 0.01263589
# Iteration 85, loss = 0.01247120
# Iteration 86, loss = 0.01268611
# Iteration 87, loss = 0.01257171
# Iteration 88, loss = 0.01225806
# Iteration 89, loss = 0.01218101
# Iteration 90, loss = 0.01259996
# Iteration 91, loss = 0.01245447
# Iteration 92, loss = 0.01212949
# Iteration 93, loss = 0.01235390
# Iteration 94, loss = 0.01216769
# Iteration 95, loss = 0.01218269
# Iteration 96, loss = 0.01217395
# Iteration 97, loss = 0.01254315
# Iteration 98, loss = 0.01213978
# Iteration 99, loss = 0.01228221
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# 2493.236537218094
# 0.809375

# %%
# Predict the classification
y_pred_tfidf = classifier_nn.predict(X_test_tfidf)

# %%
# Classifier performance
confusion = confusion_matrix(y_test_tfidf, y_pred_tfidf)
print(confusion)
print(classification_report(y_test_tfidf, y_pred_tfidf))
# Out:
# [[106  31]
#  [ 30 153]]
#               precision    recall  f1-score   support
#
#     Big-data       0.78      0.77      0.78       137
# Non Big-data       0.83      0.84      0.83       183
#
#     accuracy                           0.81       320
#    macro avg       0.81      0.80      0.81       320
# weighted avg       0.81      0.81      0.81       320

# %%
## Display the visualization of the Confusion Matrix.

sns.set(font_scale=1.4)
ax = sns.heatmap(confusion, annot=True, fmt="", cmap='Blues', xticklabels=["Big Data", "Not Big Data"], 
            annot_kws={"fontsize":20})
plt.title('Neural Network Confusion Matrix\n TFIDF \n') 
plt.xlabel('\nPredicted Values')
plt.ylabel('Actual Values') 
ax.set_yticklabels(['Big Data', 'Not Big Data'], va='center', rotation = 90) #position=(0,0.28))

plt.savefig('figures/tfidf_NN.png', bbox_inches='tight')
plt.show()

# %%
# Predict the classification for the whole data: use the whole TFIDF
t1 = time.time()
y_tfidf = classifier_nn.predict(tfidf)
t2 = time.time()

print(t2-t1)
# Out:
# 15.560861825942993

# %%
# The TFIDF keep the order from index. Just add the prediction as new variable
df_merge['Prediction_NN'] = y_tfidf
df_merge.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#    Is it related to Big-Data label Prediction_KNN Prediction_SVM  \
# 0                        NaN   NaN       Big-data   Non Big-data
# 1                        NaN   NaN       Big-data   Non Big-data
# 2                        NaN   NaN       Big-data   Non Big-data
# 3                        NaN   NaN       Big-data   Non Big-data
# 4                        NaN   NaN       Big-data   Non Big-data
#
#   Prediction_DT Prediction_RF Prediction_NN
# 0  Non Big-data  Non Big-data  Non Big-data
# 1  Non Big-data  Non Big-data      Big-data
# 2  Non Big-data  Non Big-data  Non Big-data
# 3  Non Big-data  Non Big-data  Non Big-data
# 4  Non Big-data  Non Big-data  Non Big-data

# %%
# save classification results
df_merge.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/big_data/tfidf_new_training_set.csv")
