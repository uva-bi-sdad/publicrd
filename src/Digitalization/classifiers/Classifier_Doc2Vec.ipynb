# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

import scipy.sparse
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression as lm
from scipy import stats

import gensim
import nltk
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize, punkt
from gensim.models import KeyedVectors

import matplotlib.collections as plt1
import matplotlib.pyplot as plt2
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.lines import Line2D
import seaborn as sns

import pandas as pd
pd.set_option('display.max_columns', 50)

import pickle
import time
import re
import csv
import math
import pickle
import time
import spacy

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/kno5cac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#data frame with only labeled abstracts
df_lab = pd.read_csv("/home/kno5cac/git/publicrd/data/prd/Digital_abstract_labelled/labelled_abstracts.csv")

#data frame with all of the abstracts
df = pd.read_pickle("/home/kno5cac/git/publicrd/data/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")

# %%
# Remove Null Abstracts. Reset the index and create a variable index to link with PROJECT_ID
df = df[~df.ABSTRACT.isnull()]
df.reset_index(inplace = True, drop = True)
df['index'] = df.index
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4

# %%
df_lab = df_lab[['PROJECT_ID','ABSTRACT','Is it related to Big-Data','label']]
df_lab
# Out:
#       PROJECT_ID                                           ABSTRACT  \
# 0         950056  ï»¿   DESCRIPTION (provided by applicant): Adv...
# 1        1178172  Project Summary/AbstractThe establishment of t...
# 2         163037  DESCRIPTION (provided by applicant): The long-...
# 3         880197  DESCRIPTION (provided by applicant): The most ...
# 4         887331  Transsphenoidal surgery (TSS) is the best trea...
# ...          ...                                                ...
# 1195     1226292  The candidate for this Mentored Career Develop...
# 1196      937305  ï»¿   DESCRIPTION (provided by applicant): The...
# 1197      278787  DESCRIPTION (provided by applicant): All cance...
# 1198     1098499  The NSF Big Data Innovation Hubs (Big Data Hub...
# 1199     1210375  AbstractThe principal goal of the Core Facilit...
#
#      Is it related to Big-Data         label
# 0                            1      Big-data
# 1                            1      Big-data
# 2                            0  Non Big-data
# 3                            0  Non Big-data
# 4                            0  Non Big-data
# ...                        ...           ...
# 1195                         1      Big-data
# 1196                         1      Big-data
# 1197                         0  Non Big-data
# 1198                         1      Big-data
# 1199                         0  Non Big-data
#
# [1200 rows x 4 columns]

# %%
# merge with the labelled data using PROJECT_ID.
df['PROJECT_ID'] = pd.to_numeric(df['PROJECT_ID'])
df_merge = df.merge(df_lab[['PROJECT_ID','Is it related to Big-Data','label']], how='left', on='PROJECT_ID')
len(df_merge)
# Out:
# 1143869

# %%
df_merge
# Out:
#          PROJECT_ID                                           ABSTRACT  \
# 0             89996  This is a project to explore Game-based, Metap...
# 1             89997  Institution: Franklin Institute Science Museum...
# 2             89998  Through programs (including small group conver...
# 3             89999  In partnership with the American Chemical Soci...
# 4             90001  The Center for Molecular Interfacing (CMI) wil...
# ...             ...                                                ...
# 1143864     1294186  Circadian rhythms are fundamental endogenous p...
# 1143865     1294187  Recent research suggests that learning about g...
# 1143866     1294188  The COVID-19 pandemic has caused unprecedented...
# 1143867     1294189  Subduction zones – locations where one of the ...
# 1143868     1294190  Stretching for over 80 miles along the Illinoi...
#
#                                              PROJECT_TERMS  \
# 0        Achievement; analog; base; Cognitive Science; ...
# 1        Active Learning; Child; Computer software; des...
# 2        Address; Age; Birth; Brain; Caregivers; Child;...
# 3        Advanced Development; American; Chemicals; Che...
# 4        Address; Architecture; Carbon Nanotubes; Catal...
# ...                                                    ...
# 1143864                                                NaN
# 1143865                                                NaN
# 1143866                                                NaN
# 1143867                                                NaN
# 1143868                                                NaN
#
#                                              PROJECT_TITLE DEPARTMENT AGENCY  \
# 0        RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1        ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2        BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3        FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4            CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
# ...                                                    ...        ...    ...
# 1143864  Revealing the Palatable Meal-Inducible Circadi...        NSF    NSF
# 1143865  Collaborative Research : Improving the teachin...        NSF    NSF
# 1143866  Collaborative Research: RAPID: Maintain Mobili...        NSF    NSF
# 1143867  Collaborative Research: Synthesizing arc-scale...        NSF    NSF
# 1143868  EAGER: Collaborative Research: Invisible Flood...        NSF    NSF
#
#         IC_CENTER PROJECT_NUMBER     PROJECT_START_DATE  \
# 0             NaN        0814512              9/15/2008
# 1             NaN        0741659              9/15/2008
# 2             NaN        0813522              9/15/2008
# 3             NaN        0838627               8/1/2008
# 4             NaN        0847926              10/1/2008
# ...           ...            ...                    ...
# 1143864       NaN        1931115   5/1/2020 12:00:00 AM
# 1143865       NaN        1956119   7/1/2020 12:00:00 AM
# 1143866       NaN        2028098  4/15/2020 12:00:00 AM
# 1143867       NaN        1948834   7/1/2020 12:00:00 AM
# 1143868       NaN        2026780   8/1/2020 12:00:00 AM
#
#               PROJECT_END_DATE CONTACT_PI_PROJECT_LEADER  \
# 0                    8/31/2012           REESE, DEBBIE D
# 1                    8/31/2012            SNYDER, STEVEN
# 2                    8/31/2011    FINK, LAURIE KLEINBAUM
# 3                   12/31/2010              JOST, JOHN W
# 4                    9/30/2011          ABRUNA, HECTOR D
# ...                        ...                       ...
# 1143864  4/30/2025 12:00:00 AM                       NaN
# 1143865  6/30/2025 12:00:00 AM                       NaN
# 1143866  3/31/2021 12:00:00 AM                       NaN
# 1143867  6/30/2023 12:00:00 AM                       NaN
# 1143868  7/31/2022 12:00:00 AM                       NaN
#
#                                          OTHER_PIS CONGRESSIONAL_DISTRICT  \
# 0        CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN                     01
# 1                      ELINICH, KAREN; YOON, SUSAN                     02
# 2              CADIGAN, KAREN; ELLENBOGEN, KIRSTEN                     04
# 3               MILLER, BRADLEY; BOWMAN, KATHERINE                     04
# 4                                              NaN                     22
# ...                                            ...                    ...
# 1143864                                        NaN                    NaN
# 1143865                                        NaN                    NaN
# 1143866                                        NaN                    NaN
# 1143867                                        NaN                    NaN
# 1143868                                        NaN                    NaN
#
#         DUNS_NUMBER                                  ORGANIZATION_NAME  \
# 0         068719400                         WHEELING JESUIT UNIVERSITY
# 1         001741859                                 FRANKLIN INSTITUTE
# 2         061451670                        SCIENCE MUSEUM OF MINNESOTA
# 3         009059242  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY
# 4         872612445                          CORNELL UNIVERSITY ITHACA
# ...             ...                                                ...
# 1143864   800771545                     UNIVERSITY OF TEXAS SW MED CTR
# 1143865   170230239                         UNIVERSITY OF TEXAS AUSTIN
# 1143866   003387891                  UNIVERSITY OF TENNESSEE KNOXVILLE
# 1143867   872612445                          CORNELL UNIVERSITY ITHACA
# 1143868   068552207                              WASHINGTON UNIVERSITY
#
#         ORGANIZATION_CITY ORGANIZATION_STATE ORGANIZATION_ZIP  \
# 0                WHEELING                 WV       26003-6243
# 1            PHILADELPHIA                 PA       19103-1115
# 2              SAINT PAUL                 MN       55102-1202
# 3                  DURHAM                 NC       27709-3757
# 4                  ITHACA                 NY       14850-2820
# ...                   ...                ...              ...
# 1143864               NaN                NaN              NaN
# 1143865               NaN                NaN              NaN
# 1143866               NaN                NaN              NaN
# 1143867               NaN                NaN              NaN
# 1143868               NaN                NaN              NaN
#
#         ORGANIZATION_COUNTRY BUDGET_START_DATE BUDGET_END_DATE CFDA_CODE  \
# 0              UNITED STATES               NaN             NaN    47.076
# 1              UNITED STATES               NaN             NaN    47.076
# 2              UNITED STATES               NaN             NaN    47.076
# 3              UNITED STATES               NaN             NaN    47.049
# 4              UNITED STATES               NaN             NaN    47.049
# ...                      ...               ...             ...       ...
# 1143864                  NaN               NaN             NaN    47.074
# 1143865                  NaN               NaN             NaN    47.076
# 1143866                  NaN               NaN             NaN    47.041
# 1143867                  NaN               NaN             NaN    47.050
# 1143868                  NaN               NaN             NaN    47.050
#
#            FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  ORG_COUNT  PI_COUNT  \
# 0        2008      1999467.0                         NaN          1         1
# 1        2008      1799699.0                         NaN          1         1
# 2        2008      1505858.0                         NaN          1         1
# 3        2008        51000.0                         NaN          1         1
# 4        2008      1519821.0                         NaN          1         1
# ...       ...            ...                         ...        ...       ...
# 1143864  2020       700000.0                         NaN          1         0
# 1143865  2020       136238.0                         NaN          3         0
# 1143866  2020       132226.0                         NaN          2         0
# 1143867  2020        30484.0                         NaN          3         0
# 1143868  2020       164897.0                         NaN          2         0
#
#          FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0                1999467.0            1
# 1                1799699.0            1
# 2                1505858.0            1
# 3                  51000.0            1
# 4                1519821.0            1
# ...                    ...          ...
# 1143864           700000.0            1
# 1143865           672158.0            3
# 1143866           182205.0            2
# 1143867           191004.0            3
# 1143868           299968.0            2
#
#                                               final_tokens    index  \
# 0        project explore game base metaphor enhanced ga...        0
# 1        institution franklin institute science museum ...        1
# 2        program include small group conversation citiz...        2
# 3        partnership american chemical society acs nati...        3
# 4        center molecular interfacing cmi enable integr...        4
# ...                                                    ...      ...
# 1143864  circadian_rhythm fundamental endogenous proper...  1143864
# 1143865  recent research suggest learn genetic high sch...  1143865
# 1143866  covid_19_pandemic cause unprecedented disrupti...  1143866
# 1143867  subduction_zone location earth tectonic_plate ...  1143867
# 1143868  stretch mile illinois bank mississippi_river a...  1143868
#
#         Is it related to Big-Data label
# 0                             NaN   NaN
# 1                             NaN   NaN
# 2                             NaN   NaN
# 3                             NaN   NaN
# 4                             NaN   NaN
# ...                           ...   ...
# 1143864                       NaN   NaN
# 1143865                       NaN   NaN
# 1143866                       NaN   NaN
# 1143867                       NaN   NaN
# 1143868                       NaN   NaN
#
# [1143869 rows x 33 columns]

# %%
# Save project ID of labelled data
project_id_lab = list(df_lab['PROJECT_ID'])

# Get the index of labelled abstract
subset_df = df_merge.loc[df_merge['PROJECT_ID'].isin(project_id_lab),['index', 'PROJECT_ID']]
index_lab = list(subset_df['index'])

# %% [markdown]
# # 1. Doc2Vec approach

# %% [markdown]
# ## 1.1. Vectorize, build the training and test sample

# %%
# creating dataframe with just abstracts
data = df['ABSTRACT']
indicies = data.index

# %%
#tagging and saving data (do not need to run this again - data is saved in tagged_df.csv)
#tagged_data = [TaggedDocument(words=word_tokenize(_d.lower()), tags=[str(i)]) for i, _d in enumerate(data)]
#tagged_df = pd.DataFrame(tagged_data)
#tagged_df.to_csv('tagged_df.csv')

# %%
#loading tagged_df
tagged_df = pd.read_csv('doc2vec_final.csv')

# %%
tagged_df = pd.DataFrame(tagged_df)

# %%
# Create the Doc2Vec model and train using labelled data (do not need to run this again - model saved in d2v.model)
#model = gensim.models.doc2vec.Doc2Vec(vector_size=100, epochs=100) #min_count=2 - min number of times it shows up
#model.build_vocab(tagged_data)
#model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)
#model.save("d2v.model")

# %%
# Load the Doc2Vec model
model = Doc2Vec.load("d2v.model")

# %%
# create vector of tagged data
vector = []
for i in range(0, len(tagged_df)):
    vectorthis = (model.dv[i]).tolist()
    vector.append(vectorthis)

# %%
data = df['ABSTRACT']

# %%
# append vectors to matrix
mat = []
for i in vector:
    for x in i:
        mat.append(x)

# %%
# initialize training
training = pd.DataFrame(vector)
training
# Out:
#                0         1         2         3         4         5         6   \
# 0        0.982922  2.319988  3.742522  0.944506 -1.694736 -3.728322  0.204749
# 1        0.456848 -0.227907 -0.991774  2.260244 -1.303596 -1.987082 -2.183362
# 2        3.939317 -0.077519  1.721057 -0.717855 -3.445618 -2.466907 -0.437651
# 3        0.261933  2.833923 -1.429265  2.710543 -2.051509 -2.664451  1.328356
# 4        1.591960  1.018378 -0.159254  1.763578 -1.124414 -0.417599 -1.689906
# ...           ...       ...       ...       ...       ...       ...       ...
# 1143864 -0.589433 -2.827645 -0.015131  0.440290 -3.171267  0.226309 -0.993920
# 1143865 -0.046254  1.644556 -0.228649 -1.154571 -1.796054 -2.439546 -2.409341
# 1143866  1.649566  2.593250 -2.476415  1.464013 -1.890929 -0.712783  0.072332
# 1143867 -1.415500 -0.289443  1.073774  3.017362 -0.215771  0.118964  1.296525
# 1143868  1.114188  2.349573 -1.620269  1.710281  2.185140 -2.864482  2.046483
#
#                7         8         9         10        11        12        13  \
# 0       -1.112957  1.098760 -4.612341  0.733703 -2.214583 -0.259219 -0.214456
# 1        1.811930 -0.897663  0.843100  0.932140 -4.361772 -0.521623  0.296213
# 2        3.141626 -3.202489  0.375526  0.532302 -1.165914 -0.406458  0.446012
# 3        0.693114 -2.763685  1.123290 -1.326368 -1.178106  2.254581  2.241744
# 4        0.896199 -0.812358 -0.964306 -1.619780  0.353326  2.982134  1.652212
# ...           ...       ...       ...       ...       ...       ...       ...
# 1143864  2.299028 -1.271716 -2.754301 -1.393994 -2.420811 -1.928915  2.034703
# 1143865 -1.295492  1.210209 -3.479094 -2.119251 -1.792609  1.884615  3.665569
# 1143866  0.206794  0.151559 -0.232204 -1.816210 -2.969110  2.040817 -0.778387
# 1143867  2.181842 -1.435515 -1.441369 -2.889195  0.455699 -2.281882 -0.036810
# 1143868  4.248395  1.627345 -2.415238 -2.355667  1.343128 -1.620021 -0.590868
#
#                14        15        16        17        18        19        20  \
# 0        0.995408 -1.186774 -0.131439 -1.180803  1.841610 -1.639843 -2.358011
# 1        1.349446 -0.805430 -1.736138 -0.538803  0.459269 -0.474585 -2.454310
# 2       -1.526703 -0.200713  1.268217  0.085013 -0.847399  0.953084  0.618521
# 3        0.068839  1.155099  1.886543 -2.059903 -1.559700 -0.770142 -0.253473
# 4        0.084070 -2.297758 -0.385808 -2.790571  2.477949  0.223171  0.887371
# ...           ...       ...       ...       ...       ...       ...       ...
# 1143864 -1.412915 -1.795308  1.567008 -1.223800  1.913204 -2.361304  2.478794
# 1143865  0.279281 -0.828874  0.595290  1.931901  1.646654  2.387414  1.235176
# 1143866 -0.554495  2.358896  1.262079 -0.206404  0.290963 -2.154397 -0.643661
# 1143867  1.918587 -0.049089  0.480108 -0.206097 -0.147803 -1.609531 -0.229206
# 1143868  3.989425 -0.927367 -0.949040  0.609412 -1.087631 -3.713456 -3.437425
#
#                21        22        23        24  ...        75        76  \
# 0        3.413001  3.731894  1.390462  3.263571  ... -1.041995  2.063597
# 1        1.329033  2.992836  1.203448  0.310803  ...  1.549266 -1.570076
# 2        2.339281 -1.306460  0.514830  2.718282  ...  0.788696  1.818320
# 3       -0.482159  0.112768 -0.993233 -0.440269  ... -0.095776  0.772124
# 4        1.535304  0.736297 -0.550977  3.002540  ... -0.894851  2.199989
# ...           ...       ...       ...       ...  ...       ...       ...
# 1143864 -0.169768  1.931102  0.871608  1.210561  ...  1.414410 -1.744653
# 1143865  0.581897  1.716896 -0.770842 -0.010682  ... -2.751852 -0.275039
# 1143866  2.033018  1.022280 -1.115017 -4.438424  ...  0.545783  1.158256
# 1143867  0.404716  2.443124 -0.631065  0.601501  ... -2.482953  3.767275
# 1143868 -2.400195  2.904597  0.419643 -1.855994  ...  0.240277  1.440549
#
#                77        78        79        80        81        82        83  \
# 0        0.650890 -0.009327 -2.202883 -0.411864 -1.595071 -1.730732 -1.397346
# 1       -1.332427 -0.770249  1.699491 -0.274130 -5.603177 -1.300055 -0.810193
# 2       -1.556971  1.819863  1.508475 -1.179790  0.828222  0.005567 -0.094424
# 3       -0.252873 -0.083401 -1.206205 -0.901444  1.999393  0.931728 -1.386474
# 4       -2.327350  0.552252  0.862642 -0.526882  2.033086  0.602459  0.172678
# ...           ...       ...       ...       ...       ...       ...       ...
# 1143864 -1.986873  1.542214  1.333920 -2.133246  0.615134  1.853283  3.042733
# 1143865 -1.069470 -2.049822  4.377855 -4.498168  1.907763 -3.553480  0.761350
# 1143866 -0.905748 -1.189366 -4.220345  3.305391 -1.779488  0.352255 -0.006147
# 1143867 -1.912810 -2.280514  0.836017 -0.488768 -2.498016 -1.422518  1.871884
# 1143868 -0.999763 -2.253410 -1.201714  0.126652 -3.500102 -1.743197 -0.183223
#
#                84        85        86        87        88        89        90  \
# 0       -0.712966  1.295766 -1.123551 -0.102224  2.066787  0.765735  4.270835
# 1       -2.107439  0.174144  2.185729 -2.083795  2.886135 -0.271330  3.001608
# 2       -0.004659 -0.880713 -0.720786  1.472627 -1.323683  3.885650  1.376774
# 3       -1.996466 -2.597653 -1.525401 -1.121509  0.461437 -0.235091  2.322187
# 4       -1.177264 -2.423429  1.038152 -1.498387 -1.542013  0.237539 -2.691047
# ...           ...       ...       ...       ...       ...       ...       ...
# 1143864  1.747994  0.109657 -0.033058  1.117686 -0.712576 -0.404940 -0.404730
# 1143865 -2.552432 -1.076153 -0.385006  0.612397 -0.115043  1.164006  3.233547
# 1143866 -0.420330 -0.451286  1.139648  1.253190  4.039290  1.842668 -0.361150
# 1143867  0.233190  0.885198 -1.337498 -0.182935  2.523906  0.871874 -0.152748
# 1143868 -3.745874 -0.146207 -0.951724 -1.255643  2.511757  2.331403  3.581045
#
#                91        92        93        94        95        96        97  \
# 0        3.079768 -0.978548  0.275256  0.677612 -2.733896  0.354953 -1.033716
# 1        2.179992  3.509960  0.711321 -0.808178 -1.946631 -0.329511 -1.518070
# 2       -0.988943  0.242667 -1.518137 -0.670374 -1.113849 -0.119800 -4.312647
# 3       -1.351750  0.528141 -2.293975 -0.394241 -1.240165  0.156464 -0.477509
# 4       -1.320943  1.387134  1.664728 -0.789113 -0.246745  2.204133 -1.852782
# ...           ...       ...       ...       ...       ...       ...       ...
# 1143864  2.688170  2.625527  4.112746 -4.826093  2.253988  0.963031 -3.712034
# 1143865  2.891143  0.676756 -0.612910 -1.962523 -0.686879 -1.105975 -1.178190
# 1143866 -1.808205 -1.090999  2.299752 -2.689035 -0.241323 -0.528462 -3.554354
# 1143867  1.674293 -2.512760  0.831158  0.585108 -1.611964 -2.656904 -1.396773
# 1143868  4.320572 -1.782809  2.009894 -0.390033 -1.158664 -1.814589 -1.168435
#
#                98        99
# 0        0.140886 -2.464530
# 1        1.803749 -0.085112
# 2       -0.575666 -0.374445
# 3        0.817239  0.814438
# 4       -2.572883  2.798885
# ...           ...       ...
# 1143864 -1.322149  3.365469
# 1143865 -0.875600  0.905634
# 1143866 -0.578364  0.822259
# 1143867  0.604232  0.654059
# 1143868  0.622892 -0.341059
#
# [1143869 rows x 100 columns]

# %%
#training model on labeled and whole corpus
trainingnp = training.to_numpy()

# %%
index_training = pd.read_csv('index_training.csv')
index_test = pd.read_csv('index_test.csv')

# %%
# convert to lists
index_training = list(index_training['0'])
index_test = list(index_test['0'])

# %%
# Build the training and test sample: randomly select 80% of index_lab as training and the rest as test
import random

# Build the index for the training and the test
index_training = random.sample(index_lab, int(0.8 * len(index_lab)))
index_test = list(set(index_lab) - set(index_training))

# sort those index (sort help to extract the Y value for each set)
index_training.sort()
index_test.sort()

# convert to lists
index_training = list(index_training)
index_test = list(index_test)

# Extract those index in the Doc2Vec matrix and compute the X training and Test
X_train_doc2vec = [vector[i] for i in index_training]
X_test_doc2vec = [vector[i] for i in index_test]

# %%
# Extract those index in the Doc2Vec matrix and compute the X training and Test
X_train_doc2vec = [trainingnp[i] for i in index_training]
X_test_doc2vec = [trainingnp[i] for i in index_test]

# %%
# Create Y for training and test using the index order from the sampling
Y_train_doc2vec = [df_merge.loc[df_merge['index']== i,'label'].values.tolist() for i in index_training]
Y_train_doc2vec = sum(Y_train_doc2vec, [])

Y_test_doc2vec = [df_merge.loc[df_merge['index']== i,'label'].values.tolist() for i in index_test]
Y_test_doc2vec = sum(Y_test_doc2vec, [])

# %%
len(index_training)
# Out:
# 960

# %% [markdown]
# ## 1.2. KNN classifier

# %%
# number of neighbors
k = int(math.sqrt(len(Y_train_doc2vec)))
print('Number of neighbors:', k)
# Out:
# Number of neighbors: 30

# %%
# Run KNN
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors= k)
classifier.fit(X_train_doc2vec,Y_train_doc2vec)
# Out:
# KNeighborsClassifier(n_neighbors=30)

# %%
# Predict the classification
Y_pred_doc2vec = classifier.predict(X_test_doc2vec)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_doc2vec, Y_pred_doc2vec)
#print(confusion)
print(classification_report(Y_test_doc2vec, Y_pred_doc2vec))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.79      0.58      0.67        99
# Non Big-data       0.75      0.89      0.82       141
#
#     accuracy                           0.76       240
#    macro avg       0.77      0.73      0.74       240
# weighted avg       0.77      0.76      0.75       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('KNN Confusion Matrix\n Doc2Vec \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('doc2vec_KNN.PNG')

# %%
# Predict the classification for the whole data: use the whole Doc2Vec
Y_doc2vec = classifier.predict(vector)

# The Doc2Vec keep the order from index. Just add the prediction as new variable
df['Prediction_KNN'] = Y_doc2vec
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN
# 0  project explore game base metaphor enhanced ga...      0   Non Big-data
# 1  institution franklin institute science museum ...      1   Non Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data

# %%
# Count the number of projects that is Big data related
df_bigdata = df[df['Prediction_KNN']=='Big-data']
print('Number of abstracts related to Big data:', len(df_bigdata))
# Out:
# Number of abstracts related to Big data: 55079

# %%
cb_pal = {"blue":'#377eb8', "orange":'#ff7f00', "green":'#4daf4a', "pink":'#f781bf', "brown":'#a65628', 
          "purple":'#984ea3', "gray":'#999999', "red":'#e41a1c', "yellow":'#dede00'}

# %%
# Distribution over time and agencies
df_bigdata["FY"] = df_bigdata["FY"].astype('int')
year_counts = df_bigdata['FY'].value_counts().sort_index(ascending=True)

# Distribution
year = year_counts.index.tolist()
count = year_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(year, count, color='navy')
#plt.xlim(-0.7, len(year)-0.3)
plt2.xlim(2007.3,2020.7)
plt2.xticks(year, rotation=45)
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
#x_ticks = ax.xaxis.get_major_ticks()
#x_ticks[-1].label1.set_visible(False)
plt2.xlabel("FY")
plt2.ylabel("Number of Projects")
plt2.title("Big data sample")

plt2.savefig("big_data_time.png", dpi = 800, bbox_inches = "tight")
# Out:
# <ipython-input-32-a496b776c9c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bigdata["FY"] = df_bigdata["FY"].astype('int')
# <ipython-input-32-a496b776c9c3>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

# %%
agency_counts = 100*df_bigdata["DEPARTMENT"].value_counts()/len(df_bigdata)
agency = agency_counts.index.tolist()
count = agency_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(agency, count, color=cb_pal['blue'])
plt2.ylim(0,100)
plt2.xlabel("Agency")
plt2.ylabel("Percent of Dataset")
plt2.title("Project Distribution by Funding Agency")

plt2.savefig("big_data_agency.png", dpi = 800, bbox_inches = "tight")

# %%
# save the data
#df_bigdata.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/doc2vec_method.csv")

# %% [markdown]
# ## 1.3. SVM

# %%
# We run SVM with default parameters provides by Sklearn. We train the model
from sklearn import svm
classifier_svm = svm.SVC()
classifier_svm.fit(X_train_doc2vec,Y_train_doc2vec)
# Out:
# SVC()

# %%
# Predict the classification
Y_pred_doc2vec = classifier_svm.predict(X_test_doc2vec)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_doc2vec, Y_pred_doc2vec)
#print(confusion)
print(classification_report(Y_test_doc2vec, Y_pred_doc2vec))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.70      0.73      0.71        99
# Non Big-data       0.80      0.78      0.79       141
#
#     accuracy                           0.76       240
#    macro avg       0.75      0.75      0.75       240
# weighted avg       0.76      0.76      0.76       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('SVM Confusion Matrix\n Doc2Vec \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('doc2vec_SVM.PNG')

# %%
# Predict the classification for the whole data: use the whole Doc2Vec
Y_doc2vec = classifier_svm.predict(vector)

# The Doc2Vec keep the order from index. Just add the prediction as new variable
df['Prediction_SVM'] = Y_doc2vec
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0   Non Big-data
# 1  institution franklin institute science museum ...      1   Non Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM
# 0   Non Big-data
# 1   Non Big-data
# 2   Non Big-data
# 3   Non Big-data
# 4   Non Big-data

# %%
# Cross comparision between SVM and KNN
pd.crosstab(df['Prediction_KNN'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_KNN
# Big-data           40198         14881    55079
# Non Big-data       55989       1032801  1088790
# Total              96187       1047682  1143869

# %% [markdown]
# ## 1.4. Decision Tree

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.tree import DecisionTreeClassifier
classifier_DT = DecisionTreeClassifier()
classifier_DT.fit(X_train_doc2vec,Y_train_doc2vec)
# Out:
# DecisionTreeClassifier()

# %%
# Predict the classification
Y_pred_doc2vec = classifier_DT.predict(X_test_doc2vec)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_doc2vec, Y_pred_doc2vec)
#print(confusion)
print(classification_report(Y_test_doc2vec, Y_pred_doc2vec))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.56      0.60      0.58        99
# Non Big-data       0.70      0.67      0.68       141
#
#     accuracy                           0.64       240
#    macro avg       0.63      0.63      0.63       240
# weighted avg       0.64      0.64      0.64       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('Decision Tree Confusion Matrix\n Doc2Vec \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('doc2vec_DT.PNG')

# %%
# Predict the classification for the whole data: use the whole Doc2Vec
Y_doc2vec = classifier_DT.predict(vector)

# The Doc2Vec keep the order from index. Just add the prediction as new variable
df['Prediction_DT'] = Y_doc2vec
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0   Non Big-data
# 1  institution franklin institute science museum ...      1   Non Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT
# 0   Non Big-data  Non Big-data
# 1   Non Big-data      Big-data
# 2   Non Big-data  Non Big-data
# 3   Non Big-data  Non Big-data
# 4   Non Big-data  Non Big-data

# %%
# Cross comparision between NN and SVM
pd.crosstab(df['Prediction_DT'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_DT
# Big-data           53597        278346   331943
# Non Big-data       42590        769336   811926
# Total              96187       1047682  1143869

# %%
# Cross comparision between NN and KNN
pd.crosstab(df['Prediction_DT'], df['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_DT
# Big-data           32058        299885   331943
# Non Big-data       23021        788905   811926
# Total              55079       1088790  1143869

# %% [markdown]
# ## 1.5. Random Forest

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.ensemble import RandomForestClassifier
classifier_RF = RandomForestClassifier()
classifier_RF.fit(X_train_doc2vec,Y_train_doc2vec)
# Out:
# RandomForestClassifier()

# %%
# Predict the classification
Y_pred_doc2vec = classifier_RF.predict(X_test_doc2vec)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_doc2vec, Y_pred_doc2vec)
#print(confusion)
print(classification_report(Y_test_doc2vec, Y_pred_doc2vec))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.75      0.61      0.67        99
# Non Big-data       0.76      0.86      0.80       141
#
#     accuracy                           0.75       240
#    macro avg       0.75      0.73      0.74       240
# weighted avg       0.75      0.75      0.75       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('Random Forest Confusion Matrix\n Doc2Vec \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('doc2vec_RF.PNG')

# %%
# Predict the classification for the whole data: use the whole Doc2Vec
Y_doc2vec = classifier_RF.predict(vector)

# The Doc2Vec keep the order from index. Just add the prediction as new variable
df['Prediction_RF'] = Y_doc2vec
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0   Non Big-data
# 1  institution franklin institute science museum ...      1   Non Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT Prediction_RF
# 0   Non Big-data  Non Big-data  Non Big-data
# 1   Non Big-data      Big-data  Non Big-data
# 2   Non Big-data  Non Big-data  Non Big-data
# 3   Non Big-data  Non Big-data  Non Big-data
# 4   Non Big-data  Non Big-data  Non Big-data

# %%
# Cross comparision between RF and DT
pd.crosstab(df['Prediction_RF'], df['Prediction_DT'], margins=True, margins_name="Total")
# Out:
# Prediction_DT  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data          44047         28100    72147
# Non Big-data     287896        783826  1071722
# Total            331943        811926  1143869

# %%
# Cross comparision between RF and SVM
pd.crosstab(df['Prediction_RF'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data           52821         19326    72147
# Non Big-data       43366       1028356  1071722
# Total              96187       1047682  1143869

# %%
# Cross comparision between RF and SVM
pd.crosstab(df['Prediction_RF'], df['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data           34806         37341    72147
# Non Big-data       20273       1051449  1071722
# Total              55079       1088790  1143869

# %% [markdown]
# ## 1.6. Neural network classifier

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.neural_network import MLPClassifier
classifier_nn = MLPClassifier()
classifier_nn.fit(X_train_doc2vec,Y_train_doc2vec)
# Out:
# MLPClassifier()

# %%
# Predict the classification
Y_pred_doc2vec = classifier_nn.predict(X_test_doc2vec)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_doc2vec, Y_pred_doc2vec)
#print(confusion)
print(classification_report(Y_test_doc2vec, Y_pred_doc2vec))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.69      0.72      0.70        99
# Non Big-data       0.80      0.77      0.78       141
#
#     accuracy                           0.75       240
#    macro avg       0.74      0.75      0.74       240
# weighted avg       0.75      0.75      0.75       240

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('Neural Network Confusion Matrix\n Doc2Vec \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('doc2vec_NN.PNG')

# %%
# Predict the classification for the whole data: use the whole Doc2Vec
Y_doc2vec = classifier_nn.predict(vector)

# The Doc2Vec keep the order from index. Just add the prediction as new variable
df['Prediction_NN'] = Y_doc2vec
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0   Non Big-data
# 1  institution franklin institute science museum ...      1   Non Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT Prediction_RF Prediction_NN
# 0   Non Big-data  Non Big-data  Non Big-data  Non Big-data
# 1   Non Big-data      Big-data  Non Big-data  Non Big-data
# 2   Non Big-data  Non Big-data  Non Big-data  Non Big-data
# 3   Non Big-data  Non Big-data  Non Big-data  Non Big-data
# 4   Non Big-data  Non Big-data  Non Big-data  Non Big-data

# %%
# Cross comparision between NN and KNN
pd.crosstab(df['Prediction_NN'], df['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data           38114        108164   146278
# Non Big-data       16965        980626   997591
# Total              55079       1088790  1143869

# %%
# Cross comparision between NN and SVM
pd.crosstab(df['Prediction_NN'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data           81459         64819   146278
# Non Big-data       14728        982863   997591
# Total              96187       1047682  1143869

# %%
# Cross comparision between NN and DT
pd.crosstab(df['Prediction_NN'], df['Prediction_DT'], margins=True, margins_name="Total")
# Out:
# Prediction_DT  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data          71257         75021   146278
# Non Big-data     260686        736905   997591
# Total            331943        811926  1143869

# %%
# Cross comparision between NN and RF
pd.crosstab(df['Prediction_NN'], df['Prediction_RF'], margins=True, margins_name="Total")
# Out:
# Prediction_RF  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data          50664         95614   146278
# Non Big-data      21483        976108   997591
# Total             72147       1071722  1143869

# %%
# save the data
df.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/FR_final_predicted_doc2vec.csv")

# %% [markdown]
# ## 1.7. Decision rule based on all classifiers

# %%
# Compute a score to be identify as big data
df = pd.read_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/FR_final_predicted_doc2vec.csv")
df['score'] = np.where(df['Prediction_KNN'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_SVM'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_DT'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_RF'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_NN'].str.contains("Non Big-data"), 0, 1)
# Out:
# /apps/software/standard/core/anaconda/2020.11-py3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,7,8,11,12,13,14,16,17,18,19,20,21,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0  PROJECT_ID                                           ABSTRACT  \
# 0           0       89996  This is a project to explore Game-based, Metap...
# 1           1       89997  Institution: Franklin Institute Science Museum...
# 2           2       89998  Through programs (including small group conver...
# 3           3       89999  In partnership with the American Chemical Soci...
# 4           4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                      1   068719400
# 1                      2   001741859
# 2                      4   061451670
# 3                      4   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0   Non Big-data
# 1  institution franklin institute science museum ...      1   Non Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT Prediction_RF Prediction_NN  score
# 0   Non Big-data  Non Big-data  Non Big-data  Non Big-data      0
# 1   Non Big-data      Big-data  Non Big-data  Non Big-data      1
# 2   Non Big-data  Non Big-data  Non Big-data  Non Big-data      0
# 3   Non Big-data  Non Big-data  Non Big-data  Non Big-data      0
# 4   Non Big-data  Non Big-data  Non Big-data  Non Big-data      0

# %%
# Distribution of abstracts
df['score'].value_counts()
# Out:
# 0    718472
# 1    290781
# 2     56147
# 3     33328
# 4     27130
# 5     18011
# Name: score, dtype: int64

# %%
# Used a rule (majority votes from classifiers) to identify Big-data abstracts. Useful because we have an impair number of classifier
df['Big_data'] = 0
df.loc[df['score']>3,'Big_data'] = 1
df['Big_data'].value_counts()
# Out:
# 0    1098728
# 1      45141
# Name: Big_data, dtype: int64

# %%
# subset the data to big-data and save
#df_bigdata = df[df['Big_data']==1]
#df_bigdata.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/abstracts_classification_big_data_doc2vec.csv")

# %% [markdown]
# ## Descriptive statistics of our Big data

# %%
# Distribution over time and agencies
df_bigdata["FY"] = df_bigdata["FY"].astype('int')
year_counts = df_bigdata['FY'].value_counts().sort_index(ascending=True)

# Distribution
year = year_counts.index.tolist()
count = year_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(year, count, color='navy')
#plt.xlim(-0.7, len(year)-0.3)
plt2.xlim(2007.3,2020.7)
plt2.xticks(year, rotation=45)
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
#x_ticks = ax.xaxis.get_major_ticks()
#x_ticks[-1].label1.set_visible(False)
plt2.xlabel("FY")
plt2.ylabel("Number of Projects")
plt2.title("Big Data Sample Over Time \n Doc2Vec \n")

plt2.savefig("big_data_time.png", dpi = 800, bbox_inches = "tight")
# Out:
# <ipython-input-71-9a9f563c6a99>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

# %%
agency_counts = 100*df_bigdata["DEPARTMENT"].value_counts()/len(df_bigdata)
agency = agency_counts.index.tolist()
count = agency_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(agency, count, color=cb_pal['blue'])
plt2.ylim(0,100)
plt2.xlabel("Agency")
plt2.ylabel("Percent of Dataset")
plt2.title("Project Distribution by Funding Agency \n Doc2Vec \n")

plt2.savefig("big_data_agency.png", dpi = 800, bbox_inches = "tight")
