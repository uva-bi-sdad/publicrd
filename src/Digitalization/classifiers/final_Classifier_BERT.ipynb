# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn import datasets
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

import scipy.sparse
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression as lm
from scipy import stats

import gensim
import nltk
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize, punkt
from gensim.models import KeyedVectors

import matplotlib.collections as plt1
import matplotlib.pyplot as plt2
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.lines import Line2D
import seaborn as sns

import pandas as pd
pd.set_option('display.max_columns', 50)

import pickle
import time
import re
import csv
import math
import pickle
import time
import spacy

nltk.download('punkt')

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package punkt to /home/kno5cac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#data frame with only labeled abstracts
df_lab = pd.read_csv("/home/kno5cac/git/publicrd/data/prd/Digital_abstract_labelled/DEC-2022-labelled_abstracts.csv")

#data frame with all of the abstracts
df = pd.read_pickle("/home/kno5cac/git/publicrd/data/prd/Paper/FR_meta_and_final_tokens_23DEC21.pkl")

# %%
# Reset the index and create a variable index to link with PROJECT_ID
df.reset_index(inplace = True, drop = True)
df['index'] = df.index
df.head()
# Out:
#   PROJECT_ID                                           ABSTRACT  \
# 0      89996  This is a project to explore Game-based, Metap...
# 1      89997  Institution: Franklin Institute Science Museum...
# 2      89998  Through programs (including small group conver...
# 3      89999  In partnership with the American Chemical Soci...
# 4      90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index
# 0  project explore game base metaphor enhanced ga...      0
# 1  institution franklin institute science museum ...      1
# 2  program include small group conversation citiz...      2
# 3  partnership american chemical society acs nati...      3
# 4  center molecular interfacing cmi enable integr...      4

# %%
df_lab = df_lab[['PROJECT_ID','ABSTRACT','Is it related to Big-Data','label']]
df_lab
# Out:
#       PROJECT_ID                                           ABSTRACT  \
# 0         950056  ï»¿   DESCRIPTION (provided by applicant): Adv...
# 1        1178172  Project Summary/AbstractThe establishment of t...
# 2         163037  DESCRIPTION (provided by applicant): The long-...
# 3         880197  DESCRIPTION (provided by applicant): The most ...
# 4         887331  Transsphenoidal surgery (TSS) is the best trea...
# ...          ...                                                ...
# 1595     1290459  Extracting knowledge from data using statistic...
# 1596     1290525  As the amount and variety of data available on...
# 1597     1292937  By 2030, nearly 146 million connected vehicles...
# 1598     1293276  High-performance computing (HPC) has enabled s...
# 1599     1294135  Operator theory and matrix analysis are both f...
#
#       Is it related to Big-Data         label
# 0                             1      Big-data
# 1                             1      Big-data
# 2                             0  Non Big-data
# 3                             0  Non Big-data
# 4                             0  Non Big-data
# ...                         ...           ...
# 1595                          1      Big-data
# 1596                          1      Big-data
# 1597                          1      Big-data
# 1598                          1      Big-data
# 1599                          0  Non Big-data
#
# [1600 rows x 4 columns]

# %%
# merge with the labelled data using PROJECT_ID.
df['PROJECT_ID'] = pd.to_numeric(df['PROJECT_ID'])
df_merge = df.merge(df_lab[['PROJECT_ID','Is it related to Big-Data','label']], how='left', on='PROJECT_ID')
len(df_merge)
# Out:
# 1143869

# %%
df_merge
# Out:
#          PROJECT_ID                                           ABSTRACT  \
# 0             89996  This is a project to explore Game-based, Metap...
# 1             89997  Institution: Franklin Institute Science Museum...
# 2             89998  Through programs (including small group conver...
# 3             89999  In partnership with the American Chemical Soci...
# 4             90001  The Center for Molecular Interfacing (CMI) wil...
# ...             ...                                                ...
# 1143864     1294186  Circadian rhythms are fundamental endogenous p...
# 1143865     1294187  Recent research suggests that learning about g...
# 1143866     1294188  The COVID-19 pandemic has caused unprecedented...
# 1143867     1294189  Subduction zones – locations where one of the ...
# 1143868     1294190  Stretching for over 80 miles along the Illinoi...
#
#                                              PROJECT_TERMS  \
# 0        Achievement; analog; base; Cognitive Science; ...
# 1        Active Learning; Child; Computer software; des...
# 2        Address; Age; Birth; Brain; Caregivers; Child;...
# 3        Advanced Development; American; Chemicals; Che...
# 4        Address; Architecture; Carbon Nanotubes; Catal...
# ...                                                    ...
# 1143864                                                NaN
# 1143865                                                NaN
# 1143866                                                NaN
# 1143867                                                NaN
# 1143868                                                NaN
#
#                                              PROJECT_TITLE DEPARTMENT AGENCY  \
# 0        RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1        ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2        BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3        FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4            CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
# ...                                                    ...        ...    ...
# 1143864  Revealing the Palatable Meal-Inducible Circadi...        NSF    NSF
# 1143865  Collaborative Research : Improving the teachin...        NSF    NSF
# 1143866  Collaborative Research: RAPID: Maintain Mobili...        NSF    NSF
# 1143867  Collaborative Research: Synthesizing arc-scale...        NSF    NSF
# 1143868  EAGER: Collaborative Research: Invisible Flood...        NSF    NSF
#
#         IC_CENTER PROJECT_NUMBER     PROJECT_START_DATE  \
# 0             NaN        0814512              9/15/2008
# 1             NaN        0741659              9/15/2008
# 2             NaN        0813522              9/15/2008
# 3             NaN        0838627               8/1/2008
# 4             NaN        0847926              10/1/2008
# ...           ...            ...                    ...
# 1143864       NaN        1931115   5/1/2020 12:00:00 AM
# 1143865       NaN        1956119   7/1/2020 12:00:00 AM
# 1143866       NaN        2028098  4/15/2020 12:00:00 AM
# 1143867       NaN        1948834   7/1/2020 12:00:00 AM
# 1143868       NaN        2026780   8/1/2020 12:00:00 AM
#
#               PROJECT_END_DATE CONTACT_PI_PROJECT_LEADER  \
# 0                    8/31/2012           REESE, DEBBIE D
# 1                    8/31/2012            SNYDER, STEVEN
# 2                    8/31/2011    FINK, LAURIE KLEINBAUM
# 3                   12/31/2010              JOST, JOHN W
# 4                    9/30/2011          ABRUNA, HECTOR D
# ...                        ...                       ...
# 1143864  4/30/2025 12:00:00 AM                       NaN
# 1143865  6/30/2025 12:00:00 AM                       NaN
# 1143866  3/31/2021 12:00:00 AM                       NaN
# 1143867  6/30/2023 12:00:00 AM                       NaN
# 1143868  7/31/2022 12:00:00 AM                       NaN
#
#                                          OTHER_PIS CONGRESSIONAL_DISTRICT  \
# 0        CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN                     01
# 1                      ELINICH, KAREN; YOON, SUSAN                     02
# 2              CADIGAN, KAREN; ELLENBOGEN, KIRSTEN                     04
# 3               MILLER, BRADLEY; BOWMAN, KATHERINE                     04
# 4                                              NaN                     22
# ...                                            ...                    ...
# 1143864                                        NaN                    NaN
# 1143865                                        NaN                    NaN
# 1143866                                        NaN                    NaN
# 1143867                                        NaN                    NaN
# 1143868                                        NaN                    NaN
#
#         DUNS_NUMBER                                  ORGANIZATION_NAME  \
# 0         068719400                         WHEELING JESUIT UNIVERSITY
# 1         001741859                                 FRANKLIN INSTITUTE
# 2         061451670                        SCIENCE MUSEUM OF MINNESOTA
# 3         009059242  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY
# 4         872612445                          CORNELL UNIVERSITY ITHACA
# ...             ...                                                ...
# 1143864   800771545                     UNIVERSITY OF TEXAS SW MED CTR
# 1143865   170230239                         UNIVERSITY OF TEXAS AUSTIN
# 1143866   003387891                  UNIVERSITY OF TENNESSEE KNOXVILLE
# 1143867   872612445                          CORNELL UNIVERSITY ITHACA
# 1143868   068552207                              WASHINGTON UNIVERSITY
#
#         ORGANIZATION_CITY ORGANIZATION_STATE ORGANIZATION_ZIP  \
# 0                WHEELING                 WV       26003-6243
# 1            PHILADELPHIA                 PA       19103-1115
# 2              SAINT PAUL                 MN       55102-1202
# 3                  DURHAM                 NC       27709-3757
# 4                  ITHACA                 NY       14850-2820
# ...                   ...                ...              ...
# 1143864               NaN                NaN              NaN
# 1143865               NaN                NaN              NaN
# 1143866               NaN                NaN              NaN
# 1143867               NaN                NaN              NaN
# 1143868               NaN                NaN              NaN
#
#         ORGANIZATION_COUNTRY BUDGET_START_DATE BUDGET_END_DATE CFDA_CODE  \
# 0              UNITED STATES               NaN             NaN    47.076
# 1              UNITED STATES               NaN             NaN    47.076
# 2              UNITED STATES               NaN             NaN    47.076
# 3              UNITED STATES               NaN             NaN    47.049
# 4              UNITED STATES               NaN             NaN    47.049
# ...                      ...               ...             ...       ...
# 1143864                  NaN               NaN             NaN    47.074
# 1143865                  NaN               NaN             NaN    47.076
# 1143866                  NaN               NaN             NaN    47.041
# 1143867                  NaN               NaN             NaN    47.050
# 1143868                  NaN               NaN             NaN    47.050
#
#            FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  ORG_COUNT  PI_COUNT  \
# 0        2008      1999467.0                         NaN          1         1
# 1        2008      1799699.0                         NaN          1         1
# 2        2008      1505858.0                         NaN          1         1
# 3        2008        51000.0                         NaN          1         1
# 4        2008      1519821.0                         NaN          1         1
# ...       ...            ...                         ...        ...       ...
# 1143864  2020       700000.0                         NaN          1         0
# 1143865  2020       136238.0                         NaN          3         0
# 1143866  2020       132226.0                         NaN          2         0
# 1143867  2020        30484.0                         NaN          3         0
# 1143868  2020       164897.0                         NaN          2         0
#
#          FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0                1999467.0            1
# 1                1799699.0            1
# 2                1505858.0            1
# 3                  51000.0            1
# 4                1519821.0            1
# ...                    ...          ...
# 1143864           700000.0            1
# 1143865           672158.0            3
# 1143866           182205.0            2
# 1143867           191004.0            3
# 1143868           299968.0            2
#
#                                               final_tokens    index  \
# 0        project explore game base metaphor enhanced ga...        0
# 1        institution franklin institute science museum ...        1
# 2        program include small group conversation citiz...        2
# 3        partnership american chemical society acs nati...        3
# 4        center molecular interfacing cmi enable integr...        4
# ...                                                    ...      ...
# 1143864  circadian_rhythm fundamental endogenous proper...  1143864
# 1143865  recent research suggest learn genetic high sch...  1143865
# 1143866  covid_19_pandemic cause unprecedented disrupti...  1143866
# 1143867  subduction_zone location earth tectonic_plate ...  1143867
# 1143868  stretch mile illinois bank mississippi_river a...  1143868
#
#          Is it related to Big-Data label
# 0                              NaN   NaN
# 1                              NaN   NaN
# 2                              NaN   NaN
# 3                              NaN   NaN
# 4                              NaN   NaN
# ...                            ...   ...
# 1143864                        NaN   NaN
# 1143865                        NaN   NaN
# 1143866                        NaN   NaN
# 1143867                        NaN   NaN
# 1143868                        NaN   NaN
#
# [1143869 rows x 33 columns]

# %%
# Save project ID of labelled data
project_id_lab = list(df_lab['PROJECT_ID'])

# Get the index of labelled abstract
subset_df = df_merge.loc[df_merge['PROJECT_ID'].isin(project_id_lab),['index', 'PROJECT_ID']]
index_lab = list(subset_df['index'])

# %% [markdown]
# # 1. BERT approach

# %% [markdown]
# ## 1.1. Vectorize, build the training and test sample

# %%
# creating dataframe with just abstracts
data = df['ABSTRACT']
indicies = data.index

# %%
# load model
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# embed abstracts
#vector = model.encode(df['ABSTRACT'])

# %%
#print(vector.shape)

# %%
#vector

# %%
# initialize training
#training = pd.DataFrame(vector)

# %%
#training.to_csv('BERT_vector_final.csv', index=False)

# %%
training = pd.read_csv('/home/kno5cac/git/publicrd/data/prd/Doc2Vec/bert_final.csv')

# %%
training.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.120384  0.008162  0.009289 -0.140070  0.010064  0.007225  0.061013
# 1 -0.005723 -0.023757  0.003688 -0.032687  0.033107  0.032948 -0.014487
# 2  0.036217  0.059167  0.031518 -0.000336  0.046316  0.082325 -0.027813
# 3 -0.030398 -0.084991 -0.039250  0.034691  0.002237  0.018312 -0.046295
# 4 -0.038410 -0.048780 -0.021245  0.033772 -0.002839 -0.030921  0.021801
#
#           7         8         9        10        11        12        13  \
# 0  0.042500  0.095583  0.107619 -0.023043 -0.038347  0.042783  0.032119
# 1 -0.056128 -0.006319  0.053143 -0.035040 -0.070863 -0.011705  0.057314
# 2 -0.004897 -0.024080  0.062721 -0.041332 -0.047162 -0.069163  0.007913
# 3  0.042458  0.025696 -0.037021 -0.088993 -0.029559 -0.023216  0.062934
# 4  0.049377 -0.061806  0.080630  0.049207  0.002447 -0.005403  0.020945
#
#          14        15        16        17        18        19        20  \
# 0  0.110502 -0.038045  0.089364  0.017840 -0.004085 -0.037523  0.129334
# 1 -0.053268 -0.036528  0.070674 -0.011142  0.005872  0.049121  0.080075
# 2 -0.014558  0.036254  0.047470 -0.031500  0.000672 -0.018463 -0.016055
# 3 -0.064281 -0.007081 -0.010292 -0.082310 -0.002397 -0.027546 -0.085231
# 4  0.013926  0.062776  0.002002  0.064310 -0.003859  0.037739  0.040226
#
#          21        22        23        24  ...       359       360       361  \
# 0 -0.043084  0.033499 -0.007758 -0.091202  ... -0.003242 -0.100648  0.000979
# 1 -0.016251  0.039404 -0.010731 -0.042231  ... -0.024683 -0.106609 -0.063258
# 2  0.023507  0.078935  0.047967 -0.032528  ...  0.051790 -0.010477  0.031305
# 3 -0.035928  0.110653  0.031994 -0.054664  ... -0.051298 -0.088649  0.069451
# 4 -0.058133  0.042782 -0.084857 -0.029862  ... -0.007837 -0.023693  0.025372
#
#         362       363       364       365       366       367       368  \
# 0  0.007670  0.033875  0.015629  0.033797 -0.112476 -0.047719 -0.027371
# 1 -0.023506 -0.003999 -0.008228 -0.012774 -0.053927 -0.138681  0.021173
# 2  0.044788 -0.024096 -0.030966  0.047872 -0.023352 -0.003438 -0.014512
# 3 -0.031952  0.027472 -0.030654  0.038263 -0.041856  0.048861  0.010228
# 4 -0.074445 -0.005446 -0.031198  0.027064  0.049099 -0.001438  0.059517
#
#         369       370       371       372       373       374       375  \
# 0  0.061570 -0.091944  0.132762 -0.045460  0.037191  0.084080  0.051874
# 1  0.048514 -0.066839  0.002106 -0.020242  0.052653  0.110053  0.047916
# 2  0.023850 -0.082180 -0.071767  0.073354 -0.009636  0.107215  0.112982
# 3  0.032982 -0.036680 -0.063126 -0.033184 -0.052148  0.051312  0.105293
# 4 -0.025691  0.016474  0.048081 -0.006332 -0.007037 -0.050787  0.048785
#
#         376       377       378       379       380       381       382  \
# 0  0.017190  0.053510 -0.014727  0.020528  0.008453  0.053260 -0.038878
# 1  0.111496 -0.052864 -0.004679  0.068760  0.000062 -0.033812 -0.081289
# 2  0.007532  0.051477  0.016350  0.069353  0.038180  0.169784 -0.068943
# 3 -0.016690 -0.051876  0.035793 -0.041464  0.088343 -0.034776 -0.027763
# 4 -0.153048  0.044875  0.029507 -0.029255  0.036017 -0.118791 -0.065013
#
#         383
# 0  0.035753
# 1  0.092443
# 2  0.057399
# 3 -0.017640
# 4  0.000929
#
# [5 rows x 384 columns]

# %%
#training model on labeled and whole corpus
trainingnp = training.to_numpy()

# %%
#index_training = pd.DataFrame(index_training)
#index_test = pd.DataFrame(index_test)

#index_training.to_csv('index_training.csv', index=False) 
#index_test.to_csv('index_test.csv', index=False)

# %%
project_id_training = pd.read_csv('final_projectid_training.csv')
project_id_testing = pd.read_csv('final_projectid_testing.csv')

# %%
# Build the training and test sample: randomly select 80% of index_lab as training and the rest as test
#import random

# Build the index for the training and the test
#index_training = random.sample(index_lab, int(0.8 * len(index_lab)))
#index_test = list(set(index_lab) - set(index_training))

# sort those index (sort help to extract the Y value for each set)
#index_training.sort()
#index_test.sort()

# %%
# convert to lists
project_id_training = list(project_id_training['0'])
project_id_testing = list(project_id_testing['0'])

# %%
df_train = df_merge[df_merge['PROJECT_ID'].isin(project_id_training)]
df_test = df_merge[df_merge['PROJECT_ID'].isin(project_id_testing)]

# %%
# Extract those index in the BERT matrix and compute the X training and Test
X_train_bert = [trainingnp[i] for i in df_train['index']]
X_test_bert = [trainingnp[i] for i in df_test['index']]

# %%
# Create Y for training and test using the index order from the sampling
Y_train_bert = [df_merge.loc[df_merge['index']== i,'label'].values.tolist() for i in df_train['index']]
Y_train_bert = sum(Y_train_bert, [])

Y_test_bert = [df_merge.loc[df_merge['index']== i,'label'].values.tolist() for i in df_test['index']]
Y_test_bert = sum(Y_test_bert, [])

# %% [markdown]
# ## 1.2. KNN classifier

# %%
# number of neighbors
k = int(math.sqrt(len(Y_train_bert)))
print('Number of neighbors:', k)
# Out:
# Number of neighbors: 35

# %%
# Run KNN
from sklearn.neighbors import KNeighborsClassifier
classifierKNN = KNeighborsClassifier(n_neighbors= k)

# %%
# cross-validation with 5 folds
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifierKNN,X_train_bert,Y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))
# Out:
# [0.77734375 0.84375    0.78515625 0.8046875  0.796875  ]
# Accuracy: 0.80.   Standard Deviation: 0.02

# %%
# train model after cross-validation
classifierKNN.fit(X_train_bert,Y_train_bert)
# Out:
# KNeighborsClassifier(n_neighbors=35)

# %%
# Predict the classification
Y_pred_bert = classifierKNN.predict(X_test_bert)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_bert, Y_pred_bert)
#print(confusion)
print(classification_report(Y_test_bert, Y_pred_bert))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.71      0.84      0.77       139
# Non Big-data       0.86      0.73      0.79       181
#
#     accuracy                           0.78       320
#    macro avg       0.78      0.79      0.78       320
# weighted avg       0.79      0.78      0.78       320

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('KNN Confusion Matrix\n BERT \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.savefig('bert_KNN')
plt2.show()

# %%
# Predict the classification for the whole data: use the whole BERT
Y_bert = classifierKNN.predict(trainingnp)

# The BERT keep the order from index. Just add the prediction as new variable
df['Prediction_KNN'] = Y_bert
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN
# 0  project explore game base metaphor enhanced ga...      0       Big-data
# 1  institution franklin institute science museum ...      1       Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data

# %%
# Count the number of projects that is Big data related
df_bigdata = df[df['Prediction_KNN']=='Big-data']
print('Number of abstracts related to Big data:', len(df_bigdata))
# Out:
# Number of abstracts related to Big data: 170990

# %%
cb_pal = {"blue":'#377eb8', "orange":'#ff7f00', "green":'#4daf4a', "pink":'#f781bf', "brown":'#a65628', 
          "purple":'#984ea3', "gray":'#999999', "red":'#e41a1c', "yellow":'#dede00'}

# %%
# Distribution over time and agencies
df_bigdata["FY"] = df_bigdata["FY"].astype('int')
year_counts = df_bigdata['FY'].value_counts().sort_index(ascending=True)

# Distribution
year = year_counts.index.tolist()
count = year_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(year, count, color='navy')
#plt.xlim(-0.7, len(year)-0.3)
plt2.xlim(2007.3,2020.7)
plt2.xticks(year, rotation=45)
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
#x_ticks = ax.xaxis.get_major_ticks()
#x_ticks[-1].label1.set_visible(False)
plt2.xlabel("FY")
plt2.ylabel("Number of Projects")
plt2.title("Big data sample")

plt2.savefig("big_data_time.png", dpi = 800, bbox_inches = "tight")
# Out:
# /tmp/ipykernel_45268/234042915.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bigdata["FY"] = df_bigdata["FY"].astype('int')
# /tmp/ipykernel_45268/234042915.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

# %%
agency_counts = 100*df_bigdata["DEPARTMENT"].value_counts()/len(df_bigdata)
agency = agency_counts.index.tolist()
count = agency_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(agency, count, color=cb_pal['blue'])
plt2.ylim(0,100)
plt2.xlabel("Agency")
plt2.ylabel("Percent of Dataset")
plt2.title("Project Distribution by Funding Agency")

plt2.savefig("big_data_agency.png", dpi = 800, bbox_inches = "tight")

# %%
# save the data
#df_bigdata.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/bert_method.csv")

# %% [markdown]
# ## 1.3. SVM

# %%
# We run SVM with default parameters provides by Sklearn. We train the model
from sklearn import svm
classifier_svm = svm.SVC()

# cross-validation with 5 folds
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_svm,X_train_bert,Y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_svm.fit(X_train_bert,Y_train_bert)
# Out:
# [0.80859375 0.85546875 0.796875   0.828125   0.82421875]
# Accuracy: 0.82.   Standard Deviation: 0.02
# SVC()

# %%
# Predict the classification
Y_pred_bert = classifier_svm.predict(X_test_bert)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_bert, Y_pred_bert)
#print(confusion)
print(classification_report(Y_test_bert, Y_pred_bert))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.82      0.77      0.79       139
# Non Big-data       0.83      0.87      0.85       181
#
#     accuracy                           0.82       320
#    macro avg       0.82      0.82      0.82       320
# weighted avg       0.82      0.82      0.82       320

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('SVM Confusion Matrix\n BERT \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.savefig('bert_SVM.PNG')
plt2.show()

# %%
# Predict the classification for the whole data: use the whole BERT
Y_bert = classifier_svm.predict(trainingnp)

# The BERT keep the order from index. Just add the prediction as new variable
df['Prediction_SVM'] = Y_bert
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0       Big-data
# 1  institution franklin institute science museum ...      1       Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM
# 0   Non Big-data
# 1   Non Big-data
# 2   Non Big-data
# 3   Non Big-data
# 4   Non Big-data

# %%
# Cross comparision between SVM and KNN
pd.crosstab(df['Prediction_KNN'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_KNN
# Big-data           48930        122060   170990
# Non Big-data        1510        971369   972879
# Total              50440       1093429  1143869

# %% [markdown]
# ## 1.4. Decision Tree

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.tree import DecisionTreeClassifier
classifier_DT = DecisionTreeClassifier()

# cross-validation with 5 folds
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_DT,X_train_bert,Y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_DT.fit(X_train_bert,Y_train_bert)
# Out:
# [0.67578125 0.7421875  0.6953125  0.68359375 0.71484375]
# Accuracy: 0.70.   Standard Deviation: 0.02
# DecisionTreeClassifier()

# %%
# Predict the classification
Y_pred_bert = classifier_DT.predict(X_test_bert)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_bert, Y_pred_bert)
#print(confusion)
print(classification_report(Y_test_bert, Y_pred_bert))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.61      0.62      0.61       139
# Non Big-data       0.70      0.69      0.70       181
#
#     accuracy                           0.66       320
#    macro avg       0.65      0.65      0.65       320
# weighted avg       0.66      0.66      0.66       320

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('Decision Tree Confusion Matrix\n BERT \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.savefig('bert_DT.PNG')
plt2.show()

# %%
# Predict the classification for the whole data: use the whole BERT
Y_bert = classifier_DT.predict(trainingnp)

# The BERT keep the order from index. Just add the prediction as new variable
df['Prediction_DT'] = Y_bert
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0       Big-data
# 1  institution franklin institute science museum ...      1       Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT
# 0   Non Big-data  Non Big-data
# 1   Non Big-data  Non Big-data
# 2   Non Big-data  Non Big-data
# 3   Non Big-data  Non Big-data
# 4   Non Big-data      Big-data

# %%
# Cross comparision between NN and SVM
pd.crosstab(df['Prediction_DT'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_DT
# Big-data           29226        243748   272974
# Non Big-data       21214        849681   870895
# Total              50440       1093429  1143869

# %%
# Cross comparision between NN and KNN
pd.crosstab(df['Prediction_DT'], df['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_DT
# Big-data           74119        198855   272974
# Non Big-data       96871        774024   870895
# Total             170990        972879  1143869

# %% [markdown]
# ## 1.5. Random Forest

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.ensemble import RandomForestClassifier
classifier_RF = RandomForestClassifier()

# cross-validation with 5 folds
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_RF,X_train_bert,Y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_RF.fit(X_train_bert,Y_train_bert)
# Out:
# [0.80859375 0.8203125  0.82421875 0.80078125 0.8046875 ]
# Accuracy: 0.81.   Standard Deviation: 0.01
# RandomForestClassifier()

# %%
# Predict the classification
Y_pred_bert = classifier_RF.predict(X_test_bert)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_bert, Y_pred_bert)
#print(confusion)
print(classification_report(Y_test_bert, Y_pred_bert))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.85      0.71      0.77       139
# Non Big-data       0.80      0.91      0.85       181
#
#     accuracy                           0.82       320
#    macro avg       0.83      0.81      0.81       320
# weighted avg       0.82      0.82      0.82       320

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('Random Forest Confusion Matrix\n BERT \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.savefig('bert_RF.PNG')
plt2.show()

# %%
# Predict the classification for the whole data: use the whole BERT
Y_bert = classifier_RF.predict(trainingnp)

# The BERT keep the order from index. Just add the prediction as new variable
df['Prediction_RF'] = Y_bert
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0       Big-data
# 1  institution franklin institute science museum ...      1       Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT Prediction_RF
# 0   Non Big-data  Non Big-data  Non Big-data
# 1   Non Big-data  Non Big-data  Non Big-data
# 2   Non Big-data  Non Big-data  Non Big-data
# 3   Non Big-data  Non Big-data  Non Big-data
# 4   Non Big-data      Big-data  Non Big-data

# %%
# Cross comparision between RF and DT
pd.crosstab(df['Prediction_RF'], df['Prediction_DT'], margins=True, margins_name="Total")
# Out:
# Prediction_DT  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data          20468         11834    32302
# Non Big-data     252506        859061  1111567
# Total            272974        870895  1143869

# %%
# Cross comparision between RF and SVM
pd.crosstab(df['Prediction_RF'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data           27499          4803    32302
# Non Big-data       22941       1088626  1111567
# Total              50440       1093429  1143869

# %%
# Cross comparision between RF and SVM
pd.crosstab(df['Prediction_RF'], df['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_RF
# Big-data           31680           622    32302
# Non Big-data      139310        972257  1111567
# Total             170990        972879  1143869

# %% [markdown]
# ## 1.6. Neural network classifier

# %%
# Use default parameters provides by SKLearn and train the model
from sklearn.neural_network import MLPClassifier
classifier_nn = MLPClassifier()

# cross-validation with 5 folds
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
scores = cross_val_score(classifier_nn,X_train_bert,Y_train_bert, scoring='accuracy', cv=cv)
print(scores)
print("Accuracy: %0.2f.   Standard Deviation: %0.2f" % (scores.mean(), scores.std()))

# train model after cross-validation
classifier_nn.fit(X_train_bert,Y_train_bert)
# Out:
# /home/kno5cac/.conda/envs/BERT/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/kno5cac/.conda/envs/BERT/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/kno5cac/.conda/envs/BERT/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/kno5cac/.conda/envs/BERT/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/kno5cac/.conda/envs/BERT/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [0.7734375  0.83984375 0.765625   0.80859375 0.796875  ]
# Accuracy: 0.80.   Standard Deviation: 0.03
# /home/kno5cac/.conda/envs/BERT/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
# Predict the classification
Y_pred_bert = classifier_nn.predict(X_test_bert)

# %%
# Classifier performance
from sklearn.metrics import classification_report, confusion_matrix

confusion = confusion_matrix(Y_test_bert, Y_pred_bert)
#print(confusion)
print(classification_report(Y_test_bert, Y_pred_bert))
# Out:
#               precision    recall  f1-score   support
#
#     Big-data       0.77      0.73      0.75       139
# Non Big-data       0.80      0.83      0.82       181
#
#     accuracy                           0.79       320
#    macro avg       0.78      0.78      0.78       320
# weighted avg       0.79      0.79      0.79       320

# %%
labels = ['True Neg','False Pos','False Neg','True Pos']
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
ax.set_title('Neural Network Confusion Matrix\n BERT \n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
## Display the visualization of the Confusion Matrix.
plt2.show()
plt2.savefig('bert_NN.PNG')

# %%
# Predict the classification for the whole data: use the whole BERT
Y_bert = classifier_nn.predict(trainingnp)

# The BERT keep the order from index. Just add the prediction as new variable
df['Prediction_NN'] = Y_bert
df.head()
# Out:
#    PROJECT_ID                                           ABSTRACT  \
# 0       89996  This is a project to explore Game-based, Metap...
# 1       89997  Institution: Franklin Institute Science Museum...
# 2       89998  Through programs (including small group conver...
# 3       89999  In partnership with the American Chemical Soci...
# 4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                     01   068719400
# 1                     02   001741859
# 2                     04   061451670
# 3                     04   009059242
# 4                     22   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0       Big-data
# 1  institution franklin institute science museum ...      1       Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT Prediction_RF Prediction_NN
# 0   Non Big-data  Non Big-data  Non Big-data  Non Big-data
# 1   Non Big-data  Non Big-data  Non Big-data  Non Big-data
# 2   Non Big-data  Non Big-data  Non Big-data  Non Big-data
# 3   Non Big-data  Non Big-data  Non Big-data  Non Big-data
# 4   Non Big-data      Big-data  Non Big-data  Non Big-data

# %%
# Cross comparision between NN and KNN
pd.crosstab(df['Prediction_NN'], df['Prediction_KNN'], margins=True, margins_name="Total")
# Out:
# Prediction_KNN  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data           73915         62308   136223
# Non Big-data       97075        910571  1007646
# Total             170990        972879  1143869

# %%
# Cross comparision between NN and SVM
pd.crosstab(df['Prediction_NN'], df['Prediction_SVM'], margins=True, margins_name="Total")
# Out:
# Prediction_SVM  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data           42552         93671   136223
# Non Big-data        7888        999758  1007646
# Total              50440       1093429  1143869

# %%
# Cross comparision between NN and DT
pd.crosstab(df['Prediction_NN'], df['Prediction_DT'], margins=True, margins_name="Total")
# Out:
# Prediction_DT  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data          55240         80983   136223
# Non Big-data     217734        789912  1007646
# Total            272974        870895  1143869

# %%
# Cross comparision between NN and RF
pd.crosstab(df['Prediction_NN'], df['Prediction_RF'], margins=True, margins_name="Total")
# Out:
# Prediction_RF  Big-data  Non Big-data    Total
# Prediction_NN
# Big-data          25079        111144   136223
# Non Big-data       7223       1000423  1007646
# Total             32302       1111567  1143869

# %%
# save the data
df.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/FR_final_predicted_bert.csv")

# %% [markdown]
# ## 1.7. Decision rule based on all classifiers

# %%
# Compute a score to be identify as big data
df = pd.read_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/FR_final_predicted_bert.csv")
df['score'] = np.where(df['Prediction_KNN'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_SVM'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_DT'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_RF'].str.contains("Non Big-data"), 0, 1) + np.where(df['Prediction_NN'].str.contains("Non Big-data"), 0, 1)
# Out:
# /tmp/ipykernel_45268/2721123263.py:2: DtypeWarning: Columns (3,7,8,11,12,13,14,16,17,18,19,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/FR_final_predicted_bert.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  PROJECT_ID                                           ABSTRACT  \
# 0           0       89996  This is a project to explore Game-based, Metap...
# 1           1       89997  Institution: Franklin Institute Science Museum...
# 2           2       89998  Through programs (including small group conver...
# 3           3       89999  In partnership with the American Chemical Soci...
# 4           4       90001  The Center for Molecular Interfacing (CMI) wil...
#
#                                        PROJECT_TERMS  \
# 0  Achievement; analog; base; Cognitive Science; ...
# 1  Active Learning; Child; Computer software; des...
# 2  Address; Age; Birth; Brain; Caregivers; Child;...
# 3  Advanced Development; American; Chemicals; Che...
# 4  Address; Architecture; Carbon Nanotubes; Catal...
#
#                                        PROJECT_TITLE DEPARTMENT AGENCY  \
# 0  RUI: CYGAMES: CYBER-ENABLED TEACHING AND LEARN...        NSF    NSF
# 1  ARIEL - AUGMENTED REALITY FOR INTERPRETIVE AND...        NSF    NSF
# 2  BRIGHTER FUTURES: PUBLIC DELIBERATION ABOUT TH...        NSF    NSF
# 3  FOSTERING US-INTERNATIONAL COLLABORATIVE PARTN...        NSF    NSF
# 4      CCI PHASE I: CENTER FOR MOLECULAR INTERFACING        NSF    NSF
#
#   IC_CENTER PROJECT_NUMBER PROJECT_START_DATE PROJECT_END_DATE  \
# 0       NaN        0814512          9/15/2008        8/31/2012
# 1       NaN        0741659          9/15/2008        8/31/2012
# 2       NaN        0813522          9/15/2008        8/31/2011
# 3       NaN        0838627           8/1/2008       12/31/2010
# 4       NaN        0847926          10/1/2008        9/30/2011
#
#   CONTACT_PI_PROJECT_LEADER                                  OTHER_PIS  \
# 0           REESE, DEBBIE D  CARTER, BEVERLY; WOOD, CHARLES; HITT, BEN
# 1            SNYDER, STEVEN                ELINICH, KAREN; YOON, SUSAN
# 2    FINK, LAURIE KLEINBAUM        CADIGAN, KAREN; ELLENBOGEN, KIRSTEN
# 3              JOST, JOHN W         MILLER, BRADLEY; BOWMAN, KATHERINE
# 4          ABRUNA, HECTOR D                                        NaN
#
#   CONGRESSIONAL_DISTRICT DUNS_NUMBER  \
# 0                    1.0   068719400
# 1                    2.0   001741859
# 2                    4.0   061451670
# 3                    4.0   009059242
# 4                   22.0   872612445
#
#                                    ORGANIZATION_NAME ORGANIZATION_CITY  \
# 0                         WHEELING JESUIT UNIVERSITY          WHEELING
# 1                                 FRANKLIN INSTITUTE      PHILADELPHIA
# 2                        SCIENCE MUSEUM OF MINNESOTA        SAINT PAUL
# 3  INTERNATIONAL UNION OF PURE AND APPLIED CHEMISTRY            DURHAM
# 4                          CORNELL UNIVERSITY ITHACA            ITHACA
#
#   ORGANIZATION_STATE ORGANIZATION_ZIP ORGANIZATION_COUNTRY BUDGET_START_DATE  \
# 0                 WV       26003-6243        UNITED STATES               NaN
# 1                 PA       19103-1115        UNITED STATES               NaN
# 2                 MN       55102-1202        UNITED STATES               NaN
# 3                 NC       27709-3757        UNITED STATES               NaN
# 4                 NY       14850-2820        UNITED STATES               NaN
#
#   BUDGET_END_DATE CFDA_CODE    FY  FY_TOTAL_COST  FY_TOTAL_COST_SUB_PROJECTS  \
# 0             NaN    47.076  2008      1999467.0                         NaN
# 1             NaN    47.076  2008      1799699.0                         NaN
# 2             NaN    47.076  2008      1505858.0                         NaN
# 3             NaN    47.049  2008        51000.0                         NaN
# 4             NaN    47.049  2008      1519821.0                         NaN
#
#    ORG_COUNT  PI_COUNT  FY_TOTAL_COST_SUM  NUM_RECORDS  \
# 0          1         1          1999467.0            1
# 1          1         1          1799699.0            1
# 2          1         1          1505858.0            1
# 3          1         1            51000.0            1
# 4          1         1          1519821.0            1
#
#                                         final_tokens  index Prediction_KNN  \
# 0  project explore game base metaphor enhanced ga...      0       Big-data
# 1  institution franklin institute science museum ...      1       Big-data
# 2  program include small group conversation citiz...      2   Non Big-data
# 3  partnership american chemical society acs nati...      3   Non Big-data
# 4  center molecular interfacing cmi enable integr...      4   Non Big-data
#
#   Prediction_SVM Prediction_DT Prediction_RF Prediction_NN  score
# 0   Non Big-data  Non Big-data  Non Big-data  Non Big-data      1
# 1   Non Big-data  Non Big-data  Non Big-data  Non Big-data      1
# 2   Non Big-data  Non Big-data  Non Big-data  Non Big-data      0
# 3   Non Big-data  Non Big-data  Non Big-data  Non Big-data      0
# 4   Non Big-data      Big-data  Non Big-data  Non Big-data      1

# %%
# Distribution of abstracts
df['score'].value_counts()
# Out:
# 0    729499
# 1    279672
# 2     71641
# 3     27737
# 4     19836
# 5     15484
# Name: score, dtype: int64

# %%
# Used a rule (majority votes from classifiers) to identify Big-data abstracts. Useful because we have an impair number of classifier
df['Big_data'] = 0
df.loc[df['score']>3,'Big_data'] = 1
df['Big_data'].value_counts()
# Out:
# 0    1108549
# 1      35320
# Name: Big_data, dtype: int64

# %%
# subset the data to big-data and save
df_bigdata = df[df['Big_data']==1]
df_bigdata.to_csv("/project/biocomplexity/sdad/projects_data/ncses/prd/Digital_abstract_labelled/abstracts_classification_big_data_bert.csv")

# %% [markdown]
# ## Descriptive statistics of our Big data

# %%
# Distribution over time and agencies
df_bigdata["FY"] = df_bigdata["FY"].astype('int')
year_counts = df_bigdata['FY'].value_counts().sort_index(ascending=True)

# Distribution
year = year_counts.index.tolist()
count = year_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(year, count, color='navy')
#plt.xlim(-0.7, len(year)-0.3)
plt2.xlim(2007.3,2020.7)
plt2.xticks(year, rotation=45)
ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])
#x_ticks = ax.xaxis.get_major_ticks()
#x_ticks[-1].label1.set_visible(False)
plt2.xlabel("FY")
plt2.ylabel("Number of Projects")
plt2.title("Big Data Sample Over Time \n BERT \n")

plt2.savefig("BERT_big_data_time.png", dpi = 800, bbox_inches = "tight")
# Out:
# /tmp/ipykernel_45268/2668181742.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bigdata["FY"] = df_bigdata["FY"].astype('int')
# /tmp/ipykernel_45268/2668181742.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,}'.format(int(x)) for x in ax.get_yticks().tolist()])

# %%
agency_counts = 100*df_bigdata["DEPARTMENT"].value_counts()/len(df_bigdata)
agency = agency_counts.index.tolist()
count = agency_counts.values

fig = plt2.figure()
ax = fig.add_subplot(111)
ax.set_axisbelow(True)
plt2.grid(True, color = "whitesmoke")
plt2.bar(agency, count, color=cb_pal['blue'])
plt2.ylim(0,100)
plt2.xlabel("Agency")
plt2.ylabel("Percent of Dataset")
plt2.title("Project Distribution by Funding Agency \n BERT \n")

plt2.savefig("BERT_big_data_agency.png", dpi = 800, bbox_inches = "tight")
